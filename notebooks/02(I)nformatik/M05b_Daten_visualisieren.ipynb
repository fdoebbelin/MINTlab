# %% [markdown]
# # M05b – Daten visualisieren (Übungsaufgaben mit Hinweisen)
#
# ## 🎯 Übersicht
#
# In diesem Modul wirst du **praktisch üben**, wie man mit Python Diagramme zeichnet. Jede Aufgabe hat ein **Ziel**, einen **vorbereiteten Code-Block** und einen **Lösungshinweis**. Versuche, die Aufgaben selbst zu lösen, bevor du die Lösung anschaust!
#
# ---
#
# ## 📋 Aufgabe 1: Mein erstes Liniendiagramm
#
# ### 🎯 Ziel
# Zeichne ein Liniendiagramm, das den **Temperaturverlauf** über einen Tag hinweg zeigt.
#
# ### 📊 Daten
# - **Uhrzeiten**: 6, 8, 10, 12, 14, 16, 18, 20 Uhr
# - **Temperaturen**: 12, 14, 16, 18, 17, 15, 13, 11 °C
#
# ### 💻 Dein Code

# %%
import matplotlib.pyplot as plt

# TODO: Definiere die Listen 'uhrzeiten' und 'temperaturen'
uhrzeiten = [...]
temperaturen = [...]

# TODO: Erstelle ein Liniendiagramm
# Hinweis: Nutze plt.plot(), plt.xlabel(), plt.ylabel(), plt.title()
plt.figure(figsize=(10, 6))
# HIER DEIN CODE:


# Zeige das Diagramm an
plt.show()

# %% [markdown]
# ### 💡 Lösungshinweis
#
# - Verwende `plt.plot(uhrzeiten, temperaturen)`, um die Linie zu zeichnen
# - Beschrifte die X-Achse mit "Uhrzeit" und die Y-Achse mit "Temperatur (°C)"
# - Gib dem Diagramm einen aussagekräftigen Titel
# - Optional: Nutze `marker='o'`, um Datenpunkte zu markieren
#
# ### ❓ Verständnisfrage
#
# **Was ändert sich an deinem Diagramm, wenn du `color='blue'` hinzufügst?**
#
# ---
#
# ## 📋 Aufgabe 2: Balkendiagramm für Kategorien
#
# ### 🎯 Ziel
# Erstelle ein **Balkendiagramm**, das die **Anzahl der Studierende pro Fachbereich** an einer Universität zeigt.
#
# ### 📊 Daten
# | Fachbereich | Anzahl Studierende |
# |---|---|
# | Informatik | 450 |
# | Mathematik | 280 |
# | Physik | 320 |
# | Biologie | 380 |
# | Chemie | 290 |
#
# ### 💻 Dein Code

# %%
import matplotlib.pyplot as plt

# TODO: Definiere die Listen 'fachbereiche' und 'anzahl'
fachbereiche = [...]
anzahl = [...]

# TODO: Erstelle ein Balkendiagramm
plt.figure(figsize=(10, 6))
# HIER DEIN CODE:


# Beschriftungen
plt.xlabel('Fachbereich', fontsize=12)
plt.ylabel('Anzahl Studierende', fontsize=12)
plt.title('Studierende pro Fachbereich', fontsize=14, fontweight='bold')

plt.show()

# %% [markdown]
# ### 💡 Lösungshinweis
#
# - Verwende `plt.bar(fachbereiche, anzahl)`, um die Balken zu zeichnen
# - Du kannst unterschiedliche Farben pro Balken setzen: `color=['red', 'blue', 'green', 'orange', 'purple']`
# - Mit `plt.ylim(0, 500)` kannst du die Y-Achse skalieren
# - Nutze eine `for`-Schleife und `plt.text()`, um Zahlen oben auf die Balken zu schreiben
#
# ### ❓ Verständnisfrage
#
# **Warum ist ein Balkendiagramm besser geeignet als ein Liniendiagramm für diese Daten?**
#
# ---
#
# ## 📋 Aufgabe 3: Streudiagramm mit Zusammenhang
#
# ### 🎯 Ziel
# Erstelle ein **Streudiagramm**, das die **Beziehung zwischen Lernstunden und Klausurnote** zeigt. Je mehr man lernt, desto besser sollte die Note sein!
#
# ### 📊 Daten (Beispiel)
# Du kannst diese Daten verwenden oder eigene generieren:

# %%
import numpy as np

# Beispieldaten: 20 Studierende
np.random.seed(42)
lernstunden = np.random.uniform(0, 15, 20)  # 0 bis 15 Stunden
klausurnoten = 1.0 + (5.0 - lernstunden * 0.25) + np.random.normal(0, 0.5, 20)
klausurnoten = np.clip(klausurnoten, 1, 5)  # Noten zwischen 1 (sehr gut) und 5 (mangelhaft)

# %% [markdown]
# ### 💻 Dein Code

# %%
import matplotlib.pyplot as plt
import numpy as np

# Daten vorbereiten
np.random.seed(42)
lernstunden = np.random.uniform(0, 15, 20)
klausurnoten = 1.0 + (5.0 - lernstunden * 0.25) + np.random.normal(0, 0.5, 20)
klausurnoten = np.clip(klausurnoten, 1, 5)

# TODO: Erstelle ein Streudiagramm
plt.figure(figsize=(10, 6))
# HIER DEIN CODE:


# Beschriftungen
plt.xlabel('Lernstunden', fontsize=12)
plt.ylabel('Klausurnote', fontsize=12)
plt.title('Beziehung: Lernstunden → Klausurnote', fontsize=14, fontweight='bold')
plt.grid(True, alpha=0.3)

plt.show()

# %% [markdown]
# ### 💡 Lösungshinweis
#
# - Verwende `plt.scatter(lernstunden, klausurnoten)`, um einzelne Punkte zu zeichnen
# - Setze `alpha=0.5`, um die Punkte etwas transparent zu machen
# - Mit `s=100` kannst du die Größe der Punkte anpassen
# - Nutze verschiedene Farben: `color='darkgreen'` und `edgecolors='black'`
#
# ### ❓ Verständnisfrage
#
# **Erkennt man einen Trend in deinem Diagramm? Erkläre ihn!**
#
# ---
#
# ## 📋 Aufgabe 4: Mehrere Diagramme nebeneinander (Subplots)
#
# ### 🎯 Ziel
# Erstelle **4 Diagramme nebeneinander**, die verschiedene **mathematische Funktionen** zeigen:
# 1. Sinus
# 2. Kosinus
# 3. Exponentialfunktion
# 4. Quadratische Funktion
#
# ### 💻 Dein Code

# %%
import matplotlib.pyplot as plt
import numpy as np

# Daten vorbereiten
x = np.linspace(0, 10, 100)

# TODO: Erstelle ein 2x2-Gitter von Diagrammen mit plt.subplots(2, 2)
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# TODO: Oben links – Sinus
# axes[0, 0].plot(...)
# axes[0, 0].set_title(...)


# TODO: Oben rechts – Kosinus
# axes[0, 1].plot(...)


# TODO: Unten links – Exponentialfunktion (e^x)
# axes[1, 0].plot(...)


# TODO: Unten rechts – Quadratische Funktion (x^2)
# axes[1, 1].plot(...)


# Leerzeichen zwischen Diagrammen anpassen
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 💡 Lösungshinweis
#
# - Zeichne für **Sinus**: `axes[0, 0].plot(x, np.sin(x), color='blue', linewidth=2)`
# - Zeichne für **Kosinus**: `axes[0, 1].plot(x, np.cos(x), color='red', linewidth=2)`
# - Zeichne für **Exponential**: `axes[1, 0].plot(x, np.exp(x), color='green', linewidth=2)` – aber beschränke die Y-Achse mit `axes[1, 0].set_ylim(0, 100)`!
# - Zeichne für **Quadratisch**: `axes[1, 1].plot(x, x**2, color='orange', linewidth=2)`
# - Nutze `axes[i, j].set_title()`, `axes[i, j].set_xlabel()`, `axes[i, j].set_ylabel()`
#
# ### ❓ Verständnisfrage
#
# **Welche Funktion wächst am schnellsten? Warum?**
#
# ---
#
# ## 📋 Aufgabe 5: Histogramm mit Seaborn
#
# ### 🎯 Ziel
# Erstelle ein **Histogramm**, das die **Verteilung von 1000 Körpergrößen** in einer Population zeigt.
#
# ### 📊 Kontext
# Die Körpergröße in einer Population folgt einer **Normalverteilung** (Gaußkurve). Das ist eine mathematische Verteilung, die häufig in der Natur vorkommt (z. B. Körpergrößen, Testergebnisse).
#
# ### 💻 Dein Code

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Daten generieren: 1000 Körpergrößen (Durchschnitt 175 cm, Standardabweichung 8 cm)
np.random.seed(42)
koerpergroessen = np.random.normal(loc=175, scale=8, size=1000)

# TODO: Erstelle ein Histogramm mit Seaborn
plt.figure(figsize=(10, 6))
# HIER DEIN CODE:
# Hinweis: sns.histplot(daten, kde=True, bins=30)


plt.xlabel('Körpergröße (cm)', fontsize=12)
plt.ylabel('Häufigkeit', fontsize=12)
plt.title('Verteilung der Körpergrößen', fontsize=14, fontweight='bold')

plt.show()

# %% [markdown]
# ### 💡 Lösungshinweis
#
# - Verwende `sns.histplot(koerpergroessen, kde=True, bins=30, color='skyblue', edgecolor='black')`
# - `kde=True` zeichnet zusätzlich eine glatte Kurve (Kernel Density Estimate)
# - `bins=30` teilt die Daten in 30 Balken auf
# - Mit `color='skyblue'` wird die Farbe gesetzt
#
# ### ❓ Verständnisfrage
#
# **Wo liegt der Gipfel (die häufigste Größe) des Histogramms? Warum ist die Verteilung symmetrisch?**
#
# ---
#
# ## 📋 Aufgabe 6: Boxplot zum Vergleich
#
# ### 🎯 Ziel
# Vergleiche die **Temperaturverteilung in drei europäischen Städten** mit einem **Boxplot**.
#
# ### 📊 Kontext
# Ein Boxplot zeigt schnell:
# - **Minimum und Maximum** (Whisker)
# - **Mittlere 50%** der Daten (Box)
# - **Median** (Linie in der Box)
#
# ### 💻 Dein Code

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Daten generieren
np.random.seed(42)
stockholm = np.random.normal(loc=8, scale=6, size=30)   # Kalte Stadt
rom = np.random.normal(loc=18, scale=5, size=30)        # Warme Stadt
athen = np.random.normal(loc=22, scale=6, size=30)      # Sehr warme Stadt

# TODO: Erstelle ein Dictionary mit den Daten
daten_dict = {
    'Stockholm': stockholm,
    'Rom': rom,
    'Athen': athen
}

# TODO: Erstelle ein Boxplot
plt.figure(figsize=(10, 6))
# HIER DEIN CODE:
# Hinweis: sns.boxplot(data=daten_dict, palette='Set2')


plt.ylabel('Temperatur (°C)', fontsize=12)
plt.title('Temperaturverteilung in europäischen Städten', fontsize=14, fontweight='bold')

plt.show()

# %% [markdown]
# ### 💡 Lösungshinweis
#
# - Verwende `sns.boxplot(data=daten_dict, palette='Set2')`
# - `palette='Set2'` gibt eine schöne Farbpalette vor
# - Du kannst auch andere Paletten ausprobieren: `'husl'`, `'pastel'`, `'Set1'`
#
# ### ❓ Verständnisfrage
#
# **Welche Stadt hat die größten Unterschiede zwischen dem wärmsten und kältesten Tag? Wie siehst du das im Boxplot?**
#
# ---
#
# ## 📋 Aufgabe 7: Mehrere Linien in einem Diagramm (mit Legende)
#
# ### 🎯 Ziel
# Zeige die **Verkaufstrends von drei Produkten** über 12 Monate in einem Diagramm. Nutze verschiedene Farben und eine **Legende**.
#
# ### 📊 Daten

# %%
import numpy as np

monate = ['Jan', 'Feb', 'Mär', 'Apr', 'Mai', 'Jun', 'Jul', 'Aug', 'Sep', 'Okt', 'Nov', 'Dez']

# Verkäufe in Einheiten
produkt_a = [100, 105, 110, 108, 115, 120, 125, 130, 128, 135, 140, 145]
produkt_b = [80, 85, 90, 88, 95, 100, 105, 110, 108, 115, 120, 125]
produkt_c = [60, 65, 70, 68, 75, 80, 85, 90, 88, 95, 100, 105]

# %% [markdown]
# ### 💻 Dein Code

# %%
import matplotlib.pyplot as plt

monate = ['Jan', 'Feb', 'Mär', 'Apr', 'Mai', 'Jun', 'Jul', 'Aug', 'Sep', 'Okt', 'Nov', 'Dez']
produkt_a = [100, 105, 110, 108, 115, 120, 125, 130, 128, 135, 140, 145]
produkt_b = [80, 85, 90, 88, 95, 100, 105, 110, 108, 115, 120, 125]
produkt_c = [60, 65, 70, 68, 75, 80, 85, 90, 88, 95, 100, 105]

# TODO: Erstelle ein Diagramm mit drei Linien
plt.figure(figsize=(12, 6))

# HIER DEIN CODE:
# Nutze plt.plot() dreimal, mit jeweils einem label=


# Beschriftungen und Legende
plt.xlabel('Monat', fontsize=12)
plt.ylabel('Verkäufe (Einheiten)', fontsize=12)
plt.title('Verkaufstrends 2024', fontsize=14, fontweight='bold')
plt.grid(True, alpha=0.3)

# TODO: Zeige die Legende
# plt.legend(...)

plt.show()

# %% [markdown]
# ### 💡 Lösungshinweis
#
# - Zeichne `plt.plot(monate, produkt_a, marker='o', linewidth=2, color='blue', label='Produkt A')`
# - Zeichne `plt.plot(monate, produkt_b, marker='s', linewidth=2, color='red', label='Produkt B')`
# - Zeichne `plt.plot(monate, produkt_c, marker='^', linewidth=2, color='green', label='Produkt C')`
# - Nutze `plt.legend(loc='upper left', fontsize=11)` für die Legende
#
# ### ❓ Verständnisfrage
#
# **Welches Produkt wächst am schnellsten? Wie könntest du das aus dem Diagramm sehen?**
#
# ---
#
# ## 📋 Aufgabe 8: Heatmap für Korrelationen (Knifflig!)
#
# ### 🎯 Ziel
# Erstelle eine **Heatmap**, die die **Korrelation zwischen verschiedenen Wettervariablen** zeigt.
#
# ### 📊 Kontext
# Eine **Korrelation** misst, wie stark zwei Variablen zusammenhängen:
# - **+1**: Perfekter positiver Zusammenhang (beide wachsen zusammen)
# - **0**: Kein Zusammenhang
# - **-1**: Perfekter negativer Zusammenhang (eine wächst, die andere sinkt)
#
# ### 💻 Dein Code

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Korrelationsmatrix (4x4 Matrix mit Werten zwischen -1 und +1)
korrelationen = np.array([
    [1.0, 0.85, -0.30, 0.70],     # Temperatur
    [0.85, 1.0, -0.50, 0.80],     # Luftfeuchtigkeit
    [-0.30, -0.50, 1.0, -0.40],   # Luftdruck
    [0.70, 0.80, -0.40, 1.0]      # Sonnenscheindauer
])

variablen = ['Temperatur', 'Luftfeuchtigkeit', 'Luftdruck', 'Sonnenschein']

# TODO: Erstelle eine Heatmap
plt.figure(figsize=(8, 6))

# HIER DEIN CODE:
# Hinweis: sns.heatmap(korrelationen, annot=True, cmap='coolwarm', ...)


plt.title('Korrelationen zwischen Wettervariablen', fontsize=14, fontweight='bold')

plt.show()

# %% [markdown]
# ### 💡 Lösungshinweis
#
# - Verwende `sns.heatmap(korrelationen, annot=True, cmap='coolwarm', xticklabels=variablen, yticklabels=variablen)`
# - `annot=True` zeigt die Zahlenwerte in den Feldern an
# - `cmap='coolwarm'` färbt: blau = negativ, weiß = neutral, rot = positiv
# - Optional: `cbar_kws={'label': 'Korrelation'}` für eine beschriftete Farbskala
#
# ### ❓ Verständnisfrage
#
# **Welche zwei Variablen hängen am stärksten zusammen? Welche am schwächsten?**
#
# ---
#
# ## 🎯 Reflexionsfragen (für alle Aufgaben)
#
# 1. **Welcher Diagrammtyp passt am besten zu deinen Daten?**
#    - Liniendiagramme: zeitliche Verläufe
#    - Balkendiagramme: Kategorien vergleichen
#    - Streudiagramme: Zusammenhänge zwischen zwei Variablen
#    - Histogramme: Häufigkeitsverteilungen
#
# 2. **Was ist eine aussagekräftige Beschriftung?**
#    - Titel sollte das Thema kurz zusammenfassen
#    - Achsen sollten Einheiten enthalten
#    - Eine Legende sollte mehrere Serien erklären
#
# 3. **Wie erkennst du Trends oder Anomalien schneller: in einer Tabelle oder in einem Diagramm?**
#
# 4. **Wann könnten dich Diagramme täuschen?**
#    - Wenn die Achsen nicht bei 0 starten (außer bei Serien-Vergleichen)
#    - Wenn Farben missweisung verwirren
#    - Wenn die Skalierung ungleichmäßig ist
#
# ---
#
# ## 📚 Weiterführende Links
#
# - [Matplotlib Dokumentation – Tutorials](https://matplotlib.org/stable/tutorials/index.html)
# - [Seaborn Galerie – Viele Beispiele](https://seaborn.pydata.org/examples.html)
# - [Python for Data Analysis – Wes McKinney](https://wesmckinney.com/book/)
# - [W3Schools – Python Matplotlib](https://www.w3schools.com/python/matplotlib_intro.asp)
# - [GeeksforGeeks – Python Visualization](https://www.geeksforgeeks.org/python-data-visualization-libraries/)
