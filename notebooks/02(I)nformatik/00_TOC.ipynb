# %% [markdown]
# # Inhalt
# ## Modul 1: Erste Schritte in JupyterLab
# - [Einführung](./M01a_Erste_Schritte_JupyterLab.ipynb)
# - [Aufgaben](./M01b_Erste_Schritte_JupyterLab.ipynb)
# - [Lösungen](./M01c_Erste_Schritte_JupyterLab.ipynb)
#
# ## Modul 2: Kontrolle des Programmflusses
# > Bedingte Anweisungen und Schleifen
# - [Einführung](./M02a_Programmfluss_Kontrolle.ipynb)
# - [Aufgaben](./M02b_Programmfluss_Kontrolle.ipynb)
# - [Lösungen](./M02c_Programmfluss_Kontrolle.ipynb)
#
# ## Modul 3: Funktionen und Strukturierung von Code
# - [Einführung](./M03a_Funktionen_und_Strukturierung.ipynb)
# - [Aufgaben](./M03b_Funktionen_und_Strukturierung.ipynb)
# - [Lösungen](./M03c_Funktionen_und_Strukturierung.ipynb)
#
# ## Modul 4: Datenstrukturen
# - [Einführung](./M04a_Datenstrukturen.ipynb)
# - [Aufgaben](./M04b_Datenstrukturen.ipynb)
# - [Lösungen](./M04c_Datenstrukturen.ipynb)
