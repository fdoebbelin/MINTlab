# %% [markdown]
# # Modul 7b: NumPy für wissenschaftliches Rechnen
# ## Übungsaufgaben mit Hinweisen
#
# ---
#
# ## 🎯 Lernziele
#
# **Ziel:** Mit NumPy selbstständig einfache und fortgeschrittene Aufgaben im wissenschaftlichen Rechnen lösen. Übe die Arbeit mit Arrays, vektorisierte Berechnungen und Broadcasting.
#
# ---
#
# ### 📝 Aufgabe 1 – NumPy Arrays erstellen
#
# Erstelle verschiedene Arrays und untersuche deren Eigenschaften:
#
# 1. Erstelle ein Array mit den Zahlen von 0 bis 9.
# 2. Erzeuge ein Array mit 5 Werten zwischen 1 und 100 (gleichmäßig verteilt).
# 3. Erzeuge ein Array voller Zufallszahlen zwischen 0 und 1 (Länge: 8).
# 4. Prüfe für jedes Array deren `shape` und `dtype`.

# %%
import numpy as np

# TODO: Erstelle die drei Arrays und gib deren Eigenschaften aus.
array1 = ...
array2 = ...
array3 = ...

print(array1)
print(array1.shape, array1.dtype)
# ...

# %% [markdown]
# 📌 **Hinweis:** Schau dir die Methoden `np.arange()`, `np.linspace()`, `np.random.random()` an.
#
# ---
#
# ### 📝 Aufgabe 2 – Vektorisierte Berechnungen
#
# Nutze vektorisierte Operationen, um verschiedene Berechnungen mit ganzen Arrays durchzuführen.
#
# 1. Multipliziere alle Elemente eines Arrays mit 2.
# 2. Addiere 10 zu jedem Element eines Arrays.
# 3. Wandle alle Zahlen eines Arrays in ihre Quadratwerte um.
# 4. Wende die Sinus-Funktion auf ein Array von Winkeln an (Array: Gradwerte von 0 bis 360 in 30er-Schritten).

# %%
import numpy as np

# TODO: Definiere die Arrays und führe die Berechnungen durch.
array = ...
verdoppelt = ...
plus_zehn = ...
quadrate = ...
n_rad = ...
sinus = ...

print(sinus)

# %% [markdown]
# 📌 **Hinweis:** Denke daran, Gradwerte in Radiant umzuwandeln (`np.radians`)!
#
# ---
#
# ### 📝 Aufgabe 3 – Broadcasting und Filterung
#
# Arbeite mit Broadcasting und extrahiere bestimmte Werte aus Arrays.
#
# 1. Ein Array `messwerte = [10, 20, 25, 30, 35, 40]`. Rechne alle Werte in Zentimeter um (Faktor: 100).
# 2. Filtere aus dem Array alle Werte, die größer als 2000 sind.
# 3. Addiere ein Array `[5, 10, 15, 20, 25, 30]` zu `messwerte`. Was passiert?

# %%
import numpy as np

messwerte = np.array([10, 20, 25, 30, 35, 40])
# TODO: Rechne um, filtere und addiere Arrays
messwerte_cm = ...
groß = ...
addiert = ...

print(messwerte_cm)
print(groß)
print(addiert)

# %% [markdown]
# 📌 **Hinweis:** Was passiert beim Addieren von Arrays gleicher Länge?
#
# ---
#
# ### 📝 Aufgabe 4 – Numerische Integration
#
# Berechne numerisch den Flächeninhalt unter der Sinuskurve im Intervall [0, π].
#
# 1. Teile das Intervall in 20 Abschnitte.
# 2. Berechne die y-Werte als `np.sin(x)`.
# 3. Schätze die Fläche mit der Summe der Rechtecke.

# %%
import numpy as np

n = 20
x = np.linspace(0, np.pi, n)
y = ...
dx = ...
flaeche = ...

print(flaeche)

# %% [markdown]
# 📌 **Hinweis:** Die Fläche ergibt sich aus `np.sum(y) * dx`.
#
# ---
#
# ### 📝 Aufgabe 5 – Bewegungssimulation
#
# Simuliere den Flug eines Balls unter Einfluss der Schwerkraft (vereinfacht, ohne Sprung):
#
# 1. Start: Geschwindigkeit `v0 = 15 m/s` nach oben,
# 2. Simuliere die Höhe für `t` von 0 bis 3 Sekunden (Zeitschritt: 0.05 s),
# 3. Plot die Höhe über der Zeit.

# %%
import numpy as np
import matplotlib.pyplot as plt

g = 9.81
v0 = 15

# TODO: Zeitarray, Höhe berechnen, Plot anlegen
t = ...
y = ...

plt.plot(t, y)
plt.xlabel('Zeit (s)')
plt.ylabel('Höhe (m)')
plt.title('Ball im freien Fall')
plt.grid(True)
plt.show()

# %% [markdown]
# 📌 **Hinweis:** Nutze die Formel der gleichmäßig beschleunigten Bewegung:
# `y(t) = v0 * t - 0.5 * g * t**2`
#
# ---
#
# ## 🤔 Reflexion & Verständnisfragen
#
# - Warum ist vektorisierte Rechnung mit NumPy nützlich?
# - Was passiert, wenn man ein Array und eine einzelne Zahl kombiniert?
# - Wie kann man mit NumPy nach bestimmten Bedingungen filtern?
# - Was ist der Vorteil von Broadcasting gegenüber normalen Schleifen?
#
# ---
#
# ## 🔗 Weiterführende Links
#
# - [NumPy 10 Minutes to NumPy](https://numpy.org/devdocs/user/quickstart.html)
# - [Broadcasting – NumPy](https://numpy.org/doc/stable/user/basics.broadcasting.html)
# - [Sinusfunktion mit matplotlib plotten](https://matplotlib.org/stable/gallery/lines_bars_and_markers/simple_plot.html)
# - [Python Mathe-Tutorial W3Schools](https://www.w3schools.com/python/python_math.asp)
