# %% [markdown]
# # Modul 6b: Interaktive Widgets – Übungsaufgaben mit Hinweisen
#
# ## 📋 Einleitung
#
# In diesem Modul wirst du **deine Fähigkeiten mit Widgets praktizieren**. Jede Aufgabe führt dich Schritt für Schritt durch die Erstellung von interaktiven Anwendungen. Die Aufgaben bauen aufeinander auf und steigern sich in Komplexität.
#
# **Lernziele dieses Moduls:**
# - Verschiedene Widget-Typen verwenden können
# - Die `interact()`-Funktion eigenständig anwenden
# - Mehrere Widgets kombinieren und auf Änderungen reagieren
# - Einfache interaktive Anwendungen selbst schreiben
#
# **💡 Tipps zum Arbeiten:**
# - Führe jeden Code-Block aus und versuche zu verstehen, was passiert
# - Verändere die Werte und beobachte die Effekte
# - Nutze die Hinweise nur, wenn du nicht weiterkommst
#
# ---
#
# ## 🎯 Aufgabe 1: Einfacher Schieberegler
#
# ### Aufgabenstellung
#
# Erstelle einen Schieberegler, der einen Wert zwischen 0 und 20 einstellt. Wenn der Benutzer den Schieberegler bewegt, soll in der Konsole ausgegeben werden, **ob die Zahl gerade oder ungerade ist**.
#
# ### Aufbau

# %%
# TODO: Importiere ipywidgets
import ipywidgets as widgets

# TODO: Erstelle einen IntSlider mit folgenden Eigenschaften:
# - value=10
# - min=0
# - max=20
# - step=1
# - description='Zahl:'

slider = widgets.IntSlider(
    # Deine Werte hier
)

# TODO: Schreibe eine Funktion prüfe_gerade_ungerade(n),
# die prüft, ob n gerade oder ungerade ist.
# Tipp: Nutze den Modulo-Operator (%)

def prüfe_gerade_ungerade(n):
    # Dein Code hier
    pass

# TODO: Nutze slider.observe(), um die Funktion aufzurufen,
# wenn der Schieberegler verändert wird.
# Tipp: slider.observe(funktion, names='value')

display(slider)

# %% [markdown]
# ### Lösungshinweis
#
# > Eine Zahl ist gerade, wenn `n % 2 == 0`. Die `observe()`-Methode kann verwendet werden, um auf Änderungen zu reagieren. Du kannst die Funktion direkt mit einem Lambda-Ausdruck aufrufen: `lambda change: funktion(slider.value)`
#
# ### Reflexionsfrage
#
# - Was passiert, wenn du den Schieberegler auf 15 stellst?
# - Welche Zahl zwischen 0 und 20 ist deine Lieblingszahl?
#
# ---
#
# ## 🎯 Aufgabe 2: Interaktiver Temperatur-Umrechner
#
# ### Aufgabenstellung
#
# Erstelle einen Temperatur-Umrechner mit `interact()`. Der Benutzer gibt eine Temperatur in **Celsius** ein, und die Anwendung zeigt die entsprechende Temperatur in **Fahrenheit und Kelvin** an.
#
# ### Aufbau

# %%
from ipywidgets import interact
import ipywidgets as widgets

# TODO: Schreibe eine Funktion umrechnen(celsius),
# die die Temperatur von Celsius in Fahrenheit und Kelvin umrechnet.
# Formeln:
# - Fahrenheit = (Celsius * 9/5) + 32
# - Kelvin = Celsius + 273.15

def umrechnen(celsius):
    # Dein Code hier
    pass

# TODO: Nutze interact(), um einen Schieberegler zu erstellen.
# Der Schieberegler soll von -50 bis 50 in 5er-Schritten gehen.

interact(umrechnen, celsius=(-50, 50, 5))

# %% [markdown]
# ### Lösungshinweis
#
# > Die Funktion soll mit `print()` die Umrechnungen ausgeben. Bei `interact()` bedeutet das Tupel `(min, max, step)` den Bereich und die Schrittgröße des Schiebereglers.
#
# ### Reflexionsfrage
#
# - Bei welcher Temperatur ist Celsius gleich Fahrenheit?
# - Was ist der Unterschied zwischen der höchsten und niedrigsten Temperatur auf der Erde?
#
# ---
#
# ## 🎯 Aufgabe 3: Farbmischer mit Dropdown
#
# ### Aufgabenstellung
#
# Erstelle einen **Farbmischer** mit drei Dropdown-Menüs. Der Benutzer wählt jeweils eine Primärfarbe (Rot, Grün, Blau) aus, und die Anwendung zeigt die **gemischte Farbe** als Text an.
#
# ### Aufbau

# %%
import ipywidgets as widgets
from ipywidgets import VBox, Output

# Erstelle drei Dropdown-Widgets
farbe1 = widgets.Dropdown(
    options=['Rot', 'Grün', 'Blau'],
    value='Rot',
    description='Farbe 1:'
)

# TODO: Erstelle farbe2 und farbe3 analog zu farbe1

farbe2 = widgets.Dropdown(
    # Dein Code hier
)

farbe3 = widgets.Dropdown(
    # Dein Code hier
)

# TODO: Schreibe eine Funktion mische_farben(f1, f2, f3),
# die die drei Farben "mischt" und ein Ergebnis ausgibt.
# Beispiel:
# - Rot + Rot + Rot = Dunkelrot
# - Rot + Grün + Blau = Weiß
# - Rot + Grün + Grün = Gelb-Grün

def mische_farben(f1, f2, f3):
    # Zähle die Häufigkeit jeder Farbe
    # Dein Code hier
    pass

# Erstelle ein Output-Widget für die Anzeige
output = Output()

def aktualisiere_mischung(change):
    with output:
        output.clear_output()
        mische_farben(farbe1.value, farbe2.value, farbe3.value)

# TODO: Verbinde die Dropdowns mit der Funktion aktualisiere_mischung
# Nutze: farbe1.observe(aktualisiere_mischung, names='value')

farbe1.observe(aktualisiere_mischung, names='value')
# Dein Code hier für farbe2 und farbe3

# Zeige alles an
aktualisiere_mischung(None)  # Initiale Anzeige
display(VBox([farbe1, farbe2, farbe3, output]))

# %% [markdown]
# ### Lösungshinweis
#
# > Du kannst ein Dictionary oder eine Liste verwenden, um zu zählen, welche Farbe am häufigsten vorkommt. Hier ist ein Anfang: `colors = [f1, f2, f3]` und dann `colors.count('Rot')` zählt, wie oft 'Rot' vorkommt.
#
# ### Reflexionsfrage
#
# - Wie viele verschiedene Kombinationen gibt es?
# - Welche Kombination ist deine Lieblingsfarbmischung?
#
# ---
#
# ## 🎯 Aufgabe 4: Interaktiver Kreis-Rechner
#
# ### Aufgabenstellung
#
# Erstelle einen **interaktiven Kreis-Rechner** mit `interact()`. Der Benutzer gibt den **Radius** eines Kreises ein, und die Anwendung berechnet und zeigt an:
# - **Fläche** \(A = \pi r^2\)
# - **Umfang** \(U = 2 \pi r\)
#
# ### Aufbau

# %%
from ipywidgets import interact
import math

# TODO: Schreibe eine Funktion berechne_kreis(radius),
# die Fläche und Umfang berechnet und ausgibt.
# Nutze: math.pi für π

def berechne_kreis(radius):
    # Dein Code hier
    pass

# TODO: Nutze interact() mit einem Schieberegler von 0.5 bis 10 in 0.5er-Schritten

interact(berechne_kreis, radius=(0.5, 10, 0.5))

# %% [markdown]
# ### Lösungshinweis
#
# > `math.pi` ist der Wert von π. Mit `print(f"Fläche: {fläche:.2f}")` kannst du Zahlen auf 2 Dezimalstellen runden.
#
# ### Reflexionsfrage
#
# - Bei welchem Radius ist die Fläche größer als der Umfang?
# - Wie verändert sich die Fläche, wenn du den Radius verdoppelst?
#
# ---
#
# ## 🎯 Aufgabe 5: Grafik mit Slider – Sinuskurve
#
# ### Aufgabenstellung
#
# Erstelle eine **interaktive Sinuskurve** mit `interact()`. Der Benutzer kann mit zwei Schiebereglern die **Amplitude** und die **Frequenz** einstellen. Der Plot soll sich in Echtzeit aktualisieren.
#
# ### Aufbau

# %%
from ipywidgets import interact
import numpy as np
import matplotlib.pyplot as plt

# TODO: Schreibe eine Funktion plot_sinus(amplitude, frequenz),
# die eine Sinuskurve mit den gegebenen Parametern zeichnet.
# Nutze:
# - x = np.linspace(0, 2*np.pi, 100) für x-Werte
# - y = amplitude * np.sin(frequenz * x) für y-Werte
# - plt.plot(x, y) zum Zeichnen
# - plt.ylim(-5, 5) für feste y-Grenzen

def plot_sinus(amplitude, frequenz):
    # Dein Code hier
    pass

# TODO: Nutze interact() mit zwei Schiebereglern:
# - amplitude: von 1 bis 5 in 0.5er-Schritten
# - frequenz: von 1 bis 3 in 0.5er-Schritten

interact(plot_sinus, amplitude=(1, 5, 0.5), frequenz=(1, 3, 0.5))

# %% [markdown]
# ### Lösungshinweis
#
# > `np.linspace(start, stop, anzahl)` erstellt `anzahl` gleichmäßig verteilte Werte zwischen `start` und `stop`. `plt.ylim()` setzt die Grenzen der y-Achse.
#
# ### Reflexionsfrage
#
# - Was passiert mit der Sinuskurve, wenn du die Amplitude erhöhst?
# - Was passiert mit der Sinuskurve, wenn du die Frequenz erhöhst?
# - Bei welchen Werten sieht die Kurve am interessantesten aus?
#
# ---
#
# ## 🎯 Aufgabe 6: Fortgeschritten – Fibonacci-Generator
#
# ### Aufgabenstellung
#
# Erstelle einen **Fibonacci-Generator** mit einem Schieberegler. Der Benutzer gibt an, wie viele Fibonacci-Zahlen er sehen möchte (max. 30), und die Anwendung zeigt:
# - Die Folge der Fibonacci-Zahlen
# - Die Summe aller Fibonacci-Zahlen
# - Das Verhältnis zwischen zwei aufeinanderfolgenden Zahlen (nähert sich dem Goldenen Schnitt)
#
# **Fibonacci-Folge:** \(F_n = F_{n-1} + F_{n-2}\) mit \(F_1 = 1, F_2 = 1\)
#
# ### Aufbau

# %%
from ipywidgets import interact
import ipywidgets as widgets

# TODO: Schreibe eine Funktion fibonacci(n),
# die die ersten n Fibonacci-Zahlen berechnet und ausgibt.
# Tipp: Nutze eine Liste und eine Schleife

def fibonacci(n):
    # Dein Code hier
    pass

# TODO: Nutze interact() mit einem Schieberegler von 1 bis 30

interact(fibonacci, n=(1, 30, 1))

# %% [markdown]
# ### Lösungshinweis
#
# > Starte mit einer Liste `[1, 1]` und füge dann mit einer Schleife neue Zahlen hinzu: `neue_zahl = liste[-1] + liste[-2]`. Mit `liste.append(neue_zahl)` fügst du die Zahl der Liste hinzu.
#
# ### Zusatzaufgabe (Optional)
#
# Erstelle auch eine **Visualisierung der Fibonacci-Zahlen als Balkendiagramm** mit `matplotlib`. Der Schieberegler soll auch das Diagramm aktualisieren.
#
# ### Reflexionsfrage
#
# - Welche Fibonacci-Zahl ist größer: \(F_{10}\) oder \(F_{11}\)?
# - Wie oft musst du die erste Zahl verdoppeln, um größer als \(F_{30}\) zu sein?
#
# ---
#
# ## 🧩 Zusatzaufgabe: Dein eigenes Widget-Projekt
#
# ### Aufgabenstellung
#
# Denke dir ein **eigenes Projekt** aus, das mit Widgets interessant wird:
#
# **Beispiele:**
# - **Quadratische Gleichungen:** Eingabe von a, b, c und automatische Lösung
# - **BMI-Rechner:** Höhe und Gewicht eingeben, BMI berechnen
# - **Einheitenumrechner:** Kilometer ↔ Meilen, kg ↔ Pfund, etc.
# - **Kurvenplotter:** Benutzer gibt eine Funktion ein, und die wird geplottet
# - **Statistik-Dashboard:** Eingabe von Zahlen, Berechnung von Mittelwert, Median, Standardabweichung
#
# ### Anforderungen
#
# - Mindestens 2 Eingabe-Widgets (Slider, Dropdown, Text-Input, etc.)
# - Mindestens 1 Output (Print-Ausgabe oder Plot)
# - Der Output aktualisiert sich, wenn der Benutzer etwas verändert
# - Gute Beschriftungen und aussagekräftige Ergebnisse
#
# ### Tipp
#
# > Beginne mit einer einfachen Idee und erweitere sie dann Schritt für Schritt. Starte mit einem `interact()`-Aufruf und erweitere ihn später mit benutzerdefinierten Widgets.
#
# ---
#
# ## ✅ Checklist zum Abschluss
#
# Hake alle Punkte ab, wenn du sie erledigt hast:
#
# - [ ] Aufgabe 1: Gerade/Ungerade-Checker funktioniert
# - [ ] Aufgabe 2: Temperatur-Umrechner funktioniert
# - [ ] Aufgabe 3: Farbmischer funktioniert
# - [ ] Aufgabe 4: Kreis-Rechner funktioniert
# - [ ] Aufgabe 5: Sinuskurven-Plot funktioniert
# - [ ] Aufgabe 6: Fibonacci-Generator funktioniert
# - [ ] Zusatzaufgabe: Eigenes Projekt erstellt
#
# ---
#
# ## 💬 Reflexionsfragen zum Abschluss
#
# 1. **Welche Aufgabe hat dir am besten gefallen?** Warum?
# 2. **Welche Aufgabe war für dich schwierig?** Was hast du daraus gelernt?
# 3. **Wo könntest du Widgets in deinem eigenen Leben einsetzen?** (z. B. Schulprojekt, Hobby, Wissenschaft)
# 4. **Was möchtest du als Nächstes mit Widgets machen?**
#
# ---
#
# ## 📚 Weiterführende Links
#
# - **[ipywidgets – Interactively Build Jupyter GUIs](https://ipywidgets.readthedocs.io/en/stable/examples/Using%20Interact.html)** – Offizielle Dokumentation zu `interact()` und `interactive()`
# - **[JupyterLab Extension: ipywidgets](https://github.com/jupyter-widgets/ipywidgets)** – GitHub-Repository mit Beispielen
# - **[Voila: Umwandle Notebooks in interaktive Web-Apps](https://voila.readthedocs.io/)** – Teile deine Widgets als Web-Apps
# - **[Plotly für interaktive Grafiken](https://plotly.com/python/)** – Alternative zu matplotlib für noch mehr Interaktivität
# - **[Binder-Repositories: Teile deine Projekte online](https://mybinder.org/)** – Lass andere deine Widgets direkt online testen
