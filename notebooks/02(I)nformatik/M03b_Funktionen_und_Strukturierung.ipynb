# %% [markdown]
# # Modul 3b: Funktionen und Strukturierung von Code – Übungsaufgaben mit Hinweisen
#
# ---
#
# ## 📚 Aufgabenübersicht
#
# Diese Übungsaufgaben helfen dir, Funktionen richtig zu definieren, einzusetzen und den Code zu strukturieren. Jede Aufgabe enthält Hinweise, die zum selbstständigen Arbeiten anregen, aber nicht die vollständige Lösung vorwegnehmen.
#
# ---
#
# ### **Aufgabe 1: Begrüßungsfunktion schreiben**
#
# Schreibe eine Funktion `begruesse(name)`, die einen Namen als Eingabe nimmt und einen personalisierten Begrüßungstext ausgibt.
#
# **Hinweis:**
# - Überlege, wie du einen **String zusammensetzen** kannst.
# - Mit `return` gibst du einen Wert aus der Funktion zurück.
# - Achte auf die Schreibweise des Funktionskopfs: `def ...`.
#
# ---
#
# ### **Aufgabe 2: Rechteck berechnen**
#
# Schreibe eine Funktion `rechteck_berechne(breite, hoehe)`, die **Fläche und Umfang** eines Rechtecks zurückgibt (beide Werte!).
#
# **Hinweis:**
# - Die Fläche ist `breite * hoehe`, der Umfang ist `2 * (breite + hoehe)`.
# - Nutze die Möglichkeit, **mehrere Rückgabewerte** in Python zu liefern (`return ... , ...`).
# - Wie kann man die Rückgabewerte beim Aufruf auf Variablen verteilen?
#
# ---
#
# ### **Aufgabe 3: Liste quadrieren**
#
# Erstelle eine Funktion `quadriere_liste(liste)`, die alle Elemente einer Zahl-Liste quadriert und als neue Liste zurückgibt.
#
# **Hinweis:**
# - Nutze eine **for-Schleife** oder **List-Comprehension** zum Durchlaufen der Liste.
# - Wie kann man die neuen Werte in einer neuen Liste speichern?
#
# ---
#
# ### **Aufgabe 4: Lokaler vs. globaler Scope**
#
# Gegeben ist folgender Code:

# %%
x = 10

def scope_test():
    x = 20
    print(f"x in Funktion: {x}")

scope_test()
print(f"x außerhalb: {x}")

# %% [markdown]
# **Frage:**
# - Welche Werte werden ausgegeben?
# - Was passiert, wenn man innerhalb der Funktion `global x` schreibt?
#
# **Hinweis:**
# - Überlege: Wo wird `x` jeweils definiert?
#
# ---
#
# ### **Aufgabe 5: Fibonacci als Funktion**
#
# Erstelle eine Funktion `fibonacci(n)`, die die n-te Fibonacci-Zahl berechnet.
# - Nutze **eine Schleife**, **keine Rekursion**.
#
# **Hinweis:**
# - Beginne mit den ersten zwei Zahlen (`a, b = 0, 1`) und arbeite dich iterativ vor.
# - Teste deine Funktion mit mehreren Werten für `n`.
#
# ---
#
# ### **Aufgabe 6: Analyse von Messdaten**
#
# Schreibe drei Funktionen:
# - `minimum(liste)`: Gibt das kleinste Element einer Liste zurück.
# - `maximum(liste)`: Gibt das größte Element einer Liste zurück.
# - `mittelwert(liste)`: Gibt den Durchschnitt einer Liste zurück.
#
# Kombiniere die Funktionen für eine **komplette Analyse**.
#
# **Hinweis:**
# - Nutze die eingebauten Python-Funktionen (`min`, `max`, `sum`, `len`).
# - Wie kann man mehrere Funktionen nacheinander verwenden, um ein Ergebnis-Objekt (Dictionary) zu erzeugen?
#
# ---
#
# ### **Aufgabe 7: Variablen-Scope visualisieren (Extra für Fortgeschrittene)**
#
# Schreibe eine Funktion mit **lokaler und globaler Variable**. Ändere die globale Variable innerhalb der Funktion. Erkläre am Ende, warum das funktioniert und wo Fehler auftreten können.
#
# **Hinweis:**
# - Nutze das Schlüsselwort `global` korrekt.
# - Was passiert, wenn du es weglässt?
#
# ---
#
# ## 🧠 Reflexion: Warum sind Funktionen sinnvoll?
#
# Überlege:
# - Was sind die Vorteile von Funktionen im Vergleich zu "Copy-Paste"-Code?
# - Wie helfen dir Funktionen dabei, Code verständlich und effizient zu schreiben?
#
# **Tipp:** Formuliere deine Gedanken als kurzen Text oder bespreche sie mit einem Partner.
#
# ---
#
# ## 📗 Tipps, falls du nicht weiterkommst
#
# - Teste jeden Schritt einzeln und lasse dir Zwischenergebnisse ausgeben (`print`).
# - Überlege: Welche Fehler können auftreten (Tipp: Syntaxfehler, Geltungsbereich)?
# - Nutze die Aufgaben als Basis für eigene Experimente.
# - Frag bei Unsicherheiten nach!
