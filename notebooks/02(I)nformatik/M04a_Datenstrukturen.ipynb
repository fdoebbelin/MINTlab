# %% [markdown]
# # Modul 4a – Datenstrukturen: Demonstration und Einführung
#
# ## 📚 Lernziele
#
# Nach diesem Modul verstehst du:
# - **Was Datenstrukturen sind** und warum sie wichtig sind
# - **Listen, Tupel, Sets und Dictionaries** und ihre Unterschiede
# - **Wie man auf Elemente zugreift** und sie verändert
# - **List Comprehensions** als elegante Art, Listen zu erstellen
# - **Praktische Anwendungen** von Datenstrukturen im MINT-Kontext
#
# ---
#
# ## 🎯 Einstieg: Warum Datenstrukturen wichtig sind
#
# Stell dir vor, du möchtest die Temperatur einer ganzen Woche speichern:

# %%
# Ohne Datenstrukturen:
temperatur_montag = 15
temperatur_dienstag = 16
temperatur_mittwoch = 14
temperatur_donnerstag = 18
# ... sehr umständlich!

# %% [markdown]
# Mit Datenstrukturen wird das viel einfacher:

# %%
# Mit einer Liste:
temperaturen = [15, 16, 14, 18, 17, 19, 16]
# Alle Werte an einem Ort – übersichtlich und praktisch!

# %% [markdown]
# **Datenstrukturen** sind organisierte Wege, viele zusammenhängende Werte zu speichern. Sie sind das Herzstück moderner Programmierung – ob in der Datenverwaltung, Simulation oder Grafik.
#
# ---
#
# ## 1️⃣ Listen – Die flexibleste Sammlung
#
# Eine **Liste** ist eine geordnete Sammlung von Werten. Sie können sich verändern und beliebig viele Elemente enthalten.
#
# ### Listen erstellen

# %%
# Eine leere Liste
farben = []

# Eine Liste mit Werten
zahlen = [1, 2, 3, 4, 5]
obst = ["Apfel", "Banane", "Orange"]
gemischt = [42, "Text", 3.14, True]  # Verschiedene Typen möglich!

print(zahlen)
print(obst)

# %% [markdown]
# ### Auf Elemente zugreifen
#
# **Wichtig:** Zählen in Python beginnt bei **0**, nicht bei 1!

# %%
obst = ["Apfel", "Banane", "Orange"]

# Erster Element (Index 0)
print(obst[0])  # "Apfel"

# Zweites Element (Index 1)
print(obst[1])  # "Banane"

# Letztes Element (Index -1)
print(obst[-1])  # "Orange"

# Bereich: vom 0. bis 1. Element
print(obst[0:2])  # ["Apfel", "Banane"]

# %% [markdown]
# **Verständnisfrage:** Was gibt `obst[1:3]` aus?
#
# ### Elemente verändern

# %%
obst = ["Apfel", "Banane", "Orange"]

# Ein Element überschreiben
obst[1] = "Birne"
print(obst)  # ["Apfel", "Birne", "Orange"]

# Neues Element hinzufügen
obst.append("Kirsche")
print(obst)  # ["Apfel", "Birne", "Orange", "Kirsche"]

# Element entfernen
obst.remove("Apfel")
print(obst)  # ["Birne", "Orange", "Kirsche"]

# %% [markdown]
# ### Über Listen iterieren

# %%
zahlen = [1, 2, 3, 4, 5]

# Mit for-Schleife
for zahl in zahlen:
    print(zahl * 2)  # Jede Zahl verdoppeln
    
# Mit Index
for i in range(len(zahlen)):
    print(f"Position {i}: {zahlen[i]}")

# %% [markdown]
# ### Länge und Statistik

# %%
messwerte = [15.3, 16.1, 14.8, 18.2, 17.5]

# Anzahl der Elemente
print(len(messwerte))  # 5

# Minimum, Maximum, Summe
print(min(messwerte))  # 14.8
print(max(messwerte))  # 18.2
print(sum(messwerte))  # 81.9

# Durchschnitt
print(sum(messwerte) / len(messwerte))  # 16.38

# %% [markdown]
# **Praktisch:** Diese Funktionen sind essentiell bei der Datenanalyse!
#
# ---
#
# ## 2️⃣ Tupel – Die unveränderliche Liste
#
# Ein **Tupel** ist wie eine Liste, aber **man kann es nicht verändern** (unveränderlich/immutable). Man erstellt es mit runden Klammern `()`.

# %%
# Ein Tupel erstellen
koordinaten = (10, 20)
rgb_farbe = (255, 0, 128)

# Auf Elemente zugreifen – wie bei Listen
print(koordinaten[0])  # 10
print(rgb_farbe[1])    # 0

# Man kann aber nicht verändern:
# koordinaten[0] = 15  # FEHLER! Das geht nicht.

# %% [markdown]
# ### Warum Tupel?
#
# - **Sicherheit:** Der Wert ändert sich nicht versehentlich
# - **Effizienz:** Tupel sind etwas schneller als Listen
# - **Als Dictionary-Schlüssel:** Nur Tupel, nicht Listen, können als Schlüssel verwendet werden
# - **Rückgabewerte:** Funktionen können mehrere Werte als Tupel zurückgeben

# %%
# Mehrere Werte gleichzeitig zurückgeben
def berechne_stats(liste):
    minimum = min(liste)
    maximum = max(liste)
    durchschnitt = sum(liste) / len(liste)
    return (minimum, maximum, durchschnitt)

ergebnis = berechne_stats([1, 2, 3, 4, 5])
print(ergebnis)  # (1, 5, 3.0)

# Werte direkt auspacken
min_val, max_val, avg_val = berechne_stats([1, 2, 3, 4, 5])
print(f"Min: {min_val}, Max: {max_val}, Durchschnitt: {avg_val}")

# %% [markdown]
# ---
#
# ## 3️⃣ Sets – Die Sammlung ohne Duplikate
#
# Ein **Set** ist eine ungeordnete Sammlung **eindeutiger Werte**. Es hat keine Duplikate.

# %%
# Ein Set erstellen
farben = {"Rot", "Grün", "Blau"}
zahlen = {1, 2, 3, 3, 2}  # Duplikate werden ignoriert!

print(farben)  # {'Rot', 'Grün', 'Blau'}
print(zahlen)  # {1, 2, 3}

# %% [markdown]
# ### Set-Operationen

# %%
wissenschaftler = {"Müller", "Schmidt", "Fischer"}
programmierer = {"Fischer", "Weber", "Neumann"}

# Vereinigung (alle Personen)
alle = wissenschaftler | programmierer
print(alle)  # {'Müller', 'Schmidt', 'Fischer', 'Weber', 'Neumann'}

# Schnittmenge (wer ist in beiden?)
beide = wissenschaftler & programmierer
print(beide)  # {'Fischer'}

# Differenz (nur in der ersten Gruppe)
nur_wissenschaftler = wissenschaftler - programmierer
print(nur_wissenschaftler)  # {'Müller', 'Schmidt'}

# %% [markdown]
# ### Praktisches Beispiel: Duplikate entfernen

# %%
messungen = [1, 2, 2, 3, 3, 3, 4, 4, 5]
einzigartig = set(messungen)
print(einzigartig)  # {1, 2, 3, 4, 5}

# %% [markdown]
# **Verständnisfrage:** Warum ist ein Set nützlich, wenn man wissen möchte, wie viele unterschiedliche Werte es gibt?
#
# ---
#
# ## 4️⃣ Dictionaries – Zuordnung von Schlüsseln zu Werten
#
# Ein **Dictionary** speichert Paare aus **Schlüssel** und **Wert**. Man sucht Werte nicht nach Position (wie bei Listen), sondern nach einem Schlüssel.

# %%
# Ein Dictionary erstellen
staedte = {
    "Deutschland": "Berlin",
    "Frankreich": "Paris",
    "Italien": "Rom"
}

# Werte abrufen
print(staedte["Deutschland"])  # "Berlin"
print(staedte["Frankreich"])   # "Paris"

# Neuen Eintrag hinzufügen
staedte["Spanien"] = "Madrid"
print(staedte)

# %% [markdown]
# ### Praktisches Beispiel: Schülernoten

# %%
noten = {
    "Alice": 1.5,
    "Bob": 2.0,
    "Charlie": 1.8
}

# Wert abrufen
print(noten["Alice"])  # 1.5

# Über alle Einträge iterieren
for name, note in noten.items():
    print(f"{name} hat die Note {note}")

# Nur Schlüssel
print(noten.keys())    # dict_keys(['Alice', 'Bob', 'Charlie'])

# Nur Werte
print(noten.values())  # dict_values([1.5, 2.0, 1.8])

# Durchschnittsnote
durchschnitt = sum(noten.values()) / len(noten)
print(f"Durchschnittsnote: {durchschnitt}")

# %% [markdown]
# ### Dictionaries mit mehreren Werten

# %%
schuler = {
    "Alice": {"alter": 18, "klasse": "12a"},
    "Bob": {"alter": 17, "klasse": "11b"}
}

# Auf verschachtelte Werte zugreifen
print(schuler["Alice"]["klasse"])  # "12a"

# Oder lesbar mit Variablen
info = schuler["Bob"]
print(f"Bob ist {info['alter']} Jahre alt und in {info['klasse']}")

# %% [markdown]
# **Praktisch:** Dictionaries sind perfekt für strukturierte Daten wie Benutzerprofile, Sensorwerte mit Zeitstempeln, etc.
#
# ---
#
# ## 5️⃣ List Comprehensions – Elegante Listen erstellen
#
# **List Comprehensions** sind eine kompakte Art, neue Listen aus bestehenden zu erstellen.
#
# ### Einfaches Beispiel

# %%
# Normale Art: Quadrate aller Zahlen von 1 bis 5
quadrate = []
for i in range(1, 6):
    quadrate.append(i ** 2)
print(quadrate)  # [1, 4, 9, 16, 25]

# Mit List Comprehension (viel kürzer!):
quadrate = [i ** 2 for i in range(1, 6)]
print(quadrate)  # [1, 4, 9, 16, 25]

# %% [markdown]
# ### Mit Bedingung

# %%
# Nur gerade Zahlen
zahlen = [1, 2, 3, 4, 5, 6, 7, 8]
gerade = [z for z in zahlen if z % 2 == 0]
print(gerade)  # [2, 4, 6, 8]

# Mit Transformation
quadrate_gerade = [z ** 2 for z in zahlen if z % 2 == 0]
print(quadrate_gerade)  # [4, 16, 36, 64]

# %% [markdown]
# ### Praktisches Beispiel: Temperaturumrechnung

# %%
celsius = [0, 10, 20, 30]

# Umrechnung zu Fahrenheit: F = C * 9/5 + 32
fahrenheit = [c * 9/5 + 32 for c in celsius]
print(fahrenheit)  # [32.0, 50.0, 68.0, 86.0]

# %% [markdown]
# **Syntax-Merkhilfe:**

# %% [markdown]
# ```
# [<transformation> for <variable> in <liste> if <bedingung>]
# ```

# %% [markdown]
# ---
#
# ## 📊 Zusammenfassung der Datenstrukturen
#
# | Struktur | Geordnet | Veränderbar | Duplikate | Wann verwenden |
# |----------|----------|-------------|-----------|----------------|
# | **Liste** | Ja | Ja | Ja | Wenn man Werte hinzufügen/entfernen möchte |
# | **Tupel** | Ja | Nein | Ja | Wenn Werte sicher bleiben sollen |
# | **Set** | Nein | Ja | Nein | Für eindeutige Werte, Mengenoperationen |
# | **Dictionary** | Nein | Ja | Nein (als Keys) | Für Schlüssel-Wert-Paare |
#
# ---
#
# ## 🧠 Verständnis vertiefen
#
# **Frage 1:** Welche Datenstruktur würdest du verwenden, um die Temperaturwerte einer ganzen Woche zu speichern?
#
# **Frage 2:** Warum ist ein Set nützlich, wenn man wissen möchte, wie viele unterschiedliche Namen in einer Liste vorkommen?
#
# **Frage 3:** Was ist der Unterschied zwischen `[1, 2]` und `(1, 2)`? Wann würdest du welche verwenden?
#
# ---
#
# ## 🔗 Weiterführende Links
#
# - **Python-Dokumentation: Datenstrukturen** – https://docs.python.org/3/tutorial/datastructures.html
# - **W3Schools: Python Lists** – https://www.w3schools.com/python/python_lists.asp
# - **GeeksforGeeks: Python Dictionaries** – https://www.geeksforgeeks.org/python-dictionary/
# - **Visualisierung von List Comprehensions** – https://www.pythontutor.com/ (interaktiv Code ausführen)
# - **Python Set Operations** – https://www.w3schools.com/python/python_sets.asp
#
# ---
#
# ## 💡 Nächste Schritte
#
# Im nächsten Modul werden wir diese Datenstrukturen in praktischen Anwendungen nutzen – wie zum Beispiel statistische Kennzahlen aus Messungen berechnen oder Daten von Sensoren organisieren.
