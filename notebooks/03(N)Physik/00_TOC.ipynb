# %% [markdown]
# # Inhalt
# ## Modul 1: Kinematik – Bewegung beschreiben
# - [Einführung](./M01a_Kinematik_Bewegung.ipynb)
# - [Aufgaben](./M01b_Kinematik_Bewegung.ipynb)
# - [Lösungen](./M01c_Kinematik_Bewegung.ipynb)
