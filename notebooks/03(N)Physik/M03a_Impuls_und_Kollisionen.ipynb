# %% [markdown]
# # Modul 3: Impuls und Kollisionen
#
# ## Lernziele
#
# Nach diesem Modul verstehst du:
# - Was **Impuls** (Momentum) ist und wie er berechnet wird
# - Das **Prinzip der Impulserhaltung** in isolierten Systemen
# - Den Unterschied zwischen **elastischen und inelastischen Stößen**
# - Wie man Kollisionen in einer und zwei Dimensionen simuliert
# - Wie Parameter-Variation Impulsüberträge aufzeigt
#
# ---
#
# ## 1. Einführung: Was ist Impuls?
#
# Der **Impuls** beschreibt die „Menge an Bewegung" eines Objekts. Ein schweres Auto, das langsam fährt, hat einen ähnlichen Impuls wie ein leichter Ball, der schnell fliegt.
#
# Die Formel für Impuls lautet:
#
# $$
# p = m \cdot v
# $$
#
# Dabei ist:
# - **p** der Impuls (in kg·m/s)
# - **m** die Masse des Objekts (in kg)
# - **v** die Geschwindigkeit (in m/s)
#
# ### Warum ist Impuls wichtig?
#
# Im Alltag begegnen wir Impulserhaltung überall:
# - **Billard-Spiel:** Ein Stoß wird von einer Kugel auf die andere übertragen
# - **Autounfall:** Beim Aufprall verteilt sich der Impuls auf beide Fahrzeuge
# - **Raketentriebwerk:** Gas wird ausgestoßen → die Rakete bewegt sich in die entgegengesetzte Richtung
#
# ---
#
# ## 2. Impulserhaltung – Das fundamentale Gesetz
#
# In einem **isolierten System** (ohne äußere Kräfte) bleibt der **Gesamtimpuls erhalten**. Das heißt:
#
# $$
# p_{vorher} = p_{nachher}
# $$
#
# oder ausführlicher:
#
# $$
# m_1 \cdot v_1 + m_2 \cdot v_2 = m_1 \cdot v_1' + m_2 \cdot v_2'
# $$
#
# Hier bedeuten die gestrichenen Variablen die **Geschwindigkeiten nach dem Stoß**.
#
# ### Beispiel: Zwei Eisschlitten stoßen zusammen
#
# Stellen dir zwei Schlitten auf einer Eisfläche vor:
# - Schlitten 1: Masse = 10 kg, Geschwindigkeit = 5 m/s
# - Schlitten 2: Masse = 10 kg, Geschwindigkeit = 0 m/s (steht still)
#
# Impuls vorher:
# $$
# p_{vorher} = 10 \cdot 5 + 10 \cdot 0 = 50 \text{ kg·m/s}
# $$
#
# Nach einem inelastischen Stoß (beide bleiben zusammen) mit Gesamtmasse 20 kg:
# $$
# 50 = 20 \cdot v_{nach} \quad \Rightarrow \quad v_{nach} = 2,5 \text{ m/s}
# $$
#
# ---
#
# ## 3. Elastische vs. Inelastische Stöße
#
# ### Elastischer Stoß
# - **Kinetische Energie bleibt erhalten**
# - Objekte **berühren sich, aber trennen sich wieder**
# - Beispiel: Billiardkugeln, die sich treffen
#
# Zusätzlich zur Impulserhaltung gilt:
# $$
# \frac{1}{2} m_1 v_1^2 + \frac{1}{2} m_2 v_2^2 = \frac{1}{2} m_1 v_1'^2 + \frac{1}{2} m_2 v_2'^2
# $$
#
# ### Inelastischer Stoß
# - **Kinetische Energie geht teilweise verloren** (wird zu Wärme, Schall, Verformung)
# - Objekte können sich **verbinden oder bleiben zusammen**
# - Beispiel: Autounfall, Knete, die auf den Boden fällt
#
# Impuls bleibt erhalten, aber:
# $$
# \text{KE}_{vorher} > \text{KE}_{nachher}
# $$
#
# ---
#
# ## 4. Python-Simulation: Eindimensionale Stöße
#
# Lass uns eine interaktive Simulation bauen, um Stöße zu verstehen.
#
# ### Code-Beispiel 1: Impuls berechnen

# %%
# Impuls für zwei Objekte berechnen

# Objekt 1: Schlitten
masse1 = 10  # kg
geschwindigkeit1 = 5  # m/s
impuls1 = masse1 * geschwindigkeit1

# Objekt 2: Schlitten
masse2 = 10  # kg
geschwindigkeit2 = 0  # m/s
impuls2 = masse2 * geschwindigkeit2

# Gesamtimpuls vorher
impuls_gesamt = impuls1 + impuls2

print(f"Impuls Objekt 1: {impuls1} kg·m/s")
print(f"Impuls Objekt 2: {impuls2} kg·m/s")
print(f"Gesamtimpuls (vor Stoß): {impuls_gesamt} kg·m/s")

# %% [markdown]
# **Erklärung:**
# - Wir multiplizieren Masse mit Geschwindigkeit, um den Impuls zu bekommen
# - Der Gesamtimpuls ist die Summe aller Einzelimpulse
# - Dieser Wert bleibt nach dem Stoß gleich!
#
# ---
#
# ### Code-Beispiel 2: Inelastischer Stoß simulieren

# %%
# Szenario: Zwei Schlitten stoßen zusammen und bleiben zusammen

# Vorher-Zustand
m1 = 10  # kg
v1 = 5   # m/s
m2 = 10  # kg
v2 = 0   # m/s

# Impulserhaltung
p_vorher = m1 * v1 + m2 * v2

# Nach dem Stoß: Beide Objekte kleben zusammen
m_gesamt = m1 + m2
v_nachher = p_vorher / m_gesamt

print(f"Gesamtmasse nach Stoß: {m_gesamt} kg")
print(f"Geschwindigkeit nach Stoß: {v_nachher} m/s")

# Kinetische Energie vergleichen
KE_vorher = 0.5 * m1 * v1**2 + 0.5 * m2 * v2**2
KE_nachher = 0.5 * m_gesamt * v_nachher**2
energie_verlust = KE_vorher - KE_nachher

print(f"\nKinetische Energie vorher: {KE_vorher} J")
print(f"Kinetische Energie nachher: {KE_nachher} J")
print(f"Energie verloren: {energie_verlust} J")
print(f"Prozentual: {100 * energie_verlust / KE_vorher:.1f}%")

# %% [markdown]
# **Was passiert hier?**
# - Beide Schlitten kleben zusammen → **inelastischer Stoß**
# - Die neue Geschwindigkeit wird aus der Impulserhaltung berechnet
# - **Energieverlust:** Obwohl Impuls erhalten bleibt, geht Energie verloren!
#
# ---
#
# ### Code-Beispiel 3: Elastischer Stoß (vereinfacht)

# %%
# Elastischer Stoß: Zwei gleich massive Objekte
# Wenn Masse gleich ist und ein Objekt stillsteht, 
# tauschen sie Geschwindigkeit und Richtung

# Vorher-Zustand
m1 = 10  # kg
v1 = 5   # m/s
m2 = 10  # kg
v2 = 0   # m/s

# Für elastischen Stoß bei gleicher Masse:
# Sie tauschen die Geschwindigkeiten
v1_nachher = v2
v2_nachher = v1

# Impuls prüfen
p_vorher = m1 * v1 + m2 * v2
p_nachher = m1 * v1_nachher + m2 * v2_nachher

print(f"Elastischer Stoß (gleiche Masse):")
print(f"Objekt 1 - vorher: {v1} m/s, nachher: {v1_nachher} m/s")
print(f"Objekt 2 - vorher: {v2} m/s, nachher: {v2_nachher} m/s")
print(f"\nImpuls vorher: {p_vorher} kg·m/s")
print(f"Impuls nachher: {p_nachher} kg·m/s")

# Kinetische Energie prüfen
KE_vorher = 0.5 * m1 * v1**2 + 0.5 * m2 * v2**2
KE_nachher = 0.5 * m1 * v1_nachher**2 + 0.5 * m2 * v2_nachher**2

print(f"\nKinetische Energie vorher: {KE_vorher} J")
print(f"Kinetische Energie nachher: {KE_nachher} J")
print(f"Energie bleibt gleich: {KE_vorher == KE_nachher}")

# %% [markdown]
# **Beobachtung:**
# - Beide Größen bleiben gleich → echte elastische Kollision
# - Die schnellere Kugel stoppt, die langsame bewegt sich weiter
# - Dies ist wie beim Billardspiel!
#
# ---
#
# ## 5. Interaktive Simulation mit Parameter-Variation

# %%
import matplotlib.pyplot as plt
import numpy as np

# Funktion für inelastischen Stoß
def inelastischer_stoss(m1, v1, m2, v2):
    """
    Berechnet Geschwindigkeiten nach inelastischem Stoß
    """
    p_vorher = m1 * v1 + m2 * v2
    m_gesamt = m1 + m2
    v_nachher = p_vorher / m_gesamt
    
    ke_vorher = 0.5 * m1 * v1**2 + 0.5 * m2 * v2**2
    ke_nachher = 0.5 * m_gesamt * v_nachher**2
    
    return v_nachher, ke_vorher, ke_nachher

# Verschiedene Szenarien durchspielen
print("Inelastische Stöße mit verschiedenen Massen:\n")

szenarien = [
    (10, 5, 10, 0),  # Gleiche Masse
    (20, 5, 10, 0),  # Erstes Objekt schwerer
    (5, 10, 10, 0),  # Zweites Objekt schwerer
]

for i, (m1, v1, m2, v2) in enumerate(szenarien, 1):
    v_nach, ke_vor, ke_nach = inelastischer_stoss(m1, v1, m2, v2)
    print(f"Szenario {i}:")
    print(f"  m1={m1}kg (v1={v1}m/s) + m2={m2}kg (v2={v2}m/s)")
    print(f"  → v_nachher = {v_nach:.2f} m/s")
    print(f"  → Energieverlust: {(ke_vor - ke_nach):.1f} J ({100*(ke_vor-ke_nach)/ke_vor:.1f}%)")
    print()

# %% [markdown]
# **Erkenntnisse:**
# - Je schwerer das erste Objekt, desto höher die Endgeschwindigkeit
# - Bei ungleichen Massen: Der schwerere Körper „dominiert" die Richtung
# - Der Energieverlust variiert mit den Massen!
#
# ---
#
# ## 6. Zweidimensionale Kollisionen mit Vektoren
#
# In der Realität passieren Stöße nicht immer eindimensional. Wir brauchen **Vektoren**!

# %%
import numpy as np
import matplotlib.pyplot as plt

# Zwei Objekte in 2D mit Vektoren
m1 = 10  # kg
v1 = np.array([5, 0])  # Geschwindigkeit als Vektor: 5 m/s nach rechts

m2 = 10  # kg
v2 = np.array([0, 5])  # Geschwindigkeit als Vektor: 5 m/s nach oben

# Impuls (Vektor)
p1 = m1 * v1
p2 = m2 * v2
p_gesamt = p1 + p2

print("2D-Kollision:")
print(f"Impuls Objekt 1: {p1} kg·m/s")
print(f"Impuls Objekt 2: {p2} kg·m/s")
print(f"Gesamtimpuls: {p_gesamt} kg·m/s")

# Nach inelastischem Stoß (sie bleiben zusammen)
m_gesamt = m1 + m2
v_nachher = p_gesamt / m_gesamt

print(f"\nNach dem Stoß:")
print(f"Geschwindigkeit: {v_nachher} m/s")
print(f"Betrag der Geschwindigkeit: {np.linalg.norm(v_nachher):.2f} m/s")

# Visualisierung
fig, ax = plt.subplots(figsize=(8, 8))

# Ursprung als Startpunkt
ax.arrow(0, 0, v1[0], v1[1], head_width=0.3, head_length=0.2, fc='red', ec='red', label='v1 (Objekt 1)')
ax.arrow(0, 0, v2[0], v2[1], head_width=0.3, head_length=0.2, fc='blue', ec='blue', label='v2 (Objekt 2)')
ax.arrow(0, 0, v_nachher[0]*1.4, v_nachher[1]*1.4, head_width=0.3, head_length=0.2, fc='green', ec='green', label='v_nachher')

ax.set_xlim(-1, 8)
ax.set_ylim(-1, 8)
ax.set_aspect('equal')
ax.grid(True, alpha=0.3)
ax.legend()
ax.set_xlabel('x (m/s)')
ax.set_ylabel('y (m/s)')
ax.set_title('2D-Kollision: Vektorielle Impulserhaltung')

plt.show()

# %% [markdown]
# **Was wir sehen:**
# - Die grüne Linie (Ergebnis) zeigt die Richtung des Gesamtimpulses
# - Sie liegt genau zwischen den zwei ursprünglichen Richtungen
# - Das ist **vektorielle Impulserhaltung** in Aktion!
#
# ---
#
# ## 7. Verständnisfragen
#
# 1. **Zwei Autos:** Auto A (1000 kg) fährt mit 20 m/s, Auto B (2000 kg) steht still. Sie stoßen zusammen und bleiben verbunden. Wie schnell fahren sie danach?
#
#    *Hinweis: Nutze die Impulserhaltungsformel und löse nach der Endgeschwindigkeit auf.*
#
# 2. **Energie-Vergleich:** Warum geht bei inelastischen Stößen Energie verloren, obwohl der Impuls erhalten bleibt?
#
#    *Denkanstoß: Wohin könnte die fehlende Energie verschwinden?*
#
# 3. **2D-Szenario:** Zwei Eishockey-Pucks stoßen zusammen. Einer bewegt sich nach Osten, der andere nach Norden. Was passiert nach einem inelastischen Stoß?
#
# ---
#
# ## 8. Zusammenfassung
#
# | Konzept | Definition | Formel |
# |---------|-----------|--------|
# | **Impuls** | Masse × Geschwindigkeit | $$p = m \cdot v$$ |
# | **Impulserhaltung** | Gesamtimpuls bleibt konstant | $$p_{vorher} = p_{nachher}$$ |
# | **Elastischer Stoß** | Energie + Impuls bleiben erhalten | Beide größen gleich |
# | **Inelastischer Stoß** | Nur Impuls bleibt erhalten | Energie geht verloren |
#
# ---
#
# ## 9. Weiterführende Links
#
# - [PhET: Collision Lab](https://phet.colorado.edu/en/simulations/filter?subjects=physics&types=html,prototype) – Interaktive Kollisions-Simulation
# - [Khan Academy: Impulse and Momentum](https://www.khanacademy.org/science/physics/linear-momentum) – Video-Tutorials
# - [Virtuelle Experimente: Elastische Stöße](https://www.virtuelle-experimente.de/) – Deutsche Simulation
# - [NumPy Dokumentation: Vektoren](https://numpy.org/doc/stable/reference/generated/numpy.array.html) – Für 2D/3D-Rechnungen
# - [Matplotlib Quiver Plot](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.quiver.html) – Vektoren visualisieren
#
# ---
#
# ## 10. Nächste Schritte
#
# In der **Übungsdatei (M03b)** wirst du:
# - ✅ Impulserhaltung selbst berechnen
# - ✅ Verschiedene Stoß-Szenarien simulieren
# - ✅ Mit Vektoren in 2D arbeiten
# - ✅ Parameter variieren und Effekte beobachten
#
# In der **Lösungsdatei (M03c)** findest du:
# - 📋 Ausführliche Lösungen aller Aufgaben
# - 💡 Alternative Lösungsansätze
# - 🚀 Erweiterte Konzepte und Tipps
