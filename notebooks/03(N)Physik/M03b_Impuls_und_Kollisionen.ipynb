# %% [markdown]
# # Modul 3: Impuls und Kollisionen – Übungsaufgaben
#
# ## Lernziele dieser Übung
#
# - ✅ Impuls berechnen und verstehen
# - ✅ Impulserhaltung in Kollisions-Szenarien anwenden
# - ✅ Unterschied zwischen elastischen und inelastischen Stößen praktisch erleben
# - ✅ Mit Vektoren in 2D arbeiten
# - ✅ Simulationen durch Parameter-Variation erweitern
#
# ---
#
# ## Aufgabe 1: Impuls berechnen
#
# ### Aufgabenstellung
#
# Berechne den Impuls für die folgenden Objekte:
#
# 1. Ein Auto mit Masse 1500 kg, das mit 20 m/s fährt
# 2. Ein Tennisball mit Masse 0,058 kg, der mit 50 m/s fliegt
# 3. Ein Mensch (70 kg), der mit 2 m/s spaziert
#
# **Was fällt dir auf? Welches Objekt hat den größten Impuls?**
#
# ### Code-Vorlage

# %%
# Aufgabe 1: Impuls berechnen

# Objekt 1: Auto
masse_auto = 1500  # kg
geschwindigkeit_auto = 20  # m/s
impuls_auto = ...  # TODO: Berechne den Impuls

# Objekt 2: Tennisball
masse_ball = 0.058  # kg
geschwindigkeit_ball = 50  # m/s
impuls_ball = ...  # TODO: Berechne den Impuls

# Objekt 3: Mensch
masse_mensch = 70  # kg
geschwindigkeit_mensch = 2  # m/s
impuls_mensch = ...  # TODO: Berechne den Impuls

print(f"Impuls Auto: {impuls_auto} kg·m/s")
print(f"Impuls Tennisball: {impuls_ball} kg·m/s")
print(f"Impuls Mensch: {impuls_mensch} kg·m/s")

# Zusatzfrage: Welcher Impuls ist am größten?

# %% [markdown]
# ### Lösungshinweis
#
# > Die Formel ist einfach: Impuls = Masse × Geschwindigkeit. Verwende die Variablen, die bereits definiert sind, und multipliciere sie!
#
# ### Verständnisfrage
#
# Warum hat das Auto einen größeren Impuls als der Tennisball, obwohl der Ball schneller ist?
#
# ---
#
# ## Aufgabe 2: Inelastischer Stoß berechnen
#
# ### Aufgabenstellung
#
# Zwei Objekte stoßen zusammen und bleiben verbunden (inelastischer Stoß):
# - **Objekt A:** Masse = 5 kg, Geschwindigkeit = 10 m/s
# - **Objekt B:** Masse = 15 kg, Geschwindigkeit = 0 m/s
#
# **Frage:** Wie schnell bewegen sich beide Objekte nach dem Stoß?
#
# ### Code-Vorlage

# %%
# Aufgabe 2: Inelastischer Stoß

# Vorher-Zustand
m_A = 5  # kg
v_A_vor = 10  # m/s
m_B = 15  # kg
v_B_vor = 0  # m/s

# Schritt 1: Gesamtimpuls vorher berechnen
p_gesamt = ...  # TODO: m_A * v_A_vor + m_B * v_B_vor

# Schritt 2: Gesamtmasse berechnen
m_gesamt = ...  # TODO: m_A + m_B

# Schritt 3: Geschwindigkeit nach dem Stoß berechnen (Impulserhaltung)
v_nachher = ...  # TODO: p_gesamt / m_gesamt

print(f"Gesamtimpuls: {p_gesamt} kg·m/s")
print(f"Gesamtmasse: {m_gesamt} kg")
print(f"Geschwindigkeit nach Stoß: {v_nachher} m/s")

# %% [markdown]
# ### Lösungshinweis
#
# > Folge diesen Schritten:
# > 1. Berechne den Gesamtimpuls von Objekt A und B zusammen
# > 2. Addiere die Massen
# > 3. Teile den Gesamtimpuls durch die Gesamtmasse
# > 4. Das ist deine Endgeschwindigkeit!
#
# ### Zusatz-Aufgabe
#
# Vergleiche die kinetische Energie **vor** und **nach** dem Stoß. Gehe dabei so vor:

# %%
# Kinetische Energie vorher (beide Objekte separat)
KE_vorher = ...  # TODO: 0.5 * m_A * v_A_vor**2 + 0.5 * m_B * v_B_vor**2

# Kinetische Energie nachher (kombiniert)
KE_nachher = ...  # TODO: 0.5 * m_gesamt * v_nachher**2

# Differenz
energie_verlust = ...  # TODO: KE_vorher - KE_nachher

print(f"Energie vorher: {KE_vorher} J")
print(f"Energie nachher: {KE_nachher} J")
print(f"Energie verloren: {energie_verlust} J")

# %% [markdown]
# ---
#
# ## Aufgabe 3: Elastischer Stoß (Gleichmasse)
#
# ### Aufgabenstellung
#
# Zwei Billardkugeln (gleiche Masse) stoßen zusammen:
# - **Kugel 1:** Masse = 0,17 kg, Geschwindigkeit = 4 m/s
# - **Kugel 2:** Masse = 0,17 kg, Geschwindigkeit = 0 m/s (ruhend)
#
# **Bei einem elastischen Stoß zwischen gleich schweren Objekten (eines ruhend) tauschen sie die Geschwindigkeiten!**
#
# ### Code-Vorlage

# %%
# Aufgabe 3: Elastischer Stoß

m1 = 0.17  # kg
v1_vor = 4  # m/s
m2 = 0.17  # kg
v2_vor = 0  # m/s

# Bei gleicher Masse und elastischem Stoß: Geschwindigkeiten tauschen
v1_nach = ...  # TODO: Was wird aus Kugel 1? Welche Geschwindigkeit hatte Kugel 2 vorher?
v2_nach = ...  # TODO: Was wird aus Kugel 2? Welche Geschwindigkeit hatte Kugel 1 vorher?

# Impulserhaltung prüfen
p_vorher = m1 * v1_vor + m2 * v2_vor
p_nachher = m1 * v1_nach + m2 * v2_nach

print(f"Kugel 1 - vorher: {v1_vor} m/s, nachher: {v1_nach} m/s")
print(f"Kugel 2 - vorher: {v2_vor} m/s, nachher: {v2_nach} m/s")
print(f"\nImpuls vorher: {p_vorher} kg·m/s")
print(f"Impuls nachher: {p_nachher} kg·m/s")
print(f"Impuls erhalten? {p_vorher == p_nachher}")

# %% [markdown]
# ### Lösungshinweis
#
# > Bei einem elastischen Stoß zwischen zwei gleich schweren Objekten (eines in Ruhe) tauschen sie ihre Geschwindigkeiten:
# > - Die bewegte Kugel wird zur ruhenden
# > - Die ruhende Kugel bewegt sich jetzt mit der ursprünglichen Geschwindigkeit
#
# ---
#
# ## Aufgabe 4: Parameter-Variation – Was passiert, wenn sich Massen unterscheiden?
#
# ### Aufgabenstellung
#
# Ändere die Masse von Objekt B und beobachte, wie die Endgeschwindigkeit sich verändert. Führe drei Szenarien durch:

# %%
# Aufgabe 4: Parameter-Variation mit verschiedenen Massen

# Szenario 1: m_B leicht
# Szenario 2: m_B normal
# Szenario 3: m_B schwer

m_A = 10  # kg (bleibt gleich)
v_A = 5   # m/s (bleibt gleich)

szenarien = [
    (5, "m_B ist leicht"),
    (10, "m_B ist gleich schwer"),
    (20, "m_B ist schwer"),
]

print("Effekt der Masse von B auf die Endgeschwindigkeit:")
print("-" * 50)

for m_B_wert, beschreibung in szenarien:
    m_B = m_B_wert
    v_B = 0  # Ruht
    
    # TODO: Impulserhaltung anwenden
    p_gesamt = ...
    m_gesamt = ...
    v_nachher = ...
    
    print(f"{beschreibung}:")
    print(f"  m_B = {m_B} kg → v_nachher = {v_nachher:.2f} m/s")

# %% [markdown]
# ### Lösungshinweis
#
# > Die Logik ist für alle Szenarien dieselbe:
# > 1. Gesamtimpuls = m_A × v_A + m_B × v_B
# > 2. Gesamtmasse = m_A + m_B
# > 3. Endgeschwindigkeit = Gesamtimpuls / Gesamtmasse
#
# ### Beobachtungsfragen
#
# - Wird die Endgeschwindigkeit größer oder kleiner, je schwerer m_B ist?
# - Warum ist das physikalisch sinnvoll?
#
# ---
#
# ## Aufgabe 5: 2D-Kollision mit Vektoren
#
# ### Aufgabenstellung
#
# Zwei Objekte stoßen in 2D zusammen:
# - **Objekt A:** Masse = 5 kg, Geschwindigkeit = (6, 0) m/s (nach rechts)
# - **Objekt B:** Masse = 5 kg, Geschwindigkeit = (0, 4) m/s (nach oben)
#
# Sie bleiben nach dem Stoß zusammen. **Berechne die neue Geschwindigkeit als Vektor!**
#
# ### Code-Vorlage

# %%
import numpy as np

# Aufgabe 5: 2D-Kollision

m_A = 5  # kg
v_A = np.array([6, 0])  # m/s (nach rechts)

m_B = 5  # kg
v_B = np.array([0, 4])  # m/s (nach oben)

# TODO: Berechne die Impulsvektoren
p_A = ...
p_B = ...

# TODO: Berechne den Gesamtimpuls (Vektoraddition)
p_gesamt = ...

# TODO: Berechne die Gesamtmasse
m_gesamt = ...

# TODO: Berechne die neue Geschwindigkeit (Impuls / Masse)
v_nachher = ...

print(f"Impuls A: {p_A}")
print(f"Impuls B: {p_B}")
print(f"Gesamtimpuls: {p_gesamt}")
print(f"Geschwindigkeit nach Stoß: {v_nachher}")
print(f"Betrag der Geschwindigkeit: {np.linalg.norm(v_nachher):.2f} m/s")

# %% [markdown]
# ### Lösungshinweis
#
# > Mit NumPy funktioniert Vektorrechnung genauso wie Zahlenrechnung:
# > - `p_A = m_A * v_A` ergibt einen Vektor
# > - `p_gesamt = p_A + p_B` addiert die Vektoren komponentenweise
# > - `v_nachher = p_gesamt / m_gesamt` teilt jede Komponente durch die Masse
#
# ### Bonus: Visualisierung

# %%
import matplotlib.pyplot as plt

# Zeichne die Vektoren
fig, ax = plt.subplots(figsize=(8, 8))

# Pfeile für die Geschwindigkeitsvektoren
ax.arrow(0, 0, v_A[0], v_A[1], head_width=0.3, head_length=0.2, fc='red', ec='red', label='v_A')
ax.arrow(0, 0, v_B[0], v_B[1], head_width=0.3, head_length=0.2, fc='blue', ec='blue', label='v_B')
ax.arrow(0, 0, v_nachher[0], v_nachher[1], head_width=0.3, head_length=0.2, fc='green', ec='green', label='v_nachher', linewidth=2)

ax.set_xlim(-1, 8)
ax.set_ylim(-1, 6)
ax.set_aspect('equal')
ax.grid(True, alpha=0.3)
ax.legend(fontsize=12)
ax.set_xlabel('x-Komponente (m/s)')
ax.set_ylabel('y-Komponente (m/s)')
ax.set_title('2D-Kollision: Vektorielle Impulserhaltung')

plt.show()

# %% [markdown]
# ---
#
# ## Aufgabe 6: Reflexion und Vertiefung
#
# ### Frage 1: Warum ist Impulserhaltung wichtig?
#
# Beschreibe, warum das Prinzip der Impulserhaltung in der Physik fundamental ist. Gib ein Beispiel aus deinem Alltag.
#
# ### Frage 2: Energieverlust
#
# Bei inelastischen Stößen geht Energie verloren. **Wohin?** Nenne mindestens 3 Möglichkeiten, wie Energie dissipiert werden kann.
#
# ### Frage 3: Elastisch vs. Inelastisch
#
# Klassifiziere die folgenden Ereignisse als elastisch oder inelastisch:
# - Zwei Tennisbälle stoßen in der Luft zusammen
# - Ein Auto prallt gegen eine Mauer
# - Ein Schneeball fällt zu Boden und bleibt liegen
# - Ein Billiardball trifft einen anderen Billiardball
#
# ---
#
# ## Zusammenfassung der Aufgaben
#
# | Aufgabe | Schwerpunkt | Konzept |
# |---------|------------|---------|
# | 1 | Impulsberechnung | $$p = m \cdot v$$ |
# | 2 | Inelastischer Stoß | Impulserhaltung + Energieverlust |
# | 3 | Elastischer Stoß | Energie + Impuls erhalten |
# | 4 | Parameter-Variation | Abhängigkeiten verstehen |
# | 5 | 2D-Vektoren | Impuls im Raum |
# | 6 | Konzeptionelles Verständnis | Vertiefung und Transfer |
#
# ---
#
# ## Nächste Schritte
#
# ✅ Alle Aufgaben gelöst?
#
# ➡️ Dann schau dir **M03c_Impuls_und_Kollisionen.md** an für:
# - Vollständige Lösungen mit Kommentaren
# - Alternative Lösungsansätze
# - Erweiterte Konzepte und mathematische Hintergründe
