# %% [markdown]
# # Modul 4 – Energie und Energieerhaltung
# ## Übungsaufgaben mit Hinweisen
#
# ---
#
# ## 📋 Einleitung für Lernende
#
# In diesem Modul werden deine Kenntnisse aus der **Demonstrationsdatei (M04a)** in die Praxis umgesetzt. Du wirst:
#
# - Energieberechnungen selbst durchführen
# - Python-Programme schreiben, um physikalische Szenarien zu simulieren
# - Deine Ergebnisse visualisieren und interpretieren
# - Konzepte der Energieerhaltung auf reale Probleme anwenden
#
# **Wichtig:** Versuche die Aufgaben zunächst ohne Lösung zu bearbeiten. Nutze die Hinweise nur, wenn du nicht weiterkommst!
#
# ---
#
# ## 🔧 Aufgabe 1: Energieberechnung im freien Fall
#
# ### Ziel der Aufgabe
# Du sollst ein Programm schreiben, das die kinetische, potenzielle und Gesamtenergie bei einem **fallenden Objekt** berechnet und tabellarisch ausgegeben wird.
#
# ### Aufgabenstellung
#
# Ein Ball mit Masse **m = 2 kg** wird aus einer Höhe von **h = 15 Metern** fallen gelassen (Anfangsgeschwindigkeit v₀ = 0 m/s). Verwende g = 10 m/s² für die Erdbeschleunigung.
#
# **Deine Aufgaben:**
#
# 1. Berechne die **potenzielle Energie** am Anfang
# 2. Berechne die **kinetische Energie** am Anfang
# 3. Berechne die **Gesamtenergie**
# 4. Simuliere den Fall über 2 Sekunden hinweg
# 5. Gib eine Tabelle aus, die für jeden Zeitpunkt die Höhe, Geschwindigkeit und Energien zeigt
#
# ### Startcode

# %%
# Aufgabe 1: Energieberechnung im freien Fall

import numpy as np

# Parameter
m = 2.0      # Masse in kg
g = 10       # Erdbeschleunigung in m/s²
h0 = 15      # Anfangshöhe in Meter
v0 = 0       # Anfangsgeschwindigkeit in m/s

# TODO: Berechne die Anfangsenergie
# E_anfang = ... (mit Formeln: E_kin = 0.5 * m * v0², E_pot = m * g * h0)

# Zeitarray: von 0 bis 2 Sekunden, 11 Punkte
t = np.linspace(0, 2, 11)

# TODO: Berechne Höhe und Geschwindigkeit als Funktion der Zeit
# Nutze die Formeln:
# h(t) = h0 - 0.5 * g * t²
# v(t) = v0 + g * t
# h = ... 
# v = ...

# TODO: Berechne die Energien
# E_kin = 0.5 * m * v²
# E_pot = m * g * h
# E_ges = E_kin + E_pot

# TODO: Gib eine Tabelle aus mit den Spalten:
# Zeit | Höhe | Geschwindigkeit | E_kin | E_pot | E_ges
# Nutze eine Schleife oder print mit format()

# Lösungshinweis:
# - Die Gesamtenergie E_ges sollte überall gleich sein!
# - Überprüfe dein Ergebnis: E_ges sollte etwa 300 Joule betragen

# %% [markdown]
# ### Reflexionsfragen
#
# - Ändert sich die Gesamtenergie während des Falles? Warum oder warum nicht?
# - Wie verändert sich das Verhältnis zwischen E_kin und E_pot während des Falles?
# - Was würde passieren, wenn du die Anfangshöhe verdoppelst?
#
# ---
#
# ## 🔧 Aufgabe 2: Das Pendel – Energieumwandlung erkunden
#
# ### Ziel der Aufgabe
# Du sollst ein Pendel simulieren und visualisieren, wie die Energieformen sich während der Schwingung umwandeln.
#
# ### Aufgabenstellung
#
# Simuliere ein **einfaches Pendel** mit folgenden Parametern:
# - Masse: m = 1 kg
# - Länge: L = 2 m
# - Maximale Auslenkung (Winkel): θ_max = 30° = π/6 Radiant
#
# **Deine Aufgaben:**
#
# 1. Berechne die **Höhenänderung** des Pendelgewichts relativ zum tiefsten Punkt: $$h = L \cdot (1 - \cos(\theta))$$
# 2. Berechne die **Winkelgeschwindigkeit**: $$\omega = \sqrt{g/L}$$
# 3. Simuliere die Pendelbewegung über 4 Sekunden
# 4. Zeichne ein Diagramm mit zwei Subplots:
#    - **Plot 1**: Winkelposition θ(t) über der Zeit
#    - **Plot 2**: Kinetische und potenzielle Energie über der Zeit
# 5. Beobachte: Wann ist E_kin maximal? Wann ist E_pot maximal?
#
# ### Startcode

# %%
# Aufgabe 2: Das Pendel – Energieumwandlung erkunden

import matplotlib.pyplot as plt
import numpy as np

# Parameter
m = 1.0       # Masse in kg
g = 10        # Erdbeschleunigung in m/s²
L = 2.0       # Pendellänge in Meter
theta_max = np.pi / 6  # Maximale Auslenkung in Radiant (30 Grad)

# TODO: Berechne die Eigenfrequenz omega
# omega = np.sqrt(g / L)

# TODO: Erstelle ein Zeitarray
# t = np.linspace(0, 4, 500)  # 4 Sekunden, 500 Punkte

# TODO: Berechne die Winkelposition theta(t) über die Zeit
# theta = theta_max * np.cos(omega * t)
# (Das ist die Gleichung für eine harmonische Schwingung)

# TODO: Berechne die Winkelgeschwindigkeit dtheta/dt
# omega_t = -theta_max * omega * np.sin(omega * t)

# TODO: Berechne die Höhe des Pendelgewichts über dem tiefsten Punkt
# h = L * (1 - np.cos(theta))

# TODO: Berechne die Geschwindigkeit des Pendelgewichts
# v = L * np.abs(omega_t)

# TODO: Berechne die Energien
# E_kin = 0.5 * m * v**2
# E_pot = m * g * h
# E_ges = E_kin + E_pot

# TODO: Erstelle ein Diagramm mit 2 Subplots
# fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Plot 1: Winkelposition über der Zeit
# axes[0].plot(t, np.degrees(theta), 'purple', linewidth=2)
# axes[0].set_xlabel('Zeit (s)')
# axes[0].set_ylabel('Winkelposition θ (Grad)')
# axes[0].grid(True, alpha=0.3)
# axes[0].set_title('Pendelbewegung')

# Plot 2: Energien über der Zeit
# TODO: Plottet E_kin, E_pot und E_ges in einem Graphen
# axes[1].plot(t, E_kin, 'r-', linewidth=2, label='E_kin')
# axes[1].plot(t, E_pot, 'b-', linewidth=2, label='E_pot')
# axes[1].plot(t, E_ges, 'g--', linewidth=2, label='E_ges')
# axes[1].set_xlabel('Zeit (s)')
# axes[1].set_ylabel('Energie (Joule)')
# axes[1].legend()
# axes[1].grid(True, alpha=0.3)
# axes[1].set_title('Energien beim Pendel')

# plt.tight_layout()
# plt.show()

# Lösungshinweis:
# - E_ges sollte während der gesamten Schwingung konstant bleiben
# - E_kin und E_pot sollten gegenphasig oszillieren (wenn eines hoch ist, ist das andere tief)

# %% [markdown]
# ### Reflexionsfragen
#
# - Zu welcher Zeit ist die kinetische Energie am größten? Was ist zu diesem Zeitpunkt die Position des Pendels?
# - Zu welcher Zeit ist die potenzielle Energie am größten? Was ist zu diesem Zeitpunkt die Winkelgeschwindigkeit?
# - Zeichne ein gestapeltes Flächendiagramm (mit `fill_between`), das zeigt, wie die Energien sich während einer Schwingung aufteilen.
#
# ---
#
# ## 🔧 Aufgabe 3: Vergleich verschiedener Szenarien
#
# ### Ziel der Aufgabe
# Du sollst verschiedene physikalische Szenarien vergleichen und verstehen, wie unterschiedliche Parameter die Energie beeinflussen.
#
# ### Aufgabenstellung
#
# Vergleiche folgende drei Szenarien für **fallende Objekte**:
#
# | Szenario | Masse (kg) | Höhe (m) | Anfangsgeschwindigkeit (m/s) |
# |----------|-----------|---------|------------------------------|
# | A        | 1 kg      | 10 m    | 0 m/s                        |
# | B        | 2 kg      | 10 m    | 0 m/s                        |
# | C        | 1 kg      | 20 m    | 0 m/s                        |
#
# **Deine Aufgaben:**
#
# 1. Berechne für jedes Szenario die **Anfangsenergie** (E_anfang)
# 2. Berechne für jedes Szenario die **Endgeschwindigkeit** am Boden (v_boden)
#    - **Hinweis:** Nutze die Energieerhaltung: $$E_{anfang} = \frac{1}{2} m v^2$$
# 3. Erstelle eine Vergleichstabelle mit den Ergebnissen
# 4. Schreibe eine kurze Analyse: Wie beeinflusst die Masse die Endgeschwindigkeit? Wie beeinflusst die Höhe?
#
# ### Startcode

# %%
# Aufgabe 3: Vergleich verschiedener Szenarien

# Szenarien definieren
szenarien = {
    'A': {'m': 1, 'h': 10, 'v0': 0},
    'B': {'m': 2, 'h': 10, 'v0': 0},
    'C': {'m': 1, 'h': 20, 'v0': 0}
}

g = 10  # Erdbeschleunigung in m/s²

# TODO: Erstelle eine leere Liste oder ein Dictionary für die Ergebnisse
# ergebnisse = {}

# TODO: Schleife durch alle Szenarien
# for name, params in szenarien.items():
#     m = params['m']
#     h = params['h']
#     v0 = params['v0']
#
#     # TODO: Berechne die Anfangsenergie
#     E_anfang = 0.5 * m * v0**2 + m * g * h
#
#     # TODO: Berechne die Endgeschwindigkeit mit Energieerhaltung
#     # E_anfang = 0.5 * m * v_boden²
#     # v_boden = np.sqrt(2 * E_anfang / m)
#
#     # TODO: Speichere die Ergebnisse
#     # ergebnisse[name] = {'E_anfang': E_anfang, 'v_boden': v_boden}

# TODO: Gib eine Vergleichstabelle aus
# print("VERGLEICH DER SZENARIEN")
# print(f"{'Szenario':<10} {'Masse (kg)':<15} {'Höhe (m)':<12} {'E_anfang (J)':<18} {'v_boden (m/s)':<15}")
# print("-" * 70)
# for name, params in szenarien.items():
#     print(f"{name:<10} {params['m']:<15} {params['h']:<12} {ergebnisse[name]['E_anfang']:<18.1f} {ergebnisse[name]['v_boden']:<15.2f}")

# TODO: Schreibe eine Analyse:
# - Vergleich Szenario A und B: Welche Auswirkung hat die Verdopplung der Masse?
# - Vergleich Szenario A und C: Welche Auswirkung hat die Verdopplung der Höhe?

# %% [markdown]
# ### Reflexionsfragen
#
# - Warum hat die Verdopplung der Masse in Szenario B **keine Auswirkung** auf die Endgeschwindigkeit (im Vergleich zu Szenario A)?
# - **Hinweis:** Schau dir die Formeln an – wie kürzen sich die Massen?
#
# ---
#
# ## 🔧 Aufgabe 4: Achterbahn mit Reibung
#
# ### Ziel der Aufgabe
# Du sollst verstehen, wie **Reibung** die Energieerhaltung beeinflusst und warum reale Systeme nicht unbegrenzt lange funktionieren.
#
# ### Aufgabenstellung
#
# Ein Wagen mit Masse m = 500 kg startet auf einer Achterbahn in einer Höhe von h₀ = 30 m mit Geschwindigkeit v₀ = 0 m/s.
#
# Die Achterbahn hat ein **sinusförmiges Höhenprofil**:
# $$h_{strecke}(x) = 15 \cdot \sin(\pi \cdot x / 100)$$
#
# wobei x die Strecke in Metern ist (0 bis 100 m).
#
# **Deine Aufgaben:**
#
# 1. Simuliere die Bewegung des Wagens **ohne Reibung**
# 2. Simuliere die Bewegung des Wagens **mit Reibung** (Reibungskoeffizient: μ = 0.01)
# 3. Vergleiche die beiden Szenarien in einem Diagramm:
#    - **Plot 1:** Geschwindigkeit entlang der Strecke (mit und ohne Reibung)
#    - **Plot 2:** Verfügbare Energie entlang der Strecke (mit und ohne Reibung)
# 4. Bestimme: An welcher Position kommt der Wagen mit Reibung zum Stehen?
#
# ### Startcode

# %%
# Aufgabe 4: Achterbahn mit Reibung

import matplotlib.pyplot as plt
import numpy as np

# Parameter
m = 500       # Masse in kg
g = 10        # Erdbeschleunigung in m/s²
h0 = 30       # Starthöhe in Meter
v0 = 0        # Anfangsgeschwindigkeit in m/s

# Strecke und Höhenprofil
x = np.linspace(0, 100, 1000)  # 100 Meter Strecke
h_strecke = 15 * np.sin(np.pi * x / 100)  # Höhenprofil

# Anfangsenergie
E_anfang = 0.5 * m * v0**2 + m * g * h0

# TODO: Szenario 1 – OHNE Reibung
# Die verfügbare Energie ist überall gleich
# E_verfuegbar_ohne_reibung = E_anfang (konstant)

# TODO: Berechne die kinetische Energie und Geschwindigkeit ohne Reibung
# E_kin_ohne = np.maximum(E_verfuegbar_ohne_reibung - m * g * h_strecke, 0)
# v_ohne = np.sqrt(2 * E_kin_ohne / m)

# TODO: Szenario 2 – MIT Reibung
# Der Reibungsverlust ist proportional zur zurückgelegten Strecke
# E_reibung = mu * m * g * x
# E_verfuegbar_mit_reibung = E_anfang - E_reibung

mu = 0.01  # Reibungskoeffizient

# TODO: Berechne die Energie mit Reibung
# E_reibung = mu * m * g * x
# E_verfuegbar_mit_reibung = np.maximum(E_anfang - E_reibung, 0)
# E_kin_mit = np.maximum(E_verfuegbar_mit_reibung - m * g * h_strecke, 0)
# v_mit = np.sqrt(2 * E_kin_mit / m)

# TODO: Finde die Position, wo der Wagen mit Reibung zum Stehen kommt
# (Hinweis: Wo wird E_kin_mit zu 0?)

# TODO: Erstelle ein Vergleichs-Diagramm mit 2 Subplots
# fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Plot 1: Geschwindigkeit
# axes[0].plot(x, v_ohne, 'b-', linewidth=2, label='Ohne Reibung')
# axes[0].plot(x, v_mit, 'r-', linewidth=2, label='Mit Reibung (μ=0.01)')
# axes[0].set_xlabel('Strecke (m)')
# axes[0].set_ylabel('Geschwindigkeit (m/s)')
# axes[0].legend()
# axes[0].grid(True, alpha=0.3)
# axes[0].set_title('Vergleich: Reibungseffekt auf Geschwindigkeit')

# Plot 2: Verfügbare Energie
# axes[1].plot(x, E_verfuegbar_ohne_reibung, 'b-', linewidth=2, label='Ohne Reibung')
# axes[1].plot(x, E_verfuegbar_mit_reibung, 'r-', linewidth=2, label='Mit Reibung')
# axes[1].set_xlabel('Strecke (m)')
# axes[1].set_ylabel('Verfügbare Energie (Joule)')
# axes[1].legend()
# axes[1].grid(True, alpha=0.3)
# axes[1].set_title('Energieverlust durch Reibung')

# plt.tight_layout()
# plt.show()

# Lösungshinweis:
# - Vergleiche die beiden Kurven
# - Der Reibungswert ist klein (μ = 0.01), aber über 100 Meter summiert sich der Verlust auf

# %% [markdown]
# ### Reflexionsfragen
#
# - Wie weit kommt der Wagen mit Reibung, bevor er stehen bleibt?
# - Wie viel Energie verliert der Wagen durch Reibung insgesamt?
# - Was würde passieren, wenn der Reibungskoeffizient doppelt so hoch (μ = 0.02) wäre?
#
# ---
#
# ## 🔧 Aufgabe 5: Eigenes Projekt – Das springende Ball-Experiment
#
# ### Ziel der Aufgabe
# Nutze dein Verständnis von Energie, um ein eigenes physikalisches Szenario zu simulieren und zu analysieren.
#
# ### Aufgabenstellung
#
# **Szenario:** Ein Ball wird aus einer Höhe von 5 Metern fallen gelassen. Jedes Mal, wenn er auf den Boden prallt, verliert er **20% seiner kinetischen Energie** (das ist realistisch wegen der Deformation und des Materials).
#
# **Deine Aufgaben:**
#
# 1. Simuliere die **ersten 3 Sprünge** des Balles
# 2. Berechne für jeden Sprung:
#    - Höhe nach dem Prall
#    - Geschwindigkeit beim Aufprall
#    - Geschwindigkeit nach dem Prall
#    - Energieverlust pro Stoß
# 3. Visualisiere die **Flugbahn** des Balles (Höhe über der Zeit)
# 4. Erstelle ein Diagramm, das den **Energieverlust kumulativ** zeigt
#
# ### Startcode

# %%
# Aufgabe 5: Das springende Ball-Experiment

import matplotlib.pyplot as plt
import numpy as np

# Parameter
m = 0.5       # Ballmasse in kg
g = 10        # Erdbeschleunigung in m/s²
h0 = 5        # Anfangshöhe in Meter
energie_verlust = 0.2  # 20% Energieverlust pro Stoß

# TODO: Speichere Zeit, Höhe und Energie für alle Sprünge
# Nutze Listen: zeiten = [], hoehen = [], energien = []

# TODO: Schleife für jeden Sprung (z.B. 3 Sprünge)
# Für jeden Sprung:
# - Berechne Aufprallgeschwindigkeit: v_auf = sqrt(2 * g * h)
# - Berechne Aufprallenergie: E_auf = 0.5 * m * v_auf²
# - Berechne Energie nach Prall: E_nach = E_auf * (1 - energie_verlust)
# - Berechne Höhe nach Prall: h_neu = E_nach / (m * g)
# - Speichere die Werte

# TODO: Visualisierung
# fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Plot 1: Flugbahn (Höhe über Zeit)
# axes[0].plot(zeiten, hoehen, 'o-', linewidth=2, markersize=5)
# axes[0].set_xlabel('Zeit (s)')
# axes[0].set_ylabel('Höhe (m)')
# axes[0].grid(True, alpha=0.3)
# axes[0].set_title('Springender Ball: Flugbahn')

# Plot 2: Kumulativer Energieverlust
# TODO: Berechne den kumulativen Energieverlust und plotte ihn

# plt.tight_layout()
# plt.show()

# Bonus-Frage:
# - Wie viele Sprünge braucht der Ball, um auf weniger als 1 cm Höhe zu springen?
# - Welche Gesamtenergie verliert der Ball in diesem Prozess?

# %% [markdown]
# ### Reflexionsfragen
#
# - Warum wird die Sprunghöhe nach jedem Prall kleiner?
# - Wie könnte man die Sprunghöhe mathematisch beschreiben? (Hinweis: Geometrische Reihe)
# - Wo geht die "verlorene" Energie hin? (Denk an Wärme, Schall, Verformung)
#
# ---
#
# ## 📊 Verständnis-Checkpoint
#
# Beantworte diese Fragen, um dein Verständnis zu überprüfen:
#
# 1. **Energieerhaltung:** Warum bleibt die Gesamtenergie in einem reibungsfreien System konstant, obwohl sich die einzelnen Energieformen ständig ändern?
#
# 2. **Kinetische vs. Potenzielle Energie:** Ein Auto fährt einen Berg hinauf und verliert an Geschwindigkeit. Beschreibe die Energieumwandlung mit Formeln.
#
# 3. **Reibung:** Wie beeinflusst Reibung die Energieerhaltung? Geht Energie verloren?
#
# 4. **Reale Systeme:** Warum kann ein echtes Pendel nicht ewig schwingen, wenn du es anstößt?
#
# 5. **Dimensionsanalyse:** Überprüfe, dass die Einheiten in den Formeln stimmen. Beispiel: $$E = \frac{1}{2} m v^2$$ sollte Joule ergeben (kg·m²/s²).
#
# ---
#
# ## 💡 Tipps zum Programmieren
#
# - Nutze **NumPy** für Arrays und mathematische Funktionen
# - Nutze **Matplotlib** für Visualisierungen
# - **Kommentiere deinen Code** – erkläre, was du machst
# - **Teste kleine Teile** – schreibe nicht alles auf einmal
# - **Nutze Print-Statements**, um Zwischenergebnisse zu überprüfen
# - **Googel nicht sofort** – versuche erst, die Logik selbst zu durchdenken
#
# ---
#
# ## 🌐 Weiterführende Ressourcen
#
# - **NumPy-Dokumentation – Mathematical functions**: https://numpy.org/doc/stable/reference/routines.math.html
# - **Matplotlib-Dokumentation – Pyplot**: https://matplotlib.org/stable/api/pyplot_summary.html
# - **PhET – Energy Skate Park**: https://phet.colorado.edu/en/simulations/filter?subjects=physics&types=html,prototype&keywords=energy
# - **Khan Academy – Energy Worksheets**: https://www.khanacademy.org/science/ap-physics-1
# - **Real Python – NumPy Tutorial**: https://realpython.com/numpy-array-programming/
#
# ---
#
# ## 🎯 Zusammenfassung: Was du gelernt hast
#
# Nach dieser Aufgabensammlung solltest du in der Lage sein:
#
# ✅ Kinetische und potenzielle Energie zu berechnen
# ✅ Das Prinzip der Energieerhaltung anzuwenden
# ✅ Physikalische Szenarien in Python zu simulieren
# ✅ Ergebnisse mit Matplotlib zu visualisieren
# ✅ Reale Effekte wie Reibung in Modellen zu berücksichtigen
# ✅ Deine Simulationen zu interpretieren und Schlussfolgerungen zu ziehen
#
# **Viel Erfolg beim Programmieren! 🚀**
