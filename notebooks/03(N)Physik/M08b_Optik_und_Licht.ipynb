# %% [markdown]
# # Physik Modul 8b – Optik und Licht: Übungsaufgaben mit Hinweisen
#
# ## 🎯 Lernziele für diese Übung
#
# In dieser Sitzung werdet ihr:
#
# - **Reflexions- und Brechungsgesetze anwenden** durch Python-Simulationen
# - **Linsengleichungen selbst programmieren** und Bildpositionen berechnen
# - **Ray-Tracing-Algorithmen verstehen** und umsetzen
# - **Optische Systeme analysieren** und visualisieren
# - **Kritisch denken:** Vorhersagen machen und mit Simulationen vergleichen
#
# ---
#
# ## 🔬 Aufgabe 1: Reflexionsgesetz – Interaktive Parametervariationen
#
# ### Ziel der Aufgabe
#
# Ihr werden ein Spiegelungssystem programmieren, bei dem ihr den **Einfallswinkel verändern** könnt und die **Reflexion live** visualisiert. Danach überprüft ihr, ob das Reflexionsgesetz erfüllt ist.
#
# ### Aufgabenstellung
#
# Schreibt ein Python-Programm, das:
# 1. Einen **horizontalen Spiegel** zeichnet
# 2. Einen **einstellbaren Einfallswinkel** akzeptiert (zwischen 0° und 80°)
# 3. Einen **roten Strahl** (einfallend) und einen **grünen Strahl** (reflektiert) zeigt
# 4. Die **Winkel beschriftet**
# 5. **Überprüft**, ob θ₁ = θ₂
#
# ### Hinweis
#
# Nutzt die Struktur aus M08a (Demo 1) als Vorlage. Verwendet `numpy.radians()` und `numpy.cos()` / `numpy.sin()` für die Geometrie.
#
# ### Vorbereiteter Code-Rahmen

# %%
import matplotlib.pyplot as plt
import numpy as np

# TODO: Definiere hier den Einfallswinkel (in Grad)
theta_einfallswinkel = 30  # Beispiel: ändere diesen Wert!

# TODO: Erstelle eine Figur mit matplotlib
# fig, ax = plt.subplots(...)

# TODO: Zeichne den Spiegel
# Hinweis: Horizontal von -3 bis +3

# TODO: Zeichne die Normale (Lotrechte)
# Hinweis: Nutze ax.arrow() oder ax.plot() mit Linientyp '--'

# TODO: Berechne den einfallenden Strahl
# Hinweis: x = -2 * sin(theta), y = 2 * cos(theta)

# TODO: Berechne den reflektierten Strahl
# Hinweis: Der Reflexionswinkel = Einfallswinkel

# TODO: Zeichne beide Strahlen (unterschiedliche Farben!)

# TODO: Beschrifte die Winkel im Plot

# TODO: Füge ax.set_xlim(), ax.set_ylim(), ax.set_aspect('equal') hinzu

# TODO: Überprüfe das Reflexionsgesetz
print(f"Einfallswinkel: {theta_einfallswinkel}°")
print(f"Reflexionswinkel: TODO - berechne die entsprechende Variable")
print(f"Sind sie gleich? TODO - vergleiche die Werte")

plt.show()

# %% [markdown]
# ### Verständnisfragen
#
# 1. **Warum ist der Reflexionswinkel gleich dem Einfallswinkel?** (Hinweis: Denk an die Symmetrie der Oberfläche)
# 2. **Was passiert, wenn der Einfallswinkel 0° ist?** Teste es!
# 3. **Kann der Einfallswinkel 90° sein?** Was bedeutet das physikalisch?
#
# ### Lösungshinweis
#
# Die Reflexion ist **symmetrisch zur Normalen**. Wenn der Einfallsstrahl von links oben kommt, geht der reflektierte Strahl nach rechts oben – beide bilden den gleichen Winkel mit der Normalen.
#
# ---
#
# ## 🔬 Aufgabe 2: Brechungsgesetz – Materialwechsel
#
# ### Ziel der Aufgabe
#
# Ihr werdet das **Brechungsgesetz von Snellius** praktisch anwenden: Wenn Licht von **Luft in Wasser** (oder Glas) übergeht, wird es **gebrochen**. Ihr sollt den **Brechungswinkel berechnen** und **visualisieren**.
#
# ### Aufgabenstellung
#
# Schreibt ein Programm, das:
# 1. Eine **Grenzfläche** zwischen zwei Medien zeichnet (oben: Luft, unten: Wasser)
# 2. Einen **Einfallswinkel von 45°** (in Luft) akzeptiert
# 3. Mit **Snellius' Gesetz** den Brechungswinkel berechnet: $$n_1 \sin(\theta_1) = n_2 \sin(\theta_2)$$
# 4. Beide Strahlen zeichnet und die **Winkel beschriftet**
# 5. Die **Brechungsindizes anzeigt** (Luft: 1,0; Wasser: 1,33)
#
# ### Hinweis
#
# Nutzt die Struktur aus M08a (Demo 2) als Vorlage. Die Formel umgestellt:
#
# $$\theta_2 = \arcsin\left(\frac{n_1}{n_2} \sin(\theta_1)\right)$$
#
# Nutzt `numpy.arcsin()` und `numpy.degrees()` zur Umrechnung.
#
# ### Vorbereiteter Code-Rahmen

# %%
import matplotlib.pyplot as plt
import numpy as np

# Brechungsindizes
n1 = 1.0   # Luft
n2 = 1.33  # Wasser (TODO: probiere auch n2 = 1.5 für Glas!)

# Einfallswinkel
theta1_grad = 45  # Grad

# TODO: Berechne den Brechungswinkel theta2 mit Snellius' Gesetz
# Formel: theta2_rad = arcsin((n1 / n2) * sin(theta1_rad))
# Hinweis: Konvertiere zuerst zu Radianten (np.radians), dann zurück zu Grad (np.degrees)

# TODO: Erstelle ein Plot mit Grenzfläche (horizontal, schwarz, dick)

# TODO: Färbe die zwei Medien unterschiedlich
# Hinweis: ax.fill_between() für die Hintergründe

# TODO: Zeichne die Normale (gestrichelt, grau)

# TODO: Berechne und zeichne den einfallenden Strahl (ROT)

# TODO: Berechne und zeichne den gebrochenen Strahl (ORANGE)

# TODO: Beschrifte die Winkel und Brechungsindizes

# TODO: Überprüfe Snellius' Gesetz
print(f"n1 * sin(theta1) = {n1} * sin({theta1_grad}°) = {n1 * np.sin(np.radians(theta1_grad)):.4f}")
print(f"n2 * sin(theta2) = {n2} * sin(theta2) = TODO")
print(f"Differenz: TODO (sollte ≈ 0 sein)")

plt.show()

# %% [markdown]
# ### Verständnisfragen
#
# 1. **Beobachte:** Wird das Licht zum Lot hin oder vom Lot weg gebrochen? **Warum?**
# 2. **Experiment:** Ändere n2 auf 1,5 (Glas). Wird die Brechung stärker oder schwächer?
# 3. **Grenzwinkel:** Bei welchem Einfallswinkel könnte **Totalreflexion** auftreten? (Bonus-Frage)
#
# ### Lösungshinweis
#
# Luft (n₁ = 1,0) ist **optisch dünner** als Wasser (n₂ = 1,33). Das Licht wird daher **zum Lot hin gebrochen** (der Winkel wird kleiner).
#
# ---
#
# ## 🔬 Aufgabe 3: Linsenschleiferformel – Bildberechnung
#
# ### Ziel der Aufgabe
#
# Ihr werdet die **Linsenschleiferformel** programmieren und damit die **Bildposition und Vergrößerung** berechnen. Dann visualisiert ihr Gegenstand, Linse und Bild.
#
# ### Aufgabenstellung
#
# Schreibt ein Programm, das:
# 1. **Gegenstandsweite g** und **Brennweite f** als Eingaben akzeptiert (z.B. g = 5, f = 2)
# 2. Mit der **Linsenschleiferformel** die **Bildweite b** berechnet:
#
# $$\frac{1}{f} = \frac{1}{g} + \frac{1}{b} \quad \Rightarrow \quad b = \frac{1}{\frac{1}{f} - \frac{1}{g}}$$
#
# 3. Die **Vergrößerung** berechnet: $$V = \frac{b}{g}$$
# 4. Eine **Linse, Gegenstand und Bild visualisiert**
# 5. **Überprüft**, ob die Linsenschleiferformel erfüllt ist
#
# ### Hinweis
#
# Nutzt die Struktur aus M08a (Demo 3) als Vorlage. Achtet auf den **Defintionsbereich**: Die Formel ist nicht definiert, wenn $$\frac{1}{f} = \frac{1}{g}$$.
#
# ### Vorbereiteter Code-Rahmen

# %%
import matplotlib.pyplot as plt
import numpy as np

# Parameter eingeben
f = 2.0  # Brennweite (Sammellinse: positiv; Zerstreuungslinse: negativ)
g = 5.0  # Gegenstandsweite

# TODO: Berechne die Bildweite b mit der Linsenschleiferformel
# Hinweis: 1/b = 1/f - 1/g

# TODO: Berechne die Vergrößerung V
# Hinweis: V = b / g (negativ = invertiertes Bild)

# TODO: Erstelle ein Plot
# Zeichne die Linse (vertikal, z.B. von y = -2 bis y = 2)

# TODO: Markiere die Brennpunkte (rote Punkte bei x = f und x = -f)

# TODO: Zeichne den Gegenstand (grüner Pfeil bei x = -g)

# TODO: Zeichne das Bild (blauer Pfeil bei x = b)
# Hinweis: Die Höhe des Bildes ist Höhe_Gegenstand * V

# TODO: Zeichne Konstruktionsstrahlen (z.B. parallel zur Achse → durch Brennpunkt)

# TODO: Beschrifte alle wichtigen Punkte und Abstände

# TODO: Überprüfe die Linsenschleiferformel
print(f"Brennweite f: {f}")
print(f"Gegenstandsweite g: {g}")
print(f"Bildweite b: {b:.2f}")
print(f"Vergrößerung V: {V:.2f}")
print(f"1/f = {1/f:.4f}")
print(f"1/g + 1/b = {1/g + 1/b:.4f}")
print(f"Differenz: TODO (sollte ≈ 0 sein)")

plt.show()

# %% [markdown]
# ### Verständnisfragen
#
# 1. **Was ist der Unterschied zwischen einem reellen und einem virtuellen Bild?** (Hinweis: Schau auf das Vorzeichen von b)
# 2. **Experiment:** Ändere g auf 1,5 (sehr nah an der Linse). Was passiert mit der Bildweite?
# 3. **Wann ist V = 1?** Das Bild hat die gleiche Größe wie der Gegenstand. Bei welcher Geometrie?
#
# ### Lösungshinweis
#
# - **Reelles Bild:** b > 0 (wird auf einem Schirm projiziert)
# - **Virtuelles Bild:** b < 0 (entsteht hinter der Linse, nur sichtbar durch die Linse)
# - **Vergrößerung:** V > 1 = Vergrößerung, V < 1 = Verkleinerung, V < 0 = invertiertes Bild
#
# ---
#
# ## 🔬 Aufgabe 4: Ray-Tracing – Mehrere Strahlen
#
# ### Ziel der Aufgabe
#
# Ihr werdet ein **Ray-Tracing-Programm** schreiben, das **mehrere Lichtstrahlen** durch eine Linse verfolgt. Dies ist die Basis für Computergrafik und optische Simulationen!
#
# ### Aufgabenstellung
#
# Schreibt ein Programm, das:
# 1. Eine **Sammellinse** mit bekannter Brennweite zeichnet
# 2. Ein **Gitter von Lichtstrahlen** parallel zur optischen Achse zeichnet
# 3. Jeden Strahl **bricht** (biegt), sodass er durch den Brennpunkt geht (oder von ihm zu kommen scheint)
# 4. Alle **Strahlenverläufe** in der Grafik anzeigt
# 5. Das **Bildpunkt-Konvergenzverhalten** visualisiert
#
# ### Hinweis
#
# Für einen Strahl in der Höhe h:
# - **Vor der Linse (x < 0):** Strahl parallel zur Achse (Steigung = 0)
# - **Nach der Linse (x > 0):** Strahl geht durch den Brennpunkt
#
# Die **Steigung nach der Brechung** ist:
# $$m = -\frac{h}{f}$$
#
# (negativ, weil der Strahl vom oberen zum unteren Bereich geht)
#
# ### Vorbereiteter Code-Rahmen

# %%
import matplotlib.pyplot as plt
import numpy as np

# Parameter
f = 2.0  # Brennweite
num_strahlen = 7  # Anzahl der Lichtstrahlen

# TODO: Erstelle ein Plot

# TODO: Zeichne die Linse

# TODO: Markiere die Brennpunkte

# TODO: Schleife über mehrere Strahlenhöhen
# Hinweis: h von -2.0 bis +2.0, verteilt auf num_strahlen Strahlen

# TODO: Für jeden Strahl:
#    a) Zeichne den einfallenden Strahl (parallel zur Achse, von links)
#    b) Berechne die Steigung nach der Brechung: m = -h / f
#    c) Zeichne den gebrochenen Strahl (durch den Brennpunkt, nach rechts)

# TODO: Beschrifte die Brennpunkte

# TODO: Achsen-Einstellungen (axhline, grid, etc.)

plt.show()

print(f"Ray-Tracing abgeschlossen!")
print(f"Alle {num_strahlen} Strahlen konvergieren im Brennpunkt bei x = {f}")

# %% [markdown]
# ### Verständnisfragen
#
# 1. **Warum konvergieren alle Strahlen im gleichen Punkt?** (Die Brennpunkt-Eigenschaft)
# 2. **Was würde mit den Strahlen passieren, wenn du eine **Zerstreuungslinse (f < 0)** nutzt?**
# 3. **Bonus:** Wie könntest du das Ray-Tracing auf **zwei Linsen hintereinander** erweitern?
#
# ### Lösungshinweis
#
# Das Ray-Tracing funktioniert nach dem Prinzip: **Parallel einfallende Strahlen werden von einer Sammellinse im Brennpunkt fokussiert.** Dies ist die grundlegende Eigenschaft von Linsen und wird in Kameras, Teleskopen und Lasern genutzt.
#
# ---
#
# ## 🔬 Aufgabe 5: Materialabhängigkeit – Vergleich Luft, Wasser, Glas
#
# ### Ziel der Aufgabe
#
# Ihr werdet **vergleichen**, wie Licht sich in verschiedenen Materialien unterschiedlich bricht. Ihr erstellt eine **Visualisierung mit 3 Szenen nebeneinander**.
#
# ### Aufgabenstellung
#
# Schreibt ein Programm, das:
# 1. **Drei Subplots** erstellt (für Luft, Wasser, Glas)
# 2. In jedem Subplot eine **Grenzfläche** mit dem entsprechenden Material zeichnet
# 3. Den **gleichen Einfallswinkel (45°)** für alle drei nutzt
# 4. Die **Brechungswinkel berechnet und vergleicht**
# 5. Eine **Tabelle mit den Ergebnissen** ausgibt
#
# ### Hinweis
#
# Brechungsindizes:
# - **Luft → Luft:** n₁ = 1,0, n₂ = 1,0 (keine Brechung!)
# - **Luft → Wasser:** n₁ = 1,0, n₂ = 1,33
# - **Luft → Glas:** n₁ = 1,0, n₂ = 1,5
#
# ### Vorbereiteter Code-Rahmen

# %%
import matplotlib.pyplot as plt
import numpy as np

# Brechungsindizes für verschiedene Materialien
materialien = {
    "Luft→Luft": (1.0, 1.0),
    "Luft→Wasser": (1.0, 1.33),
    "Luft→Glas": (1.0, 1.5)
}

einfallswinkel = 45  # Grad

# TODO: Erstelle 3 Subplots nebeneinander
# fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# TODO: Für jedes Material (schleife durch die Dictionaries):
#   a) Berechne den Brechungswinkel
#   b) Zeichne die Grenzfläche, Normale und beide Strahlen
#   c) Beschrifte Winkel und Material

# TODO: Gib eine Tabelle aus mit:
#   - Materialpaar
#   - n1, n2
#   - Einfallswinkel
#   - Brechungswinkel
#   - Unterschied (wie stark die Brechung ist)

plt.show()

print("\n=== Vergleich der Brechung in verschiedenen Materialien ===")
# TODO: Tabellen-Print erstellen

# %% [markdown]
# ### Verständnisfragen
#
# 1. **Warum ist die Brechung bei Glas (n=1,5) stärker als bei Wasser (n=1,33)?**
# 2. **Was würde bei Luft→Luft passieren?** (Teste es!)
# 3. **Kann man Totalreflexion auch in Luft→Wasser beobachten?** (Bonusfrage)
#
# ### Lösungshinweis
#
# Je größer der Unterschied zwischen n₁ und n₂, desto stärker die Brechung. Dies ist die Basis für **optische Instrumente** wie Prismen und Spektroskope.
#
# ---
#
# ## 📊 Reflexionsfragen am Ende der Übung
#
# Beantwortet diese Fragen schriftlich:
#
# 1. **Reflexion vs. Brechung:** Welcher Prozess findet statt, wenn Licht auf einen Spiegel trifft? Welcher, wenn es ins Wasser fällt?
#
# 2. **Brennweite und Vergrößerung:** Eine Lupe hat eine kleine Brennweite (z.B. f = 5 cm). Ein Teleskop-Objektiv hat eine große Brennweite (z.B. f = 1000 cm). Wer vergrößert mehr?
#
# 3. **Ray-Tracing in der Praxis:** Wo werden Ray-Tracing-Algorithmen in der echten Welt verwendet? (Hinweis: Denk an Kameras, Teleskope, Computer-Grafik)
#
# 4. **Licht und Farben:** In dieser Aufgabe haben wir angenommen, dass Licht aller Farben gleich gebrochen wird. Stimmt das? (Hinweis: Dispersion, Regenbogen)
#
# ---
#
# ## 🎯 Checkliste – Habe ich alles geschafft?
#
# - ☐ Aufgabe 1: Reflexionsgesetz implementiert und getestet
# - ☐ Aufgabe 2: Brechungsgesetz für mindestens ein Materialpaar berechnet
# - ☐ Aufgabe 3: Linsenschleiferformel getestet und visualisiert
# - ☐ Aufgabe 4: Ray-Tracing mit mehreren Strahlen programmiert
# - ☐ Aufgabe 5: Vergleich von 3 Materialien erstellt
# - ☐ Alle Verständnisfragen beantwortet
# - ☐ Reflexionsfragen schriftlich beantwortet
# - ☐ Code dokumentiert (Kommentare, aussagekräftige Variablennamen)
#
# ---
#
# ## 💡 Tipps für erfolgreiche Programmierung
#
# 1. **Startet klein:** Macht zuerst nur ein einfaches Plot (Spiegel + Einfallstrahl) und erweitert es dann.
#
# 2. **Nutzt aussagekräftige Variablennamen:** `theta_einfallswinkel` statt nur `t`
#
# 3. **Testet schrittweise:** Nach jedem `ax.plot()` führt den Code aus und schaut, ob es richtig aussieht.
#
# 4. **Konvertiert Einheiten:** Viele Funktionen brauchen Radianten, nicht Grad! (`np.radians()`, `np.degrees()`)
#
# 5. **Debuggen mit `print()`:** Gibt regelmäßig Zwischenergebnisse aus (z.B. berechnete Winkel).
#
# 6. **Die Matplotlib-Doku ist eure Freundin:** Schaut dort nach, wie ihr Pfeile, Linien und Text zeichnet!
#
# ---
#
# ## 🔗 Weiterführende Links
#
# - **[Matplotlib – Arrows, Lines & Shapes](https://matplotlib.org/stable/api/_as_gen/matplotlib.patches.FancyArrow.html)** – Für komplexere Grafiken
# - **[NumPy – Trigonometrische Funktionen](https://numpy.org/doc/stable/reference/routines.math.html)** – sin, cos, arcsin, etc.
# - **[PhET – Optik-Simulationen](https://phet.colorado.edu/en/simulations/?filter=light)** – Zum Vergleichen eurer Ergebnisse
# - **[Wikipedia – Snellius' Gesetz](https://de.wikipedia.org/wiki/Snelliussches_Brechungsgesetz)** – Theoretischer Hintergrund
# - **[GeoGebra – Interaktive Optik-Applets](https://www.geogebra.org/search/optik)** – Visualisierungen zum Spielen
#
# ---
#
# **Ende der Übungsdatei M08b**
