# %% [markdown]
# # M01b – Kinematik: Bewegung beschreiben – Übungsaufgaben mit Hinweisen
#
# ## Einleitung
#
# In diesem Modul wirst du die Konzepte der Kinematik **aktiv trainieren**. Löse die Aufgaben schrittweise und nutze Python, um deine Ergebnisse zu überprüfen. Jede Aufgabe hat einen Lösungshinweis – versuche zuerst ohne, schau aber hin, wenn du nicht weiterkommst.
#
# ---
#
# ## Aufgabe 1: Ort und Verschiebung berechnen
#
# ### Aufgabenstellung
#
# Ein Zugfahrer notiert die Position des Zuges an verschiedenen Haltestellen:
# - Station A: 12 km (vom Startpunkt gemessen)
# - Station B: 45 km
# - Station C: 52 km
# - Station D: 38 km (der Zug musste zurückfahren!)
#
# **Berechne:**
# 1. Die Verschiebung von A zu B
# 2. Die Verschiebung von B zu C
# 3. Die Verschiebung von C zu D
# 4. Die **Gesamtverschiebung** von A zu D
# 5. Den **Gesamtweg**, den der Zug zurückgelegt hat
#
# ### Code-Vorlage

# %%
# Positionen der Haltestellen (in km)
pos_A = 12
pos_B = 45
pos_C = 52
pos_D = 38

# TODO: Verschiebung A zu B berechnen
verschiebung_A_zu_B = # ... dein Code hier

# TODO: Verschiebung B zu C berechnen
verschiebung_B_zu_C = # ... dein Code hier

# TODO: Verschiebung C zu D berechnen
verschiebung_C_zu_D = # ... dein Code hier

# TODO: Gesamtverschiebung A zu D berechnen
gesamtverschiebung = # ... dein Code hier

# TODO: Gesamtweg berechnen (Summe aller einzelnen Strecken!)
gesamtweg = # ... dein Code hier

# Ausgabe
print(f"Verschiebung A zu B: {verschiebung_A_zu_B} km")
print(f"Verschiebung B zu C: {verschiebung_B_zu_C} km")
print(f"Verschiebung C zu D: {verschiebung_C_zu_D} km")
print(f"Gesamtverschiebung: {gesamtverschiebung} km")
print(f"Gesamtweg: {gesamtweg} km")

# %% [markdown]
# ### Lösungshinweis
#
# > **Hinweis:** Verschiebung = End - Start. Der Gesamtweg ist die **Summe der Beträge** aller einzelnen Strecken. Beachte: Die Strecke von C zu D ist negativ (Rückwärtsbewegung), aber der Weg ist immer positiv!
#
# ### Reflexionsfragen
#
# - Warum ist der Gesamtweg größer als die Gesamtverschiebung?
# - Wann wäre der Gesamtweg gleich der Gesamtverschiebung?
#
# ---
#
# ## Aufgabe 2: Durchschnittsgeschwindigkeit berechnen
#
# ### Aufgabenstellung
#
# Ein Radfahrer fährt folgende Strecke:
# - Von 10:00 Uhr bis 10:20 Uhr: 6 km
# - Von 10:20 Uhr bis 11:00 Uhr: 8 km
#
# **Berechne:**
# 1. Die Durchschnittsgeschwindigkeit in der ersten Phase (m/s und km/h)
# 2. Die Durchschnittsgeschwindigkeit in der zweiten Phase (m/s und km/h)
# 3. Die Gesamtdurchschnittsgeschwindigkeit (m/s und km/h)
#
# ### Code-Vorlage

# %%
# Phase 1: 10:00 bis 10:20 Uhr (20 Minuten)
strecke_1 = 6  # km
zeit_1 = 20    # Minuten

# TODO: Zeit in Sekunden umrechnen
zeit_1_s = # ... dein Code hier

# TODO: Strecke in Meter umrechnen
strecke_1_m = # ... dein Code hier

# TODO: Durchschnittsgeschwindigkeit berechnen (in m/s)
v_avg_1_ms = # ... dein Code hier

# TODO: Umrechnung in km/h (Multiplikation mit 3.6)
v_avg_1_kmh = # ... dein Code hier

print(f"Phase 1: {v_avg_1_ms:.2f} m/s oder {v_avg_1_kmh:.2f} km/h")

# Phase 2: 10:20 bis 11:00 Uhr (40 Minuten)
strecke_2 = 8  # km
zeit_2 = 40    # Minuten

# TODO: Dasselbe für Phase 2 wiederholen
zeit_2_s = # ... dein Code hier
strecke_2_m = # ... dein Code hier
v_avg_2_ms = # ... dein Code hier
v_avg_2_kmh = # ... dein Code hier

print(f"Phase 2: {v_avg_2_ms:.2f} m/s oder {v_avg_2_kmh:.2f} km/h")

# Gesamtdurchschnittsgeschwindigkeit
# TODO: Gesamtstrecke (in km) und Gesamtzeit (in Minuten) berechnen
gesamtstrecke_km = # ... dein Code hier
gesamtzeit_min = # ... dein Code hier

# TODO: Gesamtstrecke und Gesamtzeit in SI-Einheiten umrechnen
gesamtstrecke_m = # ... dein Code hier
gesamtzeit_s = # ... dein Code hier

# TODO: Gesamtdurchschnittsgeschwindigkeit berechnen
v_avg_gesamt_ms = # ... dein Code hier
v_avg_gesamt_kmh = # ... dein Code hier

print(f"\nGesamtdurchschnittsgeschwindigkeit: {v_avg_gesamt_ms:.2f} m/s oder {v_avg_gesamt_kmh:.2f} km/h")

# %% [markdown]
# ### Lösungshinweis
#
# > **Hinweis:**
# > - 1 km = 1000 m
# > - 1 Minute = 60 Sekunden
# > - Um von m/s zu km/h umzurechnen: multipliziere mit 3,6
# > - Gesamtdurchschnittsgeschwindigkeit = Gesamtstrecke / Gesamtzeit (nicht Durchschnitt der Geschwindigkeiten!)
#
# ---
#
# ## Aufgabe 3: Beschleunigung aus Geschwindigkeitsdaten
#
# ### Aufgabenstellung
#
# Ein Auto wird einer Speedtest unterzogen:
# - Nach 2 Sekunden: 10 m/s
# - Nach 5 Sekunden: 25 m/s
# - Nach 8 Sekunden: 22 m/s (Fahrer lässt Gas weg)
#
# **Berechne:**
# 1. Die Beschleunigung in den ersten 2–5 Sekunden
# 2. Die Beschleunigung von 5–8 Sekunden
# 3. Was sagen diese Werte über das Fahrverhalten aus?
#
# ### Code-Vorlage

# %%
# Geschwindigkeitsmessungen
t_1, v_1 = 2, 10      # Zeitpunkt 1: 2 s, Geschwindigkeit 10 m/s
t_2, v_2 = 5, 25      # Zeitpunkt 2: 5 s, Geschwindigkeit 25 m/s
t_3, v_3 = 8, 22      # Zeitpunkt 3: 8 s, Geschwindigkeit 22 m/s

# TODO: Beschleunigung zwischen t_1 und t_2 berechnen
delta_v_1 = # ... dein Code hier
delta_t_1 = # ... dein Code hier
a_1 = # ... dein Code hier

print(f"Beschleunigung (2–5 s): {a_1:.2f} m/s²")

# TODO: Beschleunigung zwischen t_2 und t_3 berechnen
delta_v_2 = # ... dein Code hier
delta_t_2 = # ... dein Code hier
a_2 = # ... dein Code hier

print(f"Beschleunigung (5–8 s): {a_2:.2f} m/s²")

# TODO: Interpretiere die Ergebnisse!
# Frage: Was bedeutet ein positives und ein negatives Beschleunigungsergebnis?

# %% [markdown]
# ### Lösungshinweis
#
# > **Hinweis:**
# > - Positive Beschleunigung = Geschwindigkeit nimmt zu
# > - Negative Beschleunigung (Verzögerung) = Geschwindigkeit nimmt ab
# > - Die Größe der Beschleunigung zeigt, wie schnell die Geschwindigkeit sich ändert
#
# ---
#
# ## Aufgabe 4: Position berechnen – Gleichförmige Bewegung
#
# ### Aufgabenstellung
#
# Ein Zug fährt mit konstanter Geschwindigkeit von 25 m/s. Die Anfangsposition ist 100 m (z.B. ab Bahnhof gemessen).
#
# **Berechne und visualisiere:**
# 1. Die Position nach 2, 5 und 10 Sekunden
# 2. Zeichne ein Zeit-Ort-Diagramm für die ersten 10 Sekunden
#
# Nutze die Formel:
# $$
# s(t) = s_0 + v \cdot t
# $$
#
# ### Code-Vorlage

# %%
import matplotlib.pyplot as plt
import numpy as np

# Gegebene Werte
s_0 = 100      # Startposition in m
v = 25         # Geschwindigkeit in m/s (konstant)

# TODO: Berechne die Position nach 2, 5 und 10 Sekunden
s_nach_2s = # ... dein Code hier
s_nach_5s = # ... dein Code hier
s_nach_10s = # ... dein Code hier

print(f"Position nach 2 s: {s_nach_2s} m")
print(f"Position nach 5 s: {s_nach_5s} m")
print(f"Position nach 10 s: {s_nach_10s} m")

# TODO: Erstelle ein Zeit-Array von 0 bis 10 Sekunden mit 100 Punkten
t = # ... dein Code hier (np.linspace(...))

# TODO: Berechne die Positionen für alle Zeitpunkte
s = # ... dein Code hier

# TODO: Zeichne das Diagramm
plt.figure(figsize=(10, 6))
# ... Code zum Zeichnen der Kurve, Achsenbeschriftung, etc.
plt.show()

# %% [markdown]
# ### Lösungshinweis
#
# > **Hinweis:**
# > - Nutze `np.linspace(0, 10, 100)` um 100 Punkte zwischen 0 und 10 zu erzeugen
# > - Die Formel s = s₀ + v·t funktioniert für jeden Wert von t
# > - Das Diagramm sollte eine **gerade Linie** sein (gleichförmige Bewegung!)
#
# ---
#
# ## Aufgabe 5: Position berechnen – Beschleunigte Bewegung
#
# ### Aufgabenstellung
#
# Ein Skateboarder startet vom Stillstand (v₀ = 0) und fährt auf einer geraden Rampe bergab. Die Beschleunigung ist konstant a = 1,5 m/s².
#
# **Berechne und visualisiere:**
# 1. Die Position nach 1, 2, 3, 4 und 5 Sekunden
# 2. Die Geschwindigkeit nach 1, 2, 3, 4 und 5 Sekunden
# 3. Zeichne beide Diagramme untereinander
#
# Nutze die Formeln:
# $$
# s(t) = v_0 \cdot t + \frac{1}{2} a \cdot t^2
# $$
# $$
# v(t) = v_0 + a \cdot t
# $$
#
# ### Code-Vorlage

# %%
import matplotlib.pyplot as plt
import numpy as np

# Gegebene Werte
s_0 = 0        # Startposition (am Anfang der Rampe)
v_0 = 0        # Anfangsgeschwindigkeit (Stillstand)
a = 1.5        # Beschleunigung in m/s²

# Zeitpunkte (in Sekunden)
zeiten = [1, 2, 3, 4, 5]

print("Berechnung für verschiedene Zeitpunkte:")
print("Zeit (s) | Position (m) | Geschwindigkeit (m/s)")
print("-" * 50)

for t_i in zeiten:
    # TODO: Position berechnen
    s_i = # ... dein Code hier
    
    # TODO: Geschwindigkeit berechnen
    v_i = # ... dein Code hier
    
    print(f"{t_i:7} | {s_i:12.2f} | {v_i:19.2f}")

# Jetzt für die Visualisierung: feinere Zeit-Auflösung
t = np.linspace(0, 5, 100)

# TODO: Position und Geschwindigkeit für alle Zeitpunkte berechnen
s = # ... dein Code hier
v = # ... dein Code hier

# TODO: Zwei Diagramme nebeneinander zeichnen
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Diagramm 1: Position über Zeit
# ... Code hier

# Diagramm 2: Geschwindigkeit über Zeit
# ... Code hier

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Lösungshinweis
#
# > **Hinweis:**
# > - Die Position-Zeit-Kurve ist eine **Parabel** (nicht linear!)
# > - Die Geschwindigkeit-Zeit-Kurve ist eine **Gerade** (zeigt konstante Beschleunigung)
# > - Die Steigung der v(t)-Kurve ist genau die Beschleunigung a
#
# ---
#
# ## Aufgabe 6: Mini-Projekt – Freier Fall simulieren
#
# ### Aufgabenstellung
#
# Simuliere einen **Ball, der aus 100 m Höhe fallen gelassen wird**. Die Fallbeschleunigung auf der Erde ist g = 9,81 m/s².
#
# **Deine Aufgaben:**
# 1. Berechne, wie lange der Ball fällt, bis er den Boden erreicht
# 2. Berechne die Aufprallgeschwindigkeit
# 3. Erstelle drei Diagramme:
#    - Höhe über Zeit
#    - Fallgeschwindigkeit über Zeit
#    - Kinetische Energie über Zeit (Hinweis: E_kin = 0,5 · m · v², mit m = 0,5 kg)
#
# ### Code-Vorlage

# %%
import matplotlib.pyplot as plt
import numpy as np

# Anfangsbedingungen
h_0 = 100      # Anfangshöhe in m
v_0 = 0        # Anfangsgeschwindigkeit (wird losgelassen)
g = 9.81       # Fallbeschleunigung in m/s²
m = 0.5        # Ballmasse in kg

# TODO: Berechne die Fallzeit (Hinweis: h = h_0 - 0,5·g·t²; setze h=0)
# Umformen: t = sqrt(2·h_0 / g)
t_fall = # ... dein Code hier

print(f"Der Ball fällt etwa {t_fall:.2f} Sekunden")

# TODO: Berechne die Aufprallgeschwindigkeit
v_aufprall = # ... dein Code hier (v = g·t)
print(f"Aufprallgeschwindigkeit: {v_aufprall:.2f} m/s")

# Zeitarray für die Simulation
t = np.linspace(0, t_fall, 100)

# TODO: Höhe, Geschwindigkeit und kinetische Energie berechnen
h = # ... dein Code hier
v = # ... dein Code hier
E_kin = # ... dein Code hier

# TODO: Drei Diagramme nebeneinander zeichnen
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

# Diagramm 1: Höhe
# ... Code hier

# Diagramm 2: Geschwindigkeit
# ... Code hier

# Diagramm 3: Kinetische Energie
# ... Code hier

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Lösungshinweis
#
# > **Hinweis:**
# > - Die Höhe nimmt **quadratisch** mit der Zeit ab (parabolische Kurve)
# > - Die Geschwindigkeit nimmt **linear** mit der Zeit zu
# > - Die kinetische Energie nimmt **quadratisch** mit der Zeit zu (weil E ~ v²)
# > - Der Ball erreicht den Boden, wenn h(t) = 0 ist
#
# ---
#
# ## Reflexionsfragen
#
# Beantworte diese Fragen nach jeder Aufgabe:
#
# 1. **Aufgabe 1:** Wie würde sich der Gesamtweg ändern, wenn der Zug alle Haltestellen in einer Linie angefahren hätte?
#
# 2. **Aufgabe 2:** Warum kann man nicht einfach die beiden Geschwindigkeiten addieren und durch 2 teilen?
#
# 3. **Aufgabe 3:** Was würde negative Beschleunigung bei einem Auto bedeuten?
#
# 4. **Aufgabe 4:** Welche Form hat die s(t)-Kurve bei gleichförmiger Bewegung? Warum ist das so?
#
# 5. **Aufgabe 5:** Warum ändert sich die Geschwindigkeit des Skateboarders immer schneller (von 0 auf 1,5 auf 3,0 auf 4,5...)?
#
# 6. **Aufgabe 6:** Was würde mit der Aufprallgeschwindigkeit passieren, wenn der Ball von 200 m statt 100 m fällt? (Tipp: Nutze dein Python-Programm, um das zu testen!)
#
# ---
#
# ## Tipps zum Debuggen
#
# Falls dein Code nicht funktioniert:
#
# 1. **Überprüfe die Einheiten:** Alle Größen in SI-Einheiten (m, s, kg)?
# 2. **Nutze `print()` zum Debuggen:** Gebe Zwischenergebnisse aus!
# 3. **Vergleiche mit den Beispielen:** Sind die Formeln identisch?
# 4. **Syntaxfehler?** Achte auf Klammern, Kommas und Einrückung!
#
# ---
#
# ## Weiterführende Links
#
# - [PhET Simulation – Position, Geschwindigkeit, Beschleunigung](https://phet.colorado.edu/en/simulations/filter?subjects=physics)
# - [Khan Academy – Kinematik (Deutsch)](https://www.khanacademy.org/science/physics)
# - [GeoGebra – Kinematik-Applet](https://www.geogebra.org/search/kinematics)
# - [YouTube – "Bewegungsgleichungen erklärt" (Deutsch)](https://www.youtube.com)
