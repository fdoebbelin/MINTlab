# %% [markdown]
# # M03a: 3D-Objekte kombinieren – Boolesche Operationen (Demonstration)
#
# ## 📌 Einleitung und Lernziel
#
# In diesem Modul lernen Sie, wie in FreeCAD zwei oder mehr **3D-Grundkörper miteinander kombiniert** werden, um komplexere Formen zu erzeugen. Das Prinzip basiert auf **booleschen Operationen** – mathematischen Operationen, die es ermöglichen, Formen zu vereinen, voneinander abzuziehen oder ihre Schnittmengen zu bestimmen.
#
# **Praktisches Beispiel:** Sie können einen Würfel mit einem Zylinder verbinden (Vereinigung) oder einen Zylinder von einem Würfel subtrahieren, um eine Bohrung zu erzeugen – genau wie beim Bohren eines Loches in ein Holzbrett.
#
# ### Warum ist das wichtig?
# Im Maschinenbau und Design ist selten ein Objekt aus nur einer einfachen Grundform aufgebaut. Stattdessen kombiniert man mehrere Formen geschickt, um fertige Bauteile zu gestalten. Mit booleschen Operationen wird dieser Prozess schnell und präzise.
#
# ---
#
# ## 🎯 Lernziele dieses Moduls
#
# Nach diesem Modul können Sie:
# - Das Konzept von **Union (Vereinigung)**, **Difference (Differenz)** und **Intersection (Schnittmenge)** verstehen und erklären
# - Zwei oder mehr Grundkörper in FreeCAD mittels Union zu einem Körper verbinden
# - Mit Difference Löcher oder Aussparungen in Objekte schneiden
# - Objekte vor der Operation gezielt ausrichten
# - Einfache zusammengesetzte Bauteile erstellen (z.B. ein Würfel mit Bohrung)
#
# ---
#
# ## 📖 Theoretische Grundlagen: Boolesche Operationen
#
# ### Was sind Boolesche Operationen?
#
# Boolesche Operationen sind mathematische Verfahren, die zwei Volumenkörper nach geometrischen Regeln kombinieren. Es gibt drei Grundoperationen:
#
# #### **1. Union (Vereinigung)**
# - **Was passiert:** Zwei Körper werden zu einer einzigen Form verschmolzen.
# - **Mathematik:** Alle Punkte, die zu Körper A **oder** zu Körper B gehören, werden zum neuen Körper.
# - **Anwendung:** Würfel + Zylinder oben auf dem Würfel = ein kombiniertes Objekt
# - **Menübefehl in FreeCAD:** `Part → Boolean → Union`
#
# #### **2. Difference (Differenz/Subtraktion)**
# - **Was passiert:** Der erste Körper wird durch den zweiten „ausgehöhlt" oder abgezogen.
# - **Mathematik:** Vom Körper A werden alle Punkte entfernt, die auch in Körper B liegen.
# - **Anwendung:** Würfel − Zylinder = Würfel mit zylindrischem Loch
# - **Menübefehl in FreeCAD:** `Part → Boolean → Difference`
# - ⚠️ **Wichtig:** Die Reihenfolge ist entscheidend! (Würfel − Zylinder ≠ Zylinder − Würfel)
#
# #### **3. Intersection (Schnittmenge)**
# - **Was passiert:** Nur der Bereich, wo beide Körper sich überlappen, bleibt erhalten.
# - **Mathematik:** Nur Punkte, die zu **beide** Körpern gehören, verbleiben.
# - **Anwendung:** Findet die gemeinsame Schnittfläche zweier Objekte
# - **Menübefehl in FreeCAD:** `Part → Boolean → Intersection`
# - 💡 **Hinweis:** Wird seltener verwendet als Union und Difference
#
# ---
#
# ## 🔧 Praktische Anwendung in FreeCAD
#
# ### Schritt-für-Schritt: Würfel mit Bohrung erstellen (Difference-Beispiel)
#
# #### **Vorbereitung: Part-Arbeitsbereich aktivieren**
#
# ```freecad-code
# # Im Part-Arbeitsbereich arbeiten
# # Menüpfad: Workbench → Part
# # Oder in der Arbeitsbereich-Auswahlliste oben rechts „Part" auswählen
# ```
#
# Die **Part Workbench** ist der Arbeitsbereich für Boolesche Operationen. Hier finden Sie alle notwendigen Werkzeuge.
#
# ---
#
# ### **Beispiel 1: Bohrung in einen Würfel (Difference-Operation)**
#
# **Ziel:** Ein 10×10×10 mm großer Würfel mit einem zylindrischen Loch (Durchmesser 4 mm) in der Mitte.
#
# #### Schritt 1: Würfel erzeugen
#
# ```freecad-code
# # Menüpfad: Part → Create primitives → Box
# #
# # Im Dialog:
# # - Length (X): 10 mm
# # - Width (Y): 10 mm
# # - Height (Z): 10 mm
# # - Position: x=0, y=0, z=0
# #
# # ✓ Klick auf „Create" oder „OK"
# ```
#
# **Ergebnis:** Ein Würfel namens „Box" erscheint im Modellbaum links und im 3D-Bereich.
#
# #### Schritt 2: Zylinder erzeugen (für die Bohrung)
#
# Der Zylinder muss so positioniert sein, dass er **durch den Würfel hindurchgeht**.
#
# ```freecad-code
# # Menüpfad: Part → Create primitives → Cylinder
# #
# # Im Dialog:
# # - Radius: 2 mm (Durchmesser = 4 mm)
# # - Height: 15 mm (größer als Würfel-Höhe, damit er oben und unten herausschaut)
# # - Position: x=5, y=5, z=-2.5
# #   (Zylinder ist in der Mitte horizontal [x=5, y=5] und ragt oben/unten über den Würfel hinaus)
# #
# # ✓ Klick auf „Create" oder „OK"
# ```
#
# **Ergebnis:** Ein Zylinder namens „Cylinder" wird erzeugt. Sie sehen jetzt Würfel und Zylinder übereinander im 3D-Bereich.
#
# #### Schritt 3: Boolesche Operation (Difference) ausführen
#
# Jetzt werden die beiden Objekte kombiniert: Der Zylinder wird vom Würfel subtrahiert.
#
# ```freecad-code
# # Menüpfad: Part → Boolean → Difference
# #
# # Im Dialog oder Eigenschaftspanel:
# # - Base (Basis-Körper): Box (der Würfel – das bleibt erhalten)
# # - Tool (Werkzeug – wird abgezogen): Cylinder (der Zylinder – wird subtrahiert)
# #
# # ✓ Klick auf „OK"
# ```
#
# **Ergebnis:**
# - Ein neues Objekt namens „Cut" (oder „Boolean") wird erzeugt
# - Der Würfel hat nun ein zylindrisches Loch in der Mitte
# - Die ursprünglichen Objekte (Box, Cylinder) bleiben im Modellbaum, sind aber verborgen
#
# **💡 Tipp:** Klicken Sie im Modellbaum auf das Auge-Symbol neben Box und Cylinder, um diese auszublenden und nur das Endergebnis (Cut) zu sehen.
#
# ---
#
# #### Schritt 4: Visuell kontrollieren
#
# ```freecad-code
# # Zoom und Rotation zur Kontrolle:
# # - Rechtsklick halten + Mausbewegung = Drehen
# # - Mittlere Maustaste halten + Mausbewegung = Verschieben
# # - Scroll-Rad = Zoomen
# # - „V" dann „F" = Ansicht an Objekt anpassen (Fit All)
# ```
#
# Drehen Sie das Modell, um die Bohrung von oben und unten zu sehen.
#
# ---
#
# ### **Beispiel 2: Zwei Formen verbinden (Union-Operation)**
#
# **Ziel:** Ein Würfel mit einem Zylinder auf der Oberseite vereinigen.
#
# #### Schritt 1: Würfel erzeugen
#
# ```freecad-code
# # Menüpfad: Part → Create primitives → Box
# # - Length: 10 mm, Width: 10 mm, Height: 5 mm
# # - Position: x=0, y=0, z=0
# ```
#
# #### Schritt 2: Zylinder erzeugen (oben auf dem Würfel)
#
# ```freecad-code
# # Menüpfad: Part → Create primitives → Cylinder
# # - Radius: 3 mm
# # - Height: 5 mm
# # - Position: x=5, y=5, z=5  (Z=5 bedeutet: genau oben auf dem Würfel)
# ```
#
# #### Schritt 3: Union-Operation ausführen
#
# ```freecad-code
# # Menüpfad: Part → Boolean → Union
# #
# # Im Dialog:
# # - Base: Box
# # - Tool: Cylinder
# #
# # ✓ OK
# ```
#
# **Ergebnis:** Ein kombiniertes Objekt „Fuse" (oder „Boolean_Fuse") wird erzeugt. Der Würfel und der Zylinder sind nun ein einziger zusammenhängender Körper.
#
# ---
#
# ### **Beispiel 3: Schnittmenge zweier Körper (Intersection-Operation)**
#
# **Ziel:** Finden, wo sich ein Würfel und eine Kugel überlappen.
#
# #### Schritt 1: Würfel erzeugen
#
# ```freecad-code
# # Menüpfad: Part → Create primitives → Box
# # - Length: 10 mm, Width: 10 mm, Height: 10 mm
# ```
#
# #### Schritt 2: Kugel erzeugen (teilweise überlappt mit Würfel)
#
# ```freecad-code
# # Menüpfad: Part → Create primitives → Sphere
# # - Radius: 8 mm
# # - Position: x=5, y=5, z=5  (Mitte des Würfels)
# ```
#
# #### Schritt 3: Intersection-Operation ausführen
#
# ```freecad-code
# # Menüpfad: Part → Boolean → Intersection
# #
# # Im Dialog:
# # - Base: Box
# # - Tool: Sphere
# #
# # ✓ OK
# ```
#
# **Ergebnis:** Ein neues Objekt zeigt nur den Bereich, wo Würfel und Kugel sich überlappen – eine Art „Schnittform".
#
# ---
#
# ## 📋 Übersicht: FreeCAD-Menübefehle für Boolesche Operationen
#
# | Operation | Menüpfad | Ergebnis |
# |-----------|----------|----------|
# | **Union** | Part → Boolean → Union | Beide Körper verschmelzen zu einer Form |
# | **Difference** | Part → Boolean → Difference | Zweiter Körper wird vom ersten abgezogen |
# | **Intersection** | Part → Boolean → Intersection | Nur die Überschneidung bleibt erhalten |
#
# ---
#
# ## ⚠️ Häufige Fehler und deren Behebung
#
# ### Fehler 1: „Boolean operation failed" (Operation schlug fehl)
#
# **Ursache:** Die Körper berühren sich nicht oder die Geometrie ist fehlerhaft.
# **Lösung:** Kontrollieren Sie, dass die Objekte sich tatsächlich berühren oder überlappen. Verschieben Sie ggf. den Zylinder, sodass er den Würfel schneidet.
#
# ```freecad-code
# # Einen Körper verschieben (falls nötig):
# # - Im Modellbaum: Objekt auswählen (z.B. Cylinder)
# # - Menüpfad: Edit → Placement
# # - Position anpassen
# ```
#
# ### Fehler 2: Falsche Reihenfolge bei Difference
#
# **Ursache:** Die Operanden sind vertauscht (Zylinder − Würfel statt Würfel − Zylinder).
# **Lösung:** Ändern Sie in den Eigenschaften des Boolean-Objekts die Base und Tool um.
#
# ```freecad-code
# # Im Eigenschaftspanel des Boolean-Objekts (rechts):
# # - „Base" und „Tool" austauschen
# # - Das Modell aktualisiert sich sofort
# ```
#
# ### Fehler 3: Objekte sind nach der Operation unsichtbar
#
# **Ursache:** Die Originalobjekte verdecken das Ergebnis oder sind zu dicht beieinander.
# **Lösung:** Blenden Sie die Originalobjekte im Modellbaum aus.
#
# ```freecad-code
# # Im Modellbaum:
# # - Auf das Auge-Symbol neben dem Objekt klicken (wird zum X)
# # - Das Objekt wird ausgeblendet
# ```
#
# ---
#
# ## 🎨 Visualisierungstipps
#
# Nach einer Booleschen Operation ist es hilfreich, die Ansicht zu optimieren:
#
# ```freecad-code
# # Schnelle Tastenkombinationen:
# # V + F   = Fit All (Ansicht anpassen)
# # V + Home = Isometrische Ansicht
# # Scroll-Rad = Zoom
# # Rechtsklick + Ziehen = Drehen
# ```
#
# ---
#
# ## 💾 Speichern Sie Ihr Modell
#
# ```freecad-code
# # Menüpfad: File → Save
# # - Dateiname eingeben, z.B. „Wuerfel_mit_Bohrung.FCStd"
# # - FreeCAD speichert alle Operationen und Objekte
# ```
#
# ---
#
# ## 🔍 Zusammenfassung der Boolesche Operationen
#
# | Typ | Visuell | Formel | Anwendung |
# |-----|---------|--------|-----------|
# | **Union** | ![Union-Symbol] | A ∪ B | Zwei Formen verbinden |
# | **Difference** | ![Difference-Symbol] | A − B | Löcher/Aussparungen erzeugen |
# | **Intersection** | ![Intersection-Symbol] | A ∩ B | Überschneidung extrahieren |
#
# ---
#
# ## 📚 Weiterführende Links
#
# - [FreeCAD Part Workbench Dokumentation](https://wiki.freecadweb.org/Part_Workbench)
# - [Boolean Operations in FreeCAD (Englisch)](https://wiki.freecadweb.org/Part_Boolean)
# - [FreeCAD YouTube-Tutorial: Boolesche Operationen](https://www.youtube.com/results?search_query=FreeCAD+boolean+operations)
# - [Thingiverse CAD-Beispiele (Inspiration für Boolesche Kombinationen)](https://www.thingiverse.com/)
# - [CAD-Grundlagen: Was sind Boolesche Operationen?](https://en.wikipedia.org/wiki/Constructive_solid_geometry)
#
# ---
#
# **Nächster Schritt:** In Modul 4 lernen Sie, eigene 2D-Skizzen zu zeichnen, die Sie ebenfalls mit Booleschen Operationen kombinieren können!
