# %% [markdown]
# # CAD Modul 4b: Sketcher – 2D-Skizzen erstellen (Übungsaufgaben mit Hinweisen)
#
# ## 📚 Einführung: Dein Arbeitsauftrag
#
# In diesem Modul wendest du die Sketcher-Techniken an, um **selbstständig verschiedene 2D-Profile zu konstruieren**. Du wirst Linien zeichnen, Constraints (Zwangsbedingungen) anwenden und Skizzen bemaßen, bis jede Skizze vollständig definiert ist (grüne Linien!).
#
# **Wichtig:** Arbeite sorgfältig Schritt für Schritt. Wenn etwas nicht funktioniert, lese den Hinweis und versuche es nochmal. 💪
#
# ---
#
# ## ✏️ Aufgabe 1: Das einfache Rechteck-Profil
#
# **Ziel:** Du erstellst ein rechteckiges Profil (100 mm × 60 mm) auf der XY-Ebene und positionierst es sauber im Koordinatensystem.
#
# ### 📋 Aufgabenschritte:
#
# 1. **Öffne FreeCAD** und wechsele zum **Sketcher-Arbeitsbereich**
#    - Hinweis: `Ansicht` → `Arbeitsbereiche` → `Sketcher`
#
# 2. **Erstelle eine neue Skizze** auf der **XY-Ebene**
#    - Hinweis: `Sketch` → `Neue Skizze erstellen` → XY_Plane wählen
#
# 3. **Zeichne ein ungefähres Rechteck** in der Mitte der Zeichenfläche
#    - Werkzeug: `Sketch` → `Skizzen-Geometrie` → `Rechteck`
#    - Klick oben links, dann unten rechts → Rechteck ist da!
#
# 4. **Wende Constraints an, um es zu vervollständigen:**
#    - TODO: Stelle sicher, dass die **vertikalen Linien vertikal** sind
#      - Hinweis: Wähle die linke Linie, dann `Sketch` → `Skizzen-Constraints` → `Vertikal`
#      - Wiederhole das für die rechte Linie
#
#    - TODO: Stelle sicher, dass die **horizontalen Linien horizontal** sind
#      - Hinweis: Wähle die obere Linie, dann `Vertikal` → STOP! Nein, das ist falsch. Versuche `Horizontal`!
#      - Wiederhole das für die untere Linie
#
# 5. **Bemaße das Rechteck:**
#    - TODO: Gib der **unteren Linie** (horizontale) eine Länge von **100 mm**
#      - Hinweis: Wähle die Linie, dann `Sketch` → `Skizzen-Constraints` → `Länge` → 100 eingeben
#
#    - TODO: Gib der **linken Linie** (vertikal) eine Länge von **60 mm**
#      - Hinweis: Wähle die Linie, dann `Sketch` → `Skizzen-Constraints` → `Länge` → 60 eingeben
#
# 6. **Positioniere das Rechteck im Raum:**
#    - TODO: Wähle die **untere linke Ecke** des Rechtecks
#      - Hinweis: Klick auf den Eckpunkt (er wird grün)
#
#    - TODO: Gib einen **horizontalen Abstand von 30 mm** zum Ursprung ein
#      - Hinweis: `Sketch` → `Skizzen-Constraints` → `Horizontaler Abstand` → 30 eingeben
#
#    - TODO: Gib einen **vertikalen Abstand von 20 mm** zum Ursprung ein
#      - Hinweis: `Sketch` → `Skizzen-Constraints` → `Vertikaler Abstand` → 20 eingeben
#
# 7. **Überprüfung:** Alle Linien sollten jetzt **grün** sein. Wenn sie noch weiß/grau sind, fehlt dir etwas – schau in den Hinweisen nach!
#
# 8. **Schließe die Skizze:** `Sketch` → `Skizze schließen`
#
# ### 🤔 Verständnisfragen:
# - Warum war es wichtig, die Linien zuerst mit Horizontal/Vertikal-Constraints zu versehen?
# - Was würde passieren, wenn du die Position nicht festlegst (also die Abstände vom Ursprung)?
#
# ---
#
# ## 🔵 Aufgabe 2: Das Kreis-Profil
#
# **Ziel:** Du erstellst einen Kreis mit exaktem Radius (40 mm) und positionierst ihn auf der XY-Ebene.
#
# ### 📋 Aufgabenschritte:
#
# 1. **Erstelle eine neue Skizze** auf der **XY-Ebene**
#    - Hinweis: `Sketch` → `Neue Skizze erstellen`
#
# 2. **Zeichne einen Kreis**
#    - Werkzeug: `Sketch` → `Skizzen-Geometrie` → `Kreis`
#    - Klick: Mittelpunkt setzen → Maus bewegen → noch einmal klicken für den Radius
#
# 3. **Bemaße den Kreis mit Radius:**
#    - TODO: Gib dem Kreis einen **Radius von 40 mm**
#      - Hinweis: Wähle den Kreis, dann `Sketch` → `Skizzen-Constraints` → `Radius` → 40 eingeben
#
# 4. **Positioniere den Mittelpunkt des Kreises:**
#    - TODO: Wähle den **Mittelpunkt des Kreises** (der zentrale Punkt)
#      - Hinweis: Klick direkt auf den Mittelpunkt-Punkt (nicht auf die Kreislinie!)
#
#    - TODO: Gib einen **horizontalen Abstand von 70 mm** ein
#      - Hinweis: `Sketch` → `Skizzen-Constraints` → `Horizontaler Abstand` → 70 eingeben
#
#    - TODO: Gib einen **vertikalen Abstand von 50 mm** ein
#      - Hinweis: `Sketch` → `Skizzen-Constraints` → `Vertikaler Abstand` → 50 eingeben
#
# 5. **Überprüfung:** Der Kreis sollte **grün** sein – vollständig definiert!
#
# 6. **Schließe die Skizze:** `Sketch` → `Skizze schließen`
#
# ### 🤔 Verständnisfragen:
# - Warum musst du bei einem Kreis auch die Position des Mittelpunkts definieren?
# - Was ist der Unterschied zwischen Radius und Durchmesser? (Tipp: Schau in Aufgabe 3!)
#
# ---
#
# ## 📦 Aufgabe 3: Das Rechteck mit Kreis-Loch (kombiniert)
#
# **Ziel:** Du erstellst ein Rechteck (120 mm × 80 mm) und setzt einen Kreis (Radius 15 mm) genau in die Mitte – dieses Profil könnte später zu einer Platte mit Bohrung werden!
#
# ### 📋 Aufgabenschritte:
#
# 1. **Erstelle eine neue Skizze** auf der **XY-Ebene**
#    - Hinweis: `Sketch` → `Neue Skizze erstellen`
#
# 2. **Zeichne ein Rechteck** mit:
#    - Länge: 120 mm (horizontal)
#    - Höhe: 80 mm (vertikal)
#    - Position der unteren linken Ecke: 20 mm von X, 10 mm von Y
#    - Folge den Schritten aus **Aufgabe 1**, um es vollständig zu definieren
#
# 3. **Zeichne einen Kreis** in der Mitte des Rechtecks:
#    - TODO: Zeichne einen Kreis irgendwo auf dem Rechteck
#    - TODO: Gib ihm einen Radius von **15 mm**
#    - TODO: Positioniere seinen Mittelpunkt:
#      - Horizontaler Abstand: TODO (Hinweis: Die Mitte des Rechtecks ist bei 20 + 120/2 = 80 mm)
#      - Vertikaler Abstand: TODO (Hinweis: Die Mitte des Rechtecks ist bei 10 + 80/2 = 50 mm)
#
# 4. **Überprüfung:** Alle Elemente sollten grün sein!
#
# 5. **Schließe die Skizze:** `Sketch` → `Skizze schließen`
#
# ### 💡 Tipps zum Berechnen der Mittelpunkte:
# - Rechteck-Ecke (X, Y) = (20, 10)
# - Rechteck-Dimension = 120 × 80
# - Mitte X = 20 + 120/2 = **80 mm**
# - Mitte Y = 10 + 80/2 = **50 mm**
#
# ### 🤔 Verständnisfragen:
# - Wie würdest du diese Skizze im nächsten Modul nutzen, um eine Platte mit Bohrung zu erzeugen?
# - Was wäre ein praktisches Anwendungsbeispiel dafür?
#
# ---
#
# ## 🔶 Aufgabe 4: Das Mehreck (Sechseck)
#
# **Ziel:** Du erstellst ein regelmäßiges Sechseck – wie eine Schraube oder ein Bolzen!
#
# ### 📋 Aufgabenschritte:
#
# 1. **Erstelle eine neue Skizze** auf der **XY-Ebene**
#
# 2. **Zeichne ein Sechseck:**
#    - Werkzeug: `Sketch` → `Skizzen-Geometrie` → `Regelmäßiges Polygon`
#    - Wähle **6 Ecken**
#    - Klick: Mittelpunkt setzen → Maus bewegen → klick für eine Ecke
#
# 3. **Bemaße das Sechseck:**
#    - TODO: Wähle eine der **Kanten (Seiten)** des Sechsecks
#    - TODO: Gib ihr eine Länge von **30 mm**
#      - Hinweis: `Sketch` → `Skizzen-Constraints` → `Länge` → 30
#
# 4. **Positioniere das Sechseck im Raum:**
#    - TODO: Wähle den **Mittelpunkt**
#    - TODO: Gib horizontalen Abstand **60 mm** ein
#    - TODO: Gib vertikalen Abstand **60 mm** ein
#
# 5. **Überprüfung:** Alle Linien sollten grün sein!
#
# 6. **Schließe die Skizze:** `Sketch` → `Skizze schließen`
#
# ### 🤔 Verständnisfragen:
# - Wofür könnten Sechsecke in technischen Designs nützlich sein?
# - Wie würde ein Achteck (8 Ecken) aussehen? Versuche es!
#
# ---
#
# ## 📐 Aufgabe 5: Das L-Profil (etwas komplexer)
#
# **Ziel:** Du erstellst ein „L"-förmiges Profil – wie ein Winkelstahl. Dies wird mit **Linien** (statt Rechteck-Werkzeug) gezeichnet und ist deshalb etwas anspruchsvoller.
#
# ### 📋 Aufgabenschritte:
#
# 1. **Erstelle eine neue Skizze** auf der **XY-Ebene**
#
# 2. **Zeichne ein L-Profil mit Linien:**
#
#    Das L besteht aus 6 Linien. Zeichne sie in dieser Reihenfolge:
#    - Linie 1: Von (10, 10) nach (10, 70) — vertikale Linie (linke Seite)
#    - Linie 2: Von (10, 70) nach (50, 70) — horizontale Linie (oben)
#    - Linie 3: Von (50, 70) nach (50, 40) — vertikale Linie (rechts oben)
#    - Linie 4: Von (50, 40) nach (40, 40) — horizontale Linie (innen)
#    - Linie 5: Von (40, 40) nach (40, 10) — vertikale Linie (rechts unten)
#    - Linie 6: Von (40, 10) nach (10, 10) — horizontale Linie (unten) — das schließt das L
#
#    Werkzeug: `Sketch` → `Skizzen-Geometrie` → `Linie`
#
# 3. **Wende Constraints an:**
#    - TODO: Stelle sicher, dass alle geraden Linien wirklich **horizontal oder vertikal** sind
#      - Hinweis: Wähle jede Linie nacheinander und wende `Horizontal` oder `Vertikal` an
#
# 4. **Bemaße die Dimensionen des L:**
#    - TODO: Gib Linie 1 eine Länge von **60 mm** (vertikal)
#    - TODO: Gib Linie 2 eine Länge von **40 mm** (horizontal)
#    - TODO: Gib Linie 3 eine Länge von **30 mm** (vertikal)
#    - TODO: Gib Linie 5 eine Länge von **30 mm** (vertikal)
#
# 5. **Positioniere das L:**
#    - TODO: Wähle den **Punkt (10, 10)** — das ist die untere linke Ecke
#    - TODO: Gib horizontalen Abstand **20 mm** ein
#    - TODO: Gib vertikalen Abstand **15 mm** ein
#
# 6. **Überprüfung:** Alle Linien sollten grün sein. Wenn nicht, überprüfe die Constraints und Bemaßungen!
#
# 7. **Schließe die Skizze:** `Sketch` → `Skizze schließen`
#
# ### 💡 Hinweise zum Zeichnen mit Linien:
# - Wenn du eine Linie zeichnest, wird sie automatisch an die **nächste Linie angebunden**, wenn du nah genug dran klickst
# - Das L-Profil sollte ein **geschlossener Polygonzug** sein (wie ein Umriss)
#
# ### 🤔 Verständnisfragen:
# - Warum ist das L-Profil technisch interessant für Konstruktionen?
# - Wie könnte man dieses Profil später in ein 3D-Objekt verwandeln? (Stichwort: Extrusion)
#
# ---
#
# ## 🎯 Bonus-Aufgabe (optional): Das Kreuzform-Profil
#
# **Ziel:** Wenn du Zeit und Lust hast, konstruiere ein Kreuzform-Profil (wie ein + oder Hinweisschild).
#
# ### 📋 Aufgabenschritte:
#
# 1. **Erstelle eine neue Skizze** auf der **XY-Ebene**
#
# 2. **Zeichne ein Kreuz aus zwei Rechtecken:**
#    - Rechteck 1: 80 mm × 20 mm (horizontal) — positioniert bei (10, 40)
#    - Rechteck 2: 20 mm × 80 mm (vertikal) — positioniert bei (40, 10)
#    - Sie sollten sich überlappen und ein Kreuz bilden
#
# 3. **Füge alle Constraints und Bemaßungen hinzu, bis alles grün ist**
#
# 4. **Schließe die Skizze**
#
# ### 💡 Idee:
# - Nutze das Rechteck-Werkzeug zweimal
# - Definiere beide Rechtecke vollständig wie in Aufgabe 1
#
# ---
#
# ## 📋 Checkliste zum Abschluss
#
# Überprüfe, ob du folgende Punkte beherrscht:
#
# - ✅ Ich kann eine neue Skizze auf der XY-Ebene erstellen
# - ✅ Ich kann Linien, Rechtecke und Kreise zeichnen
# - ✅ Ich kann Horizontal- und Vertikal-Constraints anwenden
# - ✅ Ich kann Längen- und Radius-Bemaßungen setzen
# - ✅ Ich kann Positionen mit horizontalem und vertikalem Abstand definieren
# - ✅ Ich erkenne, wann eine Skizze vollständig definiert ist (grüne Linien)
# - ✅ Ich kann Skizzen schließen und speichern
#
# Wenn du alle Aufgaben bearbeitet hast und alle Skizzen grün sind, **bist du bereit für Modul 5**! 🎉
#
# ---
#
# ## 💬 Häufige Probleme und Lösungen
#
# | **Problem** | **Was tun?** |
# |---|---|
# | Linien sind noch weiß | Kontrolliere, ob alle Constraints und Bemaßungen gesetzt sind. Nutze die Status-Bar unten für Hinweise. |
# | Ich kann einen Punkt nicht auswählen | Zoom näher heran! Nutze das Mausrad oder `+`/`-`-Tasten |
# | Ein Constraint lässt sich nicht anwenden | Überprüfe, ob wirklich die richtigen Elemente ausgewählt sind (sie sollten grün leuchten) |
# | Die Skizze lässt sich nicht schließen | Es gibt einen Fehler (rote Linien?). Lösche den fehlerhaften Constraint und versuche es nochmal |
#
# Viel Erfolg beim Üben! 💪🚀
