# %% [markdown]
# # M01b: Einführung in CAD und FreeCAD – Übungsaufgaben
#
# ## 🎯 Lernziele
#
# - Grundkörper in FreeCAD erstellen
# - Die 3D-Ansicht steuern
# - Objekteigenschaften über das Kombifenster ändern
#
# ---
#
# ## 📌 Aufgabe 1: FreeCAD starten und erste Orientierung
#
# **Aufgabenstellung:**
#
# Starten Sie FreeCAD und machen Sie sich mit der Benutzeroberfläche vertraut.
#
# ### Was Sie tun sollen:
#
# 1. **FreeCAD öffnen** (Windows: Doppelklick auf die FreeCAD-Verknüpfung)
# 2. **Beobachten Sie die Bereiche:**
#    - Wo ist das Kombifenster (Combo View)?
#    - Welche Tabs gibt es im Kombifenster (Modell, Aufgaben)?
#    - Wo ist die 3D-Ansicht (Arbeitsbereich)?
#    - Wo ist der Navigationswürfel (rechts oben in der 3D-Ansicht)?
#
# ### Reflexionsfragen:
#
# - Welche Menüs finden Sie in der Menüleiste?
# - Welche Werkzeugkästen sind sichtbar?
# - Können Sie ein Werkzeug zum Erstellen von Grundkörpern finden?
#
# ---
#
# ## 🟦 Aufgabe 2: Ihren ersten Würfel erstellen
#
# **Aufgabenstellung:**
#
# Erstellen Sie einen Würfel in FreeCAD.
#
# ### Schritt-für-Schritt Anleitung (mit Hinweisen):
#
# 1. **Öffnen Sie das Menü `Part`**
#    ```
#    Menü: Part → Create primitives → Cube
#    ```
#
#    _Hinweis:_ Falls Sie kein Part-Menü sehen, klicken Sie oben rechts auf **Workbench** und wählen Sie **Part Workbench** aus.
#
# 2. **Ein Würfel wird erstellt**
#    - Sie sehen ihn im Modell-Tab des Kombifensters (links)
#    - Sie sehen ihn in der 3D-Ansicht (Mitte)
#
# 3. **Wählen Sie den Würfel an** (klicken Sie drauf)
#
# 4. **Schauen Sie sich das Kombifenster an** (links unten)
#    - Klicken Sie auf den Tab **„Daten"**
#    - Suchen Sie nach `Height`, `Length`, `Width`
#    - Notieren Sie die aktuellen Werte: _________________
#
# ### Reflexionsfragen:
#
# - Welche Farbe hat der Würfel?
# - Wie heißt das Würfel-Objekt im Modell-Tab?
# - Wo genau in der 3D-Ansicht befindet sich der Würfel?
#
# ---
#
# ## 📦 Aufgabe 3: Größe eines Würfels ändern – Quader erstellen
#
# **Aufgabenstellung:**
#
# Ändern Sie die Größe des Würfels, um einen **Quader** zu erstellen (unterschiedliche Breite, Tiefe und Höhe).
#
# ### Schritt-für-Schritt:
#
# 1. **Der Würfel soll noch ausgewählt sein** (falls nicht, klicken Sie ihn an)
#
# 2. **Im Kombifenster (links) unten:**
#    - Klicken Sie auf den Tab **„Daten"**
#    - Suchen Sie die Eigenschaften:
#      - `Height`: Ändern Sie auf **50 mm**
#      - `Length`: Ändern Sie auf **100 mm**
#      - `Width`: Ändern Sie auf **40 mm**
#
# 3. **Nach jeder Änderung drücken Sie Enter**
#
# 4. **Beobachten Sie die 3D-Ansicht** – der Würfel wird zum Quader
#
# ### TODO – Ihre Aufgabe:
#
# Erstellen Sie einen Quader mit folgenden Maßen:
# - Länge: 80 mm
# - Breite: 60 mm
# - Höhe: 120 mm
#
# _Hinweis:_ Vergessen Sie nicht, nach jeder Eingabe **Enter** zu drücken!
#
# ### Reflexionsfragen:
#
# - Hat sich die Farbe des Objekts verändert?
# - Ist das neue Objekt größer oder kleiner als der ursprüngliche Würfel?
#
# ---
#
# ## 🔴 Aufgabe 4: Zylinder erstellen und positionieren
#
# **Aufgabenstellung:**
#
# Erstellen Sie einen **Zylinder** neben dem Quader.
#
# ### Schritt-für-Schritt:
#
# 1. **Öffnen Sie das Menü:**
#    ```
#    Menü: Part → Create primitives → Cylinder
#    ```
#
# 2. **Ein neuer Zylinder wird erstellt**
#    - Der Zylinder erscheint im Modell-Tab des Kombifensters
#    - Er wird in der 3D-Ansicht dargestellt (vermutlich überlappt er den Quader)
#
# 3. **Wählen Sie den Zylinder an**
#
# 4. **Im Kombifenster (links) unten, Tab „Daten":**
#    - `Radius`: Ändern Sie auf **15 mm**
#    - `Height`: Ändern Sie auf **80 mm**
#
# 5. **Verschieben Sie den Zylinder:**
#    - Klappen Sie den Eintrag **`Placement`** auf
#    - Klappen Sie **`Position`** auf
#    - Ändern Sie:
#      - `X`: **150 mm** (damit er neben dem Quader steht)
#      - `Y`: **0 mm**
#      - `Z`: **0 mm**
#
# ### TODO – Ihre Aufgabe:
#
# Erstellen Sie einen zweiten Zylinder mit:
# - Radius: 20 mm
# - Höhe: 50 mm
# - Position: X: 250 mm, Y: 50 mm, Z: 0 mm
#
# _Hinweis:_ Sie können den Zylinder im Modell-Tab **doppelklicken**, um ihn umzubenennen (z.B. in "Kleiner Zylinder").
#
# ### Reflexionsfragen:
#
# - Wie viele Objekte sehen Sie jetzt im Modell-Tab?
# - Wie können Sie unterscheiden, welcher Zylinder welcher ist?
#
# ---
#
# ## 🔵 Aufgabe 5: Kugel erstellen
#
# **Aufgabenstellung:**
#
# Erstellen Sie eine **Kugel** und positionieren Sie sie in Ihrem Modell.
#
# ### Schritt-für-Schritt:
#
# 1. **Öffnen Sie das Menü:**
#    ```
#    Menü: Part → Create primitives → Sphere
#    ```
#
# 2. **Im Kombifenster (links unten), Tab „Daten":**
#    - `Radius`: Ändern Sie auf **25 mm**
#
# 3. **Positionieren Sie die Kugel:**
#    - Klappen Sie `Placement` → `Position` auf
#    - Ändern Sie:
#      - `X`: **100 mm**
#      - `Y`: **100 mm**
#      - `Z`: **100 mm**
#
# ### TODO – Ihre Aufgabe:
#
# Erstellen Sie eine zweite Kugel mit:
# - Radius: 30 mm
# - Position: X: 300 mm, Y: 150 mm, Z: 50 mm
#
# ### Reflexionsfragen:
#
# - Wie viele Objekte haben Sie insgesamt erstellt?
# - Können Sie alle Objekte von einer Seite sehen, oder müssen Sie die Ansicht ändern?
#
# ---
#
# ## 🎮 Aufgabe 6: 3D-Ansicht steuern
#
# **Aufgabenstellung:**
#
# Üben Sie, die 3D-Ansicht zu steuern.
#
# ### Schritt-für-Schritt:
#
# 1. **Drehen Sie das Modell:**
#    - Halten Sie die **Mitteltaste der Maus** gedrückt
#    - Bewegen Sie die Maus nach links/rechts und oben/unten
#    - Beobachten Sie, wie sich die Ansicht dreht
#
# 2. **Zoomen Sie heran:**
#    - Drehen Sie das **Mausrad nach oben** (oder Scroll)
#    - Zoomen Sie heraus: Mausrad nach unten
#
# 3. **Verschieben Sie die Ansicht:**
#    - Halten Sie **Mitteltaste + Shift** gedrückt
#    - Bewegen Sie die Maus
#    - Das Modell verschiebt sich im Fenster
#
# 4. **Nutzen Sie Tastenkürzel:**
#    - Drücken Sie `V` (für View), dann `H` (für Home) – die Ansicht wird zurückgesetzt
#    - Drücken Sie `V`, dann `F` (Fit All) – alle Objekte werden sichtbar
#
# 5. **Nutzen Sie den Navigationswürfel:**
#    - Klicken Sie auf den kleinen Würfel **rechts oben** in der 3D-Ansicht
#    - Klicken Sie auf verschiedene Flächen des Würfels
#    - Die Ansicht wechselt entsprechend (vorne, oben, Seite, etc.)
#
# ### TODO – Ihre Aufgabe:
#
# 1. Drehen Sie Ihr Modell um 45 Grad nach links
# 2. Zoomen Sie so heran, dass nur die Kugel sichtbar ist
# 3. Zoomen Sie heraus, bis alle Objekte wieder sichtbar sind
# 4. Nutzen Sie den **Navigationswürfel**, um zur **Draufsicht** zu wechseln
# 5. Alternative: Nutzen Sie das Menü:
#    ```
#    Menü: View → Standard Views → Top
#    ```
#
# ### Reflexionsfragen:
#
# - Ist das Drehen leicht oder schwierig?
# - Können Sie unterscheiden, welches Objekt vorne und welches hinten ist?
# - Ist der Navigationswürfel hilfreich?
#
# ---
#
# ## 💾 Aufgabe 7: Projekt speichern
#
# **Aufgabenstellung:**
#
# Speichern Sie Ihre erste FreeCAD-Konstruktion.
#
# ### Schritt-für-Schritt:
#
# 1. **Öffnen Sie das Menü:**
#    ```
#    Menü: File → Save
#    ```
#    oder drücken Sie **Ctrl + S**
#
# 2. **Ein Dialog-Fenster öffnet sich**
#    - Wählen Sie einen Speicherort (z.B. Schreibtisch)
#    - Geben Sie einen Namen ein, z.B.: `Erste_Konstruktion.FCStd`
#    - Klicken Sie auf **Speichern**
#
# 3. **Die Datei wird gespeichert**
#    - Der Titel des Fensters zeigt jetzt Ihren Dateinamen
#
# ### TODO – Ihre Aufgabe:
#
# Speichern Sie Ihr Projekt unter einem eigenen Namen (verwenden Sie Ihren Namen oder ein Datum).
#
# ### Reflexionsfragen:
#
# - Was bedeutet die Endung `.FCStd`?
# - Wo haben Sie die Datei gespeichert?
# - Können Sie die Datei später wieder öffnen?
#
# ---
#
# ## 🎓 Zusammenfassung der Übungen
#
# Sie haben gelernt:
#
# ✅ Grundkörper erstellen (Würfel, Zylinder, Kugel)
# ✅ Größe von Objekten ändern über den Tab „Daten" im Kombifenster
# ✅ Objekte positionieren über `Placement` → `Position`
# ✅ Die 3D-Ansicht zu steuern (Maus, Tastatur, Navigationswürfel)
# ✅ Projekte zu speichern
#
# **Nächste Schritte:** Im nächsten Modul werden Sie lernen, wie Sie mehrere Objekte **transformieren** (verschieben, drehen, kopieren).
