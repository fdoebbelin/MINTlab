# %% [markdown]
# # CAD Modul 4c: Sketcher – 2D-Skizzen erstellen (Ausführliche Lösungen)
#
# ## 📚 Einführung: Vollständige Lösungen mit Erklärungen
#
# Hier findest du die **detaillierten Lösungen** aller Aufgaben aus Modul 4b. Jede Lösung erklärt:
# - Wie man Schritt für Schritt vorgeht
# - Warum dieser Weg sinnvoll ist
# - Welche Fehler man vermeiden sollte
# - Tipps zur Optimierung und Variationen
#
# Nutze diese Datei zur **Selbstkontrolle** oder wenn du **stecken bleibst** und einen Hinweis brauchst.
#
# ---
#
# ## ✏️ Lösung zu Aufgabe 1: Das einfache Rechteck-Profil
#
# **Ziel:** Ein rechteckiges Profil (100 mm × 60 mm) auf der XY-Ebene, sauber positioniert.
#
# ### 🔍 Detaillierte Lösung:
#
# #### **Schritt 1-2: Neue Skizze erstellen**
#
# ```
# Menü: Sketch → Neue Skizze erstellen
# Dialog: XY_Plane auswählen
# Klick: OK / Bestätigen
# ```
#
# **Ergebnis:** Du siehst eine XY-Ebene von oben (wie ein Blatt Papier auf einem Tisch). Die Werkzeugleiste für Sketcher-Funktionen ist aktiv.
#
# ---
#
# #### **Schritt 3: Rechteck zeichnen**
#
# ```
# Werkzeug aktivieren: Sketch → Skizzen-Geometrie → Rechteck
# (oder Symbol in Werkzeugleiste klicken)
#
# Cursor → Zeichenfläche
# Klick 1: Obere linke Ecke setzen (z.B. ungefähr bei Pixel (200, 200))
# Maus bewegen: diagonal zur unteren rechten Ecke
# Klick 2: Untere rechte Ecke setzen
# Ergebnis: Ein Rechteck erscheint (ungefähr, noch nicht präzise!)
#
# Taste: Esc drücken (um das Werkzeug zu beenden)
# ```
#
# **Was passiert:** Das Rechteck ist sichtbar, hat aber noch weiße/graue Linien – es ist nicht vollständig definiert. Das ist **normal** in diesem Schritt!
#
# ---
#
# #### **Schritt 4: Constraints anwenden**
#
# **Erste Aufgabe: Vertikale Linien vertikal machen**
#
# ```
# Aktion 1: Linke Linie des Rechtecks anklicken (sie wird grün)
# Menü: Sketch → Skizzen-Constraints → Vertikal
# Ergebnis: Die Linie wird sofort vertikal ausgerichtet
#
# Aktion 2: Rechte Linie des Rechtecks anklicken (sie wird grün)
# Menü: Sketch → Skizzen-Constraints → Vertikal
# Ergebnis: Die rechte Linie wird auch vertikal ausgerichtet
# ```
#
# **Erklärung:** Der Constraint „Vertikal" zwingt eine Linie, genau auf der Y-Achse zu verlaufen – kein Winkel, keine Schräge. Das ist fundamental für technische Zeichnungen.
#
# ---
#
# **Zweite Aufgabe: Horizontale Linien horizontal machen**
#
# ```
# Aktion 1: Obere Linie des Rechtecks anklicken (sie wird grün)
# Menü: Sketch → Skizzen-Constraints → Horizontal
# Ergebnis: Die Linie wird sofort horizontal ausgerichtet
#
# Aktion 2: Untere Linie des Rechtecks anklicken (sie wird grün)
# Menü: Sketch → Skizzen-Constraints → Horizontal
# Ergebnis: Die untere Linie wird auch horizontal ausgerichtet
# ```
#
# **Erklärung:** Jetzt sind alle vier Seiten „stark" definiert – keine Seite kann mehr schief werden. Das ist wichtig, bevor wir die Größe festlegen, sonst könnte FreeCAD verwirrt sein.
#
# ---
#
# #### **Schritt 5: Bemaßung – Größen festlegen**
#
# **Untere Linie bemaßen (Breite = 100 mm):**
#
# ```
# Aktion 1: Untere (horizontale) Linie des Rechtecks anklicken (grün)
# Menü: Sketch → Skizzen-Constraints → Länge
# (oder Symbol mit Maßstab in Werkzeugleiste)
#
# Ergebnis: Ein Eingabe-Fenster erscheint (oder ein kleines Textfeld)
# Eingabe: 100 eingeben (Einheit: mm, Standard in FreeCAD)
# Taste: Enter drücken
#
# Ergebnis: Die Linie wird genau 100 mm lang! Du siehst auch eine Maßlinie mit „100" auf dem Rechteck.
# ```
#
# **Wichtig:** Wenn das Eingabe-Fenster nicht sichtbar ist, schau auf den unteren Rand des FreeCAD-Fensters – dort könnte ein Text-Eingabe-Feld sein.
#
# ---
#
# **Linke Linie bemaßen (Höhe = 60 mm):**
#
# ```
# Aktion 1: Linke (vertikale) Linie des Rechtecks anklicken (grün)
# Menü: Sketch → Skizzen-Constraints → Länge
#
# Ergebnis: Eingabe-Feld erscheint
# Eingabe: 60 eingeben
# Taste: Enter drücken
#
# Ergebnis: Die Linie wird genau 60 mm lang!
# ```
#
# **Status:** Die oberen zwei Linien sollten jetzt **noch immer weiß/grau** sein – denn noch wissen wir nicht, wie lang sie sind (aber: die werden durch die anderen Constraints automatisch bestimmt). Das ist okay!
#
# ---
#
# #### **Schritt 6: Position festlegen – Abstände vom Ursprung**
#
# **Horizontaler Abstand (von der Y-Achse):**
#
# ```
# Aktion 1: Klick auf die UNTERE LINKE ECKE des Rechtecks
#           (Dieser Eckpunkt wird grün/rot, nicht die ganze Linie!)
#           Hinweis: Zoom näher heran, wenn du Schwierigkeiten hast, den Punkt zu treffen
#
# Menü: Sketch → Skizzen-Constraints → Horizontaler Abstand
# (oder Symbol für Abstands-Constraint)
#
# Ergebnis: Ein Eingabe-Feld erscheint (oder ein Dialog)
# Eingabe: 30 eingeben (Das bedeutet: 30 mm vom Ursprung nach rechts)
# Taste: Enter drücken
#
# Ergebnis: Das ganze Rechteck springt nach rechts, bis seine linke untere Ecke genau 30 mm vom Ursprung entfernt ist!
# ```
#
# ---
#
# **Vertikaler Abstand (von der X-Achse):**
#
# ```
# Aktion 1: Klick auf die UNTERE LINKE ECKE des Rechtecks
#           (Dieser Punkt wird grün/rot)
#
# Menü: Sketch → Skizzen-Constraints → Vertikaler Abstand
#
# Ergebnis: Ein Eingabe-Feld erscheint
# Eingabe: 20 eingeben (Das bedeutet: 20 mm vom Ursprung nach oben)
# Taste: Enter drücken
#
# Ergebnis: Das ganze Rechteck springt nach oben, bis seine linke untere Ecke genau 20 mm vom Ursprung entfernt ist!
# ```
#
# ---
#
# #### **Schritt 7: Überprüfung – Alles grün?**
#
# ```
# Visueller Check:
# - Alle vier Linien des Rechtecks sind GRÜN → Erfolgreich! ✅
# - Noch weiße/graue Linien? → Etwas fehlt noch (siehe Troubleshooting weiter unten)
# - Rote Linien? → Es gibt einen Konflikt in den Constraints (z.B. zwei widersprechende Bemaßungen)
# ```
#
# **Was bedeutet Grün?** Die Skizze ist **vollständig definiert (fully constrained)**. Sie kann sich kein Millimeter mehr bewegen – alles ist festgelegt!
#
# ---
#
# #### **Schritt 8: Skizze schließen und speichern**
#
# ```
# Menü: Sketch → Skizze schließen
# oder Taste: Esc drücken
#
# Ergebnis: Du kehrst zur 3D-Ansicht zurück. Im Baum (links) siehst du jetzt
# einen Eintrag wie "Sketch" oder "Sketch001"
# ```
#
# **Was gerade passiert ist:** Die Skizze wird in dem Modellbaum gespeichert und ist jetzt bereit, im **nächsten Modul** zu einem 3D-Objekt extrudiert zu werden!
#
# ---
#
# ### 💡 Alternativer Weg: Schneller mit dem Rechteck-Constraint
#
# Es gibt eine **noch schnellere Variante**, wenn FreeCAD automatisch erkennt, dass du ein Rechteck zeichnest:
#
# ```
# 1. Rechteck zeichnen
# 2. Anstatt alle vier Seiten einzeln horizontal/vertikal zu constrainen,
#    kannst du den Constraint „Rechteck" verwenden:
#
#    Menü: Sketch → Skizzen-Constraints → Symmetrisch
#    (oder ein „Make Rectangle" Constraint, wenn vorhanden)
#
#    Dadurch werden automatisch alle rechten Winkel gesetzt.
# ```
#
# Das ist aber **optional** – der manuelle Weg (wie in der Hauptlösung) funktioniert immer!
#
# ---
#
# ### 🤔 Antworten auf die Verständnisfragen:
#
# **Frage 1: Warum war es wichtig, die Linien zuerst mit Horizontal/Vertikal-Constraints zu versehen?**
#
# **Antwort:** Wenn du das nicht machst, könnte FreeCAD verwirrt sein, wenn du später die Längen festlegst. Ein Constraint kann sich „verdreht" anfühlen, und die Skizze könnte verzerrt werden. Mit Horizontal/Vertikal machst du FreeCAD klar, dass es ein echtes Rechteck ist – keine schräge Figur.
#
# ---
#
# **Frage 2: Was würde passieren, wenn du die Position nicht festlegst (also die Abstände vom Ursprung)?**
#
# **Antwort:** Die Skizze würde **nicht grün** werden – es würde noch Freiheitsgrade geben. Du könntest das Rechteck einfach überall auf der Zeichenfläche verschieben. Das ist manchmal okay (z.B. wenn du später bewusst flexibel sein möchtest), aber für eine technische Zeichnung brauchst du **Positionen** festgelegt.
#
# ---
#
# ---
#
# ## 🔵 Lösung zu Aufgabe 2: Das Kreis-Profil
#
# **Ziel:** Ein Kreis mit Radius 40 mm, positioniert bei (70, 50).
#
# ### 🔍 Detaillierte Lösung:
#
# #### **Schritt 1: Neue Skizze erstellen**
#
# ```
# Menü: Sketch → Neue Skizze erstellen
# Dialog: XY_Plane
# Klick: OK
# ```
#
# **Ergebnis:** Du siehst wieder die XY-Ebene von oben, bereit zum Zeichnen.
#
# ---
#
# #### **Schritt 2: Kreis zeichnen**
#
# ```
# Menü: Sketch → Skizzen-Geometrie → Kreis
# (oder Symbol in der Werkzeugleiste)
#
# Cursor → Zeichenfläche
# Klick 1: Mittelpunkt des Kreises setzen (z.B. Pixelposition (300, 300))
# Maus bewegen: Weg vom Mittelpunkt (der Kreis wächst mit der Mausbewegung)
# Klick 2: Radiuspunkt setzen (z.B. beim Erreichen eines ungefähren Radius)
#
# Ergebnis: Ein Kreis mit ungefährem Radius ist sichtbar (weiße/graue Linien)
#
# Taste: Esc (um das Werkzeug zu beenden)
# ```
#
# **Hinweis:** Der Kreis sieht vielleicht nicht perfekt rund aus, wenn die Ansicht verzerrt ist. Das ist normal – wir definieren ihn ja jetzt exakt!
#
# ---
#
# #### **Schritt 3: Radius bemaßen**
#
# ```
# Aktion 1: Klick auf die Kreislinie (die Linie wird grün)
#
# Menü: Sketch → Skizzen-Constraints → Radius
# (oder Symbol für Radius/Durchmesser)
#
# Ergebnis: Eingabe-Feld erscheint
# Eingabe: 40 eingeben (Das bedeutet: Radius = 40 mm)
# Taste: Enter drücken
#
# Ergebnis: Der Kreis passt sich an und hat jetzt genau einen Radius von 40 mm!
#           Auf dem Kreis siehst du eine Maßlinie mit „40"
#           Der Kreis ist aber noch nicht vollständig definiert – du siehst noch weiße Linien
# ```
#
# **Erklärung:** Der Radius definiert die **Größe** des Kreises, nicht aber seine **Position** im Raum. Darum brauchen wir noch mehr Constraints.
#
# ---
#
# #### **Schritt 4: Mittelpunkt positionieren – Horizontaler Abstand**
#
# ```
# Aktion 1: Klick auf den MITTELPUNKT des Kreises
#           (Das ist der zentrale Punkt, nicht die Kreislinie!)
#           Hinweis: Das kann knifflig sein – zoom näher heran!
#
#           Der Punkt wird grün.
#
# Menü: Sketch → Skizzen-Constraints → Horizontaler Abstand
#
# Ergebnis: Eingabe-Feld erscheint
# Eingabe: 70 eingeben (Das bedeutet: Mittelpunkt 70 mm nach rechts vom Ursprung)
# Taste: Enter drücken
#
# Ergebnis: Der ganze Kreis springt nach rechts!
# ```
#
# ---
#
# #### **Schritt 5: Mittelpunkt positionieren – Vertikaler Abstand**
#
# ```
# Aktion 1: Klick auf den MITTELPUNKT des Kreises (wieder!)
#
# Menü: Sketch → Skizzen-Constraints → Vertikaler Abstand
#
# Ergebnis: Eingabe-Feld erscheint
# Eingabe: 50 eingeben (Das bedeutet: Mittelpunkt 50 mm nach oben vom Ursprung)
# Taste: Enter drücken
#
# Ergebnis: Der Kreis springt nach oben und sitzt jetzt genau bei (70, 50)!
# ```
#
# ---
#
# #### **Schritt 6: Überprüfung – Alles grün?**
#
# ```
# Visueller Check:
# - Der Kreis ist GRÜN → Perfekt! ✅
# - Der Kreis ist noch weiß/grau? → Überprüfe die Bemaßungen und Positionen
#
# Gesamtstatus: Drei Constraints! (Radius, Horizontal, Vertikal)
# ```
#
# ---
#
# #### **Schritt 7: Skizze schließen**
#
# ```
# Menü: Sketch → Skizze schließen
# ```
#
# ---
#
# ### 🤔 Antworten auf die Verständnisfragen:
#
# **Frage 1: Warum musst du bei einem Kreis auch die Position des Mittelpunkts definieren?**
#
# **Antwort:** Ein Kreis hat **zwei Freiheitsgrade**:
# 1. Wie groß ist er? (Radius)
# 2. Wo ist er? (Position des Mittelpunkts)
#
# Wenn du nur den Radius definierst, könnte der Kreis überall auf der Ebene herumschweben. Die Position des Mittelpunkts festzulegen macht die Skizze **vollständig definiert**.
#
# ---
#
# **Frage 2: Was ist der Unterschied zwischen Radius und Durchmesser?**
#
# **Antwort:**
# - **Radius:** Der Abstand vom Mittelpunkt bis zur Außenkante. Beispiel: Radius = 40 mm
# - **Durchmesser:** Der Abstand von einer Seite der Kreislinie zur anderen, durch die Mitte.
#   - Formel: Durchmesser = 2 × Radius
#   - Beispiel: Durchmesser = 2 × 40 = 80 mm
#
# In FreeCAD nutzen wir meist den **Radius**, manchmal aber auch den Durchmesser (je nach Einstellung oder Werkzeug).
#
# ---
#
# ---
#
# ## 📦 Lösung zu Aufgabe 3: Das Rechteck mit Kreis-Loch
#
# **Ziel:** Ein Rechteck (120 mm × 80 mm) mit einem zentrierten Kreis (Radius 15 mm) – später eine Platte mit Bohrung.
#
# ### 🔍 Detaillierte Lösung:
#
# #### **Schritt 1: Neue Skizze erstellen**
#
# ```
# Menü: Sketch → Neue Skizze erstellen
# Dialog: XY_Plane
# Klick: OK
# ```
#
# ---
#
# #### **Schritt 2: Rechteck zeichnen und definieren**
#
# **Folge den gleichen Schritten wie in Aufgabe 1, aber mit anderen Werten:**
#
# ```
# 1. Rechteck zeichnen
# 2. Vertikale Constraints auf linke und rechte Linie
# 3. Horizontale Constraints auf obere und untere Linie
# 4. Untere Linie bemaßen: Länge = 120 mm
# 5. Linke Linie bemaßen: Länge = 80 mm
# 6. Untere linke Ecke:
#    - Horizontaler Abstand = 20 mm
#    - Vertikaler Abstand = 10 mm
#
# Ergebnis: Das Rechteck ist jetzt GRÜN und vollständig definiert.
# ```
#
# ---
#
# #### **Schritt 3: Kreis zeichnen (für das Loch)**
#
# ```
# Menü: Sketch → Skizzen-Geometrie → Kreis
#
# Klick 1: Mittelpunkt irgendwo setzen (wird später positioniert)
# Klick 2: Radius definieren (wird später bemaßt)
#
# Taste: Esc
#
# Ergebnis: Ein Kreis mit weiß/grauen Linien ist sichtbar
# ```
#
# ---
#
# #### **Schritt 4: Kreis bemaßen (Radius)**
#
# ```
# Aktion 1: Klick auf die Kreislinie (grün)
#
# Menü: Sketch → Skizzen-Constraints → Radius
#
# Eingabe: 15
# Taste: Enter
#
# Ergebnis: Der Kreis hat jetzt einen Radius von 15 mm
# ```
#
# ---
#
# #### **Schritt 5: Mittelpunkt des Kreises positionieren**
#
# **Berechnung der Mittelpunkte:**
#
# Das Rechteck hat folgende Dimensionen:
# - Untere linke Ecke: (20, 10)
# - Breite: 120 mm
# - Höhe: 80 mm
# - **Mittelpunkt X:** 20 + 120/2 = 20 + 60 = **80 mm**
# - **Mittelpunkt Y:** 10 + 80/2 = 10 + 40 = **50 mm**
#
# ```
# Aktion 1: Klick auf den Mittelpunkt des Kreises
#
# Menü: Sketch → Skizzen-Constraints → Horizontaler Abstand
#
# Eingabe: 80
# Taste: Enter
#
# Ergebnis: Der Kreis springt nach rechts bis X = 80 mm
# ```
#
# ---
#
# ```
# Aktion 1: Klick auf den Mittelpunkt des Kreises (nochmal)
#
# Menü: Sketch → Skizzen-Constraints → Vertikaler Abstand
#
# Eingabe: 50
# Taste: Enter
#
# Ergebnis: Der Kreis springt nach oben bis Y = 50 mm
#          Der Kreis sitzt jetzt genau in der Mitte des Rechtecks!
# ```
#
# ---
#
# #### **Schritt 6: Überprüfung**
#
# ```
# Visueller Check:
# - Rechteck: GRÜN ✅
# - Kreis: GRÜN ✅
# - Der Kreis sitzt genau in der Mitte des Rechtecks ✅
#
# Gesamtstatus: Die Skizze ist vollständig definiert!
# ```
#
# ---
#
# #### **Schritt 7: Skizze schließen**
#
# ```
# Menü: Sketch → Skizze schließen
# ```
#
# ---
#
# ### 💡 Warum ist dieses Profil praktisch?
#
# Im **nächsten Modul** (Modul 5) werden wir diese Skizze extrudieren (nach oben ziehen), um einen **3D-Körper** daraus zu machen:
# - Das Rechteck wird zu einer **Platte** (z.B. 10 mm dick)
# - Der Kreis wird zu einem **Loch** (das durch die Platte hindurch geht)
#
# Das ist ein häufiges Konstruktions-Muster in der Technik: Platten mit Bohrungen für Befestigungsschrauben!
#
# ---
#
# ### 🤔 Antworten auf die Verständnisfragen:
#
# **Frage 1: Wie würdest du diese Skizze im nächsten Modul nutzen, um eine Platte mit Bohrung zu erzeugen?**
#
# **Antwort:** Wir würden:
# 1. Diese Skizze auswählen
# 2. Den Befehl „Pad" (Extrusion) nutzen
# 3. Eine Höhe eingeben (z.B. 10 mm)
# 4. Fertig! Aus der flachen Skizze wird eine 3D-Platte mit Loch.
#
# ---
#
# **Frage 2: Was wäre ein praktisches Anwendungsbeispiel dafür?**
#
# **Antwort:**
# - **Befestigungsplatte:** Eine Platte mit mehreren Bohrungen für Schrauben
# - **Halterung:** Eine Metallplatte mit Loch zum Befestigen einer Welle
# - **Flansch:** Das Verbindungsstück an einer Rohrleitung mit Bohrungen für Verschraubung
# - **Schaltschrank-Montageplatte:** Mit Löchern zum Anbringen von Komponenten
#
# ---
#
# ---
#
# ## 🔶 Lösung zu Aufgabe 4: Das Sechseck (Mehreck)
#
# **Ziel:** Ein regelmäßiges Sechseck mit 30 mm Kantenlänge, positioniert bei (60, 60).
#
# ### 🔍 Detaillierte Lösung:
#
# #### **Schritt 1: Neue Skizze erstellen**
#
# ```
# Menü: Sketch → Neue Skizze erstellen
# Dialog: XY_Plane
# Klick: OK
# ```
#
# ---
#
# #### **Schritt 2: Sechseck zeichnen**
#
# ```
# Menü: Sketch → Skizzen-Geometrie → Regelmäßiges Polygon
# (oder ähnlicher Name wie „Polygon" oder „Regular Polygon")
#
# Dialog: Es erscheint ein Dialog oder ein Eingabe-Bereich
# Eingabe: Anzahl der Ecken = 6 (für ein Sechseck)
# Klick: Bestätigen oder einfach weitermachen
#
# Cursor → Zeichenfläche
# Klick 1: Mittelpunkt des Sechsecks setzen
# Maus bewegen: Weg vom Mittelpunkt (das Sechseck wächst)
# Klick 2: Eine Ecke des Sechsecks positionieren
#
# Ergebnis: Ein Sechseck mit weiß/grauen Linien ist sichtbar
#
# Taste: Esc
# ```
#
# **Wichtig:** Beim regelmäßigen Polygon klickst du Mittelpunkt → eine Ecke, nicht zwei gegenüberliegende Ecken wie beim Rechteck!
#
# ---
#
# #### **Schritt 3: Sechseck bemaßen (Kantenlänge)**
#
# ```
# Aktion 1: Klick auf eine der sechs Kanten/Seiten des Sechsecks
#           (Eine der Seitenkanten wird grün – nicht das ganze Sechseck!)
#
# Menü: Sketch → Skizzen-Constraints → Länge
#
# Eingabe: 30 (Das bedeutet: jede Kante ist 30 mm lang)
# Taste: Enter
#
# Ergebnis: Alle sechs Kanten des Sechsecks passen sich an und sind jetzt genau 30 mm lang!
#           Das Sechseck ist jetzt aber noch nicht positioniert (weiße Mittelpunkt-Position)
# ```
#
# **Erklärung:** Ein regelmäßiges Polygon hat die Eigenschaft, dass alle Seiten gleich lang sind. Wenn du eine Seite bemaßt, werden automatisch alle Seiten entsprechend angepasst!
#
# ---
#
# #### **Schritt 4: Mittelpunkt des Sechsecks positionieren**
#
# ```
# Aktion 1: Klick auf den MITTELPUNKT des Sechsecks
#           (Das ist der zentrale Punkt der Figur)
#
# Menü: Sketch → Skizzen-Constraints → Horizontaler Abstand
#
# Eingabe: 60 (Das bedeutet: Mittelpunkt 60 mm nach rechts)
# Taste: Enter
#
# Ergebnis: Das ganze Sechseck springt nach rechts
# ```
#
# ---
#
# ```
# Aktion 1: Klick auf den Mittelpunkt des Sechsecks (nochmal)
#
# Menü: Sketch → Skizzen-Constraints → Vertikaler Abstand
#
# Eingabe: 60 (Das bedeutet: Mittelpunkt 60 mm nach oben)
# Taste: Enter
#
# Ergebnis: Das Sechseck springt nach oben und sitzt jetzt bei (60, 60)
# ```
#
# ---
#
# #### **Schritt 5: Überprüfung**
#
# ```
# Visueller Check:
# - Das Sechseck: GRÜN ✅
# - Alle sechs Seiten leuchten grün auf
# - Das Mittelpunkt ist blau/grün (positioniert)
#
# Gesamtstatus: Das Sechseck ist vollständig definiert!
# ```
#
# ---
#
# #### **Schritt 6: Skizze schließen**
#
# ```
# Menü: Sketch → Skizze schließen
# ```
#
# ---
#
# ### 🤔 Antworten auf die Verständnisfragen:
#
# **Frage 1: Wofür könnten Sechsecke in technischen Designs nützlich sein?**
#
# **Antwort:**
# - **Schraubenkopf:** Sechskantige Schrauben sind leichter mit einem Schraubenschlüssel zu greifen
# - **Verbindungselemente:** Muttern sind oft sechskantig
# - **Rohre:** Sechskantige Rohre für bestimmte Anwendungen
# - **Design:** Sechsecke sehen modern aus und ermöglichen effiziente Flächennutzung (wie in Wabenstrukturen)
#
# Die **Geometrie des Sechsecks** ermöglicht es, diese Teile gut aneinanderzupacken oder mit Werkzeugen zu greifen.
#
# ---
#
# **Frage 2: Wie würde ein Achteck (8 Ecken) aussehen? Versuche es!**
#
# **Antwort:** Wenn du im Dialog statt 6 die Zahl **8** eingibst, entsteht ein **regelmäßiges Achteck (Oktagon)**. Es sieht wie ein Quadrat aus, bei dem die vier Ecken abgeschnitten sind. Achtecke findest du z.B. bei:
# - Stoppschilbdern (oft achteckig)
# - Besondere Schrauben und Muttern
# - Architektur (achteckige Türme)
#
# ---
#
# ---
#
# ## 📐 Lösung zu Aufgabe 5: Das L-Profil
#
# **Ziel:** Ein L-förmiges Profil aus sechs Linien, vollständig definiert mit allen Constraints und Bemaßungen.
#
# ### 🔍 Detaillierte Lösung:
#
# #### **Schritt 1: Neue Skizze erstellen**
#
# ```
# Menü: Sketch → Neue Skizze erstellen
# Dialog: XY_Plane
# Klick: OK
# ```
#
# ---
#
# #### **Schritt 2: Das L-Profil zeichnen (die sechs Linien)**
#
# Das L hat diese Form (vereinfacht):
# ```
# 1: (10,10) --- 2: (10,70)
# |                |
# |                3: (50,70)
# |                |
# |                4: (50,40)
# |                |
# 6: (40,10) --- 5: (40,40)
# ```
#
# **Werkzeug:** `Sketch → Skizzen-Geometrie → Linie`
#
# ```
# Linie 1: Von (10,10) nach (10,70) — VERTIKAL, linke Seite
#   Menü-Befehl: Sketch → Skizzen-Geometrie → Linie
#   Klick 1: Punkt bei (10,10) setzen
#   Klick 2: Punkt bei (10,70) setzen
#
# Linie 2: Von (10,70) nach (50,70) — HORIZONTAL, oben
#   Klick 1: Punkt bei (10,70) setzen (automatisch verbunden mit Linie 1!)
#   Klick 2: Punkt bei (50,70) setzen
#
# Linie 3: Von (50,70) nach (50,40) — VERTIKAL, rechts oben
#   Klick 1: Punkt bei (50,70) setzen (automatisch verbunden!)
#   Klick 2: Punkt bei (50,40) setzen
#
# Linie 4: Von (50,40) nach (40,40) — HORIZONTAL, innen
#   Klick 1: Punkt bei (50,40) setzen (automatisch verbunden!)
#   Klick 2: Punkt bei (40,40) setzen
#
# Linie 5: Von (40,40) nach (40,10) — VERTIKAL, rechts unten
#   Klick 1: Punkt bei (40,40) setzen (automatisch verbunden!)
#   Klick 2: Punkt bei (40,10) setzen
#
# Linie 6: Von (40,10) nach (10,10) — HORIZONTAL, unten
#   Klick 1: Punkt bei (40,10) setzen (automatisch verbunden!)
#   Klick 2: Punkt bei (10,10) setzen (schließt das L!)
#
# Taste: Esc (um das Werkzeug zu beenden)
#
# Ergebnis: Das L-Profil ist sichtbar mit sechs Linien (weiß/grau)
# ```
#
# **Hinweis:** Wenn FreeCAD die Linien automatisch aneinander „anklebt" (was am wahrscheinlichsten ist), dann entsteht ein schöner geschlossener Polygonzug.
#
# ---
#
# #### **Schritt 3: Constraints anwenden – Horizontal/Vertikal**
#
# Jede der sechs Linien braucht einen Constraint, damit sie wirklich horizontal oder vertikal ist:
#
# ```
# Linie 1 (vertikal):
#   Aktion 1: Klick auf Linie 1 (grün)
#   Menü: Sketch → Skizzen-Constraints → Vertikal
#   Ergebnis: Linie 1 ist exakt vertikal
#
# Linie 2 (horizontal):
#   Aktion 1: Klick auf Linie 2 (grün)
#   Menü: Sketch → Skizzen-Constraints → Horizontal
#   Ergebnis: Linie 2 ist exakt horizontal
#
# Linie 3 (vertikal):
#   Aktion 1: Klick auf Linie 3 (grün)
#   Menü: Sketch → Skizzen-Constraints → Vertikal
#
# Linie 4 (horizontal):
#   Aktion 1: Klick auf Linie 4 (grün)
#   Menü: Sketch → Skizzen-Constraints → Horizontal
#
# Linie 5 (vertikal):
#   Aktion 1: Klick auf Linie 5 (grün)
#   Menü: Sketch → Skizzen-Constraints → Vertikal
#
# Linie 6 (horizontal):
#   Aktion 1: Klick auf Linie 6 (grün)
#   Menü: Sketch → Skizzen-Constraints → Horizontal
#
# Ergebnis: Das L-Profil ist jetzt exakt rechteckig (alle Kanten perfekt senkrecht/waagerecht)
# ```
#
# ---
#
# #### **Schritt 4: Bemaßungen hinzufügen**
#
# Wir bemaßen vier der sechs Linien:
#
# ```
# Linie 1 (vertikal, linke Seite): Länge = 60 mm
#   Aktion 1: Klick auf Linie 1
#   Menü: Sketch → Skizzen-Constraints → Länge
#   Eingabe: 60
#   Taste: Enter
#
# Linie 2 (horizontal, oben): Länge = 40 mm
#   Aktion 1: Klick auf Linie 2
#   Menü: Sketch → Skizzen-Constraints → Länge
#   Eingabe: 40
#   Taste: Enter
#
# Linie 3 (vertikal, rechts oben): Länge = 30 mm
#   Aktion 1: Klick auf Linie 3
#   Menü: Sketch → Skizzen-Constraints → Länge
#   Eingabe: 30
#   Taste: Enter
#
# Linie 5 (vertikal, rechts unten): Länge = 30 mm
#   Aktion 1: Klick auf Linie 5
#   Menü: Sketch → Skizzen-Constraints → Länge
#   Eingabe: 30
#   Taste: Enter
#
# Ergebnis: Vier Maßangaben sind jetzt sichtbar auf dem L-Profil
#           Die zwei anderen Linien (4 und 6) werden automatisch durch die anderen Constraints bestimmt!
# ```
#
# **Erklärung:** Das L hat folgende Logik:
# - Linie 1 ist 60 mm lang
# - Linie 3 ist 30 mm lang
# - Darum ist die „Innenkante" (zwischen Linie 4 und 5) auch 60 - 30 = 30 mm lang
# - Ähnlich für die horizontalen Kanten
#
# ---
#
# #### **Schritt 5: Position festlegen**
#
# ```
# Aktion 1: Klick auf den Punkt (10,10) — die untere linke Ecke des L
#
# Menü: Sketch → Skizzen-Constraints → Horizontaler Abstand
# Eingabe: 20
# Taste: Enter
#
# Ergebnis: Das L springt 20 mm nach rechts
#
# Aktion 2: Klick auf denselben Punkt (10,10) nochmal
#
# Menü: Sketch → Skizzen-Constraints → Vertikaler Abstand
# Eingabe: 15
# Taste: Enter
#
# Ergebnis: Das L springt 15 mm nach oben
#          Die untere linke Ecke des L sitzt jetzt bei (20, 15)
# ```
#
# ---
#
# #### **Schritt 6: Überprüfung – Alles grün?**
#
# ```
# Visueller Check:
# - Alle sechs Linien des L sind GRÜN ✅
# - Alle Maße sind sichtbar (60, 40, 30, 30)
# - Das L sitzt an der richtigen Position
#
# Gesamtstatus: Das L-Profil ist vollständig definiert!
# ```
#
# ---
#
# #### **Schritt 7: Skizze schließen**
#
# ```
# Menü: Sketch → Skizze schließen
# ```
#
# ---
#
# ### 💡 Warum ist das L-Profil so interessant?
#
# Das L-Profil ist ein **häufig verwendetes Element** in der Technik:
#
# 1. **Tragstrukturen:** L-förmige Träger in Stahlkonstruktionen
# 2. **Befestigungswinkel:** Eisenwinkel zum Verbinden von Teilen
# 3. **Kanäle und Profile:** Aluminium-L-Profile für Konstruktionssysteme
# 4. **3D-Druck:** Das L kann extrudiert zu einem 3D-Winkelträger werden
#
# Im **nächsten Modul** würden wir dieses L-Profil extrudieren (z.B. 50 mm nach oben), um einen **echten 3D-Winkelträger** zu erzeugen!
#
# ---
#
# ### 🤔 Antworten auf die Verständnisfragen:
#
# **Frage 1: Warum ist das L-Profil technisch interessant für Konstruktionen?**
#
# **Antwort:**
# - **Hohe Festigkeit:** Die L-Form bietet hohe Steifigkeit bei geringem Gewicht (durch die Hohlräume)
# - **Einfach herzustellen:** L-Profile können leicht gefräst oder aus Standardmaterialien gebogen werden
# - **Vielseitig:** Sie können als Träger, Winkel oder Verbindungselement verwendet werden
# - **Wirtschaftlich:** Effiziente Nutzung von Material
#
# ---
#
# **Frage 2: Wie könnte man dieses Profil später in ein 3D-Objekt verwandeln? (Stichwort: Extrusion)**
#
# **Antwort:** Im nächsten Modul würden wir:
# 1. Diese L-Skizze auswählen
# 2. Den Befehl „Pad" (Extrusion) nutzen
# 3. Eine Dicke eingeben (z.B. 50 mm)
# 4. Fertig! Aus der flachen 2D-Kontur wird ein 3D-Stahlprofil
#
# Das Ergebnis würde wie ein **echter Winkelträger** aus Metall aussehen – genau wie die, die man in der Realität kaufen kann!
#
# ---
#
# ---
#
# ## 🎯 Bonus-Lösung: Das Kreuzform-Profil
#
# **Ziel:** Ein „+"-förmiges Kreuzprofil aus zwei überlappenden Rechtecken.
#
# ### 🔍 Detaillierte Lösung:
#
# #### **Schritt 1: Neue Skizze erstellen**
#
# ```
# Menü: Sketch → Neue Skizze erstellen
# Dialog: XY_Plane
# Klick: OK
# ```
#
# ---
#
# #### **Schritt 2: Erstes Rechteck (horizontal)**
#
# ```
# Menü: Sketch → Skizzen-Geometrie → Rechteck
#
# Rechteck 1 (horizontal):
# - Klick 1: Obere linke Ecke bei ungefähr (10, 50)
# - Klick 2: Untere rechte Ecke bei ungefähr (90, 40)
#
# Werkzeug beenden: Esc
#
# Ergebnis: Das erste (breite, flache) Rechteck ist sichtbar
# ```
#
# ---
#
# #### **Schritt 3: Constraints für Rechteck 1**
#
# ```
# Vertikale Seiten: Vertikal
# Horizontale Seiten: Horizontal
#
# Bemaßung:
# - Obere Seite (Breite): 80 mm
# - Linke Seite (Höhe): 20 mm
#
# Position (untere linke Ecke):
# - Horizontal: 10 mm
# - Vertikal: 40 mm
# ```
#
# (Folge den Schritten aus Aufgabe 1)
#
# ---
#
# #### **Schritt 4: Zweites Rechteck (vertikal)**
#
# ```
# Menü: Sketch → Skizzen-Geometrie → Rechteck
#
# Rechteck 2 (vertikal):
# - Klick 1: Obere linke Ecke bei ungefähr (40, 80)
# - Klick 2: Untere rechte Ecke bei ungefähr (50, 10)
#
# Werkzeug beenden: Esc
#
# Ergebnis: Das zweite (schmale, hohe) Rechteck ist sichtbar
#           Es überlappt das erste Rechteck und ergibt zusammen eine Kreuzform!
# ```
#
# ---
#
# #### **Schritt 5: Constraints für Rechteck 2**
#
# ```
# Vertikale Seiten: Vertikal
# Horizontale Seiten: Horizontal
#
# Bemaßung:
# - Obere Seite (Breite): 20 mm
# - Linke Seite (Höhe): 80 mm
#
# Position (untere linke Ecke):
# - Horizontal: 40 mm
# - Vertikal: 10 mm
# ```
#
# ---
#
# #### **Schritt 6: Überprüfung – Alles grün?**
#
# ```
# Visueller Check:
# - Beide Rechtecke sind GRÜN ✅
# - Sie bilden zusammen eine perfekte Kreuzform ✅
# - Die Kreuzform sitzt symmetrisch im Raum
#
# Gesamtstatus: Das Kreuzprofil ist vollständig definiert!
# ```
#
# ---
#
# #### **Schritt 7: Skizze schließen**
#
# ```
# Menü: Sketch → Skizze schließen
# ```
#
# ---
#
# ### 💡 Praktische Anwendung des Kreuzes:
#
# Das Kreuzprofil könnte sein:
# - **Verkehrszeichen:** Kreuzmarkierungen
# - **Maschinenteile:** Kreuzkupplungen
# - **Strukturen:** Kreuzstützpfosten
# - **Design:** Modernes Hinweisschild
#
# Wenn man dieses Profil später extrudiert, entsteht ein **3D-Kreuzträger** – sehr stabil und interessant!
#
# ---
#
# ---
#
# ## 📋 Zusammenfassung: Was du jetzt beherrschst
#
# Nach dieser Lösung-Datei solltest du:
#
# ✅ Neue Skizzen auf beliebigen Ebenen erstellen
# ✅ Linien, Rechtecke, Kreise und Polygone zeichnen
# ✅ Horizontal- und Vertikal-Constraints anwenden
# ✅ Längen- und Radius-Bemaßungen setzen
# ✅ Positionen mit Abstandsbemaßungen festlegen
# ✅ Zwischen grünen (vollständig) und weißen (unvollständig) Skizzen unterscheiden
# ✅ Skizzen schließen und speichern
# ✅ Komplexere Profile wie L und Kreuz konstruieren
#
# ---
#
# ## 🚀 Vorbereitung auf Modul 5
#
# Im **nächsten Modul** wirst du diese 2D-Skizzen nehmen und sie in **3D-Körper verwandeln**:
# - Mit **Pad (Extrusion):** Aus einer Skizze wird ein quaderförmiger Körper
# - Mit **Revolution (Rotation):** Aus einer Skizze wird ein rotationssymmetrischer Körper (wie ein Rad)
# - Mit **Pocket:** Du schneidest Material aus einem Körper heraus
#
# Das wird sehr spannend – deine Skizzen kommen zum Leben! 🎉
#
# ---
#
# **Gratuliere – du hast Modul 4 erfolgreich absolviert! 🎓**
