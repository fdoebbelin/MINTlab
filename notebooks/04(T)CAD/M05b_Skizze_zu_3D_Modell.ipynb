# %% [markdown]
# # M05b: Von der Skizze zum 3D-Modell – Übungsaufgaben
#
# ## 📌 Einleitung
#
# In diesem Übungsmodul wendest du die Techniken aus **M05a** an. Du wirst Pad, Revolution und Pocket in praktischen Aufgaben einsetzen und dabei lernen, wie sich diese Features kombinieren lassen.
#
# **Tipp:** Nutze die Schritte aus M05a als Referenz, wenn du nicht weiterkommst. Es ist völlig normal, mehrfach nachzuschlagen!
#
# ---
#
# ## 🎯 Übungsziele
#
# - Pad, Revolution und Pocket sicher anwenden können
# - Features kombinieren und Modelle strukturiert aufbauen
# - Mit FreeCAD-Menüs und Dialogen umgehen lernen
#
# ---
#
# ## ✏️ Aufgabe 1: Einfache Extrusion – Eine Holzbox
#
# **Aufgabenstellung:**
#
# Baue eine einfache **Holzbox (Quader)** mit diesen Abmessungen:
# - Länge: 80 mm
# - Breite: 60 mm
# - Höhe: 40 mm
#
# **Vorgehen:**
#
# 1. Öffne FreeCAD und erstelle ein neues Dokument
# 2. Wechsle zum **Part Design** Arbeitsbereich
# 3. Erstelle eine neue Skizze auf der **XY-Ebene**
# 4. Zeichne ein **Rechteck** mit den Maßen 80 × 60 mm
# 5. Verlasse die Skizze
# 6. Erstelle ein **Pad** mit der Höhe 40 mm
# 7. Speichere dein Projekt als `Aufgabe1_Holzbox.FCStd`
#
# **Hinweis:**
# - Die genaue Position des Rechtecks ist nicht entscheidend (z.B. Ursprung bei (0,0) oder (20,10))
# - Nach dem Pad-Befehl solltest du einen Quader sehen, den du mit der mittleren Maustaste drehen kannst
#
# **Reflexionsfrage:**
# *Was ist der Unterschied zwischen dem Pad-Befehl und der einfachen Erstellung eines Quaders über Part → Primitives?*
#
# ---
#
# ## ✏️ Aufgabe 2: Rotation – Ein Wasserglas (Zylinder)
#
# **Aufgabenstellung:**
#
# Baue einen **zylindrischen Behälter** (wie ein Glas) mit folgenden Eigenschaften:
# - Höhe: 150 mm
# - Äußerer Radius: 40 mm
# - Material sollte durchgehend zylindrisch sein
#
# **Vorgehen:**
#
# 1. Erstelle ein neues Dokument
# 2. Wechsle zum **Part Design** Arbeitsbereich
# 3. Erstelle eine neue Skizze auf der **XY-Ebene**
# 4. Zeichne ein **Rechteck**:
#    - Von (0, 0) bis (40, 150)
#    - Das Rechteck stellt die Seitenansicht eines halben Glases dar
# 5. Zeichne eine **Konstruktionslinie** von (0, 0) bis (0, 150) – das ist die **Rotationsachse** (die vertikale Achse des Glases)
# 6. Verlasse die Skizze
# 7. Erstelle eine **Revolution**:
#    - Achse: Die Konstruktionslinie (Y-Achse oder die Linie, die du gezeichnet hast)
#    - Winkel: 360° (vollständige Umdrehung)
# 8. Speichere dein Projekt als `Aufgabe2_Wasserglas.FCStd`
#
# **Hinweis:**
# - Wenn du die Rotationsachse auswählst, klicke entweder direkt auf die Linie in der Skizze oder wähle sie aus der Liste
# - Das Ergebnis sollte ein hohler Zylinder aussehen (ein echtes Glas ohne Boden)
#
# **Reflexionsfrage:**
# *Was würde passieren, wenn du die Konstruktionslinie nicht am linken Rand des Rechtecks, sondern in der Mitte platzierst?*
#
# ---
#
# ## ✏️ Aufgabe 3: Pocket – Ein Loch in die Platte
#
# **Aufgabenstellung:**
#
# Baue eine **flache Platte mit einem kreisrunden Loch** in der Mitte.
#
# **Abmessungen der Platte:**
# - Länge: 100 mm
# - Breite: 80 mm
# - Höhe: 15 mm
#
# **Abmessungen des Lochs:**
# - Durchmesser: 30 mm
# - Platziert in der Mitte der Oberseite
# - Durch die gesamte Platte (Tiefe: 15 mm)
#
# **Vorgehen:**
#
# 1. Erstelle ein neues Dokument
# 2. Erstelle die **Basis-Platte**:
#    - Neue Skizze auf XY-Ebene
#    - Rechteck 100 × 80 mm zeichnen
#    - Skizze verlassen
#    - Pad: 15 mm Höhe
# 3. Erstelle die **Skizze für das Loch**:
#    - Klick auf das Pad im Modellbaum
#    - Neue Skizze erstellen
#    - Wähle die **Oberseite** der Platte
# 4. Zeichne einen **Kreis**:
#    - Mittelpunkt: (50, 40) [die Mitte der Platte]
#    - Radius: 15 mm
#    - Skizze verlassen
# 5. Erstelle ein **Pocket**:
#    - Länge: 15 mm (durch die gesamte Platte)
# 6. Speichere dein Projekt als `Aufgabe3_Platte_mit_Loch.FCStd`
#
# **Hinweis:**
# - Wenn du die Oberseite nicht sehen kannst, rotiere die Ansicht so, dass du von oben auf die Platte schaust
# - Nach dem Pocket sollte ein Durchgangsloch sichtbar sein
#
# **Reflexionsfrage:**
# *Die Pocket-Tiefe beträgt 15 mm, genau wie die Plattenhöhe. Ist das immer notwendig, oder könnte die Pocket-Tiefe auch anders sein?*
#
# ---
#
# ## ✏️ Aufgabe 4: Kombination – Eine Platte mit mehreren Bohrungen
#
# **Aufgabenstellung:**
#
# Baue eine **Befestigungsplatte** mit vier Bohrungen (jeweils in den vier Ecken).
#
# **Plattendaten:**
# - Länge: 120 mm
# - Breite: 80 mm
# - Höhe: 10 mm
#
# **Bohrungen:**
# - Durchmesser: 12 mm
# - Platzierung: 15 mm von jeder Ecke entfernt
# - Koordinaten der Lochmitten:
#   - Oben links: (15, 15)
#   - Oben rechts: (105, 15)
#   - Unten links: (15, 65)
#   - Unten rechts: (105, 65)
# - Tiefe: durchgehend (10 mm)
#
# **Vorgehen:**
#
# 1. Erstelle ein neues Dokument
# 2. Basis-Platte erstellen (wie in Aufgabe 3):
#    - Skizze: Rechteck 120 × 80 mm
#    - Pad: 10 mm Höhe
# 3. Erstelle **eine Skizze für alle vier Bohrungen**:
#    - Neue Skizze auf der Oberseite
#    - Zeichne vier **Kreise** mit Radius 6 mm
#    - Mittelpunkte bei den Koordinaten oben (ungefähre Angaben)
#    - Skizze verlassen
# 4. Erstelle ein **Pocket** mit Tiefe 10 mm
# 5. Speichere dein Projekt als `Aufgabe4_Befestigungsplatte.FCStd`
#
# **Hinweis:**
# - Du könntest auch vier separate Pockets machen (eins für jedes Loch), aber in **einer Skizze vier Kreise** ist effizienter
# - Nach dem Pocket solltest du vier Löcher sehen
#
# **Reflexionsfrage:**
# *Wenn du später die Größe der Bohrungen ändern möchtest (z.B. von 12 mm auf 16 mm Durchmesser), welche Skizze müsst du bearbeiten?*
#
# ---
#
# ## ✏️ Aufgabe 5: Erweiterte Kombination – Ein einfaches Dreheil mit Aussparung
#
# **Aufgabenstellung:**
#
# Baue einen **kegelförmigen Drehkörper mit einer Nut** (eine Vertiefung auf der Oberseite).
#
# **Drehkörper-Profil:**
# - Zeichne ein Profil, das aussieht wie ein Kegel:
#   - Punkt 1: (0, 0)
#   - Punkt 2: (30, 0)
#   - Punkt 3: (20, 40)
#   - Punkt 4: (10, 40)
#   - Punkt 5: (0, 0) – zurück zum Start
# - **Rotationsachse:** Vertikale Linie von (0, 0) bis (0, 40)
# - Revolution um 360°
#
# **Nut (Aussparung):**
# - Nach der Revolution: Neue Skizze auf der oberen Fläche
# - Rechteck für die Nut: 10 × 5 mm, zentriert auf der Oberseite
# - Pocket-Tiefe: 5 mm
#
# **Vorgehen:**
#
# 1. Erstelle ein neues Dokument
# 2. Skizze 1 für den Kegel:
#    - XY-Ebene
#    - Zeichne das obige Profil mit Linien
#    - Zeichne die Rotationsachse als Konstruktionslinie
#    - Skizze verlassen
# 3. Revolution mit 360°
# 4. Skizze 2 auf der Oberseite des Kegels:
#    - Zeichne ein Rechteck (10 × 5 mm) auf der höchsten Fläche
#    - Skizze verlassen
# 5. Pocket: 5 mm Tiefe
# 6. Speichere dein Projekt als `Aufgabe5_Kegel_mit_Nut.FCStd`
#
# **Hinweis:**
# - Das Profil ist etwas komplexer – zeichne langsam und überprüfe jeden Punkt
# - Wenn die Nut nicht an der richtigen Stelle ist, überprüfe die Koordinaten in der Skizze
# - Dies ist eine anspruchsvollere Aufgabe – nimm dir Zeit!
#
# **Reflexionsfrage:**
# *Du hast drei Features hintereinander erstellt: Revolution, dann Pocket. Wenn du die Revolution bearbeitest (z.B. den Winkel auf 180° änderst), was passiert mit dem Pocket?*
#
# ---
#
# ## 🤔 Verständnisfragen zum Reflektieren
#
# Beantworte diese Fragen schriftlich oder mündlich:
#
# 1. **Wann benutze ich Pad und wann Revolution?**
#    - Gib zwei Beispiele für Objekte, die du mit Pad erstellen würdest
#    - Gib zwei Beispiele für Objekte, die du mit Revolution erstellen würdest
#
# 2. **Pocket vs. Boolesche Differenz:**
#    - Wo ist der Unterschied zwischen einem Pocket und der Boolschen Differenz (aus Modul 3)?
#    - Wann würdest du welche Methode nutzen?
#
# 3. **Feature-Reihenfolge:**
#    - Muss das Pad immer das erste Feature sein, oder kannst du auch anders anfangen?
#    - Was passiert, wenn du die Reihenfolge von Pad und Pocket vertauschst?
#
# 4. **Editierbarkeit:**
#    - Du hast eine Platte mit Loch konstruiert (Pad + Pocket). Die Platte soll jetzt 50 mm breit sein statt 80 mm. Wie gehst du vor?
#
# ---
#
# ## 💡 Hilfreiche Tipps & Tricks
#
# | Problem | Lösung |
# |---------|--------|
# | **Pocket funktioniert nicht** | Stelle sicher, dass die Skizze **auf einer Fläche des Pads** liegt, nicht im Raum |
# | **Revolution erzeugt ein falsches Ergebnis** | Überprüfe, dass die Rotationsachse **tatsächlich als Konstruktionslinie** definiert ist (gestrichelt) |
# | **Ich sehe die Oberseite nicht** | Drehe die Ansicht mit der mittleren Maustaste oder drücke `Home` zum Zurücksetzen |
# | **Skizze ist gelb statt grün** | Die Skizze ist nicht vollständig bestimmt – das ist für einfache Aufgaben okay |
# | **Pad/Pocket wird nicht erstellt** | Stelle sicher, dass die Skizze im Modellbaum **ausgewählt** ist |
#
# ---
#
# ## ✅ Checkliste zum Abhaken
#
# Hast du alle Aufgaben bearbeitet?
#
# - [ ] Aufgabe 1: Holzbox mit Pad
# - [ ] Aufgabe 2: Wasserglas mit Revolution
# - [ ] Aufgabe 3: Platte mit Loch (Pocket)
# - [ ] Aufgabe 4: Befestigungsplatte mit vier Bohrungen
# - [ ] Aufgabe 5: Kegel mit Nut (erweiterte Kombination)
#
# Hast du die Reflexionsfragen beantwortet?
#
# - [ ] Reflexionsfragen zu jeder Aufgabe bearbeitet
# - [ ] Verständnisfragen am Ende gelesen und überlegt
#
# ---
#
# ## 🎯 Was solltest du jetzt können?
#
# Am Ende dieser Übungen solltest du:
#
# ✅ Ein Pad schnell und sicher erstellen können
#
# ✅ Eine Revolution mit Rotationsachse durchführen können
#
# ✅ Ein Pocket zum Ausschneiden von Material nutzen können
#
# ✅ Mehrere Features hintereinander kombinieren können
#
# ✅ Im Modellbaum nachvollziehen können, wie dein Modell aufgebaut ist
#
# Falls du bei einer Aufgabe hängst, **nicht verzweifeln!** CAD braucht Übung. Schau in M05a nach oder frage deine Dozentin/deinen Dozenten.
#
# ---
#
# **Viel Erfolg beim Üben!** 🚀
