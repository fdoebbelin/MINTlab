# %% [markdown]
# # CAD Modul 4a: Sketcher – 2D-Skizzen erstellen (Demonstration & Einführung)
#
# ## 📚 Einleitung und Lernziele
#
# Willkommen zu Modul 4! Du hast bereits gelernt, wie man **vorgefertigte Grundkörper** (Würfel, Zylinder, Kugeln) in FreeCAD erzeugt, wie man sie transformiert, und wie man sie miteinander kombiniert.
#
# In diesem Modul machen wir einen wichtigen Schritt: Wir verlassen die Welt der Standard-Grundformen und **zeichnen unsere eigenen zweidimensionalen (2D) Profile**. Diese Skizzen sind wie technische Zeichnungen auf Papier – aber digital und präzise. Sie bilden die Grundlage für viele komplexe 3D-Objekte, die wir später im Modul 5 „zum Leben erwecken" werden.
#
# ### 🎯 Lernziele dieses Moduls:
#
# - Verstehen, welche Rolle 2D-Skizzen in der 3D-Konstruktion spielen
# - Den Sketcher-Arbeitsbereich (Workbench) in FreeCAD bedienen
# - Neue Skizzen anlegen und die richtige Ebene (Arbeitsfläche) wählen
# - Grundlegende Skizzenelemente zeichnen: Punkte, Linien, Rechtecke, Kreise
# - Einfache geometrische Zwangsbedingungen (Constraints) anwenden
# - Skizzen bemaßen und die Größe präzise festlegen
# - Eine vollständig definierte Skizze von einer unterdefinierten unterscheiden
#
# ---
#
# ## 🧠 Warum sind 2D-Skizzen wichtig?
#
# Stell dir vor, du möchtest einen **Drehscheibenstuhl** konstruieren. Der Sitz könnte aus einer einfachen Kreis-Skizze entstehen, die dann nach oben extrudiert wird. Oder du willst einen **Zahnradriemen** – auch hier zeichnest du zuerst das Zahnprofil als 2D-Kontur, rotierst es um eine Achse, und schon entsteht das 3D-Zahnrad.
#
# **Technische Zeichner** arbeiten schon lange so: Sie zeichnen präzise 2D-Profile, um daraus 3D-Objekte zu „denken" oder herzustellen. In FreeCAD funktioniert das genauso – nur digital und mit voller Kontrolle über jede Dimension.
#
# ---
#
# ## 📋 Der Sketcher-Arbeitsbereich: Erste Schritte
#
# ### Was ist der Sketcher?
#
# Der **Sketcher** ist ein spezieller Arbeitsbereich (Workbench) in FreeCAD, in dem du 2D-Zeichnungen erstellst. Er unterscheidet sich vom normalen 3D-Arbeitsbereich:
#
# - **3D-Ansicht:** Hier arbeitest du mit Grundkörpern und Features (wie Extrusion, Boolesche Operationen)
# - **2D-Sketcher:** Hier zeichnest du flache Konturen, die als Grundlage für 3D-Operationen dienen
#
# ### Den Sketcher wechseln
#
# > **Menübefehl (FreeCAD):**
# >
# > `Ansicht` → `Arbeitsbereiche` → `Sketcher`
# >
# > Oder nutze die **Workbench-Dropdown-Liste** (oben links im FreeCAD-Fenster) und wähle „Sketcher"
#
# Nach dem Wechsel siehst du eine neue Symbolleiste mit vielen neuen Werkzeugen zum Zeichnen von Linien, Kreisen, Rechtecken etc.
#
# ---
#
# ## ✏️ Eine erste Skizze anlegen
#
# ### Schritt 1: Neue Skizze erstellen
#
# > **Menübefehl (FreeCAD):**
# >
# > `Sketch` → `Neue Skizze erstellen`
#
# Ein Dialog-Fenster öffnet sich und fragt dich: **Auf welcher Ebene möchtest du zeichnen?**
#
# ### Ebenen verstehen: XY, XZ, YZ
#
# FreeCAD arbeitet mit einem **3D-Koordinatensystem**:
# - **X-Achse:** Nach links/rechts (rot)
# - **Y-Achse:** Nach vorne/hinten (grün)
# - **Z-Achse:** Nach oben/unten (blau)
#
# Eine **Ebene** ist eine flache Oberfläche, auf der du zeichnest:
# - **XY-Ebene:** Der Boden (von oben betrachtet)
# - **XZ-Ebene:** Die Vorderseite (von vorne betrachtet)
# - **YZ-Ebene:** Die Seite (von der Seite betrachtet)
#
# Für unser erstes Beispiel wählen wir die **XY-Ebene**, da sie intuitiv ist – wie ein Blatt Papier auf einem Tisch.
#
# ### Schritt 2: Die XY-Ebene auswählen
#
# > **Menübefehl (FreeCAD):**
# >
# > Im Skizzen-Dialog: Wähle **XY_Plane** (oder „XY-Ebene")
#
# Danach solltest du sehen:
# - FreeCAD wechselt automatisch zur **von oben schauen** Ansicht
# - Der Bildschirm zeigt jetzt nur die XY-Ebene (wie wenn du von oben auf einen Tisch schaust)
# - Die Skizzen-Werkzeugleiste wird sichtbar
#
# ---
#
# ## 🎨 Erste Zeichnungen: Linien und Formen
#
# ### Eine einfache Linie zeichnen
#
# Die **Linie** ist das Basis-Werkzeug im Sketcher.
#
# > **Menübefehl (FreeCAD):**
# >
# > `Sketch` → `Skizzen-Geometrie` → `Linie`
#
# **Wie funktioniert es?**
# 1. Klicke auf das Linien-Symbol in der Werkzeugleiste
# 2. Der Cursor verwandelt sich in ein Fadenkreuz
# 3. Klicke auf der Zeichenfläche, um den **ersten Punkt** der Linie zu setzen
# 4. Bewege die Maus zum gewünschten **Ende-Punkt**
# 5. Klicke nochmal, um die Linie abzuschließen
# 6. Drücke `Esc`, um das Werkzeug zu beenden
#
# **Beispiel:** Zeichne eine 100 mm lange horizontale Linie von links nach rechts. (Macht nichts, wenn sie nicht exakt aussieht – wir bemaßen sie gleich!)
#
# ---
#
# ### Ein Rechteck zeichnen
#
# Das Rechteck-Werkzeug ist schneller als vier einzelne Linien zu zeichnen:
#
# > **Menübefehl (FreeCAD):**
# >
# > `Sketch` → `Skizzen-Geometrie` → `Rechteck`
#
# **Wie funktioniert es?**
# 1. Klicke auf das Rechteck-Symbol
# 2. Klicke auf der Zeichenfläche, um die **erste Ecke** (z.B. oben links) zu setzen
# 3. Bewege die Maus diagonal zur **gegenüberliegenden Ecke** (z.B. unten rechts)
# 4. Klicke, um die zweite Ecke zu setzen
# 5. Das Rechteck ist fertig – drücke `Esc` zum Beenden
#
# **Beispiel:** Zeichne ein ungefähres Rechteck, das später exakt definiert wird (z.B. 50 mm breit und 30 mm hoch).
#
# ---
#
# ### Ein Kreis zeichnen
#
# Kreise sind besonders wichtig für Löcher, Wellen und runde Elemente:
#
# > **Menübefehl (FreeCAD):**
# >
# > `Sketch` → `Skizzen-Geometrie` → `Kreis`
#
# **Wie funktioniert es?**
# 1. Klicke auf das Kreis-Symbol
# 2. Klicke auf der Zeichenfläche, um den **Mittelpunkt** des Kreises zu setzen
# 3. Bewege die Maus weg vom Mittelpunkt
# 4. Klicke, um den Radius festzulegen – der Kreis ist fertig
# 5. Drücke `Esc` zum Beenden
#
# **Beispiel:** Zeichne einen Kreis irgendwo auf dem Blatt. Sein Radius ist noch nicht exakt – das korrigieren wir später mit Bemaßung.
#
# ---
#
# ## 🔧 Zwangsbedingungen (Constraints)
#
# Ein Rechteck, das du per Hand zeichnest, sieht vielleicht nicht perfekt rechtwinklig aus. Und ein Kreis könnte leicht oval wirken. Darum haben wir **Constraints** (Zwangsbedingungen) – sie sagen FreeCAD, wie die Geometrie exakt aussehen soll.
#
# ### Horizontale und vertikale Linien
#
# Wenn du eine Linie zeichnest, die **horizontal** (waagerecht) oder **vertikal** (senkrecht) sein soll, kannst du das festlegen:
#
# > **Menübefehl (FreeCAD):**
# >
# > - **Horizontal:** `Sketch` → `Skizzen-Constraints` → `Horizontal` (oder Symbol in Werkzeugleiste)
# > - **Vertikal:** `Sketch` → `Skizzen-Constraints` → `Vertikal`
#
# **Wie funktioniert es?**
# 1. Zeichne eine Linie, die in etwa horizontal sein soll (aber nicht perfekt)
# 2. Wähle die Linie an, indem du sie anklickst (sie wird grün)
# 3. Wende den Constraint „Horizontal" an
# 4. Die Linie schnellt sofort in die exakt horizontale Position!
#
# Gleiches funktioniert mit „Vertikal" für senkrechte Linien.
#
# ---
#
# ### Parallele und rechtwinklige Linien
#
# Wenn zwei Linien parallel sein sollen oder einen **rechten Winkel** (90°) bilden sollen:
#
# > **Menübefehl (FreeCAD):**
# >
# > - **Parallel:** `Sketch` → `Skizzen-Constraints` → `Parallel`
# > - **Rechtwinklig (Perpendicular):** `Sketch` → `Skizzen-Constraints` → `Perpendicular`
#
# **Wie funktioniert es? (Beispiel: Rechtwinklig)**
# 1. Zeichne zwei Linien, die ungefähr einen 90°-Winkel bilden
# 2. Halte `Ctrl` gedrückt und klicke auf beide Linien, um sie beide auszuwählen (beide werden grün)
# 3. Wende den Constraint „Rechtwinklig" an
# 4. Die beiden Linien richten sich sofort so aus, dass sie genau einen 90°-Winkel bilden
#
# ---
#
# ### Gleiche Länge
#
# Wenn zwei Linien die **gleiche Länge** haben sollen (z.B. zwei Seiten eines Quadrats):
#
# > **Menübefehl (FreeCAD):**
# >
# > `Sketch` → `Skizzen-Constraints` → `Gleich`
#
# **Wie funktioniert es?**
# 1. Wähle zwei Linien an (mit `Ctrl` + Klick), die gleich lang sein sollen
# 2. Wende den Constraint „Gleich" an
# 3. Die beiden Linien passen sich an und werden exakt gleich lang
#
# ---
#
# ## 📏 Bemaßung: Größen und Abstände definieren
#
# Bis jetzt haben wir mit **Constraints** die **Form** von Linien bestimmt (horizontal, vertikal, rechtwinklig). Jetzt brauchen wir noch die **Größen**: Wie lang ist eine Linie? Wie groß ist ein Kreis?
#
# Dafür nutzen wir **Längenbemaßung** (für Abstände und Längen) und **Radiusbemaßung** (für Kreise).
#
# ### Eine Linie bemaßen (Länge)
#
# > **Menübefehl (FreeCAD):**
# >
# > `Sketch` → `Skizzen-Constraints` → `Länge` (oder Symbol in Werkzeugleiste)
#
# **Wie funktioniert es?**
# 1. Klicke auf das Bemaßungs-Symbol für Länge
# 2. Klicke auf die Linie, die du bemaßen möchtest
# 3. Ein Dialog-Fenster oder ein Eingabe-Feld erscheint
# 4. Gib die gewünschte Länge ein (z.B. 100 für 100 mm)
# 5. Bestätige mit `Enter`
# 6. Die Linie passt sich an die exakte Länge an!
#
# **Beispiel:** Du hast eine horizontal gezogene Linie. Gebe ihr eine Bemaßung von 100 mm.
#
# ---
#
# ### Einen Kreis bemaßen (Radius oder Durchmesser)
#
# > **Menübefehl (FreeCAD):**
# >
# > `Sketch` → `Skizzen-Constraints` → `Radius`
#
# **Wie funktioniert es?**
# 1. Klicke auf das Radius-Symbol
# 2. Klicke auf den **Kreis**, den du bemaßen möchtest
# 3. Ein Eingabe-Feld erscheint
# 4. Gib den gewünschten Radius ein (z.B. 25 für einen 25 mm Radius)
# 5. Bestätige mit `Enter`
# 6. Der Kreis passt sich an den neuen Radius an
#
# ---
#
# ## 📐 Positionen festlegen: Abstände vom Ursprung
#
# Eine Skizze hat einen **Ursprung** – dort, wo die X- und Y-Achse sich treffen (der Punkt 0,0). Manchmal möchte man, dass Objekte in der Skizze einen **bestimmten Abstand zum Ursprung** haben.
#
# ### Ein Rechteck positionieren
#
# Stell dir vor, du zeichnest ein Rechteck, und es soll an einer ganz bestimmten Position sein – z.B. 50 mm von der Y-Achse entfernt und 30 mm von der X-Achse.
#
# > **Menübefehl (FreeCAD):**
# >
# > `Sketch` → `Skizzen-Constraints` → `Horizontaler Abstand` oder `Vertikaler Abstand`
#
# **Wie funktioniert es?**
# 1. Wähle einen **Punkt** deines Rechtecks (z.B. die untere linke Ecke) an
# 2. Klicke auf das Symbol für „Horizontaler Abstand"
# 3. Ein Eingabe-Feld erscheint
# 4. Gib den Abstand ein (z.B. 50 mm)
# 5. Bestätige mit `Enter`
#
# Das Rechteck verschiebt sich automatisch in die richtige Position!
#
# ---
#
# ## ✅ Skizzen-Validierung: Vollständig oder unvollständig?
#
# Eine wichtige Frage am Ende einer Skizze ist: **Ist sie vollständig definiert?**
#
# Eine **vollständig definierte Skizze** (auch „fully constrained") hat:
# - Alle Linien, Kreise und Formen haben eine exakte **Größe**
# - Alle Formen haben eine exakte **Position** im Raum
# - Es gibt keine Freiheitsgrade mehr – die Skizze kann sich nicht ändern
#
# Eine **unvollständig definierte Skizze** (auch „underconstrained") hat:
# - Noch offene Parameter – z.B. ein Kreis ohne Radiusbemaßung
# - Sie könnte theoretisch noch verändert werden
#
# **In FreeCAD erkennst du das an den Farben:**
# - **Weiße/hellgraue Linien:** Nicht vollständig definiert (noch unsicher)
# - **Grüne Linien:** Vollständig definiert (sicher und stabil)
# - **Rote Linien:** Konflikt oder Problem in den Constraints
#
# ---
#
# ## 📚 Ein vollständiges Beispiel: Das Rechteck-Profil
#
# Lass uns jetzt ein komplettes Rechteck-Profil erstellen und vollständig definieren:
#
# ### Schritt für Schritt:
#
# 1. **Neue Skizze auf XY-Ebene** erstellen
# 2. **Rechteck zeichnen** (ungefähr in der Mitte)
# 3. **Constraints anwenden:**
#    - Die vier Linien → „Horizontal" oder „Vertikal" (je nach Richtung)
#    - Oder: Ein Rechteck-Constraint anwenden, um sicherzustellen, dass die Winkel alle 90° sind
# 4. **Größe bemaßen:**
#    - Untere Linie: Längenbemaßung = 80 mm
#    - Linke Linie: Längenbemaßung = 50 mm
# 5. **Position festlegen:**
#    - Untere linke Ecke: Horizontaler Abstand zum Ursprung = 20 mm
#    - Untere linke Ecke: Vertikaler Abstand zum Ursprung = 20 mm
# 6. **Überprüfen:** Die Linien sollten jetzt grün sein – die Skizze ist vollständig definiert!
#
# ---
#
# ## 🎓 Ein zweites Beispiel: Das Kreis-Profil mit Mittelpunkt
#
# Jetzt noch ein Beispiel mit einem **Kreis**:
#
# ### Schritt für Schritt:
#
# 1. **Neue Skizze auf XY-Ebene** erstellen
# 2. **Kreis zeichnen** (irgendwo auf der Fläche)
# 3. **Radius bemaßen:** Radius = 25 mm
# 4. **Mittelpunkt positionieren:**
#    - Den Mittelpunkt des Kreises auswählen
#    - Horizontaler Abstand zum Ursprung = 60 mm
#    - Vertikaler Abstand zum Ursprung = 40 mm
# 5. **Überprüfen:** Der Kreis sollte grün sein – vollständig definiert!
#
# ---
#
# ## 🌟 Besondere Skizzen-Werkzeuge: Mehreck und Bogen
#
# ### Mehreck (Polygon)
#
# Wenn du ein **Dreieck, Sechseck oder anderes regelmäßiges Vieleck** zeichnen möchtest:
#
# > **Menübefehl (FreeCAD):**
# >
# > `Sketch` → `Skizzen-Geometrie` → `Regelmäßiges Polygon`
#
# Nach Auswahl bestimmst du:
# 1. Die Anzahl der Ecken (z.B. 6 für ein Sechseck)
# 2. Mittelpunkt und ein Eckpunkt durch Klick
#
# ### Bogen (Arc)
#
# Kurven und runde Übergänge entstehen mit dem **Bogen-Werkzeug**:
#
# > **Menübefehl (FreeCAD):**
# >
# > `Sketch` → `Skizzen-Geometrie` → `Bogen` (es gibt mehrere Varianten)
#
# Der einfachste ist der **Bogen durch 3 Punkte** – klicke Start, dann einen Punkt auf der Kurve, dann das Ende.
#
# ---
#
# ## 🔄 Die Skizze verlassen und speichern
#
# Wenn deine Skizze fertig ist und vollständig definiert:
#
# > **Menübefehl (FreeCAD):**
# >
# > `Sketch` → `Skizze schließen`
#
# Oder drücke `Esc`.
#
# Die Skizze wird geschlossen und im **Modellbaum** (links) eingebunden. Sie ist jetzt bereit, im nächsten Modul **zu einem 3D-Objekt extrudiert** zu werden!
#
# ---
#
# ## 💡 Häufige Fehler und wie du sie vermeidest
#
# | **Problem** | **Ursache** | **Lösung** |
# |---|---|---|
# | Linien sind weiß/grau statt grün | Skizze ist nicht vollständig definiert | Fehlende Constraints oder Bemaßungen hinzufügen |
# | Ich kann eine Linie nicht zeichnen | Das Werkzeug ist noch aktiv | `Esc` drücken, um das Werkzeug zu beenden |
# | Ein Constraint lässt sich nicht anwenden | Falsche Elemente ausgewählt | Überprüfe, ob z.B. wirklich zwei Linien ausgewählt sind (grün) |
# | Die Skizze schaut „verzerrt" aus | Ansicht ist schief | Drücke die `0`-Taste oder nutze `Ansicht` → `Fit All` zum Zurücksetzen |
# | Ich kann die Skizze nicht schließen | Es gibt Konflikte in den Constraints | Rote Linien prüfen und fehlerhafte Constraints löschen |
#
# ---
#
# ## 📖 Weiterführende Links
#
# Hier sind nützliche externe Ressourcen zum Vertiefen:
#
# - [FreeCAD Sketcher – Offizielle Dokumentation](https://wiki.freecadweb.org/Sketcher_Workbench)
#
# ---
#
# ## 🎯 Zusammenfassung
#
# Du hast in diesem Modul gelernt:
#
# 1. ✅ Warum 2D-Skizzen die Grundlage für 3D-Konstruktion sind
# 2. ✅ Wie du den Sketcher-Arbeitsbereich öffnest und eine neue Skizze anlegst
# 3. ✅ Wie du grundlegende Formen zeichnest: Linien, Rechtecke, Kreise, Bögen
# 4. ✅ Wie du Constraints (Horizontal, Vertikal, Gleichheit) anwendest
# 5. ✅ Wie du Skizzen bemaßt und so Größen und Positionen festlegst
# 6. ✅ Wie du überprüfst, ob eine Skizze vollständig definiert ist
# 7. ✅ Wie du eine Skizze schließt und speicherst
#
# **Im nächsten Modul (Modul 5)** werden wir diese Skizzen nehmen und sie **zu 3D-Objekten extrudieren** oder **rotieren** – aus flachen Profilen entstehen echte 3D-Körper!
#
# Viel Spaß beim Üben! 🚀
