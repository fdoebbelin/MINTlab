# %% [markdown]
# # Modul 8b: Abschlussprojekt – Eigenes CAD-Projekt umsetzen
# ## Übungsaufgaben mit Hinweisen
#
# ---
#
# ## 🎯 Einleitung zur Übung
#
# Willkommen zur praktischen Übung! Nachdem ihr in Modul 8a gesehen habt, wie eine Schachfigur konstruiert wird, seid ihr jetzt an der Reihe. In dieser Übung werdet ihr **ein eigenes Alltagsobjekt** eurer Wahl in FreeCAD konstruieren.
#
# Das Ziel ist es, alle Techniken aus den bisherigen Modulen selbstständig anzuwenden und ein komplettes Projekt von der Idee bis zum fertigen 3D-Modell durchzuführen.
#
# **Eure Aufgabe:**
# Konstruiert eine **Kaffeetasse** mit folgenden Merkmalen:
# - Zylindrischer Körper (Tassenkörper)
# - Henkel
# - Runder Boden
# - Optional: Untertasse
#
# Diese Aufgabe kombiniert verschiedene Konstruktionsmethoden: Rotation, Extrusion, boolesche Operationen und Abrundungen.
#
# ---
#
# ## 📝 Aufgabe 1: Projektplanung
#
# Bevor ihr mit der Konstruktion beginnt, plant euer Projekt!
#
# **Zu erledigen:**
#
# 1. **Macht eine Handskizze** der Kaffeetasse (Seitenansicht und Draufsicht)
# 2. **Überlegt euch Maße:**
#    - Höhe der Tasse: ca. 80-100 mm
#    - Durchmesser oben: ca. 80 mm
#    - Durchmesser unten (Boden): ca. 60 mm
#    - Wandstärke: ca. 3-5 mm
#    - Henkelbreite: ca. 10 mm
#    - Henkeldicke: ca. 5-8 mm
#
# 3. **Plant die Konstruktionsschritte:**
#    - Schritt 1: ?
#    - Schritt 2: ?
#    - Schritt 3: ?
#
# **💡 Hinweis:** Überlegt, welche Grundform die Tasse hat. Ist sie rotationssymmetrisch? Wenn ja, könnt ihr die Revolution-Methode verwenden!
#
# ---
#
# ## 🔧 Aufgabe 2: Tassenkörper erstellen (Revolution)
#
# Erstellt den Hauptkörper der Tasse durch Rotation einer Profilskizze.
#
# **Schritte:**
#
# ```
# TODO: Öffnet FreeCAD und wechselt zum Part Design-Arbeitsbereich
# Menü: Workbench → Part Design
# ```
#
# **Schritt 1: Body und Skizze erstellen**
#
# ```
# TODO: Erstellt einen neuen Body
# Menü: Part Design → ?
#
# TODO: Erstellt eine neue Skizze auf der XZ-Ebene
# Menü: Part Design → ?
# Auswahl: XZ-Ebene (vertikale Ebene)
# ```
#
# **Schritt 2: Profil der Tasse zeichnen**
#
# Zeichnet das **halbe Profil** der Tasse (Querschnitt), das später rotiert wird:
#
# ```
# TODO: Verwendet das Polyline-Werkzeug (oder Line-Werkzeug)
#
# Zeichnet folgende Kontur (von unten nach oben):
# 1. Startpunkt auf der Z-Achse bei (0, 0)
# 2. Linie nach rechts zur Position (30, 0) → Bodenradius innen
# 3. Linie nach unten zur Position (30, -3) → Bodendicke
# 4. Linie nach rechts zur Position (33, -3) → Außenradius Boden
# 5. Linie nach oben zur Position (33, 0) → Bodenaußenkante
# 6. Linie schräg nach oben und außen zur Position (40, 80) → Außenwand der Tasse
# 7. Linie nach innen zur Position (37, 80) → Wandstärke oben
# 8. Linie schräg nach unten und innen zur Position (30, 5) → Innenwand
# 9. Linie nach links zur Z-Achse (0, 5) → zurück zur Achse
# 10. Linie nach unten zur Startposition (0, 0) → Kontur schließen
# ```
#
# **💡 Hinweis:** Die Kontur muss geschlossen sein! Achtet darauf, dass Start- und Endpunkt verbunden sind.
#
# **Schritt 3: Bemaßung hinzufügen**
#
# ```
# TODO: Fügt wichtige Maße hinzu, um das Profil zu definieren
#
# Werkzeuge:
# - Constrain vertical distance → Höhe der Tasse: 80 mm
# - Constrain horizontal distance → Innenradius unten: 30 mm, Außenradius oben: 40 mm
# - Wandstärke: 3 mm
# - Bodendicke: 3 mm
# ```
#
# ```
# TODO: Schließt die Skizze
# Menü: Sketch → ?
# ```
#
# **Schritt 4: Revolution durchführen**
#
# ```
# TODO: Rotiert die Skizze um die Z-Achse
#
# Menü: Part Design → Revolution
#
# Einstellungen:
# - Axis: ? (Welche Achse?)
# - Angle: ? (Wie viele Grad für einen vollen Kreis?)
#
# Klick auf OK
# ```
#
# **💡 Hinweis:** Wenn alles geklappt hat, solltet ihr jetzt einen Tassenkörper mit Hohlraum sehen!
#
# ---
#
# ## 🎨 Aufgabe 3: Henkel hinzufügen
#
# Der Henkel ist die größte Herausforderung! Es gibt verschiedene Ansätze – hier ist ein vereinfachter Weg:
#
# **Methode: Henkel als extrudierte, gebogene Form**
#
# **Schritt 1: Neue Skizze für den Henkel erstellen**
#
# ```
# TODO: Erstellt eine neue Skizze auf der YZ-Ebene (Seitenansicht der Tasse)
# Menü: Part Design → Create Sketch
# Auswahl: YZ-Ebene
# ```
#
# **Schritt 2: Henkel-Querschnitt zeichnen**
#
# ```
# TODO: Zeichnet den Querschnitt des Henkels
#
# 1. Positioniert euch seitlich zur Tasse (Y-Z-Ansicht)
# 2. Zeichnet ein Rechteck oder einen Kreis als Henkelquerschnitt
#    - Breite: ca. 8 mm
#    - Höhe: ca. 5 mm
# 3. Positioniert den Querschnitt neben der Tassenwand (ca. bei Y = 42 mm, Z = 40 mm)
# ```
#
# ```
# TODO: Schließt die Skizze
# ```
#
# **Schritt 3: Henkel extrudieren (entlang eines Pfades - vereinfacht)**
#
# **💡 Alternative für Einsteiger:** Erstellt den Henkel als separaten Grundkörper und fügt ihn später hinzu:
#
# ```
# TODO: Methode 1 - Einfacher Henkel aus Grundkörpern
#
# 1. Erstellt einen Torus (Ringteil):
#    Menü: Part → Create Primitives → Torus
#    Major radius: 25 mm
#    Minor radius: 4 mm
#
# 2. Positioniert den Torus seitlich an der Tasse:
#    - Wählt den Torus im Modellbaum
#    - Placement → Position: X = 40 mm, Y = 0, Z = 40 mm
#    - Rotation: X-Achse = 0°, Y-Achse = 90°, Z-Achse = 0°
#
# 3. Schneidet den Henkel zurecht mit Boolean Difference:
#    - Erstellt einen Quader, der die Hälfte des Torus verdeckt
#    - Subtrahiert den Quader vom Torus
#
# 4. Verbindet Henkel und Tasse:
#    Menü: Part → Boolean → Union
#    Wählt Tasse und Henkel aus
# ```
#
# **💡 Hinweis für Fortgeschrittene:** Ihr könnt auch das **Sweep**-Werkzeug verwenden, um den Henkel entlang eines gebogenen Pfades zu extrudieren. Dies ist jedoch fortgeschritten!
#
# ---
#
# ## ✨ Aufgabe 4: Verfeinerungen
#
# Gebt eurer Tasse den letzten Schliff!
#
# **Zu erledigen:**
#
# ```
# TODO: Fügt Abrundungen hinzu
#
# 1. Rundet die obere Kante der Tasse ab:
#    Menü: Part Design → Fillet
#    Wählt die obere äußere Kante
#    Radius: 2 mm
#
# 2. Rundet die Kanten am Henkel ab (falls zutreffend)
#    Radius: 1-2 mm
# ```
#
# **Optional: Dekoration hinzufügen**
#
# ```
# TODO: Fügt eine Gravur oder ein Muster hinzu
#
# Idee 1: Text auf der Tasse
# 1. Erstellt eine Skizze auf der Außenfläche der Tasse
# 2. Fügt Text ein: Menü: Sketch → Geometries → Create Text
# 3. Verwendet Pocket, um den Text einzugravieren (Tiefe: 0.5 mm)
#
# Idee 2: Rillen als Dekorationselement
# 1. Erstellt eine Skizze mit horizontalen Linien
# 2. Verwendet Pocket in einem kreisförmigen Muster
# ```
#
# ---
#
# ## 🔍 Aufgabe 5: Überprüfung und Export
#
# **Überprüft euer Modell:**
#
# ```
# TODO: Dreht die Ansicht und betrachtet die Tasse aus allen Winkeln
#
# - Sind alle Proportionen stimmig?
# - Gibt es scharfe Kanten, die noch abgerundet werden sollten?
# - Ist der Henkel richtig positioniert?
# ```
#
# **Exportiert das Modell:**
#
# ```
# TODO: Export als STL für 3D-Druck
#
# Menü: File → Export
# Format: ?
# Dateiname: Kaffeetasse.stl
# ```
#
# **Erstellt eine technische Zeichnung (optional):**
#
# ```
# TODO: Wechselt zum TechDraw-Arbeitsbereich
# Menü: Workbench → ?
#
# TODO: Erstellt eine neue Zeichnungsseite
# Menü: TechDraw → ?
#
# TODO: Fügt Ansichten ein (Vorderansicht, Draufsicht)
# Menü: TechDraw → Insert View
#
# TODO: Fügt Bemaßungen hinzu
# ```
#
# ---
#
# ## 🎯 Zusatzaufgabe: Untertasse erstellen
#
# Für diejenigen, die schneller fertig sind oder eine zusätzliche Herausforderung suchen:
#
# **Aufgabe:** Konstruiert eine passende Untertasse zur Kaffeetasse.
#
# **Anforderungen:**
# - Flacher, runder Teller mit leicht erhöhtem Rand
# - Durchmesser: ca. 120-140 mm
# - Vertiefung in der Mitte für die Tasse (Durchmesser passend zum Tassenboden)
# - Dicke: ca. 3-5 mm
#
# **💡 Hinweis:** Auch die Untertasse ist rotationssymmetrisch – verwendet wieder die Revolution-Methode!
#
# **Schritte:**
#
# ```
# TODO: Erstellt einen neuen Body für die Untertasse
#
# TODO: Zeichnet das Profil:
# 1. Flacher Boden (Durchmesser ca. 70 mm)
# 2. Leicht nach oben gewölbter Tellerrand
# 3. Erhöhter Außenrand (ca. 3 mm hoch)
#
# TODO: Rotiert das Profil um 360°
#
# TODO: Fügt eine kreisförmige Vertiefung hinzu (Pocket)
# ```
#
# ---
#
# ## 💭 Reflexionsfragen
#
# Nachdem ihr eure Kaffeetasse fertiggestellt habt, denkt über folgende Fragen nach:
#
# 1. **Welche Konstruktionsmethode** war am nützlichsten für euer Projekt?
# 2. **Welche Herausforderungen** seid ihr begegnet? Wie habt ihr sie gelöst?
# 3. **Was würdet ihr anders machen**, wenn ihr das Projekt noch einmal konstruieren würdet?
# 4. **Welche anderen Alltagsobjekte** könnt ihr euch vorstellen, mit den gelernten Techniken zu konstruieren?
# 5. Wäre eure Tasse **3D-druckbar**? Gibt es Überhänge, die Stützen benötigen würden?
#
# ---
#
# ## 🌟 Bonusideen für eigene Projekte
#
# Falls ihr nach der Tasse noch Lust auf mehr habt, hier sind weitere Projektideen:
#
# **Nützliche Alltagsobjekte:**
# - Handyhalter (mit Aussparungen für Ladekabel)
# - Stiftehalter mit mehreren Fächern
# - Seifenschale mit Abtropflöchern
# - Kabelorganizer / Kabelhalter
# - Schlüsselanhänger mit Gravur
# - Zahnbürstenhalter
#
# **Mechanische Teile:**
# - Einfaches Zahnrad (mit Zähnen als linearem Muster)
# - Riemenscheibe
# - Flaschenöffner
# - Verschlusskappe
#
# **Dekorative Objekte:**
# - Vase mit interessantem Profil
# - Kerzenhalter
# - Kleine Skulptur oder Figur
# - Spielfigur (Würfel, Spielstein)
#
# **💡 Tipp:** Wählt ein Projekt, das eurem Kenntnisstand entspricht. Beginnt einfach und steigert die Komplexität!
#
# ---
#
# ## 🎓 Hinweise zur Lösung (nicht sofort anschauen!)
#
# <details>
# <summary>💡 Hinweis zum Tassenkörper</summary>
#
# Die Tasse ist ein **Rotationskörper**. Zeichnet das halbe Profil (Schnittansicht) als geschlossene Kontur und rotiert es um die Mittelachse mit der **Revolution**-Funktion. Achtet darauf, dass die Kontur die Rotationsachse berührt!
#
# </details>
#
# <details>
# <summary>💡 Hinweis zum Henkel</summary>
#
# Der Henkel ist der schwierigste Teil! Für Einsteiger ist es am einfachsten, den Henkel aus **Grundkörpern** (z.B. Torus) zu erstellen und dann mit der Tasse zu verschmelzen (**Boolean Union**). Fortgeschrittene können das **Sweep**- oder **Loft**-Werkzeug verwenden.
#
# </details>
#
# <details>
# <summary>💡 Hinweis zu Abrundungen</summary>
#
# Fügt Abrundungen am Ende hinzu, nicht am Anfang! Wählt die Kanten aus, die abgerundet werden sollen, und verwendet **Part Design → Fillet** mit einem Radius von 1-3 mm. Das macht das Modell realistischer und angenehmer in der Handhabung.
#
# </details>
#
# <details>
# <summary>💡 Hinweis zur Untertasse</summary>
#
# Die Untertasse funktioniert nach dem gleichen Prinzip wie die Tasse: **Revolution** eines Profils. Zeichnet einen flachen Teller mit leicht erhöhtem Rand und fügt mit **Pocket** eine kreisförmige Vertiefung für die Tasse hinzu.
#
# </details>
#
# ---
#
# ## ✅ Checkliste für euer Projekt
#
# Bevor ihr euer Projekt als abgeschlossen betrachtet, überprüft folgende Punkte:
#
# - [ ] Projekt geplant (Skizze, Maße, Konstruktionsschritte)
# - [ ] Tassenkörper mit Revolution erstellt
# - [ ] Henkel hinzugefügt (in irgendeiner Form)
# - [ ] Abrundungen an wichtigen Kanten
# - [ ] Modell aus verschiedenen Perspektiven überprüft
# - [ ] Als STL exportiert
# - [ ] (Optional) Technische Zeichnung erstellt
# - [ ] (Optional) Untertasse konstruiert
#
# ---
#
# **Viel Erfolg bei eurem Projekt! Ihr schafft das! ☕🚀**
#
# Bei Fragen oder Problemen: Schaut in Modul 8c für die vollständige Lösung oder fragt eure Dozentin/euren Dozenten!
