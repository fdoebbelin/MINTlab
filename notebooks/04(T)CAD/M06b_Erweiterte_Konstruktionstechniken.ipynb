# %% [markdown]
# # M06b – Erweiterte Konstruktionstechniken (Übungsaufgaben mit Hinweisen)
#
# ## 📌 Lernziele dieser Übung
#
# Nach dieser Lektion kannst du:
# - Ein Feature spiegeln und dabei Symmetrieebenen korrekt wählen
# - Lineare und polare Muster erzeugen
# - Fillets und Chamfers gezielt auf Kanten anwenden
# - Einfache technische Bauteile optimieren
#
# ---
#
# ## ✅ Aufgabe 1: Spiegeln einer Aussparung
#
# **Ziel:** Eine Platte mit asymmetrischer Aussparung wird durch Spiegeln symmetrisch gemacht.
#
# **Vorbereitung:**
# 1. Öffne FreeCAD und starte ein neues Projekt
# 2. Erstelle eine **Basis-Platte:**
#    - Neuer Sketch auf der XY-Ebene
#    - Rechteck: 100 × 80 mm
#    - Sketch beenden
#    - Pad: Höhe 10 mm
#
# 3. Erstelle eine **Aussparung (Pocket):**
#    - Neuer Sketch auf der Oberseite der Platte
#    - Rechteck: 30 × 20 mm, positioniert in einer **Ecke** (z.B. oben links)
#    - Sketch beenden
#    - Pocket: Tiefe 3 mm
#
# **Aufgabe:**
# - [ ] Führe im Modellbaum einen Rechtsklick auf das Pocket aus
# - [ ] Wähle `Mirrored`
# - [ ] Im Dialog: Wähle die **YZ-Ebene** aus
# - [ ] Klicke `OK`
#
# **Hinweis:** Wenn du nicht sicher bist, welche Ebene du wählen sollst:
# - YZ-Ebene spiegelt entlang der X-Richtung (links-rechts)
# - XZ-Ebene spiegelt entlang der Y-Richtung (vorne-hinten)
#
# **Überprüfung:**
# - Ist die Aussparung jetzt auf beiden Seiten vorhanden?
# - Sind die Aussparungen symmetrisch angeordnet?
#
# ---
#
# ## ✅ Aufgabe 2: Lineares Muster – Bohrungsreihe
#
# **Ziel:** 5 gleichmäßig angeordnete Bohrungen in einer Reihe erzeugen.
#
# **Vorbereitung:**
# 1. (Du kannst die Platte aus Aufgabe 1 weiterverwenden)
# 2. Erstelle eine **einzelne Bohrung:**
#    - Neuer Sketch auf der Oberseite
#    - Kreis: Ø 8 mm, zentriert bei (20 mm, 40 mm)
#    - Sketch beenden
#    - Pocket: Durchgangloch (z.B. Tiefe 10 mm)
#
# **Aufgabe:**
# - [ ] Wähle das Pocket (Bohrung) im Modellbaum
# - [ ] Rechtsklick → `LinearPattern`
# - [ ] Im Dialog:
#   - **Direction:** X-Achse
#   - **Occurrences:** 5 (insgesamt 5 Bohrungen)
#   - **Spacing:** 20 mm
# - [ ] Klicke `OK`
#
# **Hinweis:**
# - **Occurrences = 5** bedeutet: 1 Original + 4 Kopien = 5 insgesamt
# - **Spacing = 20 mm** ist der Abstand zwischen den Bohrungsmitten
#
# **Überprüfung:**
# - Erscheinen 5 Bohrungen hintereinander?
# - Sind die Abstände korrekt (20 mm)?
#
# ---
#
# ## ✅ Aufgabe 3: Polares Muster – Lochkreis
#
# **Ziel:** 6 Bohrungen gleichmäßig um einen Mittelpunkt verteilen (Lochkreis).
#
# **Vorbereitung:**
# 1. Erstelle neue Platte oder verwende eine bestehende (z.B. ein neues Rechteck 100 × 100 × 10 mm)
# 2. Erstelle eine **Bohrung nahe dem Rand:**
#    - Neuer Sketch auf Oberseite
#    - Kreis: Ø 6 mm, positioniert z.B. 40 mm vom Mittelpunkt entfernt
#    - Sketch beenden
#    - Pocket: Durchgangloch
#
# **Aufgabe:**
# - [ ] Wähle das Pocket im Modellbaum
# - [ ] Rechtsklick → `PolarPattern`
# - [ ] Im Dialog:
#   - **Axis:** Z-Achse
#   - **Occurrences:** 6
#   - **Angle:** 360° (wird automatisch auf 60° pro Loch verteilt)
# - [ ] Klicke `OK`
#
# **Hinweis:**
# - Das polare Muster verteilt die Features gleichmäßig um die gewählte Achse
# - 360° bei 6 Vorkommen = 60° Winkelabstand pro Bohrung
#
# **Überprüfung:**
# - Sehen die 6 Bohrungen aus wie ein Lochkreis?
# - Sind sie gleichmäßig verteilt (visuell in 60°-Schritten)?
#
# ---
#
# ## ✅ Aufgabe 4: Fillet – Kanten abrunden
#
# **Ziel:** Alle äußeren Kanten einer Platte mit einem Radius abrunden.
#
# **Vorbereitung:**
# 1. Verwende eine einfache Platte (z.B. 80 × 60 × 10 mm aus den vorherigen Aufgaben)
# 2. Stelle sicher, dass du im **Part Design** Arbeitsbereich bist (Dropdown oben links)
#
# **Aufgabe:**
# - [ ] Menü: `Part Design → Create a fillet` (oder Werkzeugleiste)
# - [ ] Klicke im 3D-Fenster auf die **Oberkanten** der Platte
#   - Vier lange Kanten + vier Eckkanten
#   - Tipp: Mit Shift+Klick mehrere Kanten nacheinander auswählen
# - [ ] Im Dialog:
#   - **Radius:** 2 mm
# - [ ] Klicke `OK`
#
# **Hinweis:**
# - Beginne mit den längeren Kanten, um die Auswahl zu vereinfachen
# - Du kannst einzelne Kanten abwählen, indem du mit Strg+Klick darauf klickst
#
# **Überprüfung:**
# - Sind die Kanten jetzt gerundet?
# - Sieht die Platte „weicher" und professioneller aus?
#
# ---
#
# ## ✅ Aufgabe 5: Chamfer – Kanten abschrägen
#
# **Ziel:** Einige Kanten mit einer Fase versehen.
#
# **Vorbereitung:**
# 1. Verwende eine Platte mit Bohrungen (aus Aufgabe 3)
#
# **Aufgabe:**
# - [ ] Menü: `Part Design → Create a chamfer`
# - [ ] Klicke im 3D-Fenster auf die **Bohrungskanten** (oben und unten)
# - [ ] Im Dialog:
#   - **Chamfer Size:** 0,5 mm
#   - **Type:** Size (Standard)
# - [ ] Klicke `OK`
#
# **Hinweis:**
# - Chamfer ist ideal für Bohrungen und Eingriffsseiten, damit sich spitze Ecken nicht verletzungsfördernd anfassen
# - Die Fase ist flach/gerade, nicht rund wie beim Fillet
#
# **Überprüfung:**
# - Sind die Bohrungskanten jetzt gebrochen/abgeschrägt?
# - Wirkt das Bauteil robuster?
#
# ---
#
# ## ✅ Aufgabe 6: Kombination aller Techniken – Mini-Projekt
#
# **Ziel:** Baue ein technisches Bauteil, das alle erlernten Techniken kombiniert.
#
# **Aufgabenstellung:**
# Konstruiere eine **"Halterplatte mit Lochkreis":**
#
# 1. **Basis:** Rechteckige Platte 120 × 80 × 12 mm
# 2. **Mittige Bohrung:** Ø 20 mm in der Mitte (durchgehend)
# 3. **Aussparung:** Eine rechteckige Vertiefung (50 × 30 mm, Tiefe 4 mm) auf einer Seite → **spiegeln**
# 4. **Lochkreis:** 4 Bohrungen (Ø 6 mm) um die Mittelbohrung herum in Kreisform
# 5. **Abrundungen:** Alle Außenkanten mit 1,5 mm Fillet
# 6. **Fasen:** Alle Bohrungskanten mit 0,3 mm Chamfer
#
# **Schritt-für-Schritt:**
# - [ ] Schritt 1: Erstelle die Basis-Platte (Pad)
# - [ ] Schritt 2: Zentrale Bohrung (Pocket)
# - [ ] Schritt 3: Rechteckige Aussparung (Pocket) → Spiegeln
# - [ ] Schritt 4: Bohrungen mit PolarPattern anordnen
# - [ ] Schritt 5: Fillet auf Außenkanten anwenden
# - [ ] Schritt 6: Chamfer auf Bohrungen anwenden
# - [ ] Speichere das Projekt als `Halterplatte_Modul06.FCStd`
#
# **Hinweis:** Arbeitsvorgangsfolge ist wichtig! Spiegeln, bevor du Muster anwendest.
#
# **Überprüfung:**
# - Sieht das Bauteil professionell und symmetrisch aus?
# - Sind alle Features korrekt angewendet?
# - Kannst du das Modell drehen und von allen Seiten sehen?
#
# ---
#
# ## 💭 Reflexionsfragen
#
# 1. **Spiegeln:** Wann würde ich Spiegeln statt manuelles Kopieren verwenden?
# 2. **Pattern:** Was ist der Vorteil von LinearPattern gegenüber mehrfacher Duplikation?
# 3. **Polar:** In welchen realen Objekten findest du polare Muster? (Tipp: Räder, Turbinen, Flansche)
# 4. **Fillet vs. Chamfer:** Welcher Unterschied fällt dir auf, wenn du beide auf eine Kante anwendest?
# 5. **Reihenfolge:** Warum sollte man Mirror/Pattern VOR Fillet anwenden?
#
# ---
#
# ## 🎯 Checkpoint: Checkliste zum Abschluss
#
# Bevor du zum nächsten Modul gehst, überprüfe:
#
# - [ ] Ich kann eine Feature spiegeln und die richtige Ebene wählen
# - [ ] Ich verstehe den Unterschied zwischen linearem und polarem Muster
# - [ ] Ich kann Fillets auf mehrere Kanten anwenden
# - [ ] Ich weiß, wann ich Chamfer statt Fillet nutze
# - [ ] Ich habe die Halterplatte erfolgreich konstruiert
# - [ ] Ich kann die Menübefehle ohne Hinweis finden
#
# ---
#
# ## 📞 Häufig gestellte Fragen (FAQ)
#
# **F: Ich habe die Spiegelungsebene falsch gewählt – was tun?**
# A: Undo (Strg+Z) drücken, Mirrored erneut versuchen und eine andere Ebene auswählen.
#
# **F: Mein Pattern sieht asymmetrisch aus – warum?**
# A: Überprüfe:
# - Ist die Occurrences-Zahl korrekt?
# - Ist der Spacing-Abstand korrekt?
# - Ist die Richtung/Achse korrekt?
#
# **F: Die Fillets überlapppen sich und wirken seltsam – was ist das?**
# A: Das kann bei zu großen Radien an benachbarten Kanten passieren. Verkleinere den Fillet-Radius oder wende Fillet auf weniger Kanten auf einmal an.
