# %% [markdown]
# # M06a – Erweiterte Konstruktionstechniken (Demonstration & Einführung)
#
# ## 📌 Modulübersicht
# **Thema:** Spiegelungen, Muster (Pattern), Abrundungen (Fillet) und Fasen (Chamfer) in FreeCAD
# **Lernziele:**
# - Symmetrische Strukturen durch Spiegeln erstellen
# - Wiederholte Elemente mit linearen und polaren Mustern erzeugen
# - Kanten mit Fillets abrunden und mit Chamfers abschrägen
# - Diese Techniken zur Konstruktionsbeschleunigung nutzen
#
# **Voraussetzungen:** Module 1–5 sollten absolviert sein (Grundkörper, Transformationen, Boolesche Operationen, Sketcher, Pad/Pocket/Revolution)
#
# ---
#
# ## 🎯 Einleitung
#
# Nach dem Erlernen der Grundlagen von Pad, Pocket und Revolution steht nun die **Optimierung und Verfeinerung** von 3D-Modellen im Fokus. In der realen Produktentwicklung hat man oft mit **symmetrischen Anordnungen**, **wiederholten Elementen** und **scharfen Kanten** zu tun.
#
# Dieses Modul zeigt drei mächtige Techniken:
#
# 1. **Spiegeln (Mirror):** Erzeugt Symmetrie, ohne manuell jeden Teil zu kopieren
# 2. **Muster (Pattern):** Vervielfältigt Features in regelmäßigen Abständen
# 3. **Fillet & Chamfer:** Verfeinert die Ästhetik und Funktionalität durch abgerundete oder gebrochene Kanten
#
# Diese Techniken sind in der Industrie unverzichtbar – von Maschinenbauteilen mit gleichmäßig verteilten Bohrungen bis zu ergonomisch gestalteten Konsumerprodukten.
#
# ---
#
# ## 📚 Theoretische Grundlagen
#
# ### 1. Spiegeln (Mirror-Funktion)
#
# **Konzept:** Ein vorhandenes Feature oder ein kompletter Körper wird an einer Symmetrieebene gespiegelt.
#
# - **Ebenen** in FreeCAD: XY, XZ, YZ (oder benutzerdefiniert)
# - **Anwendung:** Eine Aussparung oder ein Vorsprung auf einer Seite wird automatisch auf der anderen Seite erzeugt
# - **Vorteil:** Spart Zeit bei symmetrischen Bauteilen
#
# **Beispiel:** Eine Flanschplatte mit einer asymmetrischen Aussparung – durch Spiegeln wird die Aussparung automatisch auf die andere Seite kopiert.
#
# ### 2. Muster (Pattern/Array)
#
# Es gibt zwei Varianten:
#
# **a) Lineares Muster:**
# - Feature wird in einer geraden Linie mit gleichmäßigen Abständen wiederholt
# - Anwendung: Reihen von Bohrungen, Schlitze nebeneinander
#
# **b) Polares Muster (Circular Pattern):**
# - Feature wird um einen Mittelpunkt (Achse) verteilt
# - Anwendung: Bohrungen auf einem Kreis verteilen, Turbinenschaufeln um eine Achse anordnen
#
# **Parameter:**
# - Anzahl der Kopien
# - Abstand/Winkel zwischen den Kopien
# - Achse oder Richtung
#
# ### 3. Abrundung (Fillet) und Fase (Chamfer)
#
# **Fillet (Abrundung):**
# - Erzeugt einen glatten, runden Übergang an einer oder mehreren Kanten
# - Technische Gründe: Stabilität, Sicherheit (keine scharfen Ecken), Ergonomie
# - Stilistische Gründe: Modernes, wertiges Aussehen
#
# **Chamfer (Fase):**
# - Schneidet die Kante schräg ab (nicht rund, sondern planar)
# - Verwendung: Leichtere Montage (Passstücke passen besser), Reduktion von Graten
# - Parameter: Fasewinkel oder -tiefe
#
# ---
#
# ## 🔧 FreeCAD: Schritt-für-Schritt Demonstrationen
#
# ### Demo 1: Spiegeln eines Features
#
# **Ziel:** Eine Platte mit einer asymmetrischen Aussparung wird gespiegelt.
#
# **Menüpfade in FreeCAD:**
#
# 1. **Basis-Körper erstellen:**
#    - `Part Design → Create a pad` → Quader 100 × 80 × 10 mm (über Sketch)
#
# 2. **Pocket (Aussparung) erzeugen:**
#    - `Part Design → Create a pocket` → Z.B. eine rechteckige Vertiefung in der Ecke (40 × 20 mm, Tiefe 3 mm)
#
# 3. **Pocket spiegeln:**
#    - Pocket im Modellbaum auswählen
#    - Menü: `Part Design → Mirrored` (oder Rechtsklick → Mirrored)
#    - **Dialog öffnet sich:**
#      - **Mirror plane:** XZ-Ebene auswählen (Y-Richtung spiegeln)
#      - **OK** klicken
#
# → Das Pocket wird nun auf der gegenüberliegenden Seite automatisch dupliziert.
#
# **FreeCAD-Menücode (vereinfacht):**
# ```
# Menü → Part Design → Mirrored
# Oder: Rechtsklick auf Feature → Mirrored
# Ebenenwahl im Dialog → XZ oder YZ auswählen
# ```
#
# ---
#
# ### Demo 2: Lineares Muster
#
# **Ziel:** Eine Reihe von 5 identischen Bohrungen mit 20 mm Abstand erzeugen.
#
# **Schritt-für-Schritt:**
#
# 1. **Grund-Pocket erstellen:**
#    - Sketch mit Kreis (Ø 8 mm) zeichnen
#    - `Part Design → Create a pocket` → Loch erzeugen
#
# 2. **Pocket duplizieren (Linear Pattern):**
#    - Pocket im Modellbaum auswählen
#    - Menü: `Part Design → LinearPattern` (oder Rechtsklick → LinearPattern)
#    - **Dialog öffnet sich:**
#      - **Direction:** X-Achse auswählen (in welche Richtung wiederholen?)
#      - **Occurrences:** 5 (Wie viele Kopien insgesamt, inkl. Original?)
#      - **Spacing:** 20 mm
#      - **OK**
#
# → 5 Bohrungen in einer Reihe mit je 20 mm Abstand.
#
# **FreeCAD-Menücode:**
# ```
# Menü → Part Design → LinearPattern
# Oder: Rechtsklick auf Feature → LinearPattern
# Richtung, Anzahl, Abstand im Dialog einstellen
# ```
#
# ---
#
# ### Demo 3: Polares Muster (Lochkreis)
#
# **Ziel:** 6 Bohrungen gleichmäßig auf einem Kreis verteilen (z.B. wie bei einer Flanschplatte).
#
# **Schritt-für-Schritt:**
#
# 1. **Grund-Pocket erzeugen:**
#    - (wie in Demo 2 – eine Bohrung)
#
# 2. **Polares Muster anwenden:**
#    - Pocket auswählen
#    - Menü: `Part Design → PolarPattern` (oder Rechtsklick → PolarPattern)
#    - **Dialog öffnet sich:**
#      - **Axis:** Z-Achse auswählen (um welche Achse drehen?)
#      - **Occurrences:** 6 (6 Bohrungen total)
#      - **Angle:** 360° (vollständiger Kreis) – wird automatisch auf 60° pro Schritt berechnet
#      - **OK**
#
# → 6 gleichmäßig verteilte Bohrungen in einem Kreis.
#
# **FreeCAD-Menücode:**
# ```
# Menü → Part Design → PolarPattern
# Oder: Rechtsklick auf Feature → PolarPattern
# Achse, Anzahl, Gesamtwinkel im Dialog einstellen
# ```
#
# ---
#
# ### Demo 4: Fillet (Abrundung)
#
# **Ziel:** Alle scharfen Kanten eines Quaders abrunden.
#
# **Schritt-für-Schritt:**
#
# 1. **Quader erstellen:**
#    - (aus Modul 1–2 bekannt)
#
# 2. **Fillet anwenden:**
#    - Im Part-Design-Arbeitsbereich bleiben
#    - Menü: `Part Design → Create a fillet` (oder Werkzeugleiste)
#    - **Kanten auswählen:** Mit der Maus auf die gewünschten Kanten im 3D-Modell klicken
#      - Alle 12 Kanten eines Quaders nacheinander anklicken (oder mit Shift+Klick mehrere auswählen)
#    - **Radius:** Z.B. 2 mm eingeben
#    - **OK**
#
# → Alle Kanten des Quaders sind jetzt mit 2 mm Radius abgerundet.
#
# **FreeCAD-Menücode:**
# ```
# Menü → Part Design → Create a fillet
# Oder: Werkzeugleiste → Fillet-Icon
# Kanten im 3D-Fenster anklicken (Shift für Mehrfachauswahl)
# Radius eingeben → OK
# ```
#
# ---
#
# ### Demo 5: Chamfer (Fase)
#
# **Ziel:** Einige Kanten abschrägen (anstatt rund abgerundet).
#
# **Schritt-für-Schritt:**
#
# 1. **Objekt mit scharfen Kanten:**
#    - (z.B. der Quader aus Demo 4)
#
# 2. **Chamfer anwenden:**
#    - Menü: `Part Design → Create a chamfer` (oder Werkzeugleiste)
#    - **Kanten auswählen:** Besonders bei z.B. Durchgangsöffnungen oder Ecken
#    - **Chamfer Size:** Z.B. 1 mm eingeben (Größe der Fase)
#    - **Type:** Alternativ auch Winkel statt Tiefe wählbar
#    - **OK**
#
# → Die ausgewählten Kanten sind nun gebrochen/abgeschrägt.
#
# **FreeCAD-Menücode:**
# ```
# Menü → Part Design → Create a chamfer
# Oder: Werkzeugleiste → Chamfer-Icon
# Kanten auswählen → Größe eingeben → OK
# ```
#
# ---
#
# ## 💡 Praktisches Anwendungsbeispiel: Flanschplatte mit allen Techniken
#
# **Aufgabe:** Eine Flanschplatte (80 × 60 × 10 mm) mit:
# - Einer Aussparung (später gespiegelt)
# - 4 Bohrungen in einem Kreis
# - Abgerundeten Außenkanten
# - Gefasten Bohrungskanten
#
# **Ablauf:**
#
# 1. **Platte erzeugen:** Pad 80 × 60 × 10 mm
# 2. **Pocket (Aussparung):** Rechteck 30 × 20 mm, Tiefe 3 mm – auf einer Seite
# 3. **Mirror:** Pocket spiegeln an der YZ-Ebene
# 4. **Bohrungen:** 4 Pockets (Ø 6 mm) als lineares Muster oder einzeln
# 5. **Polar Pattern:** Diese 4 Bohrungen um die Z-Achse verteilen (4 Vorkommen, 90° verteilt)
#    - *Hinweis:* Ggf. müssen Bohrungen anders platziert werden – alternativ erst ein Pocket, dann PolarPattern auf dieses anwenden
# 6. **Fillet:** Alle Außenkanten der Platte mit 2 mm Radius abrunden
# 7. **Chamfer:** Bohrungskanten mit 0,5 mm Fase versehen
#
# **Ergebnis:** Ein professionell wirkendes, symmetrisches Bauteil mit Details.
#
# ---
#
# ## 🎓 Zusammenfassung der Menübefehle
#
# | Funktion | Menüpfad | Tastenkürzel / Alternative |
# |----------|----------|---------------------------|
# | Mirrored (Spiegeln) | `Part Design → Mirrored` | Rechtsklick auf Feature → Mirrored |
# | LinearPattern | `Part Design → LinearPattern` | Rechtsklick auf Feature → LinearPattern |
# | PolarPattern | `Part Design → PolarPattern` | Rechtsklick auf Feature → PolarPattern |
# | Fillet (Abrundung) | `Part Design → Create a fillet` | Werkzeugleiste oder Rechtsklick |
# | Chamfer (Fase) | `Part Design → Create a chamfer` | Werkzeugleiste oder Rechtsklick |
#
# ---
#
# ## 🔗 Anhang: Wichtige Hinweise
#
# **Arbeitsbereich:** Stelle sicher, dass du dich im **Part Design** Arbeitsbereich befindest. Falls nicht:
# - Oben links: Dropdown-Menü → Part Design auswählen
#
# **Modellbaum:** Alle Features sind im linken Baum sichtbar. Du kannst sie dort anklicken und mit Rechtsklick bearbeiten oder löschen.
#
# **Undo/Redo:** Wie üblich mit Strg+Z (Undo) und Strg+Y (Redo).
