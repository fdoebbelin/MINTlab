# %% [markdown]
# # M05a: Von der Skizze zum 3D-Modell – Demonstration und Einführung
#
# ## 📌 Einleitung und Lernziele
#
# **Was lernst du in diesem Modul?**
#
# Nachdem du in den vorherigen Modulen gelernt hast, wie du einfache 3D-Grundkörper erstellst, sie transformierst und mit Boolschen Operationen kombinierst, wirst du jetzt einen neuen Weg kennenlernen: **Du wirst deine eigenen 2D-Skizzen in echte 3D-Körper verwandeln.**
#
# In diesem Modul lernst du zwei grundlegende Methoden:
#
# 1. **Extrusion (Pad)** – Deine 2D-Skizze wird wie ein Kissen aufgepolstert und wird zu einem 3D-Körper
# 2. **Rotation (Revolution)** – Deine 2D-Skizze wird um eine Achse gedreht und erzeugt runde, rotationssymmetrische Formen
# 3. **Pocket (Tasche)** – Du schneidest Material aus einem bestehenden Körper heraus, indem du eine Skizze subtrahierst
#
# Am Ende dieses Moduls kannst du **ein mehrstufiges Bauteil konstruieren**, das mehrere dieser Techniken kombiniert – zum Beispiel eine Platte mit Bohrungen oder einen Drehkörper.
#
# ---
#
# ## 🎯 Lernziele dieses Moduls
#
# Nach diesem Modul kannst du:
#
# - ✅ Eine Skizze mit dem **Pad-Befehl extrudieren** und dadurch quaderförmige oder prismatische 3D-Körper erzeugen
# - ✅ Eine Skizze mit dem **Revolution-Befehl** um eine Achse rotieren und runde Bauteile (Drehteile) konstruieren
# - ✅ Den **Unterschied zwischen additiv (Material hinzufügen) und subtraktiv (Material abnehmen)** erkennen und anwenden
# - ✅ Mit **Pocket (Tasche)** Material aus einem Körper entfernen – z.B. Löcher, Nuten oder Vertiefungen erstellen
# - ✅ Ein **mehrstufiges 3D-Modell aufbauen**, das mehrere Features hintereinander anwendet
#
# ---
#
# ## 🔧 Teil 1: Extrusion – Vom Rechteck zum Quader (Pad)
#
# ### Was ist eine Extrusion (Pad)?
#
# Eine **Extrusion** ist das einfachste Verfahren, eine 2D-Skizze in 3D zu verwandeln. Stell dir vor, deine flache Zeichnung wird wie ein Kissen aufgepumpt – oder wie Papier, das du in Richtung der Blattfläche auseinander ziehst.
#
# **Praktisches Beispiel:** Du zeichnest ein Rechteck und „drückst" es dann in die Höhe – heraus kommt ein Quader.
#
# ### Schritt-für-Schritt: Eine einfache Extrusion erstellen
#
# **Schritt 1: FreeCAD öffnen und ein neues Dokument erstellen**
#
# ```freecad-code
# # Im Menü: Datei → Neu
# # Oder: Strg + N
# ```
#
# **Schritt 2: Zum Part Design Arbeitsbereich wechseln**
#
# ```freecad-code
# # Menü: Ansicht → Arbeitsbereiche
# # Wähle: Part Design
# # (oder nutze das Dropdown-Menü rechts oben in FreeCAD)
# ```
#
# **Schritt 3: Eine neue Skizze anlegen**
#
# ```freecad-code
# # Menü: Skizze → Neue Skizze erstellen
# # Oder: Klick auf das Symbol in der Werkzeugleiste (ein weißes Blatt mit Stift)
# # Ein Dialog erscheint: Wähle die XY-Ebene (oder eine andere Ebene) → OK
# ```
#
# Nach Klick auf OK befindest du dich im **Sketcher-Modus** – erkennbar an der grünen Arbeitsebene und den Sketcher-Werkzeugen.
#
# **Schritt 4: Ein einfaches Rechteck zeichnen**
#
# ```freecad-code
# # Menü: Skizze → Geometrie → Rechteck
# # Oder: Klick auf das Rechteck-Symbol in der Werkzeugleiste
# ```
#
# Zeichne jetzt ein Rechteck, indem du zwei Punkte mit der Maus setzt:
# - Erster Klick: linker unterer Punkt (z.B. bei Koordinate 0, 0)
# - Zweiter Klick: rechter oberer Punkt (z.B. bei Koordinate 10, 20 – die genauen Werte sind jetzt nicht wichtig)
#
# **Schritt 5: Skizze bemaßen und schließen**
#
# ```freecad-code
# # Menü: Skizze → Skizze verlassen
# # Oder: Klick auf den grünen Haken oben links (oder drücke ESC)
# ```
#
# Nach Verlassen des Sketchers siehst du die Skizze als weiße Linien in der 3D-Ansicht. Wenn die Skizze gelb ist, ist sie noch nicht vollständig definiert – das ist für dieses erste Beispiel aber okay.
#
# **Schritt 6: Die Extrusion (Pad) erstellen**
#
# Jetzt kommt der Zaubertrick: Wir verwandeln diese 2D-Skizze in 3D!
#
# ```freecad-code
# # Stelle sicher, dass deine Skizze in der Modellbaum-Liste ausgewählt ist
# # Menü: Part Design → Pad
# # Oder: Klick auf das Pad-Symbol in der Werkzeugleiste (ein Kissen-ähnliches Symbol)
# ```
#
# Ein Dialog-Fenster erscheint: **Pad-Parameter**
#
# Im Feld „Länge" kannst du eingeben, wie hoch dein Quader sein soll. Gib z.B. **30 mm** ein.
#
# ```freecad-code
# # Länge: 30 (mm)
# # Klick OK oder drücke Enter
# ```
#
# **✨ Voilà!** Dein flaches Rechteck ist jetzt ein echter **3D-Quader**!
#
# Du kannst die Ansicht drehen (Mittlere Maustaste + Bewegung) und siehst, dass wirklich ein 3D-Körper entstanden ist.
#
# ### Warum ist das Pad nützlich?
#
# Das **Pad**-Werkzeug ist extrem vielseitig, weil:
# - Du **beliebige 2D-Formen** (nicht nur Rechtecke!) extrudieren kannst
# - Du das Ergebnis **frei formbarer** gestalten kannst als mit vorgefertigten Grundkörpern
# - Du **mehrere Pads hintereinander** anwenden kannst, um komplexe Formen zu schaffen
#
# ### 💡 Verständnisfrage 1:
# *Was passiert, wenn du eine Länge von 0 mm eingibst? Warum könnte das schiefgehen?*
#
# ---
#
# ## 🔄 Teil 2: Rotation – Runde Bauteile entstehen (Revolution)
#
# ### Was ist eine Rotation (Revolution)?
#
# Während die **Extrusion** eine Skizze einfach nach oben „zieht", **dreht die Rotation** eine Skizze um eine Achse herum. Das Ergebnis ist eine rotationssymmetrische Form – also Bauteile, die man auch „Drehteile" nennt.
#
# **Praktisches Beispiel:**
# - Du zeichnest ein Rechteck als Seitenansicht
# - Du drehst es um eine vertikale Achse
# - Heraus kommt ein **Zylinder**
#
# Oder noch interessanter:
# - Du zeichnest ein Profil wie ein Ei-Querschnitt
# - Du drehst es um eine Mittellinie
# - Heraus kommt ein **Ei-förmiges 3D-Objekt**
#
# ### Schritt-für-Schritt: Eine Rotation erstellen
#
# **Schritt 1: Eine neue Skizze für Revolution anlegen**
#
# Wir beginnen mit einem neuen Projekt, damit wir nicht durcheinander kommen.
#
# ```freecad-code
# # Datei → Neu (oder Strg + N)
# # Wechsel zum Part Design Arbeitsbereich
# # Skizze → Neue Skizze erstellen
# # Wähle die XY-Ebene → OK
# ```
#
# **Schritt 2: Ein Profil zeichnen, das wir drehen werden**
#
# Dieses Mal zeichnen wir ein Profil, das aussieht wie die Seite eines Behälters:
#
# ```freecad-code
# # Zeichne folgende Linien mit dem Linienwerkzeug:
# # Menü: Skizze → Geometrie → Linie
# # Oder: Linien-Symbol in der Werkzeugleiste
#
# # Zeichne diese Punkte nacheinander (ungefähre Koordinaten):
# Punkt 1: (0, 0)     – Anfang
# Punkt 2: (5, 0)     – nach rechts
# Punkt 3: (5, 15)    – nach oben
# Punkt 4: (3, 20)    – oben etwas eingezogen
# Punkt 5: (3, 0)     – zurück nach unten
# Punkt 6: (0, 0)     – Schleife schließen
#
# # Das Ergebnis ist eine trapezförmige Kontur
# ```
#
# Das sieht ungefähr so aus, als würdest du eine Becher-Seitenansicht zeichnen.
#
# **Schritt 3: Die Rotationsachse hinzufügen**
#
# Damit FreeCAD weiß, um welche Achse gedreht werden soll, zeichnen wir eine **Konstruktionslinie** (eine hilfreiche Linie, die nicht zum Modell gehört):
#
# ```freecad-code
# # Menü: Skizze → Geometrie → Konstruktionslinie
# # Oder: Konstruktionslinie-Symbol in der Werkzeugleiste (gestrichelt)
#
# # Zeichne eine vertikale Linie vom Punkt (0, 0) zum Punkt (0, 30)
# # Diese Linie wird unsere Rotationsachse
# ```
#
# Die **Konstruktionslinie** erkennst du daran, dass sie gestrichelt ist – sie wird nicht Teil des Modells, sondern nur als Referenz verwendet.
#
# **Schritt 4: Skizze verlassen**
#
# ```freecad-code
# # Menü: Skizze → Skizze verlassen
# # Oder: Grüner Haken / ESC
# ```
#
# **Schritt 5: Revolution anwenden**
#
# Jetzt verwandeln wir diese Skizze in ein 3D-Dreheil:
#
# ```freecad-code
# # Stelle sicher, dass die Skizze ausgewählt ist
# # Menü: Part Design → Revolution
# # Oder: Revolution-Symbol in der Werkzeugleiste (ein rotierendes Symbol)
# ```
#
# Ein Dialog-Fenster „Revolution-Parameter" erscheint.
#
# **Wichtig:** Im Feld „Achse" musst du die **Konstruktionslinie** angeben, um die gedreht werden soll:
#
# ```freecad-code
# # Im Dialog:
# # - Achse: Wähle die Konstruktionslinie aus (klick auf sie im Modellbaum oder in der 3D-Ansicht)
# # - Winkel: 360 (für eine komplette Umdrehung)
# # → OK
# ```
#
# **✨ Fertig!** Aus deiner trapezförmigen Skizze ist ein 3D-Becher-ähnliches Objekt entstanden!
#
# ### Warum ist Revolution so mächtig?
#
# - Du kannst **beliebige Rotationskörper** erzeugen (Schüsseln, Flaschen, Teller, Zahnräder, etc.)
# - Viele **mechanische Bauteile** in der Industrie sind Drehteile – Revolution ist daher extrem praktisch
# - Mit **weniger als 360°** Drehung entstehen auch **Segmente** (z.B. halbe Zylinder)
#
# ### 💡 Verständnisfrage 2:
# *Was passiert, wenn du die Achse nicht auf dem Rand der Skizze, sondern in der Mitte platzierst? Versuche es aus!*
#
# ---
#
# ## 🔴 Teil 3: Pocket – Material subtrahieren (Aussparungen)
#
# ### Was ist ein Pocket (Tasche)?
#
# Während **Pad** Material hinzufügt und **Revolution** Material um eine Achse rotiert, **subtrahiert Pocket** Material aus einem bestehenden Körper.
#
# **Praktisches Beispiel:**
# - Du hast einen Quader (mit Pad erstellt)
# - Du zeichnest eine Skizze auf der Oberseite (z.B. ein Rechteck)
# - Du wendest Pocket an
# - Das Rechteck wird in den Quader „eingefräst" – es entsteht eine Vertiefung oder ein Loch
#
# ### Schritt-für-Schritt: Ein Pocket erstellen
#
# **Schritt 1: Ein Basis-Pad erstellen**
#
# Beginnen wir mit einem einfachen Quader als Fundament:
#
# ```freecad-code
# # Datei → Neu
# # Part Design Arbeitsbereich
# # Skizze → Neue Skizze erstellen (XY-Ebene)
# # Zeichne ein Rechteck (z.B. von (0,0) bis (50, 30))
# # Skizze verlassen
# # Part Design → Pad
# # Länge: 20 mm → OK
# ```
#
# Jetzt hast du einen Quader mit den Abmessungen 50 × 30 × 20 mm.
#
# **Schritt 2: Eine neue Skizze auf der Oberseite anlegen**
#
# ```freecad-code
# # Im Modellbaum: Klick auf den Quader (Pad)
# # Menü: Skizze → Neue Skizze erstellen
# # Ein Dialog erscheint: Wähle die Oberseite des Quaders
# # → OK
# ```
#
# Du befindest dich jetzt auf der **Oberseite** des Quaders – die Skizzenanzeige ist grün und liegt flach oben.
#
# **Schritt 3: Eine kleine Vertiefung zeichnen**
#
# ```freecad-code
# # Zeichne ein kleineres Rechteck auf der Oberseite
# # z.B. von (10, 10) bis (40, 20)
# # Skizze verlassen
# ```
#
# **Schritt 4: Pocket anwenden**
#
# ```freecad-code
# # Stelle sicher, dass die neue Skizze ausgewählt ist
# # Menü: Part Design → Pocket
# # Oder: Pocket-Symbol in der Werkzeugleiste
# ```
#
# Ein Dialog „Pocket-Parameter" erscheint:
#
# ```freecad-code
# # Länge: z.B. 5 mm (wie tief soll die Vertiefung sein?)
# # → OK
# ```
#
# **✨ Fertig!** Dein Quader hat jetzt eine **rechteckige Vertiefung** auf der Oberseite!
#
# ### Unterschied zwischen Extrusion und Pocket
#
# | Aktion | Effekt | Beispiel |
# |--------|--------|---------|
# | **Pad** (Extrusion) | Material **hinzufügen** (additiv) | Quader wird größer |
# | **Pocket** (Tasche) | Material **entfernen** (subtraktiv) | Loch oder Vertiefung |
# | **Revolution** | Material **rotierend hinzufügen** | Drehkörper, Zylinder |
#
# ### 💡 Verständnisfrage 3:
# *Was passiert, wenn du bei einem Pocket die Tiefe auf 25 mm stellst, aber der Quader nur 20 mm hoch ist?*
#
# ---
#
# ## 🏗️ Teil 4: Kombinationen – Mehrstufiges Konstruieren
#
# ### Die Kraft der Kombination
#
# Bis jetzt haben wir die Techniken einzeln betrachtet. Die wahre **Kraft von CAD** zeigt sich, wenn wir diese Techniken kombinieren:
#
# 1. **Pad:** Wir erstellen die Grundform (einen Quader)
# 2. **Pocket:** Wir schneiden ein Loch hinein
# 3. **Pad:** Wir bauen eine Erhebung darauf
# 4. **Revolution:** Wir drehen eine zylindrische Spitze oben drauf
# 5. ... usw.
#
# Jedes dieser Features wird der **Modellbaum** (links) nacheinander aufgelistet, und FreeCAD berechnet das Ergebnis automatisch neu.
#
# ### Praktisches Beispiel: Eine Platte mit Bohrung
#
# Lass mich dir ein vollständiges Beispiel zeigen:
#
# **Aufgabe:** Baue eine **flache Platte 100 × 80 × 10 mm mit einem Loch (Durchmesser 20 mm) in der Mitte.**
#
# **Schritt 1: Basis-Pad (Platte)**
#
# ```freecad-code
# # Datei → Neu
# # Part Design
# # Skizze → Neue Skizze (XY-Ebene)
# # Rechteck von (0, 0) bis (100, 80) zeichnen
# # Skizze verlassen
# # Pad: Länge 10 mm → OK
# ```
#
# Jetzt hast du eine Platte.
#
# **Schritt 2: Skizze für die Bohrung auf der Oberseite**
#
# ```freecad-code
# # Pad auswählen (im Modellbaum)
# # Skizze → Neue Skizze erstellen
# # Wähle die Oberseite der Platte
# # → OK (du bist jetzt auf der Oberseite)
# ```
#
# **Schritt 3: Kreis für Bohrung zeichnen**
#
# ```freecad-code
# # Menü: Skizze → Geometrie → Kreis
# # Zeichne einen Kreis in der Mitte der Oberseite
# # Mittelpunkt: (50, 40)  [Mitte der Platte]
# # Radius: 10 mm
# # Skizze verlassen
# ```
#
# **Schritt 4: Pocket für die Bohrung**
#
# ```freecad-code
# # Skizze mit Kreis auswählen
# # Menü: Part Design → Pocket
# # Länge: 10 mm (das ist die volle Höhe der Platte)
# # → OK
# ```
#
# **✨ Fertig!** Du hast eine Platte mit einer durchgehenden Bohrung konstruiert!
#
# In der Modellbaum sieht es jetzt so aus:
# ```
# - Körper
#   ├── Skizze (Rechteck)
#   ├── Pad (die Platte)
#   ├── Skizze001 (Kreis)
#   └── Pocket (das Loch)
# ```
#
# ### Die Schönheit dieser Struktur
#
# - **Parametrisch:** Wenn du das ursprüngliche Rechteck bearbeitest (z.B. auf 110 × 90 mm änderst), **passen sich automatisch alle folgenden Features an!**
# - **Rückverfolgbar:** Du kannst jeden Schritt anklicken und sehen, wie das Modell aufgebaut wurde
# - **Editierbar:** Du kannst jedes Feature später noch verändern oder löschen
#
# ### 💡 Verständnisfrage 4:
# *Du hast eine Platte mit Loch konstruiert. Was passiert, wenn du die Höhe des Pads von 10 mm auf 20 mm änderst, aber die Pocket-Tiefe bei 10 mm belässt?*
#
# ---
#
# ## 📚 Zusammenfassung der Befehle
#
# ### Wichtigste Menübefehle für dieses Modul:
#
# | Aktion | Menüpfad | Tastenkürzel |
# |--------|----------|--------------|
# | **Skizze erstellen** | `Skizze → Neue Skizze erstellen` | - |
# | **Skizze verlassen** | `Skizze → Skizze verlassen` | ESC |
# | **Pad erstellen** | `Part Design → Pad` | - |
# | **Revolution erstellen** | `Part Design → Revolution` | - |
# | **Pocket erstellen** | `Part Design → Pocket` | - |
#
# ### Tastatur-Shortcuts für Sketcher:
#
# ```freecad-code
# G → R   Rechteck zeichnen
# G → C   Kreis zeichnen
# G → L   Linie zeichnen
# G → K   Konstruktionslinie
# C → D   Abstand bemaßen (Constraint)
# ESC     Sketcher beenden
# ```
#
# ---
#
# ## 🎓 Weiterführende Fragen (zum Nachdenken)
#
# 1. **Was ist der Unterschied zwischen Pad und Revolution?** Wann würdest du welche Methode nutzen?
#
# 2. **Kannst du dir vorstellen, wie ein Schraubenzieher-Griff konstruiert werden könnte?** (Hinweis: Pad für den Griff, Revolution für die Spitze)
#
# 3. **Ein Pocket hat die Option „zwei Seiten"** – was könnte das bedeuten? (Schau mal in den Pocket-Einstellungen!)
#
# 4. **Warum ist es wichtig, dass die Skizzen „vollständig bestimmt" sind** (grüne Farbe)? Was könnte schiefgehen, wenn sie es nicht sind?
#
# ---
#
# ## 🔗 Weiterführende Links und Ressourcen
#
# Zum Vertiefen der Inhalte aus diesem Modul:
#
# - **[FreeCAD Part Design Dokumentation](https://wiki.freecadweb.org/Part_Design_Workbench)** – Offizielle Dokumentation zum Part Design Arbeitsbereich
# - **[FreeCAD Pad-Feature](https://wiki.freecadweb.org/PartDesign_Pad)** – Detaillierte Erklärung des Pad-Befehls
# - **[FreeCAD Revolution-Feature](https://wiki.freecadweb.org/PartDesign_Revolution)** – Anleitung zur Revolution
# - **[FreeCAD Pocket-Feature](https://wiki.freecadweb.org/PartDesign_Pocket)** – Erklärung des Pocket-Befehls
# - **[FreeCAD YouTube-Tutorials zu Pad & Pocket](https://www.youtube.com/results?search_query=freecad+pad+pocket+tutorial)** – Video-Tutorials von der Community
#
# ---
#
# ## 🎯 Lernkontrolle
#
# Am Ende dieses Moduls solltest du folgende Aufgaben bewältigen können:
#
# ✅ Eine flache Skizze mit dem Pad-Befehl in einen 3D-Quader verwandeln
#
# ✅ Eine Profilskizze mit Revolution um eine Achse drehen und ein Dreheil erzeugen
#
# ✅ Ein Loch oder eine Vertiefung mit Pocket in einen bestehenden Körper schneiden
#
# ✅ Mehrere Features hintereinander anwenden und ein mehrstufiges Modell aufbauen
#
# Falls du bei einer dieser Aufgaben unsicher bist, wiederhole die entsprechenden Schritte oder schau in den Erklärvideos unter den weiterführenden Links nach!
#
# ---
#
# **Glückwunsch!** Du hast soeben gelernt, wie aus flachen 2D-Skizzen echte 3D-Bauteile entstehen. Das ist die Grundlage für professionelle CAD-Arbeit! 🎉
