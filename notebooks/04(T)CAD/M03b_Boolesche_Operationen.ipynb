# %% [markdown]
# # M03b: 3D-Objekte kombinieren – Boolesche Operationen (Übungen)
#
# ## 📌 Einleitung
#
# In diesem Modul üben Sie praktisch die Booleschen Operationen in FreeCAD. Sie werden mehrere kleine Projekte durchführen und dabei Union, Difference und Intersection anwenden.
#
# **Ihre Aufgaben bauen aufeinander auf** – jede Aufgabe wird etwas komplexer!
#
# ---
#
# ## 🎯 Lernziele (Wiederholung)
#
# - ✅ Union, Difference und Intersection unterscheiden
# - ✅ Boolesche Operationen in FreeCAD durchführen
# - ✅ Objekte vor der Operation richtig ausrichten
# - ✅ Fehler erkennen und beheben
# - ✅ Ein zusammengesetztes Bauteil selbstständig entwerfen
#
# ---
#
# ## 📝 Aufgabe 1: Erste Union – Zwei Zylinder verbinden
#
# **Ziel:** Erstellen Sie zwei Zylinder und verbinden Sie diese mit einer Union-Operation zu einem L-förmigen Körper.
#
# ### Vorbereitung
#
# ```freecad-code
# # Arbeitsbereich: Part (Menü: View → Workbench → Part)
# # Neues Dokument: File → New
# ```
#
# ### Aufgaben-Schritte
#
# #### 1.1 Erster Zylinder (senkrecht stehend)
#
# ```freecad-code
# # Menüpfad: Part → Create primitives → Cylinder
# #
# # Einstellungen:
# # - Radius: 2 mm
# # - Height: 10 mm
# # - Position: x = 0, y = 0, z = 0
# #
# # ✓ Create
# # → Benennen Sie diesen Zylinder um in „Cylinder_vertikal"
# #   (Rechtsklick → Rename)
# ```
#
# #### 1.2 Zweiter Zylinder (horizontal – für das L)
#
# ```freecad-code
# # Menüpfad: Part → Create primitives → Cylinder
# #
# # Einstellungen:
# # - Radius: 2 mm
# # - Height: 10 mm
# # - Position: x = 0, y = 0, z = 10
# # - Rotation: Um Y-Achse um 90° drehen
# #   (Im Eigenschaftspanel unter „Placement" → Rotation)
# #
# # ✓ Create
# # → Benennen Sie diesen Zylinder um in „Cylinder_horizontal"
# ```
#
# **Hinweis:** Beide Zylinder sollen sich an ihren Enden treffen und leicht überlappen.
#
# #### 1.3 Union durchführen
#
# ```freecad-code
# # Menüpfad: Part → Boolean → Union
# #
# # Im Dialog:
# # - Base: Cylinder_vertikal (oder der erste Zylinder)
# # - Tool: Cylinder_horizontal
# #
# # ✓ OK
# #
# # Sie sehen nun ein L-förmiges Objekt!
# ```
#
# #### 1.4 Kontrollfrage
#
# **Frage:** Was unterscheidet die Union-Operation von der Difference-Operation?
#
# *Lösungshinweis:* Denken Sie an die Begriffe „zusammenfügen" und „abziehen".
#
# ---
#
# ## 📝 Aufgabe 2: Difference – Bohrung in einen Quader
#
# **Ziel:** Erstellen Sie einen Quader und bohren Sie ein zylindrisches Loch hindurch.
#
# ### Aufgaben-Schritte
#
# #### 2.1 Quader erzeugen
#
# ```freecad-code
# # Menüpfad: Part → Create primitives → Box
# #
# # Einstellungen:
# # - Length: 12 mm (X-Richtung)
# # - Width: 8 mm (Y-Richtung)
# # - Height: 6 mm (Z-Richtung)
# # - Position: x = 0, y = 0, z = 0
# #
# # ✓ Create
# # → Benennen Sie ihn um in „Quader_Hauptteil"
# ```
#
# #### 2.2 Bohr-Zylinder erzeugen
#
# ```freecad-code
# # Menüpfad: Part → Create primitives → Cylinder
# #
# # Einstellungen:
# # - Radius: 1.5 mm (Bohrungsdurchmesser: 3 mm)
# # - Height: 10 mm (größer als Quader-Höhe, damit er durch geht)
# # - Position: x = 6, y = 4, z = -2  (Mitte des Quaders, oben/unten heraus)
# #
# # ✓ Create
# # → Benennen Sie ihn um in „Bohrwerkzeug"
# ```
#
# #### 2.3 Difference-Operation
#
# ```freecad-code
# # Menüpfat: Part → Boolean → Difference
# #
# # Einstellungen:
# # - Base: Quader_Hauptteil
# # - Tool: Bohrwerkzeug
# #
# # ✓ OK
# #
# # → Blenden Sie die Originalobjekte aus (Auge-Symbol), um das Resultat zu sehen.
# ```
#
# #### 2.4 Reflexion
#
# **Fragen:**
# 1. Warum muss der Bohr-Zylinder länger sein als der Quader?
# 2. Was würde passieren, wenn Sie die Base und Tool vertauschen?
#
# *Hinweis zum Ausprobieren:* Sie können in den Eigenschaften des Boolean-Objekts Base und Tool tatsächlich austauschen und sehen, wie sich das Modell ändert!
#
# ---
#
# ## 📝 Aufgabe 3: Mehrere Löcher – Difference mit mehreren Werkzeugen
#
# **Ziel:** Erstellen Sie einen Quader mit **zwei** Bohrungen.
#
# ### Aufgaben-Schritte (Erweiterte Technik)
#
# #### 3.1 Neues Modell beginnen
#
# ```freecad-code
# # File → New
# ```
#
# #### 3.2 Quader
#
# ```freecad-code
# # Menüpfad: Part → Create primitives → Box
# # - Length: 15 mm, Width: 8 mm, Height: 6 mm
# # - Position: x = 0, y = 0, z = 0
# ```
#
# #### 3.3 Erste Bohrung
#
# ```freecad-code
# # Menüpfad: Part → Create primitives → Cylinder
# # - Radius: 1 mm
# # - Height: 10 mm
# # - Position: x = 4, y = 4, z = -2
# ```
#
# #### 3.4 Zweite Bohrung
#
# ```freecad-code
# # Menüpfad: Part → Create primitives → Cylinder
# # - Radius: 1 mm
# # - Height: 10 mm
# # - Position: x = 11, y = 4, z = -2
# ```
#
# #### 3.5 Erste Difference durchführen
#
# ```freecad-code
# # Menüpfad: Part → Boolean → Difference
# #
# # - Base: Box
# # - Tool: Cylinder_1 (die erste Bohrung)
# #
# # ✓ OK
# # → Resultat wird „Cut" oder „Boolean_xxx" genannt
# ```
#
# #### 3.6 Zweite Difference durchführen
#
# ```freecad-code
# # Menüpfad: Part → Boolean → Difference
# #
# # - Base: Cut (das Ergebnis aus Schritt 3.5)
# # - Tool: Cylinder_2 (die zweite Bohrung)
# #
# # ✓ OK
# # → Sie sehen nun zwei Bohrungen!
# ```
#
# **💡 Tipp:** Sie können Boolesche Operationen **verschachteln** – das Ergebnis einer Operation wird zur Basis der nächsten!
#
# #### 3.7 Verständnisfrage
#
# **Frage:** Warum funktioniert es, das Ergebnis einer Difference (Cut) als Base für eine neue Difference zu benutzen?
#
# ---
#
# ## 📝 Aufgabe 4: Intersection – Überlappungsbereich finden
#
# **Ziel:** Finden Sie den Bereich, wo ein Würfel und eine Kugel sich überlappen.
#
# ### Aufgaben-Schritte
#
# #### 4.1 Würfel
#
# ```freecad-code
# # Menüpfad: Part → Create primitives → Box
# # - Length: 10 mm, Width: 10 mm, Height: 10 mm
# # - Position: x = 0, y = 0, z = 0
# ```
#
# #### 4.2 Kugel (teilweise überlappt)
#
# ```freecad-code
# # Menüpfad: Part → Create primitives → Sphere
# # - Radius: 7 mm
# # - Position: x = 5, y = 5, z = 5  (Mitte des Würfels)
# ```
#
# #### 4.3 Intersection durchführen
#
# ```freecad-code
# # Menüpfad: Part → Boolean → Intersection
# #
# # - Base: Box
# # - Tool: Sphere
# #
# # ✓ OK
# ```
#
# #### 4.4 Beobachten Sie das Ergebnis
#
# **Fragen zum Nachdenken:**
# 1. Welche Form hat das resultierende Objekt ungefähr?
# 2. Können Sie erklären, warum nur dieser Teil erhalten bleibt?
# 3. Wann könnte eine Intersection-Operation im realen Maschinenbau nützlich sein?
#
# ---
#
# ## 📝 Aufgabe 5: Kreatives Projekt – Entwurf einer einfachen Komponente
#
# **Ziel:** Entwerfen Sie ein einfaches mechanisches Teil mit mindestens **zwei Booleschen Operationen**.
#
# ### Beispiel-Ideen:
#
# - **Flanschplatte:** Ein dicker, flacher Quader mit vier Ecklöchern (Difference)
# - **T-Stück:** Ein vertikaler Zylinder mit einem horizontalen Zylinder verbunden (Union)
# - **Schachtdeckel:** Ein großes Loch (Differenz) in der Mitte einer Platte
# - **Ihre eigene Idee:** Denken Sie an ein einfaches Objekt aus Ihrem Alltag!
#
# ### Aufgaben-Schritte
#
# #### 5.1 Skizze (auf Papier oder digital)
#
# ```freecad-code
# # Überlegen Sie:
# # - Welche Grundkörper brauchen Sie?
# # - Welche Operationen (Union/Difference/Intersection)?
# # - Welche Abmessungen (mm)?
# # - Zeichnen Sie eine kleine Skizze!
# ```
#
# #### 5.2 Umsetzung in FreeCAD
#
# ```freecad-code
# # Schritt 1: Alle Grundkörper erzeugen
# # Schritt 2: Objekte richtig positionieren
# # Schritt 3: Boolesche Operationen in sinnvoller Reihenfolge durchführen
# # Schritt 4: Kontrolle und Verbesserungen
# ```
#
# #### 5.3 Dokumentation
#
# ```freecad-code
# # Speichern Sie Ihr Modell:
# # - File → Save
# # - Geben Sie einem aussagekräftigen Namen (z.B. „Mein_Bauteil.FCStd")
# ```
#
# #### 5.4 Reflexion (Beantworten Sie schriftlich)
#
# 1. Welche Grundkörper haben Sie verwendet?
# 2. In welcher Reihenfolge haben Sie die Operationen durchgeführt?
# 3. Gab es Schwierigkeiten? Wie haben Sie sie gelöst?
# 4. Könnten Sie das Teil vereinfachen oder verbessern?
#
# ---
#
# ## ❓ Häufige Fragen während der Übungen
#
# **F: Meine Boolean-Operation schlägt fehl. Was kann ich tun?**
#
# A: Überprüfen Sie:
# - Berühren oder überlappen sich die Objekte tatsächlich?
# - Sind die Geometrien vollständig (keine Defekte)?
# - Versuchen Sie, das Modell zu „reparieren": Part → Check geometry
#
# **F: Nach der Operation sehe ich die Löcher nicht!**
#
# A:
# - Blenden Sie die Originalobjekte aus (Auge-Symbol)
# - Vergrößern Sie die Ansicht (Zoom)
# - Drehen Sie das Modell (Rechtsklick + Ziehen)
#
# **F: Kann ich eine Boolesche Operation rückgängig machen?**
#
# A: Ja!
# - Edit → Undo (oder Strg+Z)
# - Oder löschen Sie das Boolean-Objekt und versuchen Sie es nochmal
#
# **F: Warum wird die Reihenfolge bei Difference wichtig?**
#
# A: Weil Difference asymmetrisch ist:
# - Würfel − Zylinder = Würfel mit Loch
# - Zylinder − Würfel = Zylinder mit großem Stück entfernt
# Das sind komplett unterschiedliche Ergebnisse!
#
# ---
#
# ## 📚 Weiterführende Links
#
# - [FreeCAD Part Workbench – Boolean Operations (Englisch)](https://wiki.freecadweb.org/Part_Boolean)
# - [FreeCAD Tutorials: Boolesche Operationen](https://www.youtube.com/results?search_query=FreeCAD+boolean+operations+tutorial)
# - [Thingiverse (CAD-Designs mit Boolean-Kombinationen ansehen)](https://www.thingiverse.com)
# - [3D-Modelle vom Grundkörper zum fertigen Teil](https://reprap.org/wiki/Printing_basics)
#
# ---
#
# **Glückwunsch!** Sie haben alle Übungen absolviert. In der nächsten Lektion (M03c) finden Sie alle Lösungen mit zusätzlichen Tipps und Variationen.
