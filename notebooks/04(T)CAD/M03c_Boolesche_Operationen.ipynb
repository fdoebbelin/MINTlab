# %% [markdown]
# # M03c: 3D-Objekte kombinieren – Boolesche Operationen (Ausführliche Lösungen)
#
# ## 📌 Einleitung
#
# Diese Datei enthält **vollständige Lösungen** für alle Aufgaben aus M03b mit zusätzlichen Erklärungen, Tipps und Erweiterungen.
#
# ---
#
# ## ✅ Lösung zu Aufgabe 1: Erste Union – Zwei Zylinder verbinden
#
# ### Erwartetes Ergebnis
#
# Sie sollten ein **L-förmiges Objekt** erhalten, das aus zwei verbundenen Zylindern besteht.
#
# ### Detaillierte Lösung
#
# #### 1.1 Erster Zylinder – Schritt für Schritt
#
# ```freecad-code
# # Menüpfad: Part → Create primitives → Cylinder
# ```
#
# Im Dialog sollten Sie folgende Werte sehen:
#
# ```freecad-code
# Radius:       2.00 mm
# Height:      10.00 mm
# Axis:        Z-Achse (Standard)
# Position (x): 0 mm
# Position (y): 0 mm
# Position (z): 0 mm
# ```
#
# **Erklärung:**
# - **Radius 2 mm** bedeutet ein Durchmesser von 4 mm
# - **Height 10 mm** ist die Höhe in Z-Richtung
# - **Position (0,0,0)** ist der Ursprungspunkt (Basis des Zylinders)
#
# ```freecad-code
# # Klick: Create (oder OK)
# # Das Objekt wird automatisch „Cylinder" genannt
# # Im Modellbaum (links) sehen Sie es unter „Model"
# ```
#
# **Umbenennnen (optional, aber empfohlen):**
# ```freecad-code
# # Im Modellbaum: Rechtsklick auf „Cylinder"
# # Menü: Rename...
# # Neuer Name: Cylinder_vertikal
# # ✓ Bestätigung (Enter)
# ```
#
# #### 1.2 Zweiter Zylinder – Horizontal
#
# Der zweite Zylinder muss so positioniert und gedreht werden, dass er sich mit dem ersten zu einem L-Form verbindet.
#
# ```freecad-code
# # Menüpfad: Part → Create primitives → Cylinder
# ```
#
# **Dialog-Werte:**
# ```freecad-code
# Radius:       2.00 mm
# Height:      10.00 mm
# Axis:        Z-Achse (zunächst)
# Position (x): 0 mm
# Position (y): 0 mm
# Position (z): 10 mm
# ```
#
# ⚠️ **Wichtig:** Der Z-Position ist 10 mm, weil dieser Zylinder OBEN auf dem ersten beginnen soll (nicht darin überlappen).
#
# ```freecad-code
# # Klick: Create
# ```
#
# **Rotation durchführen (um das L zu erzeugen):**
#
# Nach dem Erstellen müssen Sie diesen Zylinder um 90° um die **Y-Achse** drehen:
#
# ```freecad-code
# # Im Modellbaum: Das neue Cylinder-Objekt auswählen
# # Im Property Panel (rechts): Suchen Sie „Placement"
# # Expand: Placement → Rotation
# # Axis (Achse): Y (wählen Sie Y-Achse aus)
# # Angle (Winkel): 90°
# # ✓ Eingabe bestätigen
# ```
#
# **Ergebnis:** Der zweite Zylinder steht jetzt horizontal und berührt den ersten Zylinder.
#
# **Umbenennen:**
# ```freecad-code
# # Im Modellbaum: Rechtsklick → Rename
# # Neuer Name: Cylinder_horizontal
# ```
#
# #### 1.3 Union-Operation
#
# ```freecad-code
# # Menüpfad: Part → Boolean → Union
# ```
#
# **Im Dialog:**
# ```
# Base (Basis):  Cylinder_vertikal (oder das erste Cylinder)
# Tool (Werkzeug): Cylinder_horizontal (oder das zweite Cylinder)
# ```
#
# ⚠️ **Hinweis:** Bei Union spielt die Reihenfolge KEINE Rolle!
# - Cylinder_1 ∪ Cylinder_2 = Cylinder_2 ∪ Cylinder_1
#
# ```freecad-code
# # Klick: OK
# ```
#
# **Ergebnis:**
# - Ein neues Objekt „Fuse" (oder „Boolean_Fuse_xxx") wird erzeugt
# - Die beiden Zylinder sind nun miteinander verschmolzen
# - Sie sehen ein perfektes L-Profil
#
# **Visualisierung verbessern:**
# ```freecad-code
# # Modellbaum: Klick auf das Auge neben „Cylinder_vertikal"
# # Das erste Auge wird zu einem X → Zylinder ausgeblendet
# # Wiederholen Sie das für „Cylinder_horizontal"
# # Jetzt sehen Sie nur das Endergebnis „Fuse"
# ```
#
# ### Antwort zu Kontrollfrage 1.4
#
# **Frage:** Was unterscheidet die Union-Operation von der Difference-Operation?
#
# **Antwort:**
# | Operation | Effekt | Mathematik |
# |-----------|--------|-----------|
# | **Union** | Beide Körper verschmelzen | A ∪ B = Alle Punkte aus A ODER B |
# | **Difference** | Ein Körper wird vom anderen subtrahiert | A − B = Punkte aus A, ABER NICHT aus B |
#
# **Vergleich:**
# - **Union:** Würfel + Zylinder = Ein Körper (größer/anders geformt)
# - **Difference:** Würfel − Zylinder = Ein Würfel mit Loch (kleiner/Material entfernt)
#
# ---
#
# ## ✅ Lösung zu Aufgabe 2: Difference – Bohrung in einen Quader
#
# ### Erwartetes Ergebnis
#
# Ein rechteckiger Quader (12×8×6 mm) mit einem **zylindrischen Loch** in der Mitte, das von oben bis unten durchgeht.
#
# ### Detaillierte Lösung
#
# #### 2.1 Quader erzeugen
#
# ```freecad-code
# # Menüpfad: Part → Create primitives → Box
# ```
#
# **Dialog-Werte:**
# ```freecad-code
# Length (X):  12.00 mm   (Länge in X-Richtung)
# Width (Y):    8.00 mm   (Breite in Y-Richtung)
# Height (Z):   6.00 mm   (Höhe in Z-Richtung)
# Position (x): 0 mm
# Position (y): 0 mm
# Position (z): 0 mm
# ```
#
# ```freecad-code
# # Klick: Create
# # Im Modellbaum: Rechtsklick → Rename → „Quader_Hauptteil"
# ```
#
# **Visualisierung:** Sie sehen einen flachen, rechteckigen Kasten.
#
# #### 2.2 Bohr-Zylinder erzeugen
#
# Der Bohr-Zylinder muss:
# - Mittig über dem Quader positioniert sein
# - LÄNGER sein als der Quader (damit er oben/unten herausragt)
# - SCHMAL sein (kleines Loch)
#
# ```freecad-code
# # Menüpfad: Part → Create primitives → Cylinder
# ```
#
# **Dialog-Werte:**
# ```freecad-code
# Radius:       1.50 mm   (Bohrungsdurchmesser = 2 × 1.5 = 3 mm)
# Height:      10.00 mm   (Quader ist 6 mm hoch, Zylinder 10 mm → ragt oben/unten heraus)
# Position (x): 6 mm      (Mitte des Quaders: 12 ÷ 2 = 6)
# Position (y): 4 mm      (Mitte des Quaders: 8 ÷ 2 = 4)
# Position (z):-2 mm      (2 mm unterhalb des Quaders, damit er oben herausragt)
# ```
#
# ⚠️ **Warum Position z = -2?**
# - Der Quader beginnt bei z=0 und ist 6 mm hoch (endet bei z=6)
# - Der Zylinder ist 10 mm lang
# - Wenn Zylinder bei z=-2 startet, geht er von z=-2 bis z=8
# - Das bedeutet: -2 bis 0 (unter dem Quader), 0 bis 6 (durch den Quader), 6 bis 8 (über dem Quader) ✓
#
# ```freecad-code
# # Klick: Create
# # Im Modellbaum: Rechtsklick → Rename → „Bohrwerkzeug"
# ```
#
# **Visualisierung:** Der Zylinder durchdringt den Quader sichtbar.
#
# #### 2.3 Difference-Operation (Subtraktive Operation)
#
# ```freecad-code
# # Menüpfad: Part → Boolean → Difference
# ```
#
# **Dialog-Werte:**
# ```freecad-code
# Base (Basis):    Quader_Hauptteil   (Das bleibt erhalten!)
# Tool (Werkzeug): Bohrwerkzeug       (Das wird subtrahiert/entfernt)
# ```
#
# ⚠️ **WICHTIG:** Die Reihenfolge ist entscheidend!
# - Quader − Zylinder = Quader mit Loch ✓ (gewünscht)
# - Zylinder − Quader = Zylinder mit große Beule ✗ (ungewünscht)
#
# ```freecad-code
# # Klick: OK
# ```
#
# **Ergebnis:** Ein neues Objekt „Cut" wird erzeugt.
#
# **Sichtbarmachen:**
# ```freecad-code
# # Modellbaum: Auge-Symbol neben „Quader_Hauptteil" und „Bohrwerkzeug" anklicken
# # Jetzt sehen Sie nur das Resultat: Ein Quader mit Loch!
# ```
#
# **Kontrolle der Bohrung:**
# ```freecad-code
# # Ansicht drehen: Rechtsklick halten + Mausbewegung
# # Zoom: Scroll-Rad
# # Sie sollten die Bohrung von oben und unten sehen können
# ```
#
# ### Antwort zu Reflexionsfragen 2.4
#
# **Frage 1: Warum muss der Bohr-Zylinder länger sein als der Quader?**
#
# **Antwort:**
# Wenn der Zylinder genau so lang wäre wie der Quader, würde er möglicherweise nicht vollständig hindurchgehen. Es gibt zwei Szenarien:
#
# 1. **Zu kurz:** Der Zylinder reicht nur teilweise durch → Bohrung hat Reste auf der Unterseite
# 2. **Genau richtig oder länger:** Der Zylinder geht komplett hindurch → Bohrung durchgehend ✓
#
# Deshalb machen wir den Zylinder extra lang (10 mm statt 6 mm) und positionieren ihn so, dass er deutlich über- und unterhalb des Quaders hinausragt.
#
# **Frage 2: Was würde passieren, wenn Sie Base und Tool vertauschen?**
#
# **Antwort:**
#
# Wenn Sie tauschen würden:
# ```
# Base:  Bohrwerkzeug (Zylinder)
# Tool:  Quader_Hauptteil (Quader)
# ```
#
# **Ergebnis:** `Zylinder − Quader`
# - Der Zylinder ist die Basis
# - Der Quader wird vom Zylinder subtrahiert
# - Sie bekämen einen **Zylinder mit einem großen rechteckigen Loch** darin
# - Das ist völlig anders!
#
# **Visueller Vergleich:**
# ```
# Quader − Zylinder:        Zylinder − Quader:
# ┌─────────┐               O (Zylinder)
# │    O    │  ← Loch      │ ┌─┐
# │    O    │              │ └─┘  ← Loch (rechteckig)
# └─────────┘
# ```
#
# ---
#
# ## ✅ Lösung zu Aufgabe 3: Mehrere Löcher – Verschachtelte Difference
#
# ### Erwartetes Ergebnis
#
# Ein Quader (15×8×6 mm) mit **zwei Bohrungen**, eine bei x=4 und eine bei x=11.
#
# ### Detaillierte Lösung
#
# #### 3.1 bis 3.4: Objekte erzeugen
#
# ```freecad-code
# # File → New (optionales neues Dokument)
#
# # 1. Box:
# # Menüpfad: Part → Create primitives → Box
# # Length: 15 mm, Width: 8 mm, Height: 6 mm
# # Position: (0, 0, 0)
#
# # 2. Cylinder_1 (erste Bohrung):
# # Menüpfad: Part → Create primitives → Cylinder
# # Radius: 1 mm, Height: 10 mm
# # Position: (4, 4, -2)
#
# # 3. Cylinder_2 (zweite Bohrung):
# # Menüpfad: Part → Create primitives → Cylinder
# # Radius: 1 mm, Height: 10 mm
# # Position: (11, 4, -2)
# ```
#
# **Modellbaum sollte enthalten:**
# - Box
# - Cylinder
# - Cylinder_001 (oder ähnlich)
#
# #### 3.5 Erste Difference
#
# ```freecad-code
# # Menüpfad: Part → Boolean → Difference
# ```
#
# **Dialog:**
# ```
# Base:  Box
# Tool:  Cylinder (erste Bohrung)
# ```
#
# ```freecad-code
# # Klick: OK
# # Resultat: „Cut" oder „Boolean_xxx" wird erzeugt
# ```
#
# **Ergebnis:** Der Quader hat jetzt **eine Bohrung**.
#
# #### 3.6 Zweite Difference – Die Verschachtelung
#
# Jetzt folgt der wichtige Schritt: **Das Ergebnis der ersten Operation wird die Basis der zweiten Operation!**
#
# ```freecad-code
# # Menüpfad: Part → Boolean → Difference
# ```
#
# **Dialog:**
# ```
# Base:  Cut (das Ergebnis aus Schritt 3.5!)
# Tool:  Cylinder_001 (zweite Bohrung)
# ```
#
# ⚠️ **Das ist der Kniff:** Wir nutzen das Ergebnis der ersten Difference, nicht das Original!
#
# ```freecad-code
# # Klick: OK
# # Resultat: Ein neues Objekt „Cut_001" wird erzeugt
# ```
#
# **Endresultat:** Der Quader hat jetzt **zwei Bohrungen**!
#
# **Visualisierung:**
# ```freecad-code
# # Modellbaum: Blenden Sie Box, Cylinder, Cylinder_001 aus (Auge-Symbol)
# # Nur „Cut_001" sichtbar machen
# # Drehen Sie das Modell, um beide Bohrungen zu sehen
# ```
#
# ### Erklärung: Warum funktioniert die Verschachtelung?
#
# **Das Prinzip:**
#
# ```
# Schritt 1: Cut = Box − Cylinder_1
# Schritt 2: Cut_001 = Cut − Cylinder_2 = (Box − Cylinder_1) − Cylinder_2
# ```
#
# Mathematisch:
# ```
# Cut_001 = Box − Cylinder_1 − Cylinder_2
# ```
#
# Das ist dasselbe, als würde man beiden Zylinder auf einmal vom Quader abziehen!
#
# **Vorteile dieser Methode:**
# - Funktioniert mit beliebig vielen Löchern
# - Sie können schrittweise überprüfen, ob jeder Schritt richtig ist
# - Einfacher als alle Zylinder gleichzeitig zu kombinieren
#
# ---
#
# ## ✅ Lösung zu Aufgabe 4: Intersection – Überlappungsbereich
#
# ### Erwartetes Ergebnis
#
# Eine **abgerundete, würfelförmige Form** – das ist die genaue Schnittstelle zwischen Würfel und Kugel.
#
# ### Detaillierte Lösung
#
# #### 4.1 bis 4.2: Würfel und Kugel erzeugen
#
# ```freecad-code
# # 1. Box:
# # Menüpfad: Part → Create primitives → Box
# # Length: 10 mm, Width: 10 mm, Height: 10 mm
# # Position: (0, 0, 0)
#
# # 2. Sphere:
# # Menüpfad: Part → Create primitives → Sphere
# # Radius: 7 mm
# # Position: (5, 5, 5)  ← Zentriert im Würfel!
# ```
#
# **Hinweis zur Kugel-Position:**
# - Der Würfel geht von (0,0,0) bis (10,10,10)
# - Mitte des Würfels: (5,5,5) ✓
# - Kugel-Radius 7 mm ist größer als halber Würfel (5 mm)
# - Das bedeutet: Die Kugel ragt überall über die Würfel-Grenzen hinaus
# - Aber es gibt auch Schnittflächen!
#
# #### 4.3 Intersection-Operation
#
# ```freecad-code
# # Menüpfad: Part → Boolean → Intersection
# ```
#
# **Dialog:**
# ```
# Base:  Box
# Tool:  Sphere
# ```
#
# ```freecad-code
# # Klick: OK
# # Resultat: „Common" oder „Boolean_xxx" wird erzeugt
# ```
#
# **Ergebnis:** Nur der Bereich, wo Würfel UND Kugel sich überlappen, bleibt sichtbar.
#
# ### Antwort zu Beobachtungsfragen 4.4
#
# **Frage 1: Welche Form hat das resultierende Objekt ungefähr?**
#
# **Antwort:**
# Das Ergebnis ist **würfelförmig mit abgerundeten Ecken und Kanten** – sozusagen ein "abgerundeter Würfel" oder eine "Kugel mit flachen Seiten".
#
# Visuell:
# ```
# Würfel:         Kugel:          Intersection (Schnitt):
#   +---+            O              ╭─────╮
#  /   /|          ◯   ◯           ╱     ╱│
# +---+ |                          │     │ │
# |   | +       ∩       =          ╰────╯  │
# |   |/                           │      │
# +---+                            ╰──────╯
#
# Kombiniert man Würfel und Kugel, bleiben
# nur die abgerundeten "Ecken" der Kugel,
# die INNERHALB des Würfels liegen.
# ```
#
# **Frage 2: Können Sie erklären, warum nur dieser Teil erhalten bleibt?**
#
# **Antwort:**
#
# Intersection bedeutet mathematisch: **Nur die Punkte, die BEIDE Bedingungen erfüllen, bleiben.**
#
# ```
# Bedingung für Würfel:  0 ≤ x ≤ 10 UND 0 ≤ y ≤ 10 UND 0 ≤ z ≤ 10
# Bedingung für Kugel:   (x-5)² + (y-5)² + (z-5)² ≤ 7²
#
# Intersection:          BEIDE Bedingungen müssen erfüllt sein
# ```
#
# Ergebnis:
# - **Würfel-Ecken:** Die äußersten Punkte des Würfels sind zu weit weg von der Kugel-Mitte → weggelassen
# - **Würfel-Mitte:** Die Mitte des Würfels liegt INNERHALB der Kugel → behalten
# - **Übergänge:** An den Kanten entstehen sanfte Übergänge
#
# **Frage 3: Wann könnte eine Intersection im Maschinenbau nützlich sein?**
#
# **Antwort:**
#
# Beispiele für praktische Verwendung:
# 1. **Schnittflächenanalyse:** Sie wollen herausfinden, wie viel Material zwei Teile gemeinsam haben
# 2. **Interferenzprüfung:** Kontrollieren, ob zwei bewegliche Teile sich überschneiden (Kollisionserkennung)
# 3. **Material-Optimierung:** Ermitteln von Bereichen maximaler Festigkeit (wo mehrere Komponenten überlappen)
# 4. **CAD-Simulation:** Berechnung von Spannungskonzentrationen in Übergangsbereichen
#
# ---
#
# ## ✅ Lösung zu Aufgabe 5: Kreatives Projekt
#
# ### Beispiel-Lösung: Flanschplatte mit vier Ecklöchern
#
# **Beschreibung:** Eine flache, quadratische Platte mit Löchern an allen vier Ecken (typisch für Befestigungsplatte).
#
# #### 5.1 Planung
#
# ```
# Komponenten:
# - Hauptplatte: 20×20×3 mm (quadratisches Blech)
# - 4 Bohrlöcher: je Radius 1.5 mm (Durchmesser 3 mm)
#   Positionen:
#   - Loch 1: (2, 2)      (rechts unten)
#   - Loch 2: (18, 2)     (rechts oben)
#   - Loch 3: (2, 18)     (links unten)
#   - Loch 4: (18, 18)    (links oben)
#
# Operationen:
# 1. Hauptplatte erzeugen
# 2. Vier Zylinder erzeugen
# 3. Vier aufeinanderfolgende Difference-Operationen
# ```
#
# #### 5.2 Umsetzung
#
# **Schritt 1: Hauptplatte**
# ```freecad-code
# # Menüpfad: Part → Create primitives → Box
# # Length: 20 mm, Width: 20 mm, Height: 3 mm
# # Position: (0, 0, 0)
# # Name: Platte
# ```
#
# **Schritt 2a: Erste Bohrung (unten-rechts)**
# ```freecad-code
# # Menüpfad: Part → Create primitives → Cylinder
# # Radius: 1.5 mm, Height: 5 mm
# # Position: (2, 2, -1)
# # Name: Bohrung_1
# ```
#
# **Schritt 2b: Zweite Bohrung (unten-links)**
# ```freecad-code
# # Menüpfad: Part → Create primitives → Cylinder
# # Radius: 1.5 mm, Height: 5 mm
# # Position: (18, 2, -1)
# # Name: Bohrung_2
# ```
#
# **Schritt 2c: Dritte Bohrung (oben-rechts)**
# ```freecad-code
# # Menüpfad: Part → Create primitives → Cylinder
# # Radius: 1.5 mm, Height: 5 mm
# # Position: (2, 18, -1)
# # Name: Bohrung_3
# ```
#
# **Schritt 2d: Vierte Bohrung (oben-links)**
# ```freecad-code
# # Menüpfad: Part → Create primitives → Cylinder
# # Radius: 1.5 mm, Height: 5 mm
# # Position: (18, 18, -1)
# # Name: Bohrung_4
# ```
#
# **Schritt 3: Difference-Operationen (nacheinander)**
#
# ```freecad-code
# # 1. Difference:
# #    Base: Platte
# #    Tool: Bohrung_1
# #    → Resultat: Cut_1
#
# # 2. Difference:
# #    Base: Cut_1
# #    Tool: Bohrung_2
# #    → Resultat: Cut_2
#
# # 3. Difference:
# #    Base: Cut_2
# #    Tool: Bohrung_3
# #    → Resultat: Cut_3
#
# # 4. Difference:
# #    Base: Cut_3
# #    Tool: Bohrung_4
# #    → Resultat: Cut_4 (Finales Objekt)
# ```
#
# **Endergebnis:** Eine quadratische Platte mit vier Ecklöchern!
#
# #### 5.3 Datei speichern
#
# ```freecad-code
# # Menüpfad: File → Save As
# # Filename: Flanschplatte_mit_vier_Loechern.FCStd
# # Speichern
# ```
#
# #### 5.4 Reflexions-Antworten
#
# **Frage 1: Welche Grundkörper haben Sie verwendet?**
# Antwort: 1 Box (Platte) + 4 Zylinder (Bohrungen) = 5 Grundkörper
#
# **Frage 2: In welcher Reihenfolge haben Sie die Operationen durchgeführt?**
# Antwort:
# - Erste Bohrung: Platte − Bohrung_1
# - Zweite Bohrung: (Platte − Bohrung_1) − Bohrung_2
# - Dritte Bohrung: ((Platte − Bohrung_1) − Bohrung_2) − Bohrung_3
# - Vierte Bohrung: (((Platte − Bohrung_1) − Bohrung_2) − Bohrung_3) − Bohrung_4
#
# **Frage 3: Gab es Schwierigkeiten? Wie haben Sie sie gelöst?**
#
# Mögliche Schwierigkeiten und Lösungen:
# - Problem: Bohrungen nicht sichtbar
#   - Lösung: Originalobjekte ausblenden (Auge-Symbol)
# - Problem: Boolean-Operation schlägt fehl
#   - Lösung: Überprüfen, dass Zylinder den Quader durchschneidet
# - Problem: Falsche Positionen
#   - Lösung: Koordinaten überprüfen und ggf. anpassen
#
# **Frage 4: Könnten Sie das Teil vereinfachen oder verbessern?**
#
# Verbesserungen:
# - **Fasen hinzufügen:** Mit Chamfer-Werkzeug scharfe Kanten brechen
# - **Abrundungen:** Mit Fillet scharfe Bohrungskanten abrunden
# - **Mehrfachmuster:** Statt einzelne Bohrungen, Muster-Funktion (Pattern) nutzen
# - **Dicke variieren:** Platte könnte an einigen Stellen dünner sein
#
# ---
#
# ## 🎓 Weitere Tipps und Tricks
#
# ### Tipp 1: Effiziente Mehrfach-Bohrungen mit Pattern
#
# Statt einzelne Difference-Operationen, kann man auch:
#
# ```freecad-code
# # Ein Array (Muster) aller Bohrungen auf einmal erstellen
# # und dann einmal abziehen – schneller und eleganter!
# # (Dies lernen Sie in Modul 6)
# ```
#
# ### Tipp 2: Fehler in Boolean-Operationen reparieren
#
# Wenn eine Operation fehlschlägt:
#
# ```freecad-code
# # Menüpfat: Part → Check geometry
# # Untersucht alle Objekte auf Fehler und repariert sie
# ```
#
# ### Tipp 3: Objekteigenschaften anschauen
#
# ```freecad-code
# # Modellbaum: Objekt auswählen
# # Property Panel (rechts):
# #   - Shape: Sehen Sie die Geometrie-Daten
# #   - Bound Box: Die Grenzen des Objekts
# #   - Volume: Das Volumen (hilfreich für Materialberechnungen)
# ```
#
# ### Tipp 4: 3D-Ansicht kontrollieren
#
# ```freecad-code
# # Tastenkombinationen für schnelle Navigation:
# # V + Home  = Isometrische Standardansicht
# # V + F     = Fit All (alles sichtbar)
# # 0 (Numpad) = Kamera rotieren
# ```
#
# ### Tipp 5: Komplexe Modelle strukturieren
#
# Bei vielen Objekten:
# ```freecad-code
# # Modellbaum: Gruppen erzeugen
# # Rechtsklick im Modellbaum → Create folder
# # Bohrungen in einen Ordner, Hauptteile in anderen
# # Übersichtlicher und leichter zu verwalten
# ```
#
# ---
#
# ## 📚 Weiterführende Ressourcen
#
# - [FreeCAD Part Design vs. Part Workbench (Englisch)](https://wiki.freecadweb.org/Part_Workbench)
# - [YouTube: Boolean Operations in FreeCAD](https://www.youtube.com/results?search_query=FreeCAD+boolean+operations)
# - [CAD-Forum: Häufige Fragen](https://www.cad-forum.de/)
# - [Thingiverse: Designs mit Boolesche Kombinationen](https://www.thingiverse.com/search?q=boolean+operations)
# - [Wikipedie: Konstruktive Festkörpergeometrie (CSG)](https://de.wikipedia.org/wiki/Konstruktive_Festk%C3%B6rpergeometrie)
#
# ---
#
# ## 🎯 Zusammenfassung und nächste Schritte
#
# Sie haben jetzt gelernt:
# - ✅ Union, Difference und Intersection zu unterscheiden
# - ✅ Boolesche Operationen in FreeCAD durchzuführen
# - ✅ Objekte richtig auszurichten
# - ✅ Fehler zu erkennen und zu beheben
# - ✅ Komplexere Modelle durch Verschachtelung aufzubauen
#
# **Nächstes Modul (M04):** Sie lernen den **Sketcher-Arbeitsbereich**, um eigene 2D-Skizzen zu zeichnen. Diese Skizzen werden dann mit Extrusion und Rotation in 3D-Körper umgewandelt – noch präzisere und kreativere Konstruktionen werden möglich!
