# %% [markdown]
# # M01a: Einführung in CAD und FreeCAD – Demonstrationsdatei
#
# ## 🎯 Lernziele dieses Moduls
#
# Nach Abschluss dieses Moduls werden Sie:
#
# - Verstehen, wofür computergestütztes Konstruieren (CAD) genutzt wird
# - Die FreeCAD-Benutzeroberfläche und wichtige Bedienelemente kennenlernen
# - Einfache 3D-Grundformen (z.B. Würfel, Quader, Zylinder, Kugel) selbstständig erzeugen
# - Das Navigieren in der 3D-Ansicht üben (heranzoomen, drehen, verschieben)

# %% [markdown]
# ## 📋 Einleitung: Was ist CAD?
#
# CAD steht für **Computer-Aided Design** (Computergestütztes Konstruieren). Es bedeutet, dass wir am Computer technische Objekte dreidimensional entwerfen, statt sie nur auf dem Papier zu zeichnen.
#
# ### Warum ist CAD wichtig?
#
# CAD wird in vielen Bereichen eingesetzt:
#
# - **Produktdesign**: Entwicklung von Handys, Möbeln, Autos
# - **Maschinenbau**: Konstruktion von Motoren, Zahnrädern, Pumpen
# - **Architektur**: Planung von Gebäuden und Räumen
# - **Elektrotechnik**: Design von Leiterplatten und Gehäusen
# - **3D-Druck**: Vorbereitung von Objekten zur Fertigung
#
# ### Vorteil: Vom virtuellen Modell zur Wirklichkeit
#
# Mit CAD können wir:
# - Ideen schnell visualisieren
# - Änderungen problemlos vornehmen
# - Das Modell exportieren und ausdrucken
# - Ein 3D-Modell in einen 3D-Drucker laden
# - Technische Zeichnungen automatisch generieren

# %% [markdown]
# ## 🖥️ FreeCAD – Die Benutzeroberfläche
#
# **FreeCAD** ist eine kostenlose und open-source CAD-Software. Sie ist auf Windows, macOS und Linux verfügbar.
#
# ### Die Hauptelemente der Benutzeroberfläche:
#
# ```
# ┌───────────────────────────────────────────────────────────┐
# │  Menüleiste (Datei, Bearbeiten, Ansicht, etc.)            │
# ├──────────────┬─────────────────────────┬──────────────────┤
# │              │                         │                  │
# │   Modell-    │   3D-Ansicht            │  Eigenschaften-  │
# │   Struktur-  │  (Hier sehen Sie        │   panel          │
# │   baum       │   Ihr 3D-Modell)        │  (Details der    │
# │  (Links)     │                         │  Objekte)        │
# │              │                         │  (Rechts)        │
# │              │                         │                  │
# └──────────────┴─────────────────────────┴──────────────────┘
#    Unten: Konsole (Meldungen und Ausgaben)
# ```
#
# ### Die wichtigsten Bereiche:
#
# 1. **Menüleiste** (oben)
#    - Enthält alle Befehle, die Sie benötigen
#    - Beispiel: `Datei` → `Speichern`
#
# 2. **Werkzeugkästen** (meist links oder oben)
#    - Schnelle Zugänge zu häufig verwendeten Funktionen
#    - Symbole für Grundkörper, Transformationen, etc.
#
# 3. **Modell-Strukturbaum** (links)
#    - Zeigt alle Objekte in Ihrem Projekt
#    - Sie können Objekte anklicken und organisieren
#
# 4. **3D-Ansicht** (in der Mitte)
#    - Der Arbeitsbereich, wo Ihr Modell angezeigt wird
#    - Interaktiv: Sie können drehen, zoomen und verschieben
#
# 5. **Eigenschaften-Panel** (rechts)
#    - Zeigt Details des aktuell ausgewählten Objekts
#    - Hier können Sie Maße und Positionen ändern

# %% [markdown]
# ## 🎮 Steuerung der 3D-Ansicht
#
# Bevor Sie mit dem Konstruieren beginnen, müssen Sie lernen, die 3D-Ansicht zu steuern:
#
# ### Mit der Maus navigieren:
#
# | Aktion | Taste/Maus-Kombination |
# |--------|------------------------|
# | **Drehen** | Mitteltaste gedrückt halten + Maus bewegen |
# | **Zoomen** | Mausrad nach oben/unten OR Scroll |
# | **Verschieben** | Mitteltaste + Shift gedrückt halten + Maus bewegen |
# | **Zurücksetzen** | `V` dann `H` (View → Home) |
#
# ### Mit der Tastatur navigieren:
#
# - `V` → `F`: Alles anpassen (Fit All)
# - `V` → `H`: Zurück zur Startposition
# - `Numpad 1`: Vorderansicht
# - `Numpad 3`: Seitenansicht
# - `Numpad 7`: Draufsicht
#
# ---
#
# ## 🔷 Grundkörper erstellen – Schritt für Schritt
#
# ### Schritt 1: Einen neuen Würfel erstellen
#
# ```
# Menü: Part (oder Part Design) → Create primitives → Cube
#    oder
# Klick auf das Würfel-Symbol in der Werkzeugleiste
# ```
#
# **Was passiert:**
# - Ein Würfel mit Kantenlänge 10 mm wird in der Mitte des Raums erstellt
# - Der Würfel wird im Modell-Strukturbaum (links) aufgelistet
# - Der Würfel erscheint in der 3D-Ansicht
#
# ### Schritt 2: Größe des Würfels ändern
#
# Nach dem Erstellen des Würfels:
#
# 1. Klicken Sie auf den Würfel im **3D-Fenster** oder im **Modell-Strukturbaum**
# 2. Schauen Sie nach rechts ins **Eigenschaften-Panel**
# 3. Suchen Sie den Eintrag `Height`, `Length` und `Width`
# 4. Ändern Sie die Werte, z.B. `Height: 20 mm`
# 5. Drücken Sie **Enter** zum Bestätigen
#
# **Beispiel:**
# - Länge (Length): 50 mm
# - Breite (Width): 40 mm
# - Höhe (Height): 30 mm
#
# → Sie erhalten einen **Quader** statt eines Würfels!
#
# ### Schritt 3: Position des Objekts ändern
#
# Im **Eigenschaften-Panel** finden Sie auch:
# - `X`, `Y`, `Z`: Die Position des Objekts im Raum
#
# Beispiel: Um den Quader nach rechts zu verschieben, ändern Sie `X: 50 mm`
#
# ---
#
# ## 🔴 Weitere Grundkörper erstellen
#
# FreeCAD bietet mehrere Standard-Grundkörper:
#
# ### 1. **Zylinder** erstellen
#
# ```
# Menü: Part → Create primitives → Cylinder
# ```
#
# **Eigenschaften eines Zylinders:**
# - `Radius`: Durchmesser an der Basis
# - `Height`: Höhe des Zylinders
# - `Angle`: Kreissektor (360° = vollständiger Zylinder)
#
# ### 2. **Kugel** erstellen
#
# ```
# Menü: Part → Create primitives → Sphere
# ```
#
# **Eigenschaften einer Kugel:**
# - `Radius`: Radius der Kugel
# - `Angle1`, `Angle2`: Um eine Kugelkappe zu erstellen (z.B. Halbkugel)
#
# ### 3. **Kegel** erstellen
#
# ```
# Menü: Part → Create primitives → Cone
# ```
#
# **Eigenschaften eines Kegels:**
# - `Radius`: Radius an der Basis
# - `Height`: Höhe des Kegels
#
# ---
#
# ## 🎨 Praktisches Beispiel: Einfache Szene aufbauen
#
# Lassen Sie uns zusammen ein einfaches 3D-Modell aus mehreren Grundkörpern erstellen:
#
# ### Aufgabe: "Haus mit Dach"
#
# 1. **Erstellen Sie einen Quader** (das Fundament des Hauses):
#    - Length: 100 mm
#    - Width: 80 mm
#    - Height: 60 mm
#
# 2. **Erstellen Sie einen zweiten Quader** (die Hauswand):
#    - Length: 90 mm
#    - Width: 70 mm
#    - Height: 50 mm
#    - Positionieren Sie ihn zentriert auf dem ersten Quader (Y: 5 mm, X: 5 mm)
#
# 3. **Erstellen Sie einen Kegel** (das Dach):
#    - Radius: 50 mm
#    - Height: 40 mm
#    - Positionieren Sie ihn oben auf dem Haus (Z: 60 mm)
#
# 4. **Drehen Sie die Ansicht**, um Ihr Modell von verschiedenen Seiten zu betrachten:
#    - Benutzen Sie die Mitteltaste + Maus zum Drehen
#
# ---
#
# ## 🔍 Ansichten anpassen
#
# ### Zoom-Funktionen:
#
# | Funktion | Ausführung |
# |----------|-----------|
# | **Hineinzoomen** | Mausrad nach oben oder `+` Taste |
# | **Herauszoomen** | Mausrad nach unten oder `-` Taste |
# | **Alles anpassen** | `V` → `F` oder Menü: View → Fit All |
#
# ### Verschiedene Standardansichten:
#
# ```
# Menü: View → Standard Views
# ```
#
# - **Front** (Vorderansicht)
# - **Top** (Draufsicht)
# - **Right** (Rechts-Ansicht)
# - **Isometric** (Isometrische Ansicht – zeigt das Modell in 3D)
#
# ---
#
# ## 📝 Speichern Ihres ersten Projekts
#
# Um Ihre Arbeit zu speichern:
#
# ```
# Menü: File → Save
#    oder
# Tastenkürzel: Ctrl + S
# ```
#
# FreeCAD speichert die Datei als `.FCStd` Datei (FreeCAD Standard).
#
# ### Speichern in anderen Formaten:
#
# Falls Sie Ihr Modell in anderen Programmen nutzen möchten:
#
# ```
# Menü: File → Export (oder Export As)
# ```
#
# Verfügbare Formate:
# - **STEP** (.step, .stp): Für Datenaustausch mit anderen CAD-Programmen
# - **IGES** (.iges, .igs): Älteres Austauschformat
# - **STL** (.stl): Für 3D-Drucker
# - **OBJ** (.obj): Für Grafikprogramme
# - **DXF** (.dxf): Für technische Zeichnungen
#
# ---
#
# ## 🎓 Zusammenfassung
#
# In diesem Modul haben Sie gelernt:
#
# - Was CAD bedeutet und wo es eingesetzt wird
# - Die Benutzeroberfläche von FreeCAD zu verstehen
# - Grundkörper wie Würfel, Zylinder und Kugel zu erstellen
# - Die 3D-Ansicht zu kontrollieren (drehen, zoomen, verschieben)
# - Grundkörper in Größe und Position anzupassen
# - Projekte zu speichern
#
# -

# %% [markdown]
# ## 📚 Weiterführende Links
#
# Vertiefen Sie Ihr Wissen mit diesen Ressourcen:
#
# - [FreeCAD Offizielle Dokumentation – Erste Schritte](https://wiki.freecadweb.org/Getting_started)
# - [Part Workbench (Arbeitsbereich für Grundkörper)](https://wiki.freecadweb.org/Part_Workbench)
# - [FreeCAD YouTube Anfänger-Tutorial](https://www.youtube.com/playlist?list=PLw48L7HmCgMKjc0hnu8rIGt7cfBM0ieiB)
