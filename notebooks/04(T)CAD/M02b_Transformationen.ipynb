# %% [markdown]
# # Modul 2b: Transformationen von Grundkörpern – Übungsaufgaben mit Hinweisen
#
# ## 📝 Anleitung zu diesem Arbeitsblatt
#
# Dieses Modul enthält **fünf praktische Aufgaben** zum Thema Transformationen. Jede Aufgabe ist mit **Hinweisen und TODO-Markierungen** versehen, damit du selbst experimentieren kannst, ohne die komplette Lösung direkt zu sehen.
#
# **Wichtig:** Arbeite diese Aufgaben am Computer mit FreeCAD durch! Das aktive Ausprobieren ist das beste Lernmittel.
#
# ---
#
# ## ✅ Aufgabe 1: Verschieben – Ein Würfel auf Reise
#
# ### Aufgabenbeschreibung
#
# Du sollen einen **Würfel** erstellen und ihn dann **mehrmals hintereinander** verschieben. Das trainiert, wie man die Koordinaten in der Property-Liste ändert.
#
# ### 📋 Deine Aufgabe (Schritt für Schritt)
#
# 1. **Neues Dokument öffnen:**
#    - Datei → Neu
#    - oder `Strg+N`
#
# 2. **Einen Würfel erstellen:**
#    - Menü: `Part → Create Primitives → Cube`
#    - oder: Button in der Werkzeugleiste
#
#    _TODO: Wie groß ist der Würfel standardmäßig? Schreib die Kantenlänge auf._
#
# 3. **Würfel im Model-Baum** (linkes Fenster) **anklicken**, um ihn zu markieren
#
# 4. **Im Property-Panel** (rechts) unter „Placement → Position":
#    - X auf **10** setzen und Enter drücken
#    - **Beobachte**: Der Würfel rückt nach rechts
#    - _TODO: In welche Richtung hat sich der Würfel bewegt? (Rechts, Links, Oben, Unten)?_
#
# 5. **Y-Position auf 5 ändern**:
#    - Y-Wert auf **5** setzen, Enter
#    - _TODO: Wie bewegt sich der Würfel jetzt? Wird er höher oder tiefer in der Ansicht?_
#
# 6. **Z-Position auf -10 ändern**:
#    - Z-Wert auf **-10** setzen, Enter
#    - _TODO: Der Würfel verschwindet teilweise hinter anderen Elementen. Warum könnte das sein?_
#
# 7. **Abschließend**: Zoom auf alles oder mit der Maus die Ansicht drehen, um den Würfel wieder komplett zu sehen
#
# ### 💡 Reflexionsfragen
#
# - Was passiert, wenn du X auf eine **negative Zahl** setzt, z.B. X = -15?
# - Welche Achse steuert die Höhe des Objekts in der Standard-Ansicht?
#
# ---
#
# ## ✅ Aufgabe 2: Drehen – Ein Zylinder kippt um
#
# ### Aufgabenbeschreibung
#
# In dieser Aufgabe sollen du einen **stehenden Zylinder** erzeugen und ihn dann **um verschiedene Achsen drehen**. So lernst du, wie die Rotation-Werte funktionieren.
#
# ### 📋 Deine Aufgabe
#
# 1. **Im gleichen Dokument** einen Zylinder erstellen:
#    - Menü: `Part → Create Primitives → Cylinder`
#
# 2. **Den Zylinder im Model-Baum anklicken**
#
# 3. **Im Property-Panel** unter „Placement → Rotation":
#    - Schau, welche Werte dort stehen (wahrscheinlich alle 0°)
#    - _TODO: Was bedeuten die drei Felder Yaw, Pitch, Roll?_
#
# 4. **Yaw-Wert auf 45° setzen**:
#    - Yaw (erste Rot-Achse) = **45°**
#    - Enter drücken
#    - _TODO: Zeichne auf, wie sich der Zylinder dreht. Kippt er nach vorne oder zur Seite?_
#
# 5. **Roll-Wert auf 90° setzen** (Yaw bleibt 45°):
#    - Roll = **90°**
#    - _TODO: Vergleiche: Sieht der Zylinder anders aus als vorher? Dreht er sich um eine andere Achse?_
#
# 6. **Alle Rotationswerte auf 0° zurücksetzen**:
#    - Yaw = 0°, Pitch = 0°, Roll = 0°
#    - Der Zylinder sollte wieder aufrecht stehen
#
# 7. **Pitch auf 90° setzen**:
#    - Pitch (zweite Rot-Achse) = **90°**
#    - _TODO: Jetzt sollte der Zylinder auf der Seite liegen. Stimmt das?_
#
# ### 💡 Reflexionsfragen
#
# - Wenn du einen Zylinder **90°** um **Pitch** drehst, liegt er dann wirklich komplett auf der Seite?
# - Was passiert, wenn du alle drei Werte auf **45°** stellst?
#
# ---
#
# ## ✅ Aufgabe 3: Koordinaten verstehen – Objekte auf einer Gitterebene
#
# ### Aufgabenbeschreibung
#
# Diese Aufgabe trainiert dein **Koordinatenverständnis**. Du sollst **vier Würfel** so positionieren, dass sie in einem **2×2 Gitter** angeordnet sind.
#
# ### 📋 Deine Aufgabe
#
# 1. **Vier Würfel erstellen**:
#    - Du kannst den ersten duplizieren und die anderen drei Kopien verschieben
#    - Oder vier separate Würfel erzeugen
#
# 2. **Die Positionen berechnen und einstellen**:
#
# | Würfel-Name | X | Y | Z | Position im Gitter |
# |------------|---|---|---|--------------------|
# | Cube_1 | 0 | 0 | 0 | Unten-Links |
# | Cube_2 | 20 | 0 | 0 | Unten-Rechts |
# | Cube_3 | 0 | 20 | 0 | Oben-Links |
# | Cube_4 | 20 | 20 | 0 | Oben-Rechts |
#
# _TODO: Setze diese Positionen nacheinander für jeden Würfel ein. Nutze das Property-Panel._
#
# 3. **Überprüfe dein Ergebnis**:
#    - Nutze die Zoom-Funktion, um alle vier Würfel zu sehen (View → Fit All, oder Taste `V` → `F`)
#    - _TODO: Bilden die vier Würfel wirklich ein Quadrat?_
#
# 4. **Zusätzliche Herausforderung**:
#    - Verschiebe einen der Würfel um Z = 10 nach oben
#    - Erstelle jetzt eine „Säule" aus zwei übereinander gestapelten Würfeln
#
# ### 💡 Reflexionsfragen
#
# - Wenn zwei Würfel beide die Z-Position 0 haben, liegen sie dann auf der gleichen Höhe?
# - Wie würde die Tabelle aussehen, wenn du **drei** Würfel in einer **Linie** anordnen möchtest (statt 2×2)?
#
# ---
#
# ## ✅ Aufgabe 4: Duplizieren – Eine Würfel-Reihe bauen
#
# ### Aufgabenbeschreibung
#
# Hier trainierst du das **Duplizieren** und lernst, schnell **wiederholte Strukturen** zu erzeugen.
#
# ### 📋 Deine Aufgabe
#
# 1. **Einen Würfel erstellen** an Position (X=0, Y=0, Z=0)
#
# 2. **Den Würfel fünfmal duplizieren**:
#    - Menü: Bearbeiten → Duplizieren
#    - oder Tastaturkürzel: `Strg+D`
#    - Dies fünfmal wiederholen
#    - _TODO: Wie viele Würfel hast du jetzt insgesamt im Model-Baum?_
#
# 3. **Die Kopien verschieben**:
#    - Jede der fünf Kopien um jeweils **20 mm auf der X-Achse** verschieben
#    - Anleitung:
#      - 1. Kopie: X = 20, Y = 0, Z = 0
#      - 2. Kopie: X = 40, Y = 0, Z = 0
#      - 3. Kopie: X = 60, Y = 0, Z = 0
#      - 4. Kopie: X = 80, Y = 0, Z = 0
#      - 5. Kopie: X = 100, Y = 0, Z = 0
#    - _TODO: Welcher Würfel ist der ursprüngliche? (Hinweis: Er sollte „Cube" heißen, nicht „Cube_copy".)_
#
# 4. **Überprüfe die Anordnung**:
#    - Fit All (V → F) und beobachte die Würfel-Reihe
#    - _TODO: Stehen alle Würfel nebeneinander, ohne sich zu überlappen?_
#
# 5. **Zusätzliche Herausforderung**:
#    - Verschiebe einen der mittleren Würfel um Z = 10 nach oben
#    - Erstelle damit ein visuelles Muster (z.B. „Berg" oder „Welle")
#
# ### 💡 Reflexionsfragen
#
# - Was ist der Unterschied zwischen einer Kopie (`Copy`) und einem Klon (`Clone`)?
# - Wenn du eine Reihe aus 10 Würfeln erstellen möchtest – würde es schneller gehen, sie alle einzeln zu duplizieren, oder gibt es eine bessere Methode?
#
# ---
#
# ## ✅ Aufgabe 5: Ausrichten – Ein Kerzenständer bauen
#
# ### Aufgabenbeschreibung
#
# Diese **Abschlussaufgabe** verbindet alles Gelernte: Du sollst ein **einfaches 3D-Modell** – einen **Kerzenständer** – konstruieren, indem du mehrere Objekte richtig zueinander ausrichtest.
#
# ### 📋 Aufbau des Kerzenständers
#
# - **Basis (Platte)**: Ein flacher Quader: 50 × 50 × 5 mm
# - **Vier Beine**: Vier Zylinder (Durchmesser 5 mm, Höhe 15 mm)
#   - Bein 1: vorne-links
#   - Bein 2: vorne-rechts
#   - Bein 3: hinten-links
#   - Bein 4: hinten-rechts
# - **Kerzen-Halter (oben auf der Platte)**: Ein kleiner Zylinder (Durchmesser 3 mm, Höhe 5 mm) in der Mitte
#
# ### 📋 Deine Aufgabe (Schritt für Schritt)
#
# 1. **Neues Dokument** öffnen
#
# 2. **Basis-Platte erstellen**:
#    - Part → Cube
#    - Im Property-Panel die Größe anpassen:
#      - Length (X): **50 mm**
#      - Width (Y): **50 mm**
#      - Height (Z): **5 mm**
#    - Position: X=0, Y=0, Z=0
#
# 3. **Vier Beine erstellen und positionieren**:
#
#    _TODO: Berechne die Positionen für die vier Beine. Tipp: Die Beine sollten an den Ecken der Platte sein._
#
#    Anhaltspunkte:
#    - Platte reicht von X=-25 bis X=+25 und Y=-25 bis Y=+25
#    - Die Beine müssen **unter** der Platte sein, also bei Z = ?
#    - Zylinder haben einen Radius, den Mittelpunkt also mittig positionieren
#
#    ```
#    Bein 1 (vorne-links):
#      Cylinder
#      Position: X = -20, Y = -20, Z = ?  (TODO: Welcher Z-Wert?)
#      Durchmesser (Radius): 2,5 mm
#      Höhe: 15 mm
#
#    Bein 2 (vorne-rechts):
#      Position: X = 20, Y = -20, Z = ?
#      ...
#
#    Bein 3 (hinten-links):
#      Position: X = -20, Y = 20, Z = ?
#      ...
#
#    Bein 4 (hinten-rechts):
#      Position: X = 20, Y = 20, Z = ?
#      ...
#    ```
#
# 4. **Kerzen-Halter in der Mitte**:
#    - Cylinder
#    - Position: X = 0, Y = 0, Z = 5  (direkt auf der Platte)
#    - Durchmesser (Radius): 1,5 mm
#    - Höhe: 5 mm
#
# 5. **Überprüfe das Ergebnis**:
#    - Fit All (V → F)
#    - _TODO: Steht der Kerzenständer stabil? Berühren die Beine die Platte?_
#    - Drehe die Ansicht mit der Maus (mittlere Maustaste halten und bewegen)
#    - _TODO: Schreib auf, was du siehst. Sieht es wie ein echtes Modell aus?_
#
# 6. **Zusätzliche Herausforderung**:
#    - Bearbeite einen der Zylinder und drehe ihn um 45° (Yaw = 45°)
#    - Oder verschiebe einen der Beine nach oben – sieht das Modell dann noch stabil aus?
#
# ### 💡 Reflexionsfragen
#
# - Wenn die Basis-Platte 50 × 50 mm ist und die Mittelpunkt bei (0, 0) liegt, wo sind dann die Ecken der Platte?
# - Warum ist es wichtig, die Z-Position der Beine **negativ** zu setzen?
# - Was würde passieren, wenn du die Beine **nicht** auf den richtigen Z-Wert stellst? (Würden sie durch die Platte gehen oder darüber schweben?)
#
# ---
#
# ## 📚 Noch Fragen?
#
# Wenn du bei einer Aufgabe steckenbleibst:
# 1. **Lese die Hinweise nochmal** gründlich durch
# 2. **Schaue die Demonstration (Modul 2a)** nochmal an
# 3. **Experimentiere**: Ändere einfach Werte und beobachte, was passiert
# 4. **Frag einen Mitschüler** oder die Lehrkraft
#
# ---
#
# ## 🔗 Schnelle Übersicht: FreeCAD-Menüpfade
#
# | Aktion | Menüpfad |
# |--------|----------|
# | Würfel erzeugen | `Part → Create Primitives → Cube` |
# | Zylinder erzeugen | `Part → Create Primitives → Cylinder` |
# | Objekt verschieben | `Bearbeiten → Platzierung` oder rechte Maustaste → Platzierung |
# | Objekt drehen | `Bearbeiten → Platzierung → Rotation` |
# | Objekt duplizieren | `Bearbeiten → Duplizieren` oder `Strg+D` |
# | Alles anzeigen | `Ansicht → Fit All` oder `V → F` |
#
# ---
#
# ## 📝 Nächste Schritte
#
# Wenn du alle Aufgaben geschafft hast, bist du bereit für **Modul 3: Boolesche Operationen**!
# Dort lernst du, wie man Objekte **kombiniert** und aus anderen **Material ausschneidet**.
