# %% [markdown]
# # M01c: Einführung in CAD und FreeCAD – Ausführliche Lösungen
#
# ## 🎯 Lösungsübersicht
#
# Dieses Dokument enthält die vollständigen Lösungen aller Aufgaben aus Modul 1b mit ausführlichen Erklärungen.
#
# ---
#
# ## ✅ Lösung Aufgabe 1: FreeCAD starten und erste Orientierung
#
# ### Beobachtungen und Erklärungen:
#
# **1. Modell-Strukturbaum (links):**
# - Zeigt eine Hierarchie aller Objekte in Ihrem Projekt
# - Anfangs ist dieser meist leer oder enthält nur die Standard-Objekte (Ursprung, Achsen)
# - Hier können Sie Objekte organisieren und umbenennen
#
# **2. Eigenschaften-Panel (rechts):**
# - Zeigt die Eigenschaften des aktuell ausgewählten Objekts
# - Wichtige Eigenschaften: Position (X, Y, Z), Größe (Height, Length, Width), Materialien, Farbe
# - Sie können diese Werte direkt hier ändern
#
# **3. 3D-Ansicht (Mitte):**
# - Dies ist der Arbeitsbereich, wo Sie Ihre Modelle konstruieren
# - Zeigt ein 3D-Koordinatensystem mit Achsen (rot = X, grün = Y, blau = Z)
#
# ### Reflexionsantworten:
#
# - **Welche Menüs finden Sie?**
#   Datei, Bearbeiten, Ansicht, Extras, Fenster, Hilfe, und der aktuelle Arbeitsbereich-Name (Part, Part Design, Sketcher, etc.)
#
# - **Werkzeugkästen:**
#   Oben oder links am Fenster; sie enthalten Icons für häufig verwendete Funktionen
#
# - **Werkzeug für Grundkörper:**
#   `Part` Menü → `Create primitives` oder durch ein Symboltool (oft ein Würfel-Icon)
#
# ---
#
# ## ✅ Lösung Aufgabe 2: Ihren ersten Würfel erstellen
#
# ### Schritt-für-Schritt Lösung:
#
# **Menüs in FreeCAD öffnen:**
#
# ```
# 1. Klicken Sie auf das Menü "Part" (oben in der Menüleiste)
# 2. Wählen Sie "Create primitives"
# 3. Klicken Sie auf "Cube"
# ```
#
# **Was jetzt passiert:**
#
# - Ein neues Objekt namens "Cube" (oder "Würfel") wird erstellt
# - Es erscheint im Modell-Strukturbaum auf der linken Seite
# - In der 3D-Ansicht (Mitte) sehen Sie einen grauen Würfel mit schwarzen Kanten
# - Der Würfel ist bereits ausgewählt (meistens grün hervorgehoben)
#
# **Im Eigenschaften-Panel:**
#
# Die aktuellen Werte eines Standard-Würfels sind:
# - `Height`: 10 mm
# - `Length`: 10 mm
# - `Width`: 10 mm
#
# Diese können je nach FreeCAD-Version leicht variieren.
#
# ### Reflexionsantworten:
#
# - **Farbe des Würfels:** Grau (Standardfarbe in FreeCAD)
# - **Name im Strukturbaum:** "Cube" oder "Würfel" (je nach Spracheinstellung)
# - **Position in der 3D-Ansicht:** Genau im Ursprung (0, 0, 0) – in der Mitte des Koordinatensystems
#
# ---
#
# ## ✅ Lösung Aufgabe 3: Größe ändern – Quader erstellen
#
# ### Schritt-für-Schritt Lösung:
#
# **Eigenschaften ändern:**
#
# 1. Klicken Sie auf den Würfel (falls nicht bereits ausgewählt)
# 2. Schauen Sie ins **Eigenschaften-Panel auf der rechten Seite**
# 3. Suchen Sie die Einträge `Height`, `Length`, `Width`
# 4. Ändern Sie die Werte:
#
# ```
# Height: 50 mm (drücken Sie Enter)
# Length: 100 mm (drücken Sie Enter)
# Width: 40 mm (drücken Sie Enter)
# ```
#
# **Warum funktioniert das?**
#
# In FreeCAD werden Objekteigenschaften real-time aktualisiert. Jedes Mal, wenn Sie einen Wert ändern und Enter drücken, wird das 3D-Modell sofort neu berechnet und angezeigt.
#
# **Ergebnis:** Sie haben erfolgreich einen **Quader** (rechteckigen Kasten) erstellt!
#
# ### TODO-Aufgabe Lösung:
#
# Um einen Quader mit folgenden Maßen zu erstellen:
# - Länge: 80 mm
# - Breite: 60 mm
# - Höhe: 120 mm
#
# **Vorgehen:**
#
# 1. Erstellen Sie einen neuen Würfel:
#    ```
#    Menü: Part → Create primitives → Cube
#    ```
#
# 2. Im Eigenschaften-Panel ändern Sie:
#    ```
#    Length: 80 mm (Enter)
#    Width: 60 mm (Enter)
#    Height: 120 mm (Enter)
#    ```
#
# 3. **Beobachtung:** Der neue Quader ist deutlich höher (120 mm) als breit und tief (80 × 60 mm)
#
# ### Reflexionsantworten:
#
# - **Farbe:** Nein, die Farbe bleibt grau
# - **Größe:** Der neue Quader mit den Maßen 80 × 60 × 120 mm ist **größer** als der ursprüngliche 10 × 10 × 10 mm Würfel
#
# ---
#
# ## ✅ Lösung Aufgabe 4: Zylinder erstellen und positionieren
#
# ### Schritt-für-Schritt Lösung:
#
# **Zylinder erstellen:**
#
# ```
# Menü: Part → Create primitives → Cylinder
# ```
#
# **Eigenschaften im Panel ändern:**
#
# 1. Klicken Sie auf den neu erstellten Zylinder, um ihn auszuwählen
# 2. Im Eigenschaften-Panel finden Sie:
#    - `Radius`: Ändern Sie auf **15 mm**
#    - `Height`: Ändern Sie auf **80 mm**
#
# 3. Verschieben Sie den Zylinder:
#    - `X`: **150 mm** (nach rechts)
#    - `Y`: **0 mm** (unverändert)
#    - `Z`: **0 mm** (unverändert)
#
# **Warum diese Position?**
#
# Die X-Koordinate von 150 mm bedeutet: Der Zylinder steht 150 mm nach rechts vom Ursprung. Der ursprüngliche Quader mit Länge 80-100 mm war bei X = 0-50 mm, also steht der Zylinder neben ihm.
#
# ### TODO-Aufgabe Lösung:
#
# Für einen zweiten Zylinder:
#
# ```
# 1. Neuen Zylinder erstellen: Part → Create primitives → Cylinder
# 2. Eigenschaften:
#    - Radius: 20 mm
#    - Height: 50 mm
#    - X: 250 mm
#    - Y: 50 mm
#    - Z: 0 mm
# ```
#
# **Resultat:** Sie haben zwei Zylinder mit unterschiedlichen Größen nebeneinander positioniert.
#
# **Umbenennen (Optional):**
#
# Um einen Zylinder umzubenennen:
# 1. Klicken Sie im Modell-Strukturbaum (links) auf den Zylinder
# 2. Drücken Sie **F2** oder doppelklicken Sie darauf
# 3. Geben Sie einen neuen Namen ein, z.B. "Großer_Zylinder"
# 4. Drücken Sie **Enter**
#
# ### Reflexionsantworten:
#
# - **Objekte im Strukturbaum:**
#   - Ursprung (Origin)
#   - Cube (erster Würfel)
#   - Cylinder (erster Zylinder)
#   - Cylinder001 (zweiter Zylinder)
#   Also: **3 Geometrie-Objekte**
#
# - **Unterscheidung:** Sie können die Zylinder umbenennen (s.o.) oder die Farbe ändern (Rechtsklick → Farbe)
#
# ---
#
# ## ✅ Lösung Aufgabe 5: Kugel erstellen
#
# ### Schritt-für-Schritt Lösung:
#
# **Kugel erstellen:**
#
# ```
# Menü: Part → Create primitives → Sphere
# ```
#
# **Eigenschaften im Panel:**
#
# 1. Wählen Sie die neu erstellte Kugel
# 2. Im Eigenschaften-Panel:
#    - `Radius`: **25 mm**
#
# 3. Positionieren Sie die Kugel:
#    - `X`: **100 mm**
#    - `Y`: **100 mm**
#    - `Z`: **100 mm**
#
# **Ergebnis:** Eine Kugel mit Radius 25 mm schwebt 100 mm nach rechts, 100 mm nach vorne und 100 mm nach oben vom Ursprung.
#
# ### TODO-Aufgabe Lösung:
#
# Für eine zweite Kugel:
#
# ```
# 1. Neue Kugel erstellen: Part → Create primitives → Sphere
# 2. Eigenschaften:
#    - Radius: 30 mm
#    - X: 300 mm
#    - Y: 150 mm
#    - Z: 50 mm
# ```
#
# ### Reflexionsantworten:
#
# - **Gesamtzahl der Objekte:**
#   - 1 Quader (Cube)
#   - 2 Zylinder (Cylinder, Cylinder001)
#   - 2 Kugeln (Sphere, Sphere001)
#   Also: **5 Geometrie-Objekte insgesamt**
#
# - **Ansicht:** Die Kugeln auf Z = 100 mm und Z = 50 mm sind möglicherweise nicht vollständig sichtbar, wenn man von vorne schaut. Sie müssen die Ansicht drehen, um alles zu sehen.
#
# ---
#
# ## ✅ Lösung Aufgabe 6: 3D-Ansicht steuern
#
# ### Schritt-für-Schritt Lösung:
#
# **1. Drehen der Ansicht:**
#
# ```
# - Halten Sie die Mitteltaste (Scrollrad) Ihrer Maus gedrückt
# - Bewegen Sie die Maus nach links/rechts → das Modell dreht sich um die vertikale Achse
# - Bewegen Sie die Maus nach oben/unten → das Modell dreht sich um die horizontale Achse
# - Lassen Sie die Taste los
# ```
#
# **2. Zoomen:**
#
# ```
# Heranzoomen:
# - Drehen Sie das Mausrad NACH OBEN
# - oder drücken Sie die "+" Taste auf der Tastatur
#
# Herauszoomen:
# - Drehen Sie das Mausrad NACH UNTEN
# - oder drücken Sie die "-" Taste auf der Tastatur
# ```
#
# **3. Verschieben der Ansicht:**
#
# ```
# - Halten Sie Mitteltaste + Shift Tasten gedrückt
# - Bewegen Sie die Maus
# - Das gesamte Modell verschiebt sich im Fenster
# ```
#
# **4. Tastenkürzel nutzen:**
#
# ```
# View zurücksetzen (Startposition): V → H
# Alle Objekte sichtbar machen:    V → F
# Vorderansicht:                    Numpad 1
# Seitenansicht:                    Numpad 3
# Draufsicht:                       Numpad 7
# ```
#
# ### TODO-Aufgabe Lösung:
#
# **Schritte:**
#
# 1. **Drehen um 45 Grad:**
#    - Mitteltaste gedrückt halten
#    - Maus nach rechts-oben bewegen (ca. 45 Grad)
#    - Loslassen
#
# 2. **Hereinzoomen auf die Kugel:**
#    - Mausrad nach oben drehen
#    - Mehrmals wiederholen, bis nur noch eine Kugel sichtbar ist
#
# 3. **Herauszoomen:**
#    - Mausrad nach unten drehen
#    - Alle Objekte sollten wieder sichtbar sein
#
# 4. **Draufsicht:**
#    - Tastatur: Numpad 7 drücken
#    - oder Menü: `View` → `Standard Views` → `Top`
#
# ### Reflexionsantworten:
#
# - **Ist das Drehen leicht?** Ja, mit Übung! Es braucht ein wenig Gewöhnung, welche Maus-Bewegung welche Rotation verursacht.
#
# - **Vorne/Hinten unterscheiden:** In der isometrischen Ansicht (Perspektivansicht) kann man räumliche Tiefe sehen. Objekte mit höheren Z-Werten sind "oben", Objekte mit niedrigeren Z-Werten sind "unten" im 3D-Raum.
#
# ---
#
# ## ✅ Lösung Aufgabe 7: Projekt speichern
#
# ### Schritt-für-Schritt Lösung:
#
# **Datei speichern:**
#
# ```
# Variante 1 (Menü):
# Menü: File → Save
#
# Variante 2 (Tastenkürzel):
# Ctrl + S
# ```
#
# **Dialog-Fenster:**
#
# 1. Ein Fenster öffnet sich mit der Frage nach dem Speicherort
# 2. Wählen Sie einen Ort (z.B. `C:\Benutzer\IhrName\Schreibtisch`)
# 3. Geben Sie einen Namen ein, z.B.:
#    ```
#    Erste_Konstruktion.FCStd
#    Mein_CAD_Projekt.FCStd
#    ```
# 4. Klicken Sie auf **Speichern**
#
# **Ergebnis:** Die Datei wird gespeichert, und der Titel des FreeCAD-Fensters zeigt jetzt den Dateinamen.
#
# ### TODO-Aufgabe Lösung:
#
# **Speichern mit eigenem Namen:**
#
# ```
# Menü: File → Save (oder Ctrl + S)
#
# Im Dialog:
# Speicherort: C:\Benutzer\IhrName\Meine_Dokumente
# Dateiname: MaxMüller_CAD_Projekt_20251112.FCStd
#            (oder: Modul_01_Erste_Konstruktion.FCStd)
#
# Klick: Speichern
# ```
#
# Die Datei wird jetzt mit Ihrem Namen gespeichert.
#
# ### Reflexionsantworten:
#
# - **Was bedeutet `.FCStd`?**
#   FCStd = FreeCAD Standard Format. Das ist das native Format von FreeCAD und speichert alle Informationen über Ihr Projekt (Geometrie, Parameter, Skizzen, etc.).
#
# - **Wo ist die Datei gespeichert?**
#   An dem Ort, den Sie im Dialog ausgewählt haben (meistens der Schreibtisch oder Dokumente-Ordner).
#
# - **Kann ich die Datei später öffnen?**
#   Ja! Einfach: `Datei` → `Öffnen` → Datei auswählen. Sie können auch Dateien öffnen, die Sie mit Ihrem Namen gespeichert haben.
#
# ---
#
# ## 🎓 Zusammenfassung der Lösungen
#
# Sie haben erfolgreich gelernt:
#
# ✅ **Grundkörper erstellen:** Würfel, Zylinder, Kugel über `Part → Create primitives`
# ✅ **Größe ändern:** Durch die Eingabe von Height, Length, Width im Eigenschaften-Panel
# ✅ **Positionieren:** Durch X, Y, Z Werte im Eigenschaften-Panel
# ✅ **3D-Ansicht kontrollieren:** Drehen (Mitteltaste), Zoomen (Mausrad), Verschieben (Mitteltaste + Shift)
# ✅ **Projekte speichern:** Mit Ctrl + S im FCStd-Format
#
# ---
#
# ## 📌 Wichtige Hinweise und Tipps
#
# ### 1. **Tastenkürzel merken:**
# - `Ctrl + S`: Speichern
# - `V + H`: View zurücksetzen
# - `V + F`: Alles anpassen
# - `Numpad 7`: Draufsicht
#
# ### 2. **Häufige Fehler vermeiden:**
# - **Objekt nicht sichtbar?** → `V + F` drücken (Alles anpassen)
# - **Nach dem Ändern von Eigenschaften nichts passiert?** → **Enter drücken**!
# - **Falscher Arbeitsbereich?** → Workbench wechseln (oben rechts)
#
# ### 3. **Objekte organisieren:**
# - Benennen Sie Objekte aussagekräftig (z.B. "Fundament", "Dach")
# - Nutzen Sie Farben zur Unterscheidung (Rechtsklick → Farbe)
# - Nutzen Sie die Strukturbaum-Hierarchie
#
# ### 4. **Nächste Schritte:**
# Im nächsten Modul werden Sie lernen:
# - Objekte zu verschieben und zu drehen (Transformationen)
# - Mehrere Objekte zu kombinieren (Boolesche Operationen)
# - Symmetrische Strukturen zu erzeugen
#
# ---
#
# ## 📚 Weiterführende Ressourcen
#
# - [FreeCAD Offizielle Wiki – Part Workbench](https://wiki.freecadweb.org/Part_Workbench)
# - [Geometrische Grundformen – Wikipedia](https://de.wikipedia.org/wiki/Geometrischer_K%C3%B6rper)
# - [3D-Koordinatensystem erklärt – Khan Academy](https://www.youtube.com/watch?v=NpoIHluOB4k)
#
# ---
#
# ## 🧪 Zusatzaufgaben für Fortgeschrittene
#
# ### Aufgabe A: Komplexere Szene erstellen
#
# Erstellen Sie eine Szene mit mindestens 10 Objekten verschiedener Formen und Größen:
# - 3-4 Quader
# - 3-4 Zylinder
# - 2-3 Kugeln
# - Optional: Kegel (Cone)
#
# Positionieren Sie sie so, dass eine interessante 3D-Szene entsteht.
#
# ### Aufgabe B: Symmetrische Anordnung
#
# Erstellen Sie eine symmetrische Anordnung von Objekten um den Ursprung (Mittelpunkt).
#
# ### Aufgabe C: Eigenes Projekt planen
#
# Denken Sie sich ein einfaches Objekt aus der Realität (z.B. ein Haus, ein Spielzeugauto, ein Roboter-Kopf) und überlegen Sie, welche Grundkörper Sie dafür brauchen würden.
