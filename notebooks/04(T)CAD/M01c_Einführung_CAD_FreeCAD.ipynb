# %% [markdown]
# # M01c: Einführung in CAD und FreeCAD – Ausführliche Lösungen
#
# ## 🎯 Lösungsübersicht
#
# Dieses Dokument enthält die vollständigen Lösungen aller Aufgaben aus Modul 1b mit ausführlichen Erklärungen. Die Lösungen zeigen die Arbeit mit der **aktuellen FreeCAD-Oberfläche (ab Version 0.21)** ohne separates Eigenschaften-Panel rechts.
#
# ---
#
# ## ✅ Lösung Aufgabe 1: FreeCAD starten und erste Orientierung
#
# ### Beobachtungen und Erklärungen:
#
# **1. Kombifenster (Combo View, links):**
# - Enthält zwei Tabs: „Modell“ (Projektstruktur) und „Aufgaben“ (spezielle Bearbeitungsoptionen)
# - Wird ein Objekt ausgewählt, erscheinen unten die Tabs „Daten“ und „Ansicht“ für Eigenschaften
# - Das Modell-Tab ersetzt den früheren Strukturbaum
#
# **2. 3D-Ansicht (Mitte):**
# - Arbeitsbereich zur Konstruktion und Navigation
# - Navigationswürfel (rechts oben) für Ansichtsperspektiven
#
# ### Reflexionsantworten:
#
# - **Menüs:** Datei, Bearbeiten, Ansicht, Extras, Fenster, Hilfe, Part/Part Design etc.
# - **Werkzeugkästen:** Symbole meist oben oder links
# - **Grundkörper-Werkzeuge:** `Part` → `Create primitives`
#
# ---
#
# ## ✅ Lösung Aufgabe 2: Ihren ersten Würfel erstellen
#
# ### Schritt-für-Schritt Lösung:
#
# **Würfel erstellen:**
#
# ```
# Menü: Part → Create primitives → Cube
# ```
#
# - Der Würfel erscheint im **Modell-Tab** des Kombifensters (links)
# - In der 3D-Ansicht wird er angezeigt
#
# **Eigenschaften im Kombifenster ändern:**
# - Klick auf den Würfel im Modell-Tab
# - Unten erscheinen die Tabs „Daten“ und „Ansicht“
# - Standardwerte: Height: 10 mm, Length: 10 mm, Width: 10 mm
#
# ### Reflexionsantworten:
#
# - **Farbe:** Standard grau
# - **Objektname:** „Cube“ oder „Würfel“
# - **Position:** (0, 0, 0) im Raum
#
# ---
#
# ## ✅ Lösung Aufgabe 3: Größe ändern – Quader erstellen
#
# ### Schritt-für-Schritt Lösung:
#
# 1. Würfel im Kombifenster auswählen
# 2. Tab „Daten“ unten öffnen
# 3. Eigenschaften ändern:
#    - Height: 50 mm
#    - Length: 100 mm
#    - Width: 40 mm
#    - Nach jeder Änderung Enter drücken!
#
# ### TODO-Aufgabe Lösung:
#
# 1. Neuen Würfel erstellen
# 2. Länge: 80 mm, Breite: 60 mm, Höhe: 120 mm im Kombifenster unter „Daten“ einstellen
#
# ### Reflexionsantworten:
#
# - **Farbe:** Bleibt grau
# - **Größe:** Neuer Quader ist größer als Standard-Würfel
#
# ---
#
# ## ✅ Lösung Aufgabe 4: Zylinder erstellen und positionieren
#
# ### Schritt-für-Schritt Lösung:
#
# 1. Menü: Part → Create primitives → Cylinder
# 2. Im Modell-Tab auswählen
# 3. Im Tab „Daten“ unten ändern:
#    - Radius: 15 mm, Height: 80 mm
# 4. Platzierung:
#    - „Placement“ → aufklappen → „Position“ → X: 150 mm
#
# ### TODO-Aufgabe Lösung:
#
# - Zweiten Zylinder erstellen, Eigenschaften wie Radius: 20 mm, Height: 50 mm, Position: X: 250 mm, Y: 50 mm, Z: 0 mm einstellen
#
# ### Reflexionsantworten:
#
# - **Objekte im Modell-Tab:** Cube und zwei Cylinder
# - **Unterscheidung:** Umbenennen im Kombifenster möglich
#
# ---
#
# ## ✅ Lösung Aufgabe 5: Kugel erstellen
#
# ### Schritt-für-Schritt Lösung:
#
# 1. Menü: Part → Create primitives → Sphere
# 2. Kugel im Modell-Tab auswählen
# 3. Im Kombifenster unten, Tab „Daten":
#    - Radius: 25 mm
#    - „Placement“ → Position: X: 100 mm, Y: 100 mm, Z: 100 mm
#
# ### TODO-Aufgabe Lösung:
#
# - Zweite Kugel: Radius: 30 mm; Position: X: 300 mm, Y: 150 mm, Z: 50 mm
#
# ### Reflexionsantworten:
#
# - **Anzahl:** Cube, zwei Cylinder, zwei Sphere
# - Ansicht ggf. drehen
#
# ---
#
# ## ✅ Lösung Aufgabe 6: 3D-Ansicht steuern
#
# ### Schritt-für-Schritt Lösung:
#
# **Drehen:** Mitteltaste gedrückt halten + Maus bewegen
# **Zoomen:** Mausrad drehen
# **Verschieben:** Mitteltaste + Shift
# **Zurücksetzen:** `V` + `H` (oder Navigationswürfel klicken)
# **Draufsicht oder andere Ansicht:** Über Navigationswürfel (rechts oben in der 3D-Ansicht)
#
# ### TODO-Aufgabe Lösung:
#
# 1. Modell drehen: Mitteltaste
# 2. Auf die Kugel zoomen: Mausrad
# 3. Herauszoomen: wieder Mausrad
# 4. Draufsicht: Navigationswürfel
#
# ### Reflexionsantworten:
#
# - Drehen erfordert etwas Übung
# - Navigationswürfel macht Ansichten einfach
#
# ---
#
# ## ✅ Lösung Aufgabe 7: Projekt speichern
#
# **Speichern:**
#
# Menü: File → Save oder `Ctrl + S`
#
# - Speicherort und Dateiname festlegen; z.B. „Meine_Konstruktion.FCStd“
# - Im Dialog speichern
#
# **Öffnen:** File → Open → Datei auswählen
#
# ### Reflexionsantworten:
#
# - `.FCStd`: FreeCAD Standardformat
# - Datei im gewählten Ordner
# - Einfach wieder öffnen im Menü
#
# ---
#
# ## 🎓 Zusammenfassung der Lösungen
#
# Sie haben erfolgreich mit der aktuellen FreeCAD-Oberfläche gearbeitet:
#
# ✅ Grundkörper im Kombifenster erstellt
# ✅ Eigenschaften über „Daten“ geändert
# ✅ Objekte positioniert und benannt
# ✅ 3D-Ansicht gesteuert (Maus, Tastatur, Navigationswürfel)
# ✅ Projekt als `.FCStd` gespeichert
#
# ---
#
# ## 📌 Hinweise für FreeCAD ab Version 0.20/0.21
#
# - Eigenschaften finden sich jetzt unten im Kombifenster, nicht mehr rechts.
# - Den Modell- und Aufgaben-Tab nutzen
# - Der Navigationswürfel ist ein nützliches Werkzeug für Ansichtswechsel
