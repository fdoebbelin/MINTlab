# %% [markdown]
# # M06c – Erweiterte Konstruktionstechniken (Ausführliche Lösungen)
#
# ## 📌 Lösungen zu allen Aufgaben aus M06b
#
# ---
#
# ## 🔍 Lösung 1: Spiegeln einer Aussparung – Vollständiger Lösungsweg
#
# ### Ziel
# Eine Platte mit asymmetrischer Aussparung wird durch Spiegeln symmetrisch gemacht.
#
# ### Schritt-für-Schritt Lösung
#
# **Schritt 1: Basis-Platte erstellen**
#
# ```
# Menü → Part Design → Create sketch
# → Ebene XY-Ebene auswählen
# ```
#
# Im Sketcher:
# ```
# - Rechteck zeichnen: 100 × 80 mm
#   (Menü → Sketcher → Create a rectangle, oder Werkzeugleiste)
# - Mit Constraints (Zwangsbedingungen) präzise definieren:
#   Horizontal: 100 mm
#   Vertikal: 80 mm
# - Sketcher beenden (Schließen-Button oder ESC)
# ```
#
# ```
# Menü → Part Design → Create a pad
# → Length: 10 mm
# → OK
# ```
#
# **Schritt 2: Aussparung auf einer Seite erzeugen**
#
# ```
# Auf die Oberseite der Platte klicken
# → Menü → Part Design → Create sketch
# ```
#
# Im Sketcher:
# ```
# - Rechteck zeichnen: 30 × 20 mm
# - Mit Constraints positionieren: z.B. 10 mm von oben, 10 mm von links
# - Sketcher beenden
# ```
#
# ```
# Menü → Part Design → Create a pocket
# → Type: Dimension
# → Length: 3 mm
# → OK
# ```
#
# **Schritt 3: Mirror-Funktion anwenden (Die Lösung!)**
#
# ```
# Im Modellbaum (linke Seite):
# - Rechtsklick auf "Pocket" (die Aussparung)
# → Im Kontextmenü: "Mirrored" auswählen
# ```
#
# Ein Dialog öffnet sich:
#
# ```
# Mirror plane auswählen:
# → YZ-Plane (für Spiegelung in X-Richtung: links-rechts)
#    ODER
# → XZ-Plane (für Spiegelung in Y-Richtung: vorne-hinten)
# ```
#
# **Richtige Wahl für diese Aufgabe:**
# - Wenn die ursprüngliche Aussparung in der **Ecke oben links** ist und wir sie spiegeln wollen, um symmetrisch zu sein:
#   - Verwende **YZ-Plane** → spiegelt links/rechts
#
# ```
# → OK klicken
# ```
#
# ### ✅ Überprüfung
# - Im 3D-Fenster: Drehe das Modell (Mittlere Maustaste + Bewegen)
# - Du solltest zwei identische Aussparungen sehen – eine oben links und eine oben rechts
# - Im Modellbaum: Der "Pocket" ist jetzt erweitert und zeigt ein "Mirrored"-Element darunter
#
# ### 💡 Erklärung: Warum funktioniert das?
#
# Die **Mirror-Funktion** nutzt eine Symmetrieebene:
# - **YZ-Ebene:** Alle Punkte werden an dieser Ebene gespiegelt → X-Koordinaten werden invertiert
# - **XZ-Ebene:** Alle Punkte werden an dieser Ebene gespiegelt → Y-Koordinaten werden invertiert
#
# Wenn ein Pocket bei (10, 10) ist und wir an der YZ-Ebene spiegeln, entsteht ein zweites Pocket bei (-10, 10), was in den Plattenkoordinaten (80+10=90, 10) entspricht – also auf der anderen Seite.
#
# ---
#
# ## 🔍 Lösung 2: Lineares Muster – Bohrungsreihe
#
# ### Ziel
# 5 gleichmäßig angeordnete Bohrungen in einer Reihe erzeugen.
#
# ### Schritt-für-Schritt Lösung
#
# **Schritt 1: Basis-Platte (wie in Lösung 1)**
#
# Pad 100 × 80 × 10 mm erstellt.
#
# **Schritt 2: Erste Bohrung erzeugen**
#
# ```
# Auf die Oberseite klicken
# → Menü → Part Design → Create sketch
# ```
#
# Im Sketcher:
# ```
# - Kreis zeichnen (Werkzeugleiste oder Menü → Sketcher → Create a circle)
# - Radius: 4 mm (Durchmesser Ø 8 mm)
# - Mittelpunkt platzieren: 20 mm von links, 40 mm von oben
#   (Mit Constraints: Horizontal-Constraint auf 20, Vertikal-Constraint auf 40)
# - Sketcher beenden
# ```
#
# ```
# Menü → Part Design → Create a pocket
# → Type: Through All (durchgehendes Loch)
#    oder explizite Tiefe: 10 mm
# → OK
# ```
#
# **Schritt 3: LinearPattern anwenden (Die Lösung!)**
#
# ```
# Im Modellbaum:
# - Rechtsklick auf "Pocket" (die Bohrung)
# → Im Kontextmenü: "LinearPattern" auswählen
# ```
#
# Ein Dialog öffnet sich:
#
# ```
# Parameter:
# ─────────
#
# Direction: X-Axis (oder Y-Axis, je nach gewünschter Richtung)
# → X-Axis wählen (horizontale Reihe)
#
# Occurrences: 5
# → Dies bedeutet: 1 Original + 4 Kopien = 5 Bohrungen insgesamt
#
# Spacing: 20 mm
# → Abstand zwischen den Mittelpunkten der Bohrungen
#
# [OK] drücken
# ```
#
# ### ✅ Überprüfung
# - Im 3D-Fenster: 5 Bohrungen sichtbar, in einer horizontalen Linie
# - Abstände: 20 mm zwischen den Mittelpunkten
# - Im Modellbaum: "LinearPattern" als neues Feature sichtbar
#
# ### 💡 Erklärung: Parameter verstehen
#
# ```
# Occurrences = Anzahl der Bohrungen insgesamt
# Spacing = Abstand VON einer Bohrung ZUR NÄCHSTEN
#
# Beispiel mit 5 Vorkommen, 20 mm Abstand:
# Bohrung 1: Position 0
# Bohrung 2: Position 0 + 20 = 20 mm
# Bohrung 3: Position 20 + 20 = 40 mm
# Bohrung 4: Position 40 + 20 = 60 mm
# Bohrung 5: Position 60 + 20 = 80 mm
# ```
#
# ### Häufiger Fehler
# **Problem:** Man hat 6 Bohrungen statt 5.
# **Grund:** Occurrences wurde auf 6 gesetzt (oder Spacing war falsch).
# **Lösung:** Undo und nochmals mit korrekten Parametern versuchen.
#
# ---
#
# ## 🔍 Lösung 3: Polares Muster – Lochkreis
#
# ### Ziel
# 6 Bohrungen gleichmäßig um einen Mittelpunkt verteilen (klassischer Lochkreis).
#
# ### Schritt-für-Schritt Lösung
#
# **Schritt 1 & 2: Neue Platte + erste Bohrung**
#
# ```
# Neue Platte: 100 × 100 × 10 mm (Pad)
#
# Bohrung erstellen:
# → Sketch auf Oberseite
# → Kreis: Ø 6 mm, positioniert 40 mm vom Mittelpunkt
#    (Mit Constraints: Abstand vom Ursprung = 40 mm)
# → Pocket (durchgehend oder Tiefe 10 mm)
# ```
#
# **Hinweis:** Der Bohrung sollte nicht zu nah am Mittelpunkt sein (min. 20-30 mm).
#
# **Schritt 3: PolarPattern anwenden (Die Lösung!)**
#
# ```
# Im Modellbaum:
# - Rechtsklick auf "Pocket" (die erste Bohrung)
# → Im Kontextmenü: "PolarPattern" auswählen
# ```
#
# Ein Dialog öffnet sich:
#
# ```
# Parameter:
# ─────────
#
# Axis: Z-Axis
# → Z-Axis wählen (um die Hochachse drehen)
#
# Occurrences: 6
# → 6 Bohrungen insgesamt verteilt
#
# Angle: 360
# → Voller Kreis
# → FreeCAD berechnet automatisch: 360° ÷ 6 = 60° pro Bohrung
#
# [OK] drücken
# ```
#
# ### ✅ Überprüfung
# - Im 3D-Fenster: 6 Bohrungen gleichmäßig um die Mitte verteilt
# - Drehe das Modell: Lochkreis sollte perfekt symmetrisch aussehen
# - Im Modellbaum: "PolarPattern" als neues Feature
#
# ### 💡 Erklärung: Achsenauswahl
#
# ```
# Achse für polare Muster:
#
# Z-Axis  → Bohrungen um die Hochachse verteilen
#          (typisch für von oben betrachtete Flansche)
#
# X-Axis  → Bohrungen um die Vorne-hinten-Achse verteilen
#          (seitliche Perspektive)
#
# Y-Axis  → Bohrungen um die Links-rechts-Achse verteilen
#          (auch seitlich, andere Perspektive)
# ```
#
# ### Variante: Andere Anzahl von Bohrungen
#
# ```
# Wenn du 8 Bohrungen möchtest:
# ─────────────────────────────
# Occurrences: 8
# Angle: 360
# → 360° ÷ 8 = 45° pro Bohrung
#
# Wenn du 4 Bohrungen möchtest:
# ─────────────────────────────
# Occurrences: 4
# Angle: 360
# → 360° ÷ 4 = 90° pro Bohrung
# ```
#
# ---
#
# ## 🔍 Lösung 4: Fillet – Kanten abrunden
#
# ### Ziel
# Alle äußeren Kanten einer Platte mit Radius abrunden (professionelles Aussehen).
#
# ### Schritt-für-Schritt Lösung
#
# **Schritt 1: Einfache Platte vorbereiten**
#
# ```
# Pad: 80 × 60 × 10 mm (wie in vorherigen Übungen)
# ```
#
# **Schritt 2: Fillet-Funktion anwenden (Die Lösung!)**
#
# ```
# Menü → Part Design → Create a fillet
# (Alternative: Werkzeugleiste, Fillet-Icon anklicken)
# ```
#
# Ein Dialog öffnet sich und wartet auf Kantenauswahl:
#
# ```
# Schritt 1: Kanten im 3D-Fenster auswählen
# ──────────────────────────────
#
# Eine rechteckige Platte hat 12 Kanten:
# - 4 Kanten oben (Oberfläche)
# - 4 Kanten unten (Unterfläche)
# - 4 vertikale Kanten an den Seiten
#
# Klicke EINZELN auf jede Kante, die abgerundet werden soll.
# Oder nutze Shift+Klick für mehrfache Auswahl.
#
# Beispiel: Alle 4 oberen Kanten auswählen
# ─ Klick auf Kante 1 (oben vorne)
# ─ Shift+Klick auf Kante 2 (oben rechts)
# ─ Shift+Klick auf Kante 3 (oben hinten)
# ─ Shift+Klick auf Kante 4 (oben links)
#
# Alle Kanten sollten jetzt grün/rot hervorgehoben sein.
#
# Schritt 2: Radius definieren
# ──────────────────────────────
#
# Im Dialog:
# Radius: 2 mm
#
# (Du kannst hier auch eine Variable oder Formel eingeben)
#
# Schritt 3: OK
# ────────────
#
# [OK] klicken
# ```
#
# ### ✅ Überprüfung
# - Im 3D-Fenster: Alle ausgewählten Kanten sind jetzt abgerundet
# - Im Modellbaum: "Fillet" als neues Feature
# - Drehe das Modell: Alle Radiusschwellungen sollten gleichmäßig sein
#
# ### 💡 Erklärung: Fillet-Mechanik
#
# Ein **Fillet** erzeugt einen glatten Übergangsbogen zwischen zwei Flächen:
#
# ```
# VOR Fillet:          NACH Fillet (r = 2mm):
# ───────────          ──────────────
#   ╱                      ╱───╲
#  │  scharfe Kante       │     \ (rund)
#  │                      │
# ```
#
# ### Häufiger Fehler & Lösung
#
# **Problem:** Fillet kann nicht angewendet werden (Fehlermeldung).
# **Gründe & Lösungen:**
# 1. Falsche Kanten ausgewählt → Nur echte scharfe Kanten können Fillet bekommen
# 2. Radius zu groß → Verkleinern (z.B. 0,5 mm statt 5 mm)
# 3. Feature-Reihenfolge falsch → Fillet sollte am Ende sein
#
# ---
#
# ## 🔍 Lösung 5: Chamfer – Kanten abschrägen
#
# ### Ziel
# Bohrungskanten mit einer Fase versehen (für leichtere Montage und Sicherheit).
#
# ### Schritt-für-Schritt Lösung
#
# **Schritt 1: Platte mit Bohrungen vorbereiten**
#
# ```
# Von früheren Aufgaben: Platte mit mehreren Bohrungen
# ```
#
# **Schritt 2: Chamfer-Funktion anwenden (Die Lösung!)**
#
# ```
# Menü → Part Design → Create a chamfer
# (Alternative: Werkzeugleiste, Chamfer-Icon)
# ```
#
# Ein Dialog öffnet sich:
#
# ```
# Schritt 1: Kanten auswählen
# ────────────────────────────
#
# Klicke auf die INNENKANTEN der Bohrungen.
# (Das sind die Kanten an der Bohrungswand, oben und unten)
#
# Shift+Klick für Mehrfachauswahl alle Bohrungskanten markieren.
#
# Schritt 2: Chamfer-Größe definieren
# ────────────────────────────────────
#
# Im Dialog:
# Chamfer Size: 0,5 mm
#
# Type: Size (Standardmethode)
#       (Alternativ: Angle, wenn du einen Winkel definieren möchtest)
#
# Schritt 3: OK
# ────────────
#
# [OK] klicken
# ```
#
# ### ✅ Überprüfung
# - Im 3D-Fenster: Bohrungskanten sind jetzt abgeschrägt (nicht rund, sondern flach angewinkelt)
# - Im Modellbaum: "Chamfer" als neues Feature
# - Vergleich: Fillet vs. Chamfer sollte deutlich unterschiedlich aussehen
#
# ### 💡 Erklärung: Fillet vs. Chamfer
#
# ```
# FILLET (Abrundung):          CHAMFER (Fase):
# ─ Glatter Radius             ─ Flache Anschrägung
# ─ Schönes, wertiges Design   ─ Praktische Funktion
# ─ Ergonomisch                ─ Leichtere Montage
# Beispiel:                    Beispiel:
#    ╱────╲ (gerundet)            ╱───╲ (Ebene)
#   │      │                      │     │
# ```
#
# **Praktische Wahl:**
# - **Fillet:** Außenkanten von Produkten (Design)
# - **Chamfer:** Bohrungen, Eingriffsseiten, funktionale Kanten
#
# ---
#
# ## 🔍 Lösung 6: Kombination – Halterplatte mit Lochkreis
#
# ### Ziel
# Konstruiere eine technische Halterplatte mit allen erlernten Techniken.
#
# ### Vollständiger Konstruktionsprozess
#
# **Phase 1: Basis-Platte**
#
# ```
# Menü → Part Design → Create a pad
# → Sketch auf XY-Ebene
#   Rechteck: 120 × 80 mm
# → Pad-Höhe: 12 mm
# ```
#
# **Phase 2: Mittige Bohrung**
#
# ```
# → Sketch auf Oberseite
#   Kreis: Ø 20 mm, zentriert
# → Pocket: Through All (durchgehend)
# ```
#
# **Phase 3: Aussparung (eine Seite)**
#
# ```
# → Sketch auf Oberseite
#   Rechteck: 50 × 30 mm, positioniert z.B. oben links
# → Pocket: Tiefe 4 mm
# ```
#
# **Phase 4: Aussparung spiegeln (WICHTIG: BEVOR Muster!)**
#
# ```
# Modellbaum: Rechtsklick auf Pocket (Aussparung)
# → Mirrored
# → YZ-Ebene auswählen
# → OK
# ```
#
# **Phase 5: Lochkreis erstellen**
#
# ```
# → Sketch auf Oberseite
#   Kreis: Ø 6 mm, platziert 35 mm vom Mittelpunkt entfernt
# → Pocket: Tiefe 12 mm (durchgehend)
# ```
#
# ```
# Modellbaum: Rechtsklick auf dieses Pocket
# → PolarPattern
# → Axis: Z-Axis
# → Occurrences: 4
# → Angle: 360
# → OK
# ```
#
# **Phase 6: Außenkanten abrunden**
#
# ```
# Menü → Part Design → Create a fillet
# → Alle 4 oberen Außenkanten anklicken (Shift+Klick)
# → Radius: 1,5 mm
# → OK
# ```
#
# **Phase 7: Bohrungskanten fasen**
#
# ```
# Menü → Part Design → Create a chamfer
# → Die Innenkanten aller Bohrungen anklicken
# → Chamfer Size: 0,3 mm
# → OK
# ```
#
# ### ✅ Überprüfung des Abschlussmodells
#
# - [ ] Basis-Platte sichtbar?
# - [ ] Mittige Bohrung durchgehend?
# - [ ] Aussparung auf beiden Seiten symmetrisch?
# - [ ] 4 Bohrungen in Kreisform?
# - [ ] Außenkanten abgerundet (2 mm)?
# - [ ] Bohrungen gefaset (0,3 mm)?
# - [ ] Modellbaum zeigt alle Features in Reihenfolge?
#
# ### 💡 Wichtige Reihenfolge
#
# ```
# 1. Basis (Pad)
# 2. Zentrale Struktur (Pockets)
# 3. Spiegeln (Mirror) – vor Mustern!
# 4. Muster (Pattern/PolarPattern)
# 5. Verfeinerungen (Fillet)
# 6. Details (Chamfer)
# ```
#
# **Warum diese Reihenfolge?**
# - Spiegeln wirkt auf ein einzelnes Feature
# - Pattern basiert auf bereits gespiegelten Elementen
# - Fillet & Chamfer kommen ganz zum Schluss, um Komplexität zu reduzieren
#
# ---
#
# ## 🧠 Alternativlösungen & Tipps
#
# ### Tipp 1: Verschiedene Radiusgrößen
#
# ```
# Wenn du mehrere Fillets mit unterschiedlichen Radien brauchst:
# ─ Wende Fillet mehrfach an
# ─ Erste Anwendung: 4 Außenkanten mit 2 mm
# ─ Zweite Anwendung: 2 spezielle Kanten mit 0,5 mm
# ```
#
# ### Tipp 2: Muster mit Offset
#
# ```
# LinearPattern mit negativem Spacing:
# ─ Occurrences: 5
# ─ Spacing: -20 mm
# → Erzeugt Muster in die entgegengesetzte Richtung
# ```
#
# ### Tipp 3: Asymmetrische Muster
#
# ```
# Wenn eine Bohrung nicht zentriert ist:
# ─ LinearPattern trotzdem anwenden
# → Das Muster wird relativ zur ursprünglichen Position erzeugt
# ```
#
# ---
#
# ## 📊 Zusammenfassung aller Lösungen
#
# | Aufgabe | Funktion | Menüpfad | Wichtige Parameter |
# |---------|----------|----------|-------------------|
# | 1 | Mirror | Rechtsklick → Mirrored | Mirror plane |
# | 2 | LinearPattern | Rechtsklick → LinearPattern | Direction, Occurrences, Spacing |
# | 3 | PolarPattern | Rechtsklick → PolarPattern | Axis, Occurrences, Angle |
# | 4 | Fillet | Part Design → Create a fillet | Kantenauswahl, Radius |
# | 5 | Chamfer | Part Design → Create a chamfer | Kantenauswahl, Chamfer Size |
# | 6 | Alle kombiniert | Siehe Phasen 1–7 | Reihenfolge beachten! |
#
# ---
#
# ## 🔗 Weiterführende Ressourcen & Vertiefung
#
# **FreeCAD Dokumentation:**
# - [Part Design Mirrored](https://wiki.freecadweb.org/Part_Design_Mirrored)
# - [Part Design LinearPattern](https://wiki.freecadweb.org/Part_Design_LinearPattern)
# - [Part Design PolarPattern](https://wiki.freecadweb.org/Part_Design_PolarPattern)
# - [Part Design Fillet](https://wiki.freecadweb.org/Part_Design_Fillet)
# - [Part Design Chamfer](https://wiki.freecadweb.org/Part_Design_Chamfer)
#
# **Video-Tutorials:**
# - YouTube: "FreeCAD Mirror Pattern Tutorial"
# - YouTube: "FreeCAD Part Design Advanced Features"
#
# **Praktische Anwendungsbeispiele:**
# - Maschinenbaubauteile (Flanschen, Naben)
# - Kunststoffspritzteile mit mehrfachen Merkmalen
# - Möbelkomponenten mit symmetrischen Strukturen
#
# ---
#
# ## ✨ Fazit: Warum diese Techniken wichtig sind
#
# 1. **Spiegeln:** Spart Zeit bei symmetrischen Teilen (häufigster Fall in der Technik)
# 2. **Pattern:** Automatisiert wiederholte Strukturen – weniger manuelle Arbeit, weniger Fehler
# 3. **Fillet:** Verleiht Professionionalität und Sicherheit
# 4. **Chamfer:** Praktische Funktion für Montage und Gradbildung
#
# **Branchen, die diese Techniken nutzen:**
# - Maschinenbau
# - Elektrotechnik (Schaltschränke, Halterungen)
# - Automobilindustrie
# - Medizintechnik
# - Möbeldesign
#
# Mit diesen Techniken bist du nun fähig, professionelle, marktreife CAD-Modelle zu erstellen!
