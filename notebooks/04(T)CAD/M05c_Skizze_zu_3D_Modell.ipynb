# %% [markdown]
# # M05c: Von der Skizze zum 3D-Modell – Ausführliche Lösungen
#
# ## 📌 Einleitung zu den Lösungen
#
# Diese Datei enthält die **vollständigen Lösungen** für alle Aufgaben aus **M05b**.
#
# **Wie du diese Datei nutzt:**
# - Versuche zuerst, die Aufgaben in M05b selbstständig zu lösen
# - Wenn du nicht weiterkommst, schau hier nach (aber erst nach echtem Bemühen!)
# - Vergleiche deine Lösungen mit den hier gezeigten
# - Achte auf die **Erklärungen** – sie zeigen das „Warum", nicht nur das „Wie"
#
# ---
#
# ## ✅ Lösung Aufgabe 1: Holzbox mit Pad
#
# ### Schritt-für-Schritt Lösung
#
# **Schritt 1: Dokument vorbereiten**
#
# ```freecad-code
# # Menü: Datei → Neu
# # Oder: Strg + N
# ```
#
# **Schritt 2: Part Design Arbeitsbereich**
#
# ```freecad-code
# # Dropdown-Menü oben rechts (neben dem Bearbeitungsbereich)
# # Oder: Menü Ansicht → Arbeitsbereiche → Part Design
# ```
#
# **Schritt 3: Neue Skizze**
#
# ```freecad-code
# # Menü: Skizze → Neue Skizze erstellen
# # Dialog: Wähle XY_Plane → OK
# ```
#
# **Schritt 4: Rechteck zeichnen**
#
# ```freecad-code
# # Menü: Skizze → Geometrie → Rechteck
# # Oder: Rechteck-Symbol in Werkzeugleiste
#
# # Erste Ecke: Klick bei (0, 0) oder irgendwo auf der grünen Ebene
# # Zweite Ecke: Klick bei (80, 60) – zur Genauigkeit:
# #  - Halte bei der ersten Ecke die Taste gedrückt
# #  - Bewege die Maus nach rechts-oben
# #  - Beobachte, ob die Länge auf 80 und die Breite auf 60 angezeigt wird
# #  - Lasse los, wenn die Werte passen (oder akzeptiere ungefähre Werte)
# ```
#
# **Wichtig:** Die genauen Maße sind nicht kritisch – das Rechteck kann auch 78 × 61 mm sein. FreeCAD zeigt die Abmessungen während des Zeichnens an.
#
# **Schritt 5: Skizze verlassen**
#
# ```freecad-code
# # Menü: Skizze → Skizze verlassen
# # Oder: Grüner Haken oben links
# # Oder: ESC-Taste
# ```
#
# Jetzt solltest du **weiße Linien** (das Rechteck) auf der schwarzen 3D-Ansicht sehen.
#
# **Schritt 6: Pad erstellen**
#
# ```freecad-code
# # Wichtig: Stelle sicher, dass die Skizze im Modellbaum (links) ausgewählt ist
# # Menü: Part Design → Pad
# # Oder: Pad-Symbol in der Werkzeugleiste (kissen-ähnliches Symbol)
# ```
#
# Ein Dialog „Pad-Parameter" öffnet sich.
#
# ```freecad-code
# # Länge: 40 (mm)
# # Typ: Normales Pad (Standard)
# # Klick: OK
# ```
#
# **✨ Ergebnis:** Du siehst jetzt einen grauen **Quader** in der 3D-Ansicht!
#
# ### Verständniserklärung
#
# **Warum funktioniert das?**
#
# 1. Das **Rechteck** ist eine 2D-Form
# 2. Der **Pad-Befehl** nimmt diese 2D-Form und „extrudiert" sie
# 3. Extrusion bedeutet: Die Form wird entlang ihrer Normalen (senkrecht zur Ebene) verschoben
# 4. Das Ergebnis ist ein **3D-Volumen**
#
# **Unterschied zu Primitives:**
# - **Primitive (Quader):** Du gibst direkt Länge, Breite, Höhe ein – fertig
# - **Pad:** Du zeichnest eine beliebige 2D-Form und extrudierst sie – das ist viel flexibler!
#
# Mit Pad könntest du z.B. ein **L-förmiges Profil** zeichnen und extrudieren – das wäre mit Primitives nicht möglich.
#
# ### Mögliche Fehler & Lösungen
#
# | Fehler | Ursache | Lösung |
# |--------|--------|--------|
# | Pad-Button ist grau/deaktiviert | Skizze nicht ausgewählt | Klick auf die Skizze im Modellbaum |
# | Der Quader entsteht nicht | Skizze ist leer oder ungültig | Überprüfe, dass das Rechteck korrekt gezeichnet wurde |
# | Pad wird in die falsche Richtung extrudiert | Normal (Normale der Ebene) ist nach unten gerichtet | Im Pad-Dialog: „Umgekehrt" anhaken oder „Symmetrisch" nutzen |
#
# ---
#
# ## ✅ Lösung Aufgabe 2: Wasserglas mit Revolution
#
# ### Schritt-für-Schritt Lösung
#
# **Schritt 1-3: Vorbereitung**
#
# ```freecad-code
# # Neues Dokument: Datei → Neu
# # Part Design Arbeitsbereich
# # Neue Skizze: Skizze → Neue Skizze erstellen → XY_Plane
# ```
#
# **Schritt 4: Profil zeichnen**
#
# Jetzt zeichnen wir ein Rechteck, das die **Seitenansicht eines halben Glases** darstellt:
#
# ```freecad-code
# # Werkzeug: Linie (nicht Rechteck!)
# # Menü: Skizze → Geometrie → Linie
# # Oder: Liniensymbol in Werkzeugleiste
#
# # Zeichne folgende Punkte in Reihenfolge:
# Punkt 1: (0, 0)      # Start unten links
# Punkt 2: (30, 0)     # Nach rechts → das ist der äußere Radius
# Punkt 3: (30, 150)   # Nach oben → das ist die Höhe
# Punkt 4: (0, 150)    # Nach links
# Punkt 5: (0, 0)      # Zurück zum Start → Schleife schließen
# ```
#
# Das Ergebnis ist ein **Rechteck von 30 × 150 mm** – die Seitenansicht des Glases.
#
# **Schritt 5: Konstruktionslinie (Rotationsachse) zeichnen**
#
# ```freecad-code
# # Werkzeug: Konstruktionslinie
# # Menü: Skizze → Geometrie → Konstruktionslinie
# # Oder: Symbol in Werkzeugleiste (gestrichelte Linie)
#
# # Zeichne eine vertikale Linie von:
# Punkt 1: (0, 0)
# Punkt 2: (0, 150)
#
# # Diese Linie ist die ROTATIONSACHSE!
# # Sie muss gestrichelt (grün gestrichelt) sein
# ```
#
# **Wichtig:** Die Konstruktionslinie muss auf der **linken Seite** des Rechtecks sein (bei x=0), denn dort ist der Mittelpunkt des Glases!
#
# **Schritt 6: Skizze verlassen**
#
# ```freecad-code
# # Menü: Skizze → Skizze verlassen
# # Oder: ESC
# ```
#
# **Schritt 7: Revolution erstellen**
#
# ```freecad-code
# # Stelle sicher, dass die Skizze ausgewählt ist (im Modellbaum)
# # Menü: Part Design → Revolution
# # Oder: Revolution-Symbol (rotierender Pfeil)
# ```
#
# Ein Dialog „Revolution-Parameter" erscheint.
#
# ```freecad-code
# # Im Dialog:
# # - Achse: Klick auf die Konstruktionslinie (in der Skizze oder im Modellbaum)
# #          Wenn du nicht weißt, auf welche Linie, versuche es einfach:
# #          Die richtige Achse erzeugt einen Zylinder
# # - Winkel: 360 (für volle Umdrehung)
# # - Typ: Normales Pad
# # → OK
# ```
#
# **✨ Ergebnis:** Du siehst einen **hohlen Zylinder** – ein echtes Glas!
#
# ### Verständniserklärung
#
# **Warum funktioniert das?**
#
# 1. Das **Rechteck** stellt die Seitenansicht dar (wie ein Glas von der Seite)
# 2. Die **Konstruktionslinie** ist die Drehachse (der Mittelpunkt des Glases)
# 3. Die **Revolution** dreht das Rechteck um 360° um die Achse
# 4. Das Ergebnis ist ein **3D-Rotationskörper** – ein Zylinder
#
# **Alternative Effekte:**
#
# Wenn du verschiedene **Profile** zeichnest und drehst:
# - **Rechteck** → Zylinder
# - **Dreieck** → Kegel
# - **Trapez** → Kegelstumpf
# - **Zusammengesetztes Profil** → komplexe Drehteile wie Flaschen, Kreisel, etc.
#
# ### Mögliche Fehler & Lösungen
#
# | Fehler | Ursache | Lösung |
# |--------|--------|--------|
# | Revolution erzeugt ein seltsames Objekt | Falsche Achse gewählt | Versuche die andere Linie als Achse |
# | Das Objekt ist halbtransparent/grün | Die Konstruktionslinie ist nicht korrekt | Lösche die Skizze und versuche es erneut |
# | Keine Revolution möglich | Skizze ungültig | Überprüfe, dass das Rechteck geschlossen ist |
#
# ---
#
# ## ✅ Lösung Aufgabe 3: Platte mit Loch (Pocket)
#
# ### Schritt-für-Schritt Lösung
#
# **Schritt 1-3: Basis-Platte erstellen**
#
# ```freecad-code
# # Neues Dokument
# # Part Design Arbeitsbereich
# # Neue Skizze auf XY_Plane
# ```
#
# **Schritt 4: Rechteck für die Platte**
#
# ```freecad-code
# # Werkzeug: Rechteck
# # Zeichne Rechteck von (0, 0) bis (100, 80)
# # Das sind die Abmessungen der Platte (Länge × Breite)
# ```
#
# **Schritt 5: Pad für die Basis**
#
# ```freecad-code
# # Skizze verlassen
# # Part Design → Pad
# # Länge: 15 (mm)
# # → OK
# ```
#
# Jetzt hast du eine **flache Platte** 100 × 80 × 15 mm.
#
# **Schritt 6: Neue Skizze auf der Oberseite**
#
# Das ist die kritische Stelle! Wir müssen eine Skizze **auf der Oberseite der Platte** erstellen.
#
# ```freecad-code
# # Im Modellbaum: Klick auf das Pad (um es auszuwählen)
# # Menü: Skizze → Neue Skizze erstellen
# ```
#
# Ein Dialog erscheint mit Ebenen-Optionen. Hier musst du die **Oberseite des Pads** wählen:
#
# ```freecad-code
# # Der Dialog zeigt eine Liste mit Ebenen
# # Wähle: „Face6" oder die Fläche, die oben ist
# # (Tipp: Wenn du unsicher bist, klick auf die Oberseite der Platte in der 3D-Ansicht)
# # → OK
# ```
#
# Du befindest dich jetzt auf der **grünen Oberseite** der Platte!
#
# **Schritt 7: Kreis für das Loch zeichnen**
#
# ```freecad-code
# # Werkzeug: Kreis
# # Menü: Skizze → Geometrie → Kreis
# # Oder: Kreis-Symbol
#
# # Zeichne einen Kreis:
# # Mittelpunkt: Klick in der Mitte der Platte (ungefähr bei (50, 40))
# # Radius: Bewege die Maus so, dass der Radius 15 mm ist
# # (Die Größe wird während des Zeichnens angezeigt)
# ```
#
# **Schritt 8: Skizze verlassen**
#
# ```freecad-code
# # Menü: Skizze → Skizze verlassen
# # Der Kreis wird weiß sichtbar auf der Oberseite
# ```
#
# **Schritt 9: Pocket erstellen**
#
# ```freecaf-code
# # Stelle sicher, dass die Kreis-Skizze ausgewählt ist
# # Menü: Part Design → Pocket
# # Oder: Pocket-Symbol in Werkzeugleiste
# ```
#
# Dialog „Pocket-Parameter":
#
# ```freecad-code
# # Länge: 15 (mm) – das ist die volle Höhe der Platte
# # Typ: Durch alles (Through All) oder einfach 15 mm eingeben
# # → OK
# ```
#
# **✨ Ergebnis:** Die Platte hat jetzt ein **kreisrundes Durchgangsloch** in der Mitte!
#
# ### Verständniserklärung
#
# **Unterschied zwischen Pocket und Boolesche Differenz:**
#
# | Pocket | Boolesche Differenz |
# |--------|-------------------|
# | Wird in der **Part Design** angewendet | Wird in der **Part**-Workbench angewendet |
# | Funktioniert **nur auf Skizzen** | Funktioniert auf bereits vorhandenen Körpern |
# | Ist eine **Feature** (bleibt editierbar) | Ist eine **Operation** (kann nicht leicht geändert werden) |
# | Besser für parametrisches Design | Besser für schnelle Operationen |
#
# **Warum ist Pocket besser?**
# - Du kannst die Kreis-Skizze später noch bearbeiten (z.B. den Radius ändern)
# - Das Loch passt sich automatisch an
# - Mit Boolesche Differenz müsste man den Zylinder neu erzeugen und die Operation wiederholen
#
# ### Mögliche Fehler & Lösungen
#
# | Fehler | Ursache | Lösung |
# |--------|--------|--------|
# | Pocket-Button grau | Skizze auf falscher Ebene oder nicht ausgewählt | Überprüfe, dass Skizze auf Pad-Oberseite liegt |
# | Loch ist schief/versetzt | Kreis-Mittelpunkt ist nicht korrekt | Zeichne die Skizze erneut, Mittelpunkt in Mitte prüfen |
# | Pocket entfernt zu viel Material | Länge zu groß | Länge auf 15 mm oder weniger setzen |
#
# ---
#
# ## ✅ Lösung Aufgabe 4: Befestigungsplatte mit vier Bohrungen
#
# ### Schritt-für-Schritt Lösung
#
# **Schritt 1-2: Basis-Platte (wie Aufgabe 3)**
#
# ```freecad-code
# # Neues Dokument
# # Part Design Arbeitsbereich
# # Skizze auf XY_Plane
# # Rechteck: (0, 0) bis (120, 80)
# # Skizze verlassen
# # Pad: 10 mm
# ```
#
# Jetzt hast du eine Platte 120 × 80 × 10 mm.
#
# **Schritt 3: Skizze für alle vier Bohrungen**
#
# ```freecad-code
# # Pad auswählen
# # Neue Skizze → wähle Oberseite → OK
# ```
#
# **Schritt 4: Vier Kreise zeichnen**
#
# ```freecad-code
# # Werkzeug: Kreis
# # Zeichne folgende vier Kreise (Radius 6 mm jeweils):
#
# Kreis 1: Mittelpunkt (15, 15)    # Oben links
# Kreis 2: Mittelpunkt (105, 15)   # Oben rechts
# Kreis 3: Mittelpunkt (15, 65)    # Unten links
# Kreis 4: Mittelpunkt (105, 65)   # Unten rechts
#
# # Jeder Kreis hat Radius 6 mm (Durchmesser 12 mm)
# ```
#
# **Wichtig:** Du kannst alle vier Kreise in **einer Skizze** zeichnen! Das ist effizienter als vier separate Pockets.
#
# **Schritt 5: Skizze verlassen**
#
# ```freecad-code
# # Menü: Skizze → Skizze verlassen
# # Du siehst jetzt vier weiße Kreise auf der Platte
# ```
#
# **Schritt 6: Ein Pocket für alle vier Bohrungen**
#
# ```freecad-code
# # Skizze ausgewählt (sollte sein)
# # Menü: Part Design → Pocket
# # Länge: 10 mm (volle Höhe)
# # → OK
# ```
#
# **✨ Ergebnis:** Die Platte hat **vier Bohrungen** an den vier Ecken!
#
# ### Verständniserklärung
#
# **Warum eine Skizze für alle vier Kreise?**
#
# ```
# EFFIZIENT (diese Lösung):
# ┌─────────────────────┐
# │  Skizze mit 4 Krn  │
# │   (ein Objekt)     │
# └──────────┬──────────┘
#            │
#           Pocket
#            │
#     4 Bohrungen
# ```
#
# ```
# INEFFIZIENT (alternative):
# ┌─────────────────────┐
# │  Skizze 1: Kreis 1 │ ──┐
# ├─────────────────────┤  │
# │  Skizze 2: Kreis 2 │  ├──► 4 Pockets
# ├─────────────────────┤  │    (mehr Arbeit)
# │  Skizze 3: Kreis 3 │  │
# ├─────────────────────┤  │
# │  Skizze 4: Kreis 4 │ ──┘
# └─────────────────────┘
# ```
#
# **Erkenntnis:** Wenn mehrere Features **gleich** sind (alle vier Bohrungen), sollten sie in einer Skizze zusammengefasst werden.
#
# ### Mögliche Fehler & Lösungen
#
# | Fehler | Ursache | Lösung |
# |--------|--------|--------|
# | Nicht alle vier Löcher entstehen | Nur ein Kreis ist in Skizze | Überprüfe Skizze und zeichne alle vier Kreise |
# | Koordinaten sind falsch | Matherechnung falsch | 15 mm von Kante + 90 mm = 105 mm ✓ |
#
# ---
#
# ## ✅ Lösung Aufgabe 5: Kegel mit Nut (erweiterte Kombination)
#
# ### Schritt-für-Schritt Lösung
#
# **Schritt 1: Neues Dokument und Vorbereitung**
#
# ```freecad-code
# # Datei → Neu
# # Part Design Arbeitsbereich
# # Neue Skizze auf XY_Plane
# ```
#
# **Schritt 2: Kegel-Profil zeichnen**
#
# Das Profil ist ein wenig komplexer. Zeichne folgende **Linie**:
#
# ```freecad-code
# # Werkzeug: Linie (nicht Rechteck!)
# # Menü: Skizze → Geometrie → Linie
#
# # Zeichne diese Punkte in Reihenfolge:
# Punkt 1: (0, 0)     # Unten Mitte (Start)
# Punkt 2: (30, 0)    # Nach rechts → Basis des Kegels
# Punkt 3: (20, 40)   # Schräg oben rechts → rechte Seite des Kegels
# Punkt 4: (10, 40)   # Nach links oben → linke Spitze
# Punkt 5: (0, 0)     # Zurück zum Start → Schleife schließen
#
# # Das Ergebnis: Ein trapezförmiges Profil
# # Wenn du es in der Rotation siehst, wird es zu einem Kegel!
# ```
#
# **Schritt 3: Rotationsachse zeichnen**
#
# ```freecaf-code
# # Werkzeug: Konstruktionslinie
# # Zeichne eine vertikale Linie:
# Punkt 1: (0, 0)
# Punkt 2: (0, 40)
#
# # Diese Linie ist die ROTATIONSACHSE!
# ```
#
# **Schritt 4: Skizze verlassen und Revolution erstellen**
#
# ```freecad-code
# # Menü: Skizze → Skizze verlassen
# # Menü: Part Design → Revolution
# # Im Dialog:
# #   - Achse: Konstruktionslinie auswählen
# #   - Winkel: 360
# # → OK
# ```
#
# **✨ Du siehst einen Kegel!**
#
# **Schritt 5: Skizze für die Nut auf der Oberseite**
#
# ```freecaf-code
# # Klick auf die Revolution (im Modellbaum)
# # Neue Skizze erstellen
# # Wähle die Oberseite des Kegels (die kleine Fläche oben)
# # → OK
# ```
#
# **Schritt 6: Rechteck für die Nut zeichnen**
#
# ```freecad-code
# # Werkzeug: Rechteck
# # Die Nut soll 10 × 5 mm sein und zentriert oben
#
# # Zeichne ein Rechteck:
# Punkt 1: (5, 18)    # Ungefähr unten links der Nut
# Punkt 2: (15, 20)   # Ungefähr oben rechts
#
# # Das Rechteck ist ungefähr zentriert oben auf dem Kegel
# # (Die exakten Koordinaten sind schwer zu bestimmen, da die obere Fläche klein ist)
# ```
#
# **Tipp:** Wenn die genaue Platzierung schwierig ist, zeichne einfach **irgendwo ein Rechteck** auf der Oberseite – der pädagogische Zweck ist erreicht!
#
# **Schritt 7: Skizze verlassen und Pocket**
#
# ```freecad-code
# # Menü: Skizze → Skizze verlassen
# # Menü: Part Design → Pocket
# # Länge: 5 mm
# # → OK
# ```
#
# **✨ Fertig!** Du siehst einen **Kegel mit einer Vertiefung oben**!
#
# ### Verständniserklärung
#
# **Feature-Reihenfolge im Modellbaum:**
#
# ```
# - Körper
#   ├── Sketch (Kegel-Profil + Achse)
#   ├── Revolution (der Kegel entsteht)
#   ├── Sketch001 (Rechteck für Nut)
#   └── Pocket (Vertiefung entsteht)
# ```
#
# **Was passiert bei Änderungen?**
#
# Wenn du später die Revolution bearbeitest:
# - Z.B. Winkel auf 180° (nur halber Kegel)
# - Das Pocket bleibt erhalten und wird auch zur Hälfte entfernt
# - Der ganze Modellbaum passt sich an!
#
# Das ist die **Kraft des parametrischen Designs**.
#
# ### Mögliche Fehler & Lösungen
#
# | Fehler | Ursache | Lösung |
# |--------|--------|--------|
# | Kegel sieht falsch aus | Profil nicht korrekt | Überprüfe, dass alle 5 Punkte der Reihe nach gezeichnet sind |
# | Nut ist nicht oben | Skizze auf falscher Fläche | Stelle sicher, dass du auf der **oberen Spitzenfläche** zeichnest |
# | Skizze 001 erscheint nicht | Revolution war nicht ausgewählt | Klick auf Revolution vor neuer Skizze |
#
# ---
#
# ## 🤔 Antworten zu den Verständnisfragen
#
# ### Frage 1: Wann benutze ich Pad und wann Revolution?
#
# **Pad verwenden für:**
# - Rechteckige Grundformen (Quader, Balken, Platten)
# - Prismatische Formen (Formen, die nach unten constant bleiben)
# - Objekte, die keine Rotationssymmetrie haben
# - Beispiele: Kiste, Buch, Schrank, Platte mit Loch
#
# **Revolution verwenden für:**
# - Runde, zylindrische Formen
# - Rotationssymmetrische Objekte
# - Drehteile in der Mechanik
# - Beispiele: Glas, Tasse, Flaschenform, Rad, Kegelstumpf
#
# ### Frage 2: Pocket vs. Boolesche Differenz
#
# **Pocket:**
# - Subtrahiert eine Skizze von einem Körper
# - Ist ein **Feature** (bleibt in der Modellbaum-Struktur)
# - Sehr parametrisch und editierbar
# - Nutze dich: Wenn Material aus einem Pad entfernt wird
#
# **Boolesche Differenz:**
# - Subtrahiert einen ganzen Körper von einem anderen
# - Ist eine **Operation** (zwei Körper werden kombiniert)
# - Weniger editierbar
# - Nutze dich: Wenn zwei separate Körper kombiniert werden
#
# ### Frage 3: Feature-Reihenfolge – Muss Pad immer zuerst kommen?
#
# **Antwort: Normalerweise ja, aber nicht immer!**
#
# Typisch:
# 1. Pad (Grundform)
# 2. Pocket (Aussparung)
# 3. Noch mehr Features...
#
# Alternative (fortgeschrittene Technik):
# - Du könntest auch mit Revolution starten
# - Oder ein Pocket auf leere Luft zeichnen (funktioniert aber nicht)
#
# **Faustregel:** Der erste Feature muss einen **3D-Körper erzeugen** (Pad oder Revolution). Dann kannst du weitere Features darauf aufbauen.
#
# ### Frage 4: Platte breiter machen – wie geht man vor?
#
# **Antwort:** Bearbeite die erste Skizze!
#
# ```freecad-code
# # Im Modellbaum: Doppelklick auf die erste Skizze (Rechteck)
# # Die Skizze öffnet sich zum Bearbeiten
# # Ändere die Breite von 80 mm auf 50 mm
# # Skizze verlassen
# # Der ganze Modellbaum wird automatisch neu berechnet!
# ```
#
# Das ist das **parametrische Design** – alle Features passen sich an!
#
# ---
#
# ## 🎯 Erweiterte Tipps & Tricks
#
# ### Tipp 1: „Durch alles" beim Pocket
#
# Wenn du die volle Höhe nicht genau kennst, nutze im Pocket-Dialog:
#
# ```freecad-code
# # Typ: "Durch alles" (Through All)
# # Das schneidet automatisch durch den ganzen Körper
# ```
#
# ### Tipp 2: Symmetrisches Pocket
#
# Im Pocket-Dialog:
#
# ```freecad-code
# # Option: "Symmetrisch"
# # Das schneidet zur Hälfte nach oben und unten
# # Nützlich, wenn die Nut mittig sein soll
# ```
#
# ### Tipp 3: Model Tree Einblenden
#
# Wenn du den Modellbaum nicht siehst:
#
# ```freecad-code
# # Menü: Ansicht → Panels → Modellbaum
# # Oder: Ansicht → Panels → Eigenschaften
# ```
#
# ### Tipp 4: Features verstecken
#
# Um zu sehen, wie das Modell **ohne ein bestimmtes Feature** aussieht:
#
# ```freecad-code
# # Rechtsklick auf Feature im Modellbaum
# # → Toggle visibility (Sichtbarkeit umschalten)
# # Das Feature wird grau und ist nicht sichtbar
# ```
#
# ---
#
# ## ✅ Abschließende Reflexion
#
# ### Was hast du gelernt?
#
# ✅ **Pad** – 2D-Skizzen linear extrudieren
#
# ✅ **Revolution** – 2D-Skizzen um eine Achse rotieren
#
# ✅ **Pocket** – Material aus Körpern subtrahieren
#
# ✅ **Kombination von Features** – mehrstufige Modelle bauen
#
# ✅ **Parametrisches Design** – Features bleiben editierbar
#
# ### Nächste Schritte
#
# Mit diesen Fähigkeiten kannst du schon:
# - Einfache mechanische Teile konstruieren
# - Alltagsgegenstände modellieren
# - Eigene Ideen in CAD umsetzen
#
# Im **nächsten Modul (Modul 6)** lernst du:
# - **Spiegeln** – Symmetrische Formen schneller erstellen
# - **Muster (Array)** – Wiederholte Elemente automatisch vervielfältigen
# - **Fillet & Chamfer** – Kanten abrunden und abschrägen
#
# ---
#
# **Gratuliere dir selbst!** Du machst große Fortschritte in CAD! 🎉
#
# ---
#
# ## 🔗 Weiterführende Ressourcen
#
# - **[FreeCAD Part Design – Offizielle Dokumentation](https://wiki.freecadweb.org/Part_Design_Workbench)**
# - **[Revolution – Wie Drehteile entstehen](https://wiki.freecadweb.org/PartDesign_Revolution)**
# - **[Pocket – Aussparungen richtig erstellen](https://wiki.freecadweb.org/PartDesign_Pocket)**
# - **[Community Forum – Fragen stellen](https://forum.freecadweb.org/)**
# - **[YouTube: FreeCAD Tutorials](https://www.youtube.com/results?search_query=freecad+pad+pocket+revolution)**
