# %% [markdown]
# # Modul 8a: Abschlussprojekt – Eigenes CAD-Projekt umsetzen
# ## Demonstration und Einführung
#
# ---
#
# ## 🎯 Einleitung
#
# Herzlich willkommen zum Abschlussmodul des CAD-Einführungskurses! In den vergangenen sieben Modulen habt ihr eine beeindruckende Lernreise durchlaufen: Ihr habt die FreeCAD-Oberfläche kennengelernt, Grundkörper erstellt, diese transformiert und mit booleschen Operationen kombiniert, 2D-Skizzen gezeichnet, daraus 3D-Körper extrudiert und rotiert, erweiterte Konstruktionstechniken wie Muster und Abrundungen angewendet und gelernt, wie man Modelle für den 3D-Druck exportiert oder technische Zeichnungen erstellt.
#
# Nun ist es Zeit, all diese Werkzeuge und Techniken zu einem großen Ganzen zusammenzuführen! In diesem Modul werdet ihr ein eigenes CAD-Projekt von Anfang bis Ende durchführen – von der ersten Idee über die Planung bis zur fertigen 3D-Konstruktion. Diese Projektarbeit zeigt euch nicht nur, was ihr alles gelernt habt, sondern gibt euch auch die Möglichkeit, kreativ zu sein und ein Objekt nach euren eigenen Vorstellungen zu gestalten.
#
# **MINT-Bezug:** CAD ist im technischen Bereich unverzichtbar – von der Produktentwicklung über den Maschinenbau bis zur Architektur. Die Fähigkeit, eine Idee in ein digitales 3D-Modell umzusetzen, ist eine Schlüsselkompetenz in vielen technischen Berufen. Durch das eigenständige Projektmanagement lernt ihr nicht nur CAD-Techniken, sondern auch systematisches Problemlösen und strukturiertes Arbeiten.
#
# **Lernziele:**
# - Eigenständig ein geeignetes Objekt/Projekt für die Konstruktion auswählen können
# - Einen Konstruktionsplan erstellen (Überlegen, welche Schritte, Formen und Features benötigt werden)
# - Alle erlernten CAD-Werkzeuge situativ anwenden
# - Probleme bei der Modellierung selbstständig lösen
# - Das fertige 3D-Modell anschaulich präsentieren können
#
# ---
#
# ## 📋 Der Konstruktionsprozess – Von der Idee zum Modell
#
# Bevor wir mit einem konkreten Beispiel starten, schauen wir uns an, wie ein typischer CAD-Konstruktionsprozess abläuft:
#
# ### 1. Ideenfindung und Projektauswahl
# Überlegt euch, was ihr konstruieren möchtet. Gute Projekte sind:
# - **Nützliche Alltagsobjekte:** Handyhalter, Stiftehalter, Schlüsselanhänger, Kabelorganizer
# - **Mechanische Teile:** Einfache Zahnräder, Riemenscheiben, Verbindungselemente
# - **Dekorative Objekte:** Schachfiguren, Vasen, Figuren, Spielsteine
# - **Funktionale Bauteile:** Gehäuse für elektronische Komponenten, Halterungen, Adapter
#
# **Tipp:** Wählt ein Objekt mit klaren geometrischen Formen und nicht zu vielen Details – so bleibt die Konstruktion überschaubar!
#
# ### 2. Analyse und Planung
# Bevor ihr FreeCAD öffnet, macht euch Gedanken:
# - Welche **Hauptformen** hat das Objekt? (Zylinder, Quader, Rotationskörper?)
# - Welche **Abmessungen** sind sinnvoll? (Messt ggf. ein reales Objekt aus)
# - Welche **Features** werden benötigt? (Bohrungen, Abrundungen, Muster?)
# - In welcher **Reihenfolge** baut ihr das Modell auf?
#
# Eine grobe **Handskizze** mit Maßangaben kann sehr hilfreich sein!
#
# ### 3. Konstruktion in FreeCAD
# Jetzt setzt ihr euren Plan in die Tat um:
# - Beginnt mit der **Grundform** (Grundkörper oder Skizze mit Extrusion/Rotation)
# - Fügt **weitere Features** Schritt für Schritt hinzu
# - **Überprüft regelmäßig** euer Modell aus verschiedenen Blickwinkeln
# - **Passt Maße an**, wenn etwas nicht passt
#
# ### 4. Verfeinerung
# Gebt eurem Modell den letzten Schliff:
# - Fügt **Abrundungen** an scharfen Kanten hinzu
# - Verwendet **Muster**, wenn Elemente sich wiederholen
# - Optimiert die **Proportionen** für ein stimmiges Gesamtbild
#
# ### 5. Export und Präsentation
# Bereitet euer fertiges Modell für die Präsentation vor:
# - Exportiert es als **STL-Datei** für den 3D-Druck
# - Erstellt eine **technische Zeichnung** mit Bemaßung
# - Macht **Screenshots** aus verschiedenen Perspektiven
#
# ---
#
# ## 🏆 Demonstrationsprojekt: Schachfigur (König)
#
# Als Beispiel konstruieren wir gemeinsam eine klassische Schachfigur – einen König. Dieses Projekt kombiniert viele der gelernten Techniken: Rotation von Skizzen (da Schachfiguren rotationssymmetrisch sind), Vereinigung von Körpern, Abrundungen und mehr.
#
# ### Phase 1: Analyse der Schachfigur
#
# Ein Schachkönig besteht typischerweise aus folgenden Elementen:
# - **Basis/Sockel:** Eine flache, runde Plattform
# - **Schaft:** Ein sich verjüngender Körper
# - **Hals:** Eine Einschnürung
# - **Krone/Kopf:** Der obere Bereich mit charakteristischer Form
# - **Kreuz:** Das Erkennungszeichen des Königs (optional für Einsteiger)
#
# Da alle diese Elemente rotationssymmetrisch um die Mittelachse sind, ist die **Revolution (Rotation einer Skizze)** die ideale Methode!
#
# ---
#
# ### Phase 2: Skizze des Profils erstellen
#
# In FreeCAD arbeiten wir im **Part Design**-Arbeitsbereich.
#
# ```
# Menü: Start → Part Design
# ```
#
# **Schritt 1: Neuen Body erstellen**
# ```
# Menü: Part Design → Create Body
# ```
# Ein "Body" ist ein Container für zusammenhängende Features.
#
# **Schritt 2: Neue Skizze anlegen**
# ```
# Menü: Part Design → Create Sketch
# Wählt die XZ-Ebene (vertikale Ebene)
# ```
#
# **Schritt 3: Profil der Schachfigur zeichnen**
#
# Wir zeichnen nur die **halbe Kontur** der Figur (Profil), die dann um die Mittelachse rotiert wird.
#
# ```
# 1. Wählt das Linien-Werkzeug aus der Sketcher-Werkzeugleiste
#
# 2. Zeichnet folgende Kontur (von unten nach oben):
#    - Startpunkt auf der Z-Achse bei (0, 0)
#    - Linie nach rechts zur Position ca. (15, 0) → Basis-Radius
#    - Linie schräg nach oben zur Position ca. (12, 5) → Sockel
#    - Linie schräg nach innen zur Position ca. (8, 20) → Schaft beginnt
#    - Linie schräg nach innen zur Position ca. (6, 35) → Schaft verjüngt sich
#    - Linie leicht nach außen zur Position ca. (7, 40) → Hals/Wulst
#    - Linie nach innen zur Position ca. (5, 45) → Einschnürung
#    - Linie nach außen zur Position ca. (9, 55) → Kopf beginnt
#    - Linie nach oben zur Position ca. (9, 65) → Kopfhöhe
#    - Linie nach innen zur Position ca. (4, 70) → Kronenansatz
#    - Linie nach oben zur Position ca. (4, 75) → Krone
#    - Linie nach links zur Z-Achse (0, 75) → Abschluss oben
#    - Linie nach unten entlang der Z-Achse zurück zu (0, 0) → Schließt die Kontur
#
# 3. Die Kontur muss eine geschlossene Form bilden!
# ```
#
# **Tipp:** Nutzt das **Polyline-Werkzeug** (durchgängige Linie), um mehrere Segmente hintereinander zu zeichnen.
#
# **Schritt 4: Bemaßung hinzufügen**
#
# Fügt wichtige Maße hinzu, um die Form zu definieren:
#
# ```
# Werkzeug: Constrain vertical distance (vertikaler Abstand)
# - Gesamthöhe: 75 mm
# - Basishöhe: 5 mm
# - Schafthöhe: 35 mm
#
# Werkzeug: Constrain horizontal distance (horizontaler Abstand)
# - Basisradius: 15 mm
# - Schaftradius unten: 8 mm
# - Kopfradius: 9 mm
# ```
#
# ```
# Menü: Sketch → Close (Skizze schließen)
# ```
#
# ---
#
# ### Phase 3: Rotation der Skizze (Revolution)
#
# Jetzt verwandeln wir die 2D-Kontur in einen 3D-Körper:
#
# ```
# Menü: Part Design → Revolution
#
# Einstellungen im Dialog:
# - Axis: Vertical sketch axis (Z-Achse)
# - Angle: 360° (vollständige Rotation)
# - Symmetric to plane: nicht aktiviert
#
# Klick auf OK
# ```
#
# **Ergebnis:** Eure Schachfigur nimmt Form an! Die Profilkontur wurde um die Mittelachse gedreht und ein Rotationskörper entsteht.
#
# ---
#
# ### Phase 4: Verfeinerungen hinzufügen
#
# **Abrundungen für realistischeres Aussehen:**
#
# ```
# Menü: Part Design → Fillet (Abrundung)
#
# 1. Wählt scharfe Kanten aus (z.B. an Übergängen zwischen Sockel und Schaft)
# 2. Gebt einen Radius ein, z.B. 1-2 mm
# 3. Klick auf OK
#
# Wiederholt dies für weitere Kanten nach Belieben
# ```
#
# **Optionale Erweiterung: Kreuz auf der Krone**
#
# Für fortgeschrittene Lernende kann ein Kreuz auf der Krone hinzugefügt werden:
#
# ```
# 1. Erstellt eine neue Skizze auf der Oberseite der Figur (Top-Fläche auswählen)
#    Menü: Part Design → Create Sketch → Wählt die oberste Fläche
#
# 2. Zeichnet ein einfaches Kreuz:
#    - Vertikale Linie von ca. (-1, -4) nach (-1, 4)
#    - Horizontale Linie von ca. (-3, 0) nach (1, 0)
#    - Bemaßt die Linien (Breite: 2 mm, Länge: 8 mm)
#
# 3. Extrudiert das Kreuz nach oben:
#    Menü: Part Design → Pad
#    Length: 5 mm
# ```
#
# ---
#
# ### Phase 5: Überprüfung und Export
#
# **Ansicht optimieren:**
# ```
# Menü: View → Draw Style → Shaded with edges (Schattiert mit Kanten)
# ```
#
# **3D-Modell aus allen Perspektiven betrachten:**
# - Dreht die Ansicht mit gedrückter mittlerer Maustaste
# - Zoomt mit dem Mausrad
# - Überprüft, ob alle Proportionen stimmig sind
#
# **Export als STL für 3D-Druck:**
# ```
# Menü: File → Export
# - Dateiformat: STL Mesh (*.stl)
# - Dateinamen eingeben: Schachkoenig.stl
# - Speichern
# ```
#
# **Technische Zeichnung erstellen (optional):**
# ```
# 1. Wechselt zum TechDraw-Arbeitsbereich:
#    Menü: Workbench → TechDraw
#
# 2. Erstellt eine neue Zeichnung:
#    Menü: TechDraw → Insert Default Page
#
# 3. Fügt Ansichten ein:
#    Menü: TechDraw → Insert View
#    Wählt euren Body aus
#
# 4. Fügt Maßangaben hinzu:
#    Menü: TechDraw → Insert Dimension → Length Dimension
# ```
#
# ---
#
# ## 🎨 Variationsmöglichkeiten
#
# Experimentiert mit eurem Modell:
#
# **Größenanpassungen:**
# - Verändert die Bemaßungen in der Skizze → Rechtsklick auf Sketch → Edit Sketch
# - Passt einzelne Maße an (z.B. Höhe auf 100 mm, Basis auf 20 mm)
# - Die Figur wird automatisch neu berechnet!
#
# **Designänderungen:**
# - Fügt mehr Wülste oder Rillen hinzu
# - Macht den Schaft schlanker oder kräftiger
# - Ändert die Form der Krone
#
# **Weitere Schachfiguren:**
# - Erstellt nach dem gleichen Prinzip andere Figuren: Dame, Turm, Läufer, Springer, Bauer
# - Jede Figur hat ihr charakteristisches Profil!
#
# ---
#
# ## 💡 Wichtige FreeCAD-Befehle im Überblick
#
# ### Sketcher-Arbeitsbereich:
# - **Create Sketch:** Neue 2D-Skizze anlegen
# - **Line:** Gerade Linie zeichnen
# - **Polyline:** Durchgehende Linienkette zeichnen
# - **Circle:** Kreis zeichnen
# - **Constrain Vertical Distance:** Vertikalen Abstand festlegen
# - **Constrain Horizontal Distance:** Horizontalen Abstand festlegen
# - **Close Sketch:** Skizze beenden
#
# ### Part Design-Arbeitsbereich:
# - **Create Body:** Neuen Körper-Container erstellen
# - **Pad:** Skizze extrudieren (in die Tiefe ziehen)
# - **Revolution:** Skizze um eine Achse rotieren
# - **Pocket:** Material durch Skizze entfernen
# - **Fillet:** Kanten abrunden
# - **Chamfer:** Kanten abschrägen
# - **Boolean Union:** Körper vereinigen
# - **Boolean Difference:** Einen Körper von einem anderen abziehen
#
# ### Ansicht und Navigation:
# - **Mittlere Maustaste gedrückt + Bewegen:** Ansicht drehen
# - **Mausrad:** Zoom
# - **Shift + Mittlere Maustaste:** Ansicht verschieben
# - **View → Standard Views → Front/Top/Right:** Standardansichten
# - **View → Fit All (V, F):** Gesamtes Modell anzeigen
#
# ---
#
# ## 🔍 Reflexionsfragen
#
# - Warum eignet sich die Revolution-Methode besonders gut für Schachfiguren?
# - Welche anderen Objekte aus dem Alltag sind rotationssymmetrisch?
# - Wie würdet ihr vorgehen, wenn das Objekt NICHT symmetrisch ist?
# - Welche Schritte waren für euch am herausforderndsten?
# - Wo habt ihr Probleme gelöst, indem ihr zurückgegangen und Maße angepasst habt?
#
# ---
#
# ## 📚 Weiterführende Ressourcen
#
# - **FreeCAD-Dokumentation – Part Design:** https://wiki.freecad.org/PartDesign_Workbench/de
# - **FreeCAD-Tutorial Revolution:** https://wiki.freecad.org/PartDesign_Revolution/de
# - **FreeCAD Forum (deutsche Community):** https://forum.freecad.org/viewforum.php?f=13
# - **YouTube-Kanal "Learn FreeCAD":** https://www.youtube.com/@LearnFreeCAD
# - **FreeCAD 3D-Druck Workflow:** https://wiki.freecad.org/Manual:Preparing_models_for_3D_printing/de
#
# ---
#
# ## 🎓 Zusammenfassung
#
# In diesem Demonstrationsmodul haben wir:
# - Den vollständigen Konstruktionsprozess von der Idee bis zum fertigen Modell durchlaufen
# - Eine rotationssymmetrische Schachfigur durch Rotation einer Profilskizze erstellt
# - Features wie Abrundungen zur Verfeinerung eingesetzt
# - Das Modell für Export und 3D-Druck vorbereitet
#
# Im nächsten Schritt (Modul 8b) werdet ihr selbst ein eigenes Objekt auswählen und konstruieren! Nutzt das Gelernte als Inspiration und entwickelt eure eigene Idee.
#
# **Viel Erfolg bei eurem CAD-Projekt! 🚀**
